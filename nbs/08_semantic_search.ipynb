# %%
#| default_exp fast_search

# %%
#| export
from seo_rat.indextime import  get_file_names

get_file_names()
# Out:
# ['تمديد الغاز المركزي بمصر',
#  'انواع مواسير الغاز',
#  'تمديد غاز مركزي للمطاعم',
#  'عازل اسطح الكويت',
#  'تمديد الغاز المركزي بالرياض',
#  'تمديد الغاز المركزي بالمدنية',
#  'تمديد الغاز المركزي خميس مشيط',
#  'شركة تمديد غاز مركزي بالدمام',
#  'تمديد غاز مركزي محايل عسير',
#  'تمديد غاز مركزي أبو ظبي',
#  'اسطوانة الغاز فايبر',
#  'تمديد مواسير الغاز للمطبخ',
#  ' تمديد الغاز المركزي بالعلا ',
#  'تمديد الغاز المركزي جدة',
#  'تمديد غاز مركزي بابها',
#  'تمديد_الغاز_المركزي_بالطائف',
#  'تمديد الغاز المركزي بالقطيف',
#  'تمديد الغاز المركزي بيشة',
#  'تمديد الغاز المركزي الاحساء',
#  'خزان الغاز المركزي',
#  'تمديد الغاز المركزي بمكة',
#  'تمديد الغاز المركزي تبوك',
#  'تمديد غاز مركزي بالخرج']

# %%
import os
full_path = "/home/kareem/Desktop/web_dev_js/astro_hacking/emdad_gaz/emdadgaz/src/content/post/"
page_names= os.listdir(full_path)
page_names =[full_path+el for el in page_names]
page_names

with open(page_names[0],"r",encoding="utf-8") as file:
    markdown_content = file.read()
markdown_content,len(markdown_content)
# Out:
# ('---\npublishDate: 2024-10-26\ntitle: 01012097813  شركة تمديد غاز بمصر\nexcerpt: شركة تمديد غاز بمصر لتمديد مواسير الغاز نحاس و  الروماني للمطاعم والمنازل والمصانع في من شركة تمديد الغاز  في مصر\nimage: ~/assets/images/nice_look.png\ncategory: امداد_غاز\ntags:\n  - مصر\n  - امداد_غاز\n  - كشف_تسربات_غاز\n  - المملكة العربية\nphoneNumber: "01012097813"\nwNumber: "+201012097813"\n---\n\n\nتعتبر شركة **إمداد الغاز** من أفضل شركات تمديد الغاز المركزي في مصر، حيث تقدم خدمات كشف تسربات الغاز وتركيب المواسير بمختلف أنواعها، بالإضافة إلى تنفيذ شبكات الغاز بدقة وسرعة مع الالتزام بمعايير الأمان تحت إشراف هندسي متخصص. تعتمد الشركة على أجهزة وأدوات متقدمة للتمديد والتركيب داخل المنشآت الخاصة والعامة والسكنية بأمان تام وبأسعار تنافسية.\n\nتواصل معنا للحصول على معاينة واستشارة مجانية.\n\n## شركة تمديد الغاز المركزي بمصر\n\nتُعد شركة **تمديد الغاز** الأفضل في مجال تمديد الغاز المركزي بمصر، حيث نوفر خدمات توصيل وصيانة وإصلاح تمديدات الغاز، وتصليح المواسير المتضررة، إضافة إلى الصيانة الدورية في جميع أنحاء مصر. ويعمل لدينا فريق مدرب تحت إشراف هندسي عالي المستوى.\n\nيبدأ فريقنا بحسابات دقيقة من قبل مهندسينا لتحديد عدد المواسير المطلوبة لضمان إمداد كافٍ يلبي احتياجاتك دون هدر. وبعد ذلك، يقوم الفنيون بتركيب خطوط الغاز بدقة، مع اتخاذ كافة احتياطات الأمان واختبارات الجودة اللازمة، لضمان سلامتك من مخاطر التسرب أو الحرائق، حيث يمكنك مشاهدة كافة الخطوات أمامك للشعور بالاطمئنان.\n\n![شركة تمديد غاز بمصر](~/assets/images/yello_tank.png)\n## تمديد مواسير الغاز للمطابخ\n\nيتم الفحص الأولي لمكان تركيب الغاز وتحديد قطر وطول الأنابيب المطلوبة بمعاينة دقيقة تحت إشراف مهندس مختص.\n\nوتتم خطوات تركيب تمديد غاز المطابخ كالتالي:\n\n1. **تحديد مكان المصدر الرئيسي للغاز:** يتم بالتنسيق مع شركة الغاز المحلية لضمان الأمان.\n2. **تحديد المسار لتركيب المواسير:** يُفضل أن يكون المسار مستقيم قدر الإمكان، مع تجنب أي عوائق قد تعترض المواسير.\n3. **حفر الخندق المطلوب لتمديد المواسير:** يُحفر الخندق بعرض 30 سم وعمق 50 سم، لضمان التركيب الصحيح.\n4. **وضع المواسير داخل الخندق وربطها بإحكام:** يتم استخدام وصلات ذات جودة عالية لضمان الأمان والسلامة.\n5. **اختبار المواسير لضمان جودتها وسلامتها:** يُجرى الاختبار باستخدام مقياس الضغط وأجهزة كشف تسرب الغاز الحديثة، للتأكد من سلامة التمديدات.\n\n\n## اختيار انواع مواسير تمديد الغاز المناسبة\xa0\n\n![تمديد غاز مركزي بمصر](~/assets/images/orange_gaz.webp)\nتعتبر مواسير الغاز **الروماني** و**الروسي** من أفضل الأنواع من حيث الجودة، لكن منذ عام 2020 أصبحت غير متوفرة في السوق السعودي. وأفضل بديل لهما هو **المواسير الأوكرانية**، والتي نوصي بها لعملائنا في إمداد الغاز.\n\nكما وضحنا سابقًا، يتم استخدام **مواسير الحديد الأسود** لتمديد الأجزاء المدفونة من شبكة الغاز، سواء كانت خارج المبنى أو داخله، مثل تلك الموضوعة تحت البلاط أو داخل الجدران، مع ضرورة عزلها جيدًا لمقاومة الرطوبة والصدأ. أما **مواسير الحديد المجلفن**، فتُستخدم للتمديدات المكشوفة، سواء كانت على الجدران الداخلية أو الخارجية للمبنى، لضمان الحماية والمتانة.\n\n<!-- "~/assets/images/orange_gaz.webp" -->\n\n\n## مواصفات مواسير الغاز\n\n![مواسير غاز مركزي بمصر](~/assets/images/nice_look.png)\nهناك العديد من المواصفات التي يجب مراعتها عند اختيار المواسير المناسبة لمكان التشغل سواء كان المنزل أو مطعم أو مصنع\nنقدم لك بعض المعايير التي تسهل عليك إختيار أفضل نوع من المواسير :\n\n1. يفضل إستخدام مواسير الحديد المجلفن حيث أنها تعد من أفضل أنواع المواسير التي يتم استخدامها بكثافة حيث تقدم متانة وصلابة وأمان عالي مع سعر متوسط\n2. يجب أن يتناسب حجم المواسير وقطرها مع مساحة المكان الذي سيتم توزيع الخطوط بداخله لتوفير الأموال وتقليل المساحة المشغولة ليمنحك شكل جمالي وتوفير مساحة أيضا والحفاظ علي أموالك في المقام الأول\n3. تأكد من طلاء المواسير المستخدمة بالأصباغ الحديثة التي تحميها من درجات الحرارة المتغير مثل الإنخفاض السريع حتي لا تتأثر بالعوامل البيئية في مصر\n4. تأكد من وجود ضمانات الجودة وأن المواسير المستخدمة معتمدة فعلا وليست مغشوشة ، يمكنك التواصل معانا لمساعدتك\n5. التأكد من ان المواسير المستخدمة قادرة علي تحمل الضغط والخبطاط وانها صلبة غير سهلة الكسر او التلف\n6. يجب التاكد من ان الصمامات والمحابس الخاصة بالأمان مصنوعة من النحاس الخالص أو التياتنوم لتجنب حدوث أي تسربات في الغاز\n\n## بع ...
#  16665)

# %%
from seo_rat.fast_gsc import search_page_analytics

response = await search_page_analytics(
    "sc-domain:emdadelgaz.com",
    page_url="https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr",
    range_type="last_months",
    months=1,
    show_queries=True,
)
response
# Out:
# {'site_url': 'sc-domain:emdadelgaz.com',
#  'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#  'date_range': {'start': '2024-11-10',
#   'end': '2024-12-10',
#   'type': 'last_months',
#   'total_days': 30},
#  'main_metrics': {'_id': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'clicks': 6.0,
#   'impressions': 137.0,
#   'avg_position': 0.09850603724674262,
#   'total_impressions': 137.0,
#   'dates': ['2024-11-11',
#    '2024-12-02',
#    '2024-12-08',
#    '2024-11-25',
#    '2024-12-01',
#    '2024-11-17',
#    '2024-12-05',
#    '2024-12-07',
#    '2024-11-12',
#    '2024-11-23',
#    '2024-11-29',
#    '2024-12-06',
#    '2024-11-13',
#    '2024-11-10',
#    '2024-11-21',
#    '2024-11-24',
#    '2024-11-16',
#    '2024-12-03',
#    '2024-11-22',
#    '2024-11-15',
#    '2024-11-28',
#    '2024-11-30',
#    '2024-12-04',
#    '2024-12-09',
#    '2024-11-19',
#    '2024-11-26',
#    '2024-11-18',
#    '2024-11-14',
#    '2024-11-27',
#    '2024-11-20'],
#   'queries': ['تمديد غاز للمطاعم',
#    'شركة تركيب غاز مركزي',
#    'دهان مواسير الغاز الطبيعي',
#    'شركة تمديد',
#    'سعر متر مواسير الغاز الطبيعي',
#    'اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن',
#    'تمديد مواسير الغاز للمطابخ',
#    'مواسير غاز بلاستيك',
#    'شركة تمديد غاز مركزي',
#    'تغطية مواسير الغاز',
#    'شركة تمديد غاز',
#    'تمديد الغاز',
#    'سعر تمديد مواسير الغاز',
#    'سعر ماسورة حديد 1 بوصة في مصر',
#    'شركة تمديدات الغاز المركزي',
#    'سعر متر مواسير الحديد المجلفن',
#    'سعر متر مواسير الغاز في مصر',
#    'تمديد غاز',
#    'تمديد غاز منزلي',
#    'معاينة الغاز الطبيعي',
#    'مواسير غاز',
#    'تمديد غاز مركزي'],
#   'countries': ['gbr',
#    'sau',
#    'jor',
#    'egy',
#    'usa',
#    'ita',
#    'omn',
#    'gtm',
#    'phl',
#    'tun',
#    'ind',
#    'rou'],
#   'devices': ['MOBILE', 'DESKTOP'],
#   'ctr': 0.043795620437956206,
#   'date_count': 30},
#  'query_performance': [{'_id': 'شركة تمديد غاز مركزي',
#    'clicks': 3,
#    'impressions': 8,
#    'avg_position': 0.5416666666666666,
#    'total_impressions': 8,
#    'dates': ['2024-11-18',
#     '2024-11-22',
#     '2024-11-17',
#     '2024-11-14',
#     '2024-11-26'],
#    'ctr': 0.375},
#   {'_id': 'تمديد مواسير الغاز للمطابخ',
#    'clicks': 2.0,
#    'impressions': 21.0,
#    'avg_position': 0.4444444444444445,
#    'total_impressions': 21.0,
#    'dates': ['2024-11-26',
#     '2024-12-07',
#     '2024-12-02',
#     '2024-12-06',
#     '2024-12-09',
#     '2024-12-03',
#     '2024-11-27',
#     '2024-11-25',
#     '2024-11-10',
#     '2024-11-21',
#     '2024-11-30',
#     '2024-11-20',
#     '2024-12-01',
#     '2024-12-05'],
#    'ctr': 0.09523809523809523},
#   {'_id': 'تمديد غاز منزلي',
#    'clicks': 1.0,
#    'impressions': 8.0,
#    'avg_position': 1.2916666666666667,
#    'total_impressions': 8.0,
#    'dates': ['2024-11-18', '2024-12-04', '2024-11-24', '2024-12-07'],
#    'ctr': 0.125},
#   {'_id': 'شركة تمديد',
#    'clicks': 0,
#    'impressions': 4,
#    'avg_position': 9.75,
#    'total_impressions': 4,
#    'dates': ['2024-11-12', '2024-11-11'],
#    'ctr': 0.0},
#   {'_id': 'سعر متر مواسير الحديد المجلفن',
#    'clicks': 0,
#    'impressions': 2,
#    'avg_position': 31.75,
#    'total_impressions': 2,
#    'dates': ['2024-11-30', '2024-11-22'],
#    'ctr': 0.0},
#   {'_id': 'شركة تمديد غاز',
#    'clicks': 0.0,
#    'impressions': 7.0,
#    'avg_position': 0.9142857142857144,
#    'total_impressions': 7.0,
#    'dates': ['2024-12-04', '2024-11-24', '2024-11-16', '2024-11-25'],
#    'ctr': 0.0},
#   {'_id': 'سعر متر مواسير الغاز في مصر',
#    'clicks': 0.0,
#    'impressions': 17.0,
#    'avg_position': 0.4831932773109243,
#    'total_impressions': 17.0,
#    'dates': ['2024-11-11',
#     '2024-11-18',
#     '2024-12-02',
#     '2024-11-27',
#     '2024-11-25',
#     '2024-11-30',
#     '2024-11-21',
#     '2024-12-01',
#     '2024-11-17',
#     '2024-11-24',
#     '2024-12-04',
#     '2024-12-08'],
#    'ctr': 0.0},
#   {'_id': 'سعر ماسورة حديد 1 بوصة في مصر',
#    'clicks': 0,
#    'impressions': 2,
#    'avg_position': 23.0,
#    'total_impressions': 2,
#    'dates': ['2024-12-06', '2024-11-15'],
#    'ctr': 0.0},
#   {'_id': 'اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن',
#    'clicks': 0.0,
#    'impressions': 2.0,
#    'avg_position': 28.5,
#    'total_impressions': 2.0,
#    'dates': ['2024-12-08'],
#    'ctr': 0.0},
#   {'_id': 'تمديد غاز للمطاعم',
#    'clicks': 0,
#    'impressions': 5,
#    'avg_position': 0.6,
#    'total_impressions': 5,
#    'dates': ['2024-11-23', '2024-11-30', '2024-11-10'],
#    'ctr': 0.0},
#   {'_id': 'مواسير غاز بلاستيك',
#    'clicks': 0,
#    'impressions': 2,
#    'avg_position': 1.0,
#    'total_impressions': 2,
#    'dates': ['2024-11-10'],
#    'ctr': 0.0},
#   {'_id': 'شركة تركيب غاز مركزي',
#    'clicks': 0,
#    'impressions': 8,
#    'avg_position': 5.8125,
#    'total_impressions': 8,
#    'dates': ['2024-11-18', '2024-11-30'],
#    'ctr': 0.0},
#   {'_id': 'دهان مواسير الغاز الطبيعي',
#    'clicks': 0,
#    'impressions': 2,
#    'avg_position': 2.0,
#    'total_impressions': 2,
#    'dates': ['2024-11-16'],
#    'ctr': 0.0},
#   {'_id': 'سعر متر مواسير الغاز الطبيعي',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 12.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-28'],
#    'ctr': 0.0},
#   {'_id': 'مواسير غاز',
#    'clicks': 0.0,
#    'impressions': 14.0,
#    'avg_position': 0.11111111111111112,
#    'total_impressions': 14.0,
#    'dates': ['2024-11-15',
#     '2024-11-26',
#     '2024-11-29',
#     '2024-11-27',
#     '2024-11-30',
#     '2024-12-04',
#     '2024-11-24',
#     '2024-12-05'],
#    'ctr': 0.0},
#   {'_id': 'تمديد الغاز',
#    'clicks': 0,
#    'impressions': 2,
#    'avg_position': 2.25,
#    'total_impressions': 2,
#    'dates': ['2024-11-11', '2024-11-25'],
#    'ctr': 0.0},
#   {'_id': 'شركة تمديدات الغاز المركزي',
#    'clicks': 0,
#    'impressions': 2,
#    'avg_position': 2.75,
#    'total_impressions': 2,
#    'dates': ['2024-11-20', '2024-11-24'],
#    'ctr': 0.0},
#   {'_id': 'تمديد غاز مركزي',
#    'clicks': 0,
#    'impressions': 7,
#    'avg_position': 1.7142857142857142,
#    'total_impressions': 7,
#    'dates': ['2024-11-30',
#     '2024-11-10',
#     '2024-12-06',
#     '2024-11-29',
#     '2024-12-02',
#     '2024-11-28'],
#    'ctr': 0.0},
#   {'_id': 'تمديد غاز',
#    'clicks': 0.0,
#    'impressions': 4.0,
#    'avg_position': 1.375,
#    'total_impressions': 4.0,
#    'dates': ['2024-12-09', '2024-11-13', '2024-11-16', '2024-11-30'],
#    'ctr': 0.0},
#   {'_id': 'سعر تمديد مواسير الغاز',
#    'clicks': 0.0,
#    'impressions': 16.0,
#    'avg_position': 0.7692307692307693,
#    'total_impressions': 16.0,
#    'dates': ['2024-11-15',
#     '2024-11-18',
#     '2024-11-19',
#     '2024-11-26',
#     '2024-11-28',
#     '2024-12-08',
#     '2024-11-20',
#     '2024-11-13',
#     '2024-11-25',
#     '2024-12-01',
#     '2024-11-24',
#     '2024-11-16'],
#    'ctr': 0.0},
#   {'_id': 'تغطية مواسير الغاز',
#    'clicks': 0.0,
#    'impressions': 2.0,
#    'avg_position': 29.0,
#    'total_impressions': 2.0,
#    'dates': ['2024-12-08'],
#    'ctr': 0.0},
#   {'_id': 'معاينة الغاز الطبيعي',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 53.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-19'],
#    'ctr': 0.0}],
#  'country_performance': [{'_id': 'egy',
#    'clicks': 6.0,
#    'impressions': 118.0,
#    'avg_position': 0.0832222433822129,
#    'total_impressions': 118.0,
#    'dates': ['2024-11-10',
#     '2024-11-25',
#     '2024-11-30',
#     '2024-11-28',
#     '2024-12-08',
#     '2024-12-02',
#     '2024-11-11',
#     '2024-11-15',
#     '2024-11-22',
#     '2024-12-07',
#     '2024-12-09',
#     '2024-12-05',
#     '2024-11-17',
#     '2024-12-01',
#     '2024-11-26',
#     '2024-12-04',
#     '2024-11-13',
#     '2024-11-27',
#     '2024-11-20',
#     '2024-11-19',
#     '2024-11-29',
#     '2024-12-06',
#     '2024-11-18',
#     '2024-12-03',
#     '2024-11-16',
#     '2024-11-24',
#     '2024-11-21'],
#    'ctr': 0.05084745762711865},
#   {'_id': 'tun',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 1.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-20'],
#    'ctr': 0.0},
#   {'_id': 'gtm',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 48.0,
#    'total_impressions': 1,
#    'dates': ['2024-12-06'],
#    'ctr': 0.0},
#   {'_id': 'gbr',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 5.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-14'],
#    'ctr': 0.0},
#   {'_id': 'phl',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 53.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-19'],
#    'ctr': 0.0},
#   {'_id': 'ind',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 6.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-16'],
#    'ctr': 0.0},
#   {'_id': 'ita',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 4.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-23'],
#    'ctr': 0.0},
#   {'_id': 'omn',
#    'clicks': 0,
#    'impressions': 1,
#    'avg_position': 1.0,
#    'total_impressions': 1,
#    'dates': ['2024-11-27'],
#    'ctr': 0.0},
#   {'_id': 'rou',
#    'clicks': 0.0,
#    'impressions': 2.0,
#    'avg_position': 28.5,
#    'total_impressions': 2.0,
#    'dates': ['2024-12-08'],
#    'ctr': 0.0},
#   {'_id': 'sau',
#    'clicks': 0,
#    'impressions': 4,
#    'avg_position': 3.625,
#    'total_impressions': 4,
#    'dates': ['2024-11-29', '2024-12-02', '2024-11-28', '2024-11-30'],
#    'ctr': 0.0},
#   {'_id': 'jor',
#    'clicks': 0,
#    'impressions': 3,
#    'avg_position': 18.166666666666668,
#    'total_impressions': 3,
#    'dates': ['2024-11-12'],
#    'ctr': 0.0},
#   {'_id': 'usa',
#    'clicks': 0,
#    'impressions': 3,
#    'avg_position': 19.0,
#    'total_impressions': 3,
#    'dates': ['2024-11-15', '2024-11-22', '2024-11-30'],
#    'ctr': 0.0}],
#  'device_performance': [{'_id': 'DESKTOP',
#    'clicks': 3.0,
#    'impressions': 28.0,
#    'avg_position': 0.7472527472527473,
#    'total_impressions': 28.0,
#    'dates': ['2024-11-23',
#     '2024-12-06',
#     '2024-11-12',
#     '2024-11-18',
#     '2024-11-13',
#     '2024-11-14',
#     '2024-11-10',
#     '2024-11-16',
#     '2024-11-15',
#     '2024-11-22',
#     '2024-12-08',
#     '2024-11-25',
#     '2024-11-30',
#     '2024-11-17',
#     '2024-12-07',
#     '2024-11-19',
#     '2024-11-26'],
#    'ctr': 0.10714285714285714},
#   {'_id': 'MOBILE',
#    'clicks': 3.0,
#    'impressions': 109.0,
#    'avg_position': 0.1019367991845056,
#    'total_impressions': 109.0,
#    'dates': ['2024-12-07',
#     '2024-12-09',
#     '2024-11-29',
#     '2024-11-12',
#     '2024-11-27',
#     '2024-11-13',
#     '2024-11-20',
#     '2024-11-18',
#     '2024-12-06',
#     '2024-11-24',
#     '2024-11-10',
#     '2024-11-21',
#     '2024-12-03',
#     '2024-11-16',
#     '2024-12-02',
#     '2024-11-15',
#     '2024-11-11',
#     '2024-12-08',
#     '2024-11-25',
#     '2024-11-30',
#     '2024-11-28',
#     '2024-12-01',
#     '2024-11-17',
#     '2024-12-04',
#     '2024-12-05',
#     '2024-11-26',
#     '2024-11-19'],
#    'ctr': 0.027522935779816515}]}

# %%
# | export
from sentence_transformers import SentenceTransformer
from qdrant_client import QdrantClient
from qdrant_client.models import VectorParams, PointStruct, Distance
from datetime import datetime
from typing import Dict, List, Optional
from fastapi import HTTPException
from uuid import uuid4

class KeywordVectorDB:
    def __init__(self):
        self.model = SentenceTransformer(
            "Omartificial-Intelligence-Space/Arabic-Triplet-Matryoshka-V2",device="cuda"
        )
        self.client = QdrantClient("localhost", port=6333)

    def get_or_create_collection(self, page_url: str) -> str:
        """Get existing collection or create if doesn't exist"""
        collection_name = self._get_collection_name(page_url)

        # Check if collection exists
        collections = self.client.get_collections().collections
        exists = any(c.name == collection_name for c in collections)

        if not exists:
            self.client.create_collection(
                collection_name=collection_name,
                vectors_config=VectorParams(size=self.model.get_sentence_embedding_dimension(), distance=Distance.COSINE),
            )

        return collection_name

    def process_search_analytics(self, analytics_data: Dict):
        """Process search analytics data and update/store in vector DB"""
        collection_name = self.get_or_create_collection(analytics_data["page_url"])
        points_to_upsert = []  # Collect all points here

        for query_data in analytics_data["query_performance"]:
            keyword = query_data["_id"]
            keyword_vector = self.model.encode(keyword)
            point_id = str(uuid4())

            # Check if keyword exists
            search_result = self.client.search(
                collection_name=collection_name,
                query_vector=keyword_vector,
                limit=1,
                score_threshold=0.95,
            )

            # Prepare new metadata
            new_metadata = {
                "keyword": keyword,
                "site_url": analytics_data["site_url"],
                "page_url": analytics_data["page_url"],
                "date_range": analytics_data["date_range"],
                "performance": {
                    "clicks": query_data["clicks"],
                    "impressions": query_data["impressions"],
                    "position": query_data["avg_position"],
                    "ctr": query_data["ctr"],
                    "dates": query_data["dates"],
                },
                "last_updated": datetime.now().isoformat(),
            }

            if search_result:
                # Update existing keyword
                existing_point = search_result[0]
                point_id = existing_point.id

                # Preserve existing metadata fields
                existing_metadata = existing_point.payload
                new_metadata["in_content"] = existing_metadata.get("in_content", False)

                new_metadata['is_optimized'] = existing_metadata.get("is_optimized",False)
                new_metadata["is_important"] = existing_metadata.get("is_important",False)
                new_metadata["is_focus_keyword"] = existing_metadata.get(
                    "is_focus_keyword", False
                )

            # Create point structure
            point = PointStruct(
                id=point_id,
                vector=keyword_vector.tolist(),
                payload=new_metadata,
            )
            points_to_upsert.append(point)

        # Single batch upsert for all points
        if points_to_upsert:
            self.client.upsert(collection_name=collection_name, points=points_to_upsert)

    def _get_collection_name(self, url: str) -> str:
        """Convert URL to valid collection name"""
        return url.replace("https://", "").replace("/", "_").replace(".", "_")
    def search_keywords(
        self,
        page_url: str,
        query_text: str = None,
        limit: int = 10,
        filter_params: Dict = None,
    ) -> List[Dict]:
        """Search keywords in a page collection"""
        collection_name = self._get_collection_name(page_url)

        if query_text:
            # Vector search with query
            query_vector = self.model.encode(query_text)
            results = self.client.search(
                collection_name=collection_name,
                query_vector=query_vector.tolist(),
                query_filter=filter_params,
                limit=limit,
            )
        else:
            # Regular filtering without vector search
            results = self.client.scroll(
                collection_name=collection_name, scroll_filter=filter_params, limit=limit
            )[0]  # scroll returns tuple (points, offset)

        # Format results
        return [
            {
                "keyword": point.payload["keyword"],
                "score": getattr(point, "score", 1.0),
                **point.payload,
            }
            for point in results
        ]

    def get_page_keywords(
        self,
        page_url: str,
        category: str = None,
        in_content: bool = None,
        min_clicks: int = None,
    ) -> List[Dict]:
        """Get keywords for a specific page with optional filters"""

        conditions = []

        if category:
            conditions.append({"key": "category", "match": {"value": category}})
        if in_content is not None:
            conditions.append({"key": "in_content", "match": {"value": in_content}})
        if min_clicks:
            conditions.append({"key": "performance.clicks", "range": {"gte": min_clicks}})

        filter_params = {"must": conditions} if conditions else None

        return self.search_keywords(page_url, filter_params=filter_params)
    def update_content_status(self, page_url: str, markdown_content: str):
        """Update in_content status for all keywords based on markdown content"""
        collection_name = self._get_collection_name(page_url)
        results = self.client.scroll(collection_name=collection_name, limit=1000)[0]

        for point in results:
            metadata = point.payload
            keyword = metadata["keyword"]

            # Update just the metadata
            metadata["in_content"] = keyword.lower() in markdown_content.lower()
            metadata["last_updated"] = datetime.now().isoformat()


            # Update only the payload for this point ID
            self.client.set_payload(
                collection_name=collection_name, payload=metadata, points=[point.id]
            )
    def set_keyword_importance(self, page_url: str, keyword: str, is_important: bool):
        """Set importance status for a specific keyword"""
        collection_name = self._get_collection_name(page_url)

        # Find the keyword
        results = self.client.scroll(
            collection_name=collection_name,
            filter={"must": [{"key": "keyword", "match": {"value": keyword}}]},
            limit=1,
        )[0]

        if results:
            point = results[0]
            metadata = point.payload
            metadata["is_important"] = is_important
            metadata["last_updated"] = datetime.now().isoformat()

            self.client.set_payload(
                collection_name=collection_name, payload=metadata, points=[point.id]
            )
            return True
        return False


    def get_keyword_importance(self, page_url: str, keyword: str) -> Optional[bool]:
        """Get importance status for a specific keyword"""
        collection_name = self._get_collection_name(page_url)

        results = self.client.scroll(
            collection_name=collection_name,
            filter={"must": [{"key": "keyword", "match": {"value": keyword}}]},
            limit=1,
        )[0]

        if results:
            return results[0].payload.get("is_important", False)
        return None

# %%
# | export
async def store_page_keywords(
    site_url: str, page_url: str, range_type: str = "last_days", days: int = 7
):
    """Store page keywords in vector database"""
    try:
        # Get search analytics data
        analytics_data = await search_page_analytics(
            site_url=site_url,
            page_url=page_url,
            range_type=range_type,
            days=days,
            show_queries=True,
        )

        # Initialize vector DB
        vector_db = KeywordVectorDB()

        # Process and store data
        vector_db.process_search_analytics(analytics_data)

        return {
            "status": "success",
            "message": f"Stored keywords for {page_url}",
            "collection_name": vector_db._get_collection_name(page_url),
        }

    except Exception as e:
        raise HTTPException(
            status_code=500, detail=f"Failed to store keywords: {str(e)}"
        )

# %%
result = await store_page_keywords(
    "sc-domain:emdadelgaz.com",
    "https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr",
    range_type="last_days",
    days=30,
)

# %%
result
# Out:
# {'status': 'success',
#  'message': 'Stored keywords for https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#  'collection_name': 'emdadelgaz_com_tmdyd-alghaz-almrkzy-bmsr'}

# %%
# Initialize
vector_db = KeywordVectorDB()

# %%
from seo_rat.article import  ArticleStore

# %%
# vector_db.update_content_status("https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr",markdown_content)

# %%
article_store = ArticleStore(
    db=your_mongodb_database, content_base_path="path/to/content"
)

# Example usage for a specific page and keyword
page_url = "https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr"
relative_path = "tmdyd-alghaz-almrkzy-bmsr.md"  # The markdown file path relative to content_base_path
keyword = "تمديد الغاز"

# Update optimization status for a single keyword
result = vector_db.update_keyword_optimization(
    page_url=page_url,
    keyword=keyword,
    article_store=article_store,
    relative_path=relative_path,
)

# To update all keywords for a page
# First get all keywords from the vector database
keywords = vector_db.get_page_keywords(page_url)

# Then update each keyword's optimization status
for keyword_data in keywords:
    vector_db.update_keyword_optimization(
        page_url=page_url,
        keyword=keyword_data["keyword"],
        article_store=article_store,
        relative_path=relative_path,
    )

# %%
similar_keywords = vector_db.search_keywords(
    page_url="https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr", query_text="تمديد غاز"
)

# %%
similar_keywords
# Out:
# [{'keyword': 'تمديد غاز',
#   'score': 1.0,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0.0,
#    'impressions': 4.0,
#    'position': 1.375,
#    'ctr': 0.0,
#    'dates': ['2024-12-09', '2024-11-13', '2024-11-16', '2024-11-30']},
#   'last_updated': '2024-12-13T02:26:04.206517',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'تمديد غاز منزلي',
#   'score': 0.88548094,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 1.0,
#    'impressions': 8.0,
#    'position': 1.2916666666666667,
#    'ctr': 0.125,
#    'dates': ['2024-11-18', '2024-12-04', '2024-11-24', '2024-12-07']},
#   'last_updated': '2024-12-13T02:26:04.201211',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'شركة تمديد غاز',
#   'score': 0.8643093,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0.0,
#    'impressions': 7.0,
#    'position': 0.9142857142857144,
#    'ctr': 0.0,
#    'dates': ['2024-12-04', '2024-11-24', '2024-11-16', '2024-11-25']},
#   'last_updated': '2024-12-13T02:26:04.197855',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'تمديد غاز مركزي',
#   'score': 0.84188646,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0,
#    'impressions': 7,
#    'position': 1.7142857142857142,
#    'ctr': 0.0,
#    'dates': ['2024-11-30',
#     '2024-11-10',
#     '2024-12-06',
#     '2024-11-29',
#     '2024-12-02',
#     '2024-11-28']},
#   'last_updated': '2024-12-13T02:26:04.215024',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'مواسير غاز',
#   'score': 0.8002041,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0.0,
#    'impressions': 14.0,
#    'position': 0.11111111111111112,
#    'ctr': 0.0,
#    'dates': ['2024-11-27',
#     '2024-12-04',
#     '2024-11-24',
#     '2024-11-26',
#     '2024-12-05',
#     '2024-11-15',
#     '2024-11-29',
#     '2024-11-30']},
#   'last_updated': '2024-12-13T02:26:04.190656',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'تمديد غاز للمطاعم',
#   'score': 0.75236875,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0,
#    'impressions': 5,
#    'position': 0.6,
#    'ctr': 0.0,
#    'dates': ['2024-11-23', '2024-11-10', '2024-11-30']},
#   'last_updated': '2024-12-13T02:26:04.218154',
#   'in_content': False,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'تمديد مواسير الغاز للمطابخ',
#   'score': 0.7371721,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 2.0,
#    'impressions': 21.0,
#    'position': 0.4444444444444445,
#    'ctr': 0.09523809523809525,
#    'dates': ['2024-11-21',
#     '2024-11-10',
#     '2024-11-25',
#     '2024-12-01',
#     '2024-11-27',
#     '2024-11-30',
#     '2024-11-26',
#     '2024-12-03',
#     '2024-12-05',
#     '2024-12-07',
#     '2024-12-09',
#     '2024-12-02',
#     '2024-12-06',
#     '2024-11-20']},
#   'last_updated': '2024-12-13T02:26:04.203833',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'تغطية مواسير الغاز',
#   'score': 0.71589166,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0.0,
#    'impressions': 2.0,
#    'position': 29.0,
#    'ctr': 0.0,
#    'dates': ['2024-12-08']},
#   'last_updated': '2024-12-13T02:26:04.209321',
#   'in_content': False,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'شركة تمديد غاز مركزي',
#   'score': 0.70888245,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 3,
#    'impressions': 8,
#    'position': 0.5416666666666666,
#    'ctr': 0.375,
#    'dates': ['2024-11-18',
#     '2024-11-22',
#     '2024-11-17',
#     '2024-11-14',
#     '2024-11-26']},
#   'last_updated': '2024-12-13T02:26:04.159996',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False},
#  {'keyword': 'سعر تمديد مواسير الغاز',
#   'score': 0.6756766,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-10',
#    'end': '2024-12-10',
#    'type': 'last_days',
#    'total_days': 30},
#   'performance': {'clicks': 0.0,
#    'impressions': 16.0,
#    'position': 0.7692307692307693,
#    'ctr': 0.0,
#    'dates': ['2024-12-08',
#     '2024-11-13',
#     '2024-11-25',
#     '2024-12-01',
#     '2024-11-16',
#     '2024-11-24',
#     '2024-11-19',
#     '2024-11-26',
#     '2024-11-18',
#     '2024-11-15',
#     '2024-11-28',
#     '2024-11-20']},
#   'last_updated': '2024-12-13T02:26:04.187705',
#   'in_content': True,
#   'is_optimized': False,
#   'is_important': False,
#   'is_focus_keyword': False}]

# %%
# Regular filtering without query
focus_keywords = vector_db.get_page_keywords(
    page_url="https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr",
    # category="FOCUS_AND_INCLUDED",
    in_content=True,
    
)

# %%
focus_keywords
# Out:
# []

# %%
# Get high-performing keywords
top_keywords = vector_db.get_page_keywords(
    page_url="https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr", min_clicks=3
)

# %%
top_keywords
# Out:
# [{'keyword': 'شركة تمديد غاز مركزي',
#   'score': 1.0,
#   'site_url': 'sc-domain:emdadelgaz.com',
#   'page_url': 'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr',
#   'date_range': {'start': '2024-11-09',
#    'end': '2024-12-09',
#    'type': 'last_days',
#    'total_days': 31},
#   'performance': {'clicks': 3,
#    'impressions': 8,
#    'position': 0.5416666666666666,
#    'ctr': 0.375,
#    'dates': ['2024-11-18',
#     '2024-11-26',
#     '2024-11-14',
#     '2024-11-17',
#     '2024-11-22']},
#   'last_updated': '2024-12-12T12:24:08.388579',
#   'in_content': False,
#   'is_focus_keyword': False,
#   'category': 'UNCATEGORIZED'}]
