# %% [markdown]
# ## Keywords
#
# - [x] Level 1 (basic SEO , Metadata, Urls and Heading)
#
#   - [x] Full Path
#   - [x] File name
#   - [x] URLs
#     - [x] URLs Target keywords
#   - [x] Headings
#     1. [x] Head 1
#     2. [x] Heading 2
#     3. [x] Heading 3
#     4. [x] Heading 4
#     5. [x] Heading 5
#     6. [x] Heading 6
#     - [x] Position of the heading
#       - [x] full path
#       - [x] line number
#   - [x] Number of headings in the files and their numbers 3 head2 and 2 head 1...etc
#   - [x] Keywords Length
#   - [x] SEO Title
#   - [x] Focus Keywords
#   - [x] Meta Description
#
# - [x] Level 2 (Links Attributes, phone numbers)
#
#   - [x] External Links
#   - [x] Internal Links
#   - [x] Focus keywords in Alt text
#   - [x] Focus keyword in the beginning
#   - [x] Get Phone numbers
#
# - [x] Refactor the Function into Isolated Classes
#   - [x] URls
#   - [x] Heading
#   - [x] Keywords
#     - [x] SQL Design
#   - [x] Frontmatter and Metadata
# - Add More test to Leve 1 and Level 2 and Level 3 and aslo improve the code structure of my Files to be a in a better design
# - mongodb code to update my values
# - [x] Level 3 (SQL Design for Data )
#   - [ ] Focus keyword found in the content
#   - [ ] Focus keyword not found in subheading(s) like H2,H3,H4..etc
#   - [ ] Add an Image with your Focus Keyword as alt text
#   - [ ] Keyword Density is 0.06 which is low, or hight
#   - [ ] URL is 61 characters long!
#   - [ ] Slug Title
#   - [ ] Canconcial URL
#   - [ ] at the 10% of the content
# - [ ] Bouns Heading Tag Hierarchy Erro Checker Tool
# - [ ] Bouns Title & Meta Description Analyzer Tool
# - [ ] Level 4 ( LLms Generator)
#   - [ ] Search intent detector
#     - [ ] plan for keywords search intent will use it
#     - [ ] analzye for the SERB
#   - [ ] AI for optimize the metadescription,description for the product
#   - [ ] Auto generate for the Schema based on the content
#     - [ ] it can detect the "how to " and make it automated
#   - [ ] you haven't used this focus Keyword before
#   - [ ] we found 0 outbound links in your content and all of them are nofollow
#   - [ ] Add Related Keywords
#     - [ ] Generate with AI
#   - [ ] SEO width
#   - [ ] Avoid dead links on your site
#   - [ ] Keyword Search Diagram
#   - [ ] Transitions word Percent
# - [ ] Level 5 (Recommenditions)
#   - [ ] Smart Content Suggestions
#   - [ ] Keyword Suggestions
#   - [ ] Semantic Search
# - [ ] Title Readability
# - [ ] Level 6 (Fastapi Backend with nice frontend)
#
#   1. [ ] Focus keyword used at the beginning of SEO title
#   2. [ ] You are using a number in your SEO title
#
# - [ ] Content Readability
#   1. [ ] You see to be using Table of content
#   2. [ ] At least one paragraph is long condiser usign short paragraphs
#   3. [ ] Your content contains images and/or video(s)
#   - [ ] Content is to long or to short
# - [ ] Topics to hack
#   1. [ ] Caching python code
#   2. [ ] Profiling for every function
#   3. [ ] Async code
#   4. [ ] Test Driven Developement
#   5. [ ] Interactive Debuging in notebook
#   6. [ ] Write Documentation with nbdev
