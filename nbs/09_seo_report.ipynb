# %%
# | default_exp seo_report

# %%
# | export
from typing import Dict, List
from sqlmodel import Session, select
from seo_rat.article import get_article_by_path, insert_article, Article
from seo_rat.sqlite_db import SQLiteDB
from seo_rat.models import Website
from seo_rat.content_mapper import map_all_urls_to_files
from seo_rat.content_parser import (
    parse_notebook_metadata,
    filter_external_links,
    filter_internal_links,
    extract_links,
)

# %%
# | export
def sync_articles_to_db(
    session: Session, website_id: int, url_file_mapping: Dict[str, str]
):
    """Insert all articles into database"""
    for url, file_path in url_file_mapping.items():
        if file_path:  # Only if file exists
            # Check if already exists
            existing = get_article_by_path(session, file_path)
            if not existing:
                insert_article(session, website_id, file_path)

# %%
# | hide
db = SQLiteDB()
with db.get_session() as session:
    websites = session.exec(select(Website)).all()
    for w in websites:
        print(f"ID: {w.id}, URL: {w.url}")
url_mapping = map_all_urls_to_files(
    "https://kareemai.com/sitemap.xml",
    "/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/",
    "https://kareemai.com/",
)

sync_articles_to_db(session, website_id=2, url_file_mapping=url_mapping)
articles = session.exec(select(Article)).all()
for article in articles:
    print(article)
# Out:
# ID: 2, URL: https://kareemai.com
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/papers.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=1 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 901517)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/oss/opensource.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=2 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 914530)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-12-15.md' secondary_keywords=None website_id=2 focus_keyword=None id=3 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 923431)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-12-13.md' secondary_keywords=None website_id=2 focus_keyword=None id=4 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 933589)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-06-06-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=5 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 942662)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-25-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=6 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 951406)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-21-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=7 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 961181)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-19-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=8 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 969771)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-17-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=9 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 980147)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/tools_reviews/super_productivity_app.md' secondary_keywords=None website_id=2 focus_keyword=None id=10 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 989458)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/ds_and_algo/master_ds.md' secondary_keywords=None website_id=2 focus_keyword=None id=11 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 998356)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/courses/havrard CS197 AI research experiences.md' secondary_keywords=None website_id=2 focus_keyword=None id=12 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 7157)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/speech_recognition/muaalm_quran_chance.md' secondary_keywords=None website_id=2 focus_keyword=None id=13 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 16050)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/pyversity_qdrant.ipynb' secondary_keywords=None website_id=2 focus_keyword=None id=14 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 25002)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/blog_zaraah.ipynb' secondary_keywords=None website_id=2 focus_keyword=None id=15 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 33792)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/seo/how_i_use_nlp_for_seo.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=16 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 43988)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/one_plus_pad_3.md' secondary_keywords=None website_id=2 focus_keyword=None id=17 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 52845)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei_mate_pad_11.md' secondary_keywords=None website_id=2 focus_keyword=None id=18 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 61537)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei freebuds 5i.md' secondary_keywords=None website_id=2 focus_keyword=None id=19 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 69984)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/sparse_embedding/bm25_from_scratch.ipynb' secondary_keywords=None website_id=2 focus_keyword=None id=20 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 78892)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/sparse_embedding/bm25_arabic_qdrant.ipynb' secondary_keywords=None website_id=2 focus_keyword=None id=21 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 87011)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/mteb_encoding/my_little_dargon.md' secondary_keywords=None website_id=2 focus_keyword=None id=22 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 96356)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/math/math_skills_for_AI.md' secondary_keywords=None website_id=2 focus_keyword=None id=23 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 106116)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/protienai.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=24 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 115081)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/fake_graviety.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=25 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 124359)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/fl/what_is_federated_learning.md' secondary_keywords=None website_id=2 focus_keyword=None id=26 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 133423)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/back_to_rss.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=27 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 141358)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/digital_minimalisim_arabic.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=28 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 149993)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/gpuvec.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=29 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 159136)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/kamcalorie.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=30 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 168431)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/why_I_am_blogging.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=31 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 177007)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.md' secondary_keywords=None website_id=2 focus_keyword=None id=32 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 185613)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/mteb_encoding/tiny-gte_transformer_model.md' secondary_keywords=None website_id=2 focus_keyword=None id=33 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 194558)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/sparse_embedding/bm25_benchmark_full.ipynb' secondary_keywords=None website_id=2 focus_keyword=None id=34 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 203076)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/late_interaction.ipynb' secondary_keywords=None website_id=2 focus_keyword=None id=35 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 211739)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei freebuds 7i.md' secondary_keywords=None website_id=2 focus_keyword=None id=36 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 222052)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei_watch_gt_4_experience.md' secondary_keywords=None website_id=2 focus_keyword=None id=37 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 231476)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/seo/google_ads_black_box.md' secondary_keywords=None website_id=2 focus_keyword=None id=38 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 239916)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/seo/the_curse_of_seo.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=39 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 249072)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/ctranslate_maswray.md' secondary_keywords=None website_id=2 focus_keyword=None id=40 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 258129)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/speech_recognition/my_dream_job_at_tarteel.md' secondary_keywords=None website_id=2 focus_keyword=None id=41 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 267051)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/feed.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=42 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 275673)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-18-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=43 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 285636)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-20-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=44 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 294526)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-23-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=45 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 303523)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-28-til.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=46 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 312226)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-10-21.md' secondary_keywords=None website_id=2 focus_keyword=None id=47 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 319977)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-12-14.md' secondary_keywords=None website_id=2 focus_keyword=None id=48 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 328452)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/index.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=49 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 338391)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/index.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=50 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 347684)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/publish.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=51 created_at=datetime.datetime(2026, 1, 18, 14, 46, 58, 356400)
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/dspy/Opencode.md' secondary_keywords=None website_id=2 focus_keyword=None id=52 created_at=datetime.datetime(2026, 2, 24, 5, 37, 58, 119964)

# %%
# | export


def find_duplicate_metadata(
    session: Session, field: str, similarity_threshold: float = 0.9
) -> List[Dict]:
    """Find pages with duplicate or very similar titles"""
    from seo_rat.content_parser import parse_metadata, calculate_similarity

    articles = session.exec(select(Article)).all()
    titles = {}

    # Collect all titles
    for article in articles:
        with open(article.file_path, "r") as f:
            if article.file_path.endswith(".ipynb"):
                metdata = parse_notebook_metadata(f.read())
                titles[article.file_path] = metdata.get(field, "")
            elif article.file_path.endswith(".md") or article.file_path.endswith(
                ".qmd"
            ):
                metadata = parse_metadata(f.read())
                titles[article.file_path] = metadata.get(field, "")

    # Find duplicates
    duplicates = []
    checked = set()

    for path1, field1 in titles.items():
        for path2, field2 in titles.items():
            if path1 >= path2 or (path1, path2) in checked:
                continue

            similarity = calculate_similarity(field1, field2)
            if similarity >= similarity_threshold:
                duplicates.append(
                    {
                        "file1": path1,
                        "file2": path2,
                        f"{field}{1}": field1,
                        f"{field}{2}": field2,
                        "similarity": similarity,
                    }
                )
            checked.add((path1, path2))

    return duplicates

# %%
# | hide
find_duplicate_metadata(session, "description", similarity_threshold=0.7)
# Out:
# []

# %%
# | export


def analyze_links(content: str, domain: str) -> Dict:
    """Analyze internal and external links in content"""
    links = extract_links(content)
    all_urls = list(links.keys())

    internal = filter_internal_links(all_urls, domain)
    external = filter_external_links(all_urls, domain)

    return {
        "total_links": len(all_urls),
        "internal_count": len(internal),
        "external_count": len(external),
        "internal_links": internal,
        "external_links": external,
    }

# %%
# | test

from seo_rat.content_parser import remove_metadata

article = session.exec(select(Article)).first()
print(article)
with open(article.file_path, "r") as f:
    content = remove_metadata(f.read())

link_analysis = analyze_links(content, "kareemai.com")
print(link_analysis)

print(f"Total: {link_analysis['total_links']}")
print(f"Internal: {link_analysis['internal_count']}")
print(f"External: {link_analysis['external_count']}")
# Out:
# file_path='/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/papers.qmd' secondary_keywords=None website_id=2 focus_keyword=None id=1 created_at=datetime.datetime(2026, 1, 18, 14, 46, 57, 901517)
# {'total_links': 7, 'internal_count': 3, 'external_count': 4, 'internal_links': ['blog/feed.qmd', 'oss/opensource.qmd', 'index.qmd'], 'external_links': ['https://www.researchgate.net/publication/392372128_QARI-OCR_High-Fidelity_Arabic_Text_Recognition_through_Multimodal_Large_Language_Model_Adaptation?_sg%5B0%5D=Ddb9kwrghDtknsstHB3jlx1WzktpoFiMyRPptkC8aa65gsBxoJELnyU0eWOEMdJZc7iDzAWz_H6F-tcBgH5cEFeAxcJSKj_KPbQmRJ4U.0revArIdJ55OwTpYSzjXCjzvTRcpqs6fjm7JpaoCoUTXQ3fpCpx0DPLOF7UnmV8HWDrYSY9_QqO1XfHUzMtApQ&_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6ImxvZ2luIiwicGFnZSI6InByb2ZpbGUiLCJwcmV2aW91c1BhZ2UiOiJwcm9maWxlIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ', "https://www.researchgate.net/publication/375102394_Explainable_Artificial_Intelligence_of_Multi-level_Stacking_Ensemble_for_Detection_of_Alzheimer's_Disease_based_on_Particle_Swarm_Optimization_and_the_Sub-scores_of_Cognitive_Biomarkers", 'https://www.researchgate.net/publication/390783955_Optimizing_Medical_Image_Classification_Leveraging_Advanced_Segmentation_Models_for_Enhanced_Object_Detection_in_Real-World_Scenarios?_sg%5B0%5D=Ddb9kwrghDtknsstHB3jlx1WzktpoFiMyRPptkC8aa65gsBxoJELnyU0eWOEMdJZc7iDzAWz_H6F-tcBgH5cEFeAxcJSKj_KPbQmRJ4U.0revArIdJ55OwTpYSzjXCjzvTRcpqs6fjm7JpaoCoUTXQ3fpCpx0DPLOF7UnmV8HWDrYSY9_QqO1XfHUzMtApQ&_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6ImxvZ2luIiwicGFnZSI6InByb2ZpbGUiLCJwcmV2aW91c1BhZ2UiOiJwcm9maWxlIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ', 'https://www.researchgate.net/publication/384044186_AI-Powered_ICare_Infant_Cry_Analysis_and_Speech_Therapy?_sg%5B0%5D=Ddb9kwrghDtknsstHB3jlx1WzktpoFiMyRPptkC8aa65gsBxoJELnyU0eWOEMdJZc7iDzAWz_H6F-tcBgH5cEFeAxcJSKj_KPbQmRJ4U.0revArIdJ55OwTpYSzjXCjzvTRcpqs6fjm7JpaoCoUTXQ3fpCpx0DPLOF7UnmV8HWDrYSY9_QqO1XfHUzMtApQ&_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6ImxvZ2luIiwicGFnZSI6InByb2ZpbGUiLCJwcmV2aW91c1BhZ2UiOiJwcm9maWxlIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ']}
# Total: 7
# Internal: 3
# External: 4

# %%
#| export
from seo_rat.content_parser import (
    parse_metadata,
    parse_notebook_metadata,
    remove_metadata,
    extract_headers,
    extract_images,
    check_desc_length,
    check_content_length,
    check_title_length,
    imgs_missing_alts,
)
from seo_rat.seo_analysis import check_h1_count

# %%
# | export
def generate_seo_report(session: Session, website_id: int, domain: str) -> Dict:
    """Generate comprehensive SEO report for all pages"""

    articles = session.exec(
        select(Article).where(Article.website_id == website_id)
    ).all()

    page_reports = []
    issues = []

    for article in articles:
        try:
            with open(article.file_path, "r") as f:
                raw_content = f.read()

            # Parse metadata
            if article.file_path.endswith(".ipynb"):
                metadata = parse_notebook_metadata(raw_content)
            else:
                metadata = parse_metadata(raw_content)

            content = remove_metadata(raw_content)
            headers = extract_headers(article.file_path)
            images = extract_images(content)

            # Run checks
            report = {
                "file_path": article.file_path,
                "title_check": check_title_length(
                    metadata.get("title", "")
                ),  # Pass string
                "description_check": check_desc_length(metadata.get("description", "")),
                "content_check": check_content_length(content),
                "h1_check": check_h1_count(
                    headers, title=metadata.get("title", ""), is_quarto=True
                ),
                "missing_alts": imgs_missing_alts(images),
                "link_analysis": analyze_links(content, domain),
            }

            # Collect issues
            if not report["h1_check"]["has_single_h1"]:
                issues.append(f"{article.file_path}: Multiple or no H1")
            if not report["content_check"]["is_sufficient"]:
                issues.append(f"{article.file_path}: Content too short")

            page_reports.append(report)

        except Exception as e:
            print(f"Error analyzing {article.file_path}: {e}")

    # Site-wide checks
    duplicate_titles = find_duplicate_metadata(session, "title", 0.9)
    duplicate_descriptions = find_duplicate_metadata(session, "description", 0.9)

    return {
        "total_pages": len(articles),
        "pages_analyzed": len(page_reports),
        "page_reports": page_reports,
        "duplicate_titles": duplicate_titles,
        "duplicate_descriptions": duplicate_descriptions,
        "issues": issues,
        "summary": {
            "total_issues": len(issues),
            "duplicate_titles_count": len(duplicate_titles),
            "duplicate_descriptions_count": len(duplicate_descriptions),
        },
    }

# %%
report = generate_seo_report(session, website_id=2, domain="kareemai.com")
print(f"Total pages: {report['total_pages']}")
print(f"Issues found: {report['summary']['total_issues']}")
# Out:
# Error analyzing /home/kobo/Desktop/obsidian_valuts/logseq/karem-site/index.qmd: 'title'
# Total pages: 52
# Issues found: 1

# %%
report["page_reports"][13]
# Out:
# {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/pyversity_qdrant.ipynb',
#  'title_check': {'length': 53, 'optimal_lenth': True},
#  'description_check': {'length': 110, 'optimal_lenth': False},
#  'content_check': {'word_count': 6920, 'is_sufficient': True},
#  'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#  'missing_alts': [],
#  'link_analysis': {'total_links': 2,
#   'internal_count': 0,
#   'external_count': 2,
#   'internal_links': [],
#   'external_links': ['https://github.com/Pringled/pyversity',
#    'https://qdrant.tech/blog/mmr-diversity-aware-reranking/#step-3-setting-up-qdrant-for-visual-fashion-search']}}

# %%
report
# Out:
# {'total_pages': 52,
#  'pages_analyzed': 51,
#  'page_reports': [{'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/papers.qmd',
#    'title_check': {'length': 59, 'optimal_lenth': True},
#    'description_check': {'length': 153, 'optimal_lenth': True},
#    'content_check': {'word_count': 422, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 3,
#     'external_count': 4,
#     'internal_links': ['blog/feed.qmd', 'oss/opensource.qmd', 'index.qmd'],
#     'external_links': ['https://www.researchgate.net/publication/392372128_QARI-OCR_High-Fidelity_Arabic_Text_Recognition_through_Multimodal_Large_Language_Model_Adaptation?_sg%5B0%5D=Ddb9kwrghDtknsstHB3jlx1WzktpoFiMyRPptkC8aa65gsBxoJELnyU0eWOEMdJZc7iDzAWz_H6F-tcBgH5cEFeAxcJSKj_KPbQmRJ4U.0revArIdJ55OwTpYSzjXCjzvTRcpqs6fjm7JpaoCoUTXQ3fpCpx0DPLOF7UnmV8HWDrYSY9_QqO1XfHUzMtApQ&_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6ImxvZ2luIiwicGFnZSI6InByb2ZpbGUiLCJwcmV2aW91c1BhZ2UiOiJwcm9maWxlIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ',
#      "https://www.researchgate.net/publication/375102394_Explainable_Artificial_Intelligence_of_Multi-level_Stacking_Ensemble_for_Detection_of_Alzheimer's_Disease_based_on_Particle_Swarm_Optimization_and_the_Sub-scores_of_Cognitive_Biomarkers",
#      'https://www.researchgate.net/publication/390783955_Optimizing_Medical_Image_Classification_Leveraging_Advanced_Segmentation_Models_for_Enhanced_Object_Detection_in_Real-World_Scenarios?_sg%5B0%5D=Ddb9kwrghDtknsstHB3jlx1WzktpoFiMyRPptkC8aa65gsBxoJELnyU0eWOEMdJZc7iDzAWz_H6F-tcBgH5cEFeAxcJSKj_KPbQmRJ4U.0revArIdJ55OwTpYSzjXCjzvTRcpqs6fjm7JpaoCoUTXQ3fpCpx0DPLOF7UnmV8HWDrYSY9_QqO1XfHUzMtApQ&_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6ImxvZ2luIiwicGFnZSI6InByb2ZpbGUiLCJwcmV2aW91c1BhZ2UiOiJwcm9maWxlIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ',
#      'https://www.researchgate.net/publication/384044186_AI-Powered_ICare_Infant_Cry_Analysis_and_Speech_Therapy?_sg%5B0%5D=Ddb9kwrghDtknsstHB3jlx1WzktpoFiMyRPptkC8aa65gsBxoJELnyU0eWOEMdJZc7iDzAWz_H6F-tcBgH5cEFeAxcJSKj_KPbQmRJ4U.0revArIdJ55OwTpYSzjXCjzvTRcpqs6fjm7JpaoCoUTXQ3fpCpx0DPLOF7UnmV8HWDrYSY9_QqO1XfHUzMtApQ&_tp=eyJjb250ZXh0Ijp7ImZpcnN0UGFnZSI6ImxvZ2luIiwicGFnZSI6InByb2ZpbGUiLCJwcmV2aW91c1BhZ2UiOiJwcm9maWxlIiwicG9zaXRpb24iOiJwYWdlQ29udGVudCJ9fQ']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/oss/opensource.qmd',
#    'title_check': {'length': 59, 'optimal_lenth': True},
#    'description_check': {'length': 150, 'optimal_lenth': True},
#    'content_check': {'word_count': 460, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 23,
#     'internal_count': 4,
#     'external_count': 14,
#     'internal_links': ['../papers.qmd',
#      '../blog/feed.qmd',
#      '../til/index.qmd',
#      '../index.qmd'],
#     'external_links': ['#fastai',
#      '#metaflow',
#      '#kubeflow',
#      '#jupyter',
#      '#great-expectations',
#      'https://github.com/fastai',
#      'https://github.com/outerbounds/metaflow-card-notebook',
#      'https://outerbounds.com/blog/notebooks-in-production-with-metaflow/',
#      'https://github.com/jupyterhub/repo2docker-action',
#      'https://github.com/jupyter/repo2docker',
#      'https://binderhub.readthedocs.io/en/latest/zero-to-binderhub/setup-binderhub.html',
#      'https://mybinder.org/',
#      'https://github.com/great-expectations/great_expectations_action',
#      'https://github.blog/2020-10-01-keeping-your-data-pipelines-healthy-with-the-great-expectations-github-action/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-12-15.md',
#    'title_check': {'length': 55, 'optimal_lenth': True},
#    'description_check': {'length': 137, 'optimal_lenth': False},
#    'content_check': {'word_count': 381, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 3,
#     'internal_count': 3,
#     'external_count': 0,
#     'internal_links': ['../../papers.qmd',
#      '../../blog/feed.qmd',
#      '../../index.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-12-13.md',
#    'title_check': {'length': 64, 'optimal_lenth': False},
#    'description_check': {'length': 139, 'optimal_lenth': False},
#    'content_check': {'word_count': 635, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 4,
#     'external_count': 3,
#     'internal_links': ['../../blog/feed.qmd',
#      '../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd'],
#     'external_links': ['https://neetcode.com',
#      'https://deep-ml.com',
#      'https://web.stanford.edu/~jurafsky/slp3/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-06-06-til.qmd',
#    'title_check': {'length': 65, 'optimal_lenth': False},
#    'description_check': {'length': 153, 'optimal_lenth': True},
#    'content_check': {'word_count': 784, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../../blog/feed.qmd',
#      '../index.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-25-til.qmd',
#    'title_check': {'length': 55, 'optimal_lenth': True},
#    'description_check': {'length': 150, 'optimal_lenth': True},
#    'content_check': {'word_count': 1116, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 12,
#     'internal_count': 4,
#     'external_count': 5,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': ['https://xmad.ai',
#      'https://arxiv.org/html/2401.18059v1',
#      'https://pyrefly.org/',
#      'https://arxiv.org/abs/2406.02359',
#      'https://docs.llamaindex.ai/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-21-til.qmd',
#    'title_check': {'length': 65, 'optimal_lenth': False},
#    'description_check': {'length': 151, 'optimal_lenth': True},
#    'content_check': {'word_count': 1219, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-19-til.qmd',
#    'title_check': {'length': 58, 'optimal_lenth': True},
#    'description_check': {'length': 152, 'optimal_lenth': True},
#    'content_check': {'word_count': 1125, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 4,
#     'external_count': 3,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': ['https://substack.com/@jayalammar',
#      'https://newsletter.maartengrootendorst.com/',
#      'https://decodingml.substack.com/p/llm-engineers-handbook-is-finally']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-17-til.qmd',
#    'title_check': {'length': 48, 'optimal_lenth': False},
#    'description_check': {'length': 160, 'optimal_lenth': True},
#    'content_check': {'word_count': 625, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 3,
#     'internal_count': 1,
#     'external_count': 2,
#     'internal_links': ['https://kareemai.com/til/'],
#     'external_links': ['https://x.com/antoine_chaffin/status/1923378986219958526',
#      'https://betatim.github.io/posts/til-explained/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/tools_reviews/super_productivity_app.md',
#    'title_check': {'length': 62, 'optimal_lenth': False},
#    'description_check': {'length': 161, 'optimal_lenth': False},
#    'content_check': {'word_count': 468, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 17,
#     'internal_count': 5,
#     'external_count': 1,
#     'internal_links': ['https://kareemai.com/blog/posts/life_style/back_to_rss.html',
#      'https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html',
#      'https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html',
#      '../../../papers.qmd',
#      '../../../oss/opensource.qmd'],
#     'external_links': ['https://super-productivity.com/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/ds_and_algo/master_ds.md',
#    'title_check': {'length': 58, 'optimal_lenth': True},
#    'description_check': {'length': 140, 'optimal_lenth': False},
#    'content_check': {'word_count': 516, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 9,
#     'internal_count': 5,
#     'external_count': 4,
#     'internal_links': ['https://kareemai.com/blog/posts/ds_and_algo/Static_array.html',
#      '../../feed.qmd',
#      '../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd'],
#     'external_links': ['https://www.manning.com/books/grokking-data-structures',
#      'https://www.udemy.com/course/python-ds-skills/',
#      'https://neetcode.io/roadmap',
#      'https://codingchallenges.fyi/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/courses/havrard CS197 AI research experiences.md',
#    'title_check': {'length': 60, 'optimal_lenth': True},
#    'description_check': {'length': 149, 'optimal_lenth': False},
#    'content_check': {'word_count': 601, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 4,
#     'external_count': 2,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://colah.github.io/notes/taste/',
#      'https://www.youtube.com/watch?v=Unzc731iCUY&pp=ygUyaG93IHRvIG1ha2Ugc2xpZGVzaG93IGFuZCBwcmVzZW50YXRpb24gbWl0IGxlY3R1cmU%3D']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/speech_recognition/muaalm_quran_chance.md',
#    'title_check': {'length': 65, 'optimal_lenth': False},
#    'description_check': {'length': 152, 'optimal_lenth': True},
#    'content_check': {'word_count': 1240, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 1,
#     'external_count': 3,
#     'internal_links': ['https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html'],
#     'external_links': ['https://developer.nvidia.com/tensorrt',
#      'https://huggingface.co/docs/optimum/index',
#      'https://github.com/obadx/quran-muaalem']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/pyversity_qdrant.ipynb',
#    'title_check': {'length': 53, 'optimal_lenth': True},
#    'description_check': {'length': 110, 'optimal_lenth': False},
#    'content_check': {'word_count': 6920, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 2,
#     'internal_count': 0,
#     'external_count': 2,
#     'internal_links': [],
#     'external_links': ['https://github.com/Pringled/pyversity',
#      'https://qdrant.tech/blog/mmr-diversity-aware-reranking/#step-3-setting-up-qdrant-for-visual-fashion-search']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/blog_zaraah.ipynb',
#    'title_check': {'length': 30, 'optimal_lenth': False},
#    'description_check': {'length': 87, 'optimal_lenth': False},
#    'content_check': {'word_count': 8375, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 1,
#     'external_count': 7,
#     'internal_links': [''],
#     'external_links': ['https://minishlab.github.io/',
#      'https://github.com/MinishLab/model2vec',
#      'https://huggingface.co/NAMAA-Space/bojji',
#      'https://huggingface.co/NAMAA-Space/zarra',
#      'https://huggingface.co/datasets/allenai/c4',
#      'https://huggingface.co/blog/Navid-AI/arabic-rag-leaderboard',
#      'https://huggingface.co/spaces/mteb/leaderboard']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/seo/how_i_use_nlp_for_seo.qmd',
#    'title_check': {'length': 55, 'optimal_lenth': True},
#    'description_check': {'length': 160, 'optimal_lenth': True},
#    'content_check': {'word_count': 631, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 1,
#     'external_count': 5,
#     'internal_links': ['https://kareemai.com/blog/feed.html'],
#     'external_links': ['https://anwan.me/',
#      'https://kamcalorie.com',
#      'https://www.tanorfix.com/',
#      'https://www.smaagarden.com/',
#      'https://www.alainclean.com/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/one_plus_pad_3.md',
#    'title_check': {'length': 47, 'optimal_lenth': False},
#    'description_check': {'length': 235, 'optimal_lenth': False},
#    'content_check': {'word_count': 3839, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 1,
#     'external_count': 1,
#     'internal_links': ['https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html'],
#     'external_links': ['https://whatsapp.com/channel/0029VbC3Vu68PgsB7BxcX42z']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei_mate_pad_11.md',
#    'title_check': {'length': 58, 'optimal_lenth': True},
#    'description_check': {'length': 153, 'optimal_lenth': True},
#    'content_check': {'word_count': 540, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 5,
#     'external_count': 1,
#     'internal_links': ['Huawei%20freebuds%207i.md',
#      'one_plus_pad_3.md',
#      '../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd'],
#     'external_links': ['https://whatsapp.com/channel/0029Vb6c2NK77qVIcdILrb3U']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei freebuds 5i.md',
#    'title_check': {'length': 51, 'optimal_lenth': True},
#    'description_check': {'length': 165, 'optimal_lenth': False},
#    'content_check': {'word_count': 1232, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 6,
#     'external_count': 3,
#     'internal_links': ['Huawei%20freebuds%207i.md',
#      'Huawei_mate_pad_11.md',
#      'one_plus_pad_3.md',
#      '../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd'],
#     'external_links': ['https://whatsapp.com/channel/0029Vb6c2NK77qVIcdILrb3U',
#      'https://smarttech101.com/bluetoothctl-management-of-bluetooth-devices-in-linux/',
#      'https://kamcalorie.com']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/sparse_embedding/bm25_from_scratch.ipynb',
#    'title_check': {'length': 57, 'optimal_lenth': True},
#    'description_check': {'length': 160, 'optimal_lenth': True},
#    'content_check': {'word_count': 2061, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 2,
#     'external_count': 1,
#     'internal_links': ['https://kareemai.com/blog/posts/nlp/embedding_world/sparse_embedding/bm25_arabic_qdrant.html',
#      'https://kareemai.com/blog/posts/nlp/embedding_world/sparse_embedding/bm25_benchmark_full.html'],
#     'external_links': ['https://molab.marimo.io/notebooks/nb_qmRNbuWUz4fvLdfDt8Un7E/app']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/sparse_embedding/bm25_arabic_qdrant.ipynb',
#    'title_check': {'length': 60, 'optimal_lenth': True},
#    'description_check': {'length': 156, 'optimal_lenth': True},
#    'content_check': {'word_count': 2032, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 2,
#     'external_count': 2,
#     'internal_links': ['https://kareemai.com/blog/posts/nlp/embedding_world/sparse_embedding/bm25_from_scratch.html',
#      'https://kareemai.com/blog/posts/nlp/embedding_world/sparse_embedding/bm25_benchmark_full.html'],
#     'external_links': ['https://www.xbites.io/',
#      'https://qdrant.tech/articles/hybrid-search/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/mteb_encoding/my_little_dargon.md',
#    'title_check': {'length': 23, 'optimal_lenth': False},
#    'description_check': {'length': 170, 'optimal_lenth': False},
#    'content_check': {'word_count': 1256, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 0,
#     'external_count': 0,
#     'internal_links': [],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/math/math_skills_for_AI.md',
#    'title_check': {'length': 61, 'optimal_lenth': False},
#    'description_check': {'length': 150, 'optimal_lenth': True},
#    'content_check': {'word_count': 3241, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 6,
#     'external_count': 4,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd',
#      'https://kareemai.com/blog/posts/fl/what_is_federated_learning.html',
#      'https://kareemai.com/blog/posts/life_style/kamcalorie.html'],
#     'external_links': ['https://www.goodreads.com/book/show/22363984',
#      'https://www.google.com/url?sa=E&q=https%3A%2F%2Fwww.amazon.com%2Fstores%2Fauthor%2FB07BPS6WQL',
#      'https://www.google.com/url?sa=E&q=https%3A%2F%2Fchristophm.github.io%2Finterpretable-ml-book%2F',
#      'https://www.google.com/url?sa=E&q=https%3A%2F%2Fwww.amazon.com%2Fstores%2FChristopher-M.-Bishop%2Fauthor%2FB001IGLMNY%3Fref%3Dap_rdr%26isDramIntegrated%3Dtrue%26shoppingPortalEnabled%3Dtrue%23']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/protienai.qmd',
#    'title_check': {'length': 55, 'optimal_lenth': True},
#    'description_check': {'length': 150, 'optimal_lenth': True},
#    'content_check': {'word_count': 507, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 4,
#     'external_count': 2,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://www.protienai.com',
#      'https://www.kamcalorie.com']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/fake_graviety.qmd',
#    'title_check': {'length': 48, 'optimal_lenth': False},
#    'description_check': {'length': 129, 'optimal_lenth': False},
#    'content_check': {'word_count': 2291, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 4,
#     'external_count': 1,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://ar.wikipedia.org/wiki/%D8%AC%D8%A7%D8%B0%D8%A8%D9%8A%D8%A9']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/fl/what_is_federated_learning.md',
#    'title_check': {'length': 26, 'optimal_lenth': False},
#    'description_check': {'length': 127, 'optimal_lenth': False},
#    'content_check': {'word_count': 965, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 4,
#     'external_count': 1,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://flower.ai/docs/framework/tutorial-series-what-is-federated-learning.html#Challenges-of-classical-machine-learning']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/back_to_rss.qmd',
#    'title_check': {'length': 56, 'optimal_lenth': True},
#    'description_check': {'length': 138, 'optimal_lenth': False},
#    'content_check': {'word_count': 783, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 4,
#     'external_count': 2,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://github.com/yang991178/fluent-reader',
#      'https://www.answer.ai/posts/2025-06-05-readbench.html']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/digital_minimalisim_arabic.qmd',
#    'title_check': {'length': 46, 'optimal_lenth': False},
#    'description_check': {'length': 90, 'optimal_lenth': False},
#    'content_check': {'word_count': 699, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 18,
#     'internal_count': 4,
#     'external_count': 6,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://one-sec.app/',
#      'https://chromewebstore.google.com/detail/minimal-theme-for-twitter/pobhoodpcipjmedfenaigbeloiidbflp',
#      'https://chromewebstore.google.com/detail/unhook-remove-youtube-rec/khncfooichmfjbepaaaebmommgaepoid',
#      'https://chromewebstore.google.com/detail/enhancer-for-youtube/ponfpcnoihfmfllpaingbgckeeldkhle?hl=en-US',
#      'https://activitywatch.net/',
#      'https://dumbphone.so/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/gpuvec.qmd',
#    'title_check': {'length': 36, 'optimal_lenth': False},
#    'description_check': {'length': 177, 'optimal_lenth': False},
#    'content_check': {'word_count': 682, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 19,
#     'internal_count': 2,
#     'external_count': 16,
#     'internal_links': ['https://kareemai.com/blog/posts/fl/what_is_federated_learning.html',
#      'https://kareemai.com/blog/posts/life_style/kamcalorie.html'],
#     'external_links': ['https://gpuvec.com',
#      'https://gpuvec.com/providers',
#      'https://gpuvec.com/vector-db',
#      'https://gpuvec.com/comparison-tool',
#      'https://gpuvec.com/model-size-calculator',
#      'https://gpuvec.com/cost-estimator',
#      'https://gpuvec.com/gpus',
#      'https://gpuvec.com/gpus/h200',
#      'https://gpuvec.com/gpus/a100',
#      'https://gpuvec.com/gpus/a10',
#      'https://gpuvec.com/gpus/h100',
#      'https://gpuvec.com/gpus/rtx-6000-ada',
#      'https://gpuvec.com/gpus/rtx-4090',
#      'https://gpuvec.com/gpus/rtx-5090',
#      'https://gpuvec.com/gpus/rtx-3090',
#      'https://open.substack.com/pub/gpuvec/p/coming-soon?r=5h4pn1&utm_campaign=post&utm_medium=web&showWelcomeOnShare=false']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/kamcalorie.qmd',
#    'title_check': {'length': 60, 'optimal_lenth': True},
#    'description_check': {'length': 158, 'optimal_lenth': True},
#    'content_check': {'word_count': 346, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 4,
#     'external_count': 1,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://www.kamcalorie.com/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/life_style/why_I_am_blogging.qmd',
#    'title_check': {'length': 60, 'optimal_lenth': True},
#    'description_check': {'length': 182, 'optimal_lenth': False},
#    'content_check': {'word_count': 518, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.md',
#    'title_check': {'length': 37, 'optimal_lenth': False},
#    'description_check': {'length': 195, 'optimal_lenth': False},
#    'content_check': {'word_count': 2046, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 3,
#     'internal_count': 1,
#     'external_count': 2,
#     'internal_links': ['tiny-gte_transformer_model.html'],
#     'external_links': ['https://doi.org/10.48550/ARXIV.2004.07180',
#      'https://twitter.com/AbdelkareemElk1']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/mteb_encoding/tiny-gte_transformer_model.md',
#    'title_check': {'length': 51, 'optimal_lenth': True},
#    'description_check': {'length': 164, 'optimal_lenth': False},
#    'content_check': {'word_count': 482, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 4,
#     'external_count': 4,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://www.sbert.net/',
#      'https://huggingface.co/TaylorAI/gte-tiny',
#      'https://huggingface.co/spaces/mteb/leaderboard',
#      'https://www.linkedin.com/posts/prithivirajdamodaran_%3F%3F%3F%3F-%3F%3F%3F%3F-%3F%3F%3F%3F%3F-%3F%3F%3F%3F-activity-7120279840569597952-iwc-']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/sparse_embedding/bm25_benchmark_full.ipynb',
#    'title_check': {'length': 29, 'optimal_lenth': False},
#    'description_check': {'length': 98, 'optimal_lenth': False},
#    'content_check': {'word_count': 2516, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 2,
#     'internal_count': 2,
#     'external_count': 0,
#     'internal_links': ['https://kareemai.com/blog/posts/nlp/embedding_world/sparse_embedding/bm25_from_scratch.html',
#      'https://kareemai.com/blog/posts/nlp/embedding_world/sparse_embedding/bm25_arabic_qdrant.html'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/nlp/embedding_world/late_interaction.ipynb',
#    'title_check': {'length': 69, 'optimal_lenth': False},
#    'description_check': {'length': 167, 'optimal_lenth': False},
#    'content_check': {'word_count': 624, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei freebuds 7i.md',
#    'title_check': {'length': 77, 'optimal_lenth': False},
#    'description_check': {'length': 244, 'optimal_lenth': False},
#    'content_check': {'word_count': 2266, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 1,
#     'external_count': 2,
#     'internal_links': ['https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html'],
#     'external_links': ['https://whatsapp.com/channel/0029Vb6c2NK77qVIcdILrb3U',
#      'https://consumer.huawei.com/eg/headphones/freebuds7i/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/products_reviews/Huawei_watch_gt_4_experience.md',
#    'title_check': {'length': 27, 'optimal_lenth': False},
#    'description_check': {'length': 92, 'optimal_lenth': False},
#    'content_check': {'word_count': 1334, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 1,
#     'external_count': 3,
#     'internal_links': ['https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html'],
#     'external_links': ['https://www.sleepcycle.com/',
#      'https://whatsapp.com/channel/0029Vb6c2NK77qVIcdILrb3U',
#      'https://consumer.huawei.com/sa/wearables/watch-gt4/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/seo/google_ads_black_box.md',
#    'title_check': {'length': 20, 'optimal_lenth': False},
#    'description_check': {'length': 98, 'optimal_lenth': False},
#    'content_check': {'word_count': 363, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 2,
#     'external_count': 3,
#     'internal_links': ['https://kareemai.com/blog/posts/seo/how_i_use_nlp_for_seo.html',
#      'https://kareemai.com/blog/posts/seo/the_curse_of_seo.html'],
#     'external_links': ['https://www.reddit.com/r/googleads/comments/1fu5acv/suspended_account/',
#      'https://support.google.com/adspolicy/answer/2375414?hl=en',
#      'https://oudhmotors.com/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/seo/the_curse_of_seo.qmd',
#    'title_check': {'length': 52, 'optimal_lenth': True},
#    'description_check': {'length': 140, 'optimal_lenth': False},
#    'content_check': {'word_count': 1021, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 24,
#     'internal_count': 4,
#     'external_count': 18,
#     'internal_links': ['../../../papers.qmd',
#      '../../../oss/opensource.qmd',
#      '../../../til/index.qmd',
#      '../../feed.qmd'],
#     'external_links': ['https://www.semrush.com/',
#      'https://rankmath.com/',
#      'https://mangools.com/',
#      'https://search.google.com/search-console/about',
#      'https://app.neilpatel.com/',
#      'https://keywordtool.io/',
#      'https://www.guinrank.com/',
#      'https://moz.com/',
#      'https://khamsat.com/marketing/backlinks-building/2836532-%D8%AE%D8%B7%D8%A9-%D8%A8%D8%A7%D9%83-%D9%84%D9%8A%D9%86%D9%83-pbn-%D8%A7%D9%84%D8%A3%D9%81%D8%B6%D9%84-%D8%AD%D8%A7%D9%84%D9%8A%D8%A7',
#      'https://khamsat.com/marketing/backlinks-building/2191705-%D8%AD%D8%B2%D9%85%D8%A9-%D8%A8%D8%A7%D9%83%D9%84%D9%8A%D9%86%D9%83-%D9%85%D8%AA%D9%83%D8%A7%D9%85%D9%84%D8%A9-%D9%84%D9%85%D9%88%D9%82%D8%B9%D9%83-%D8%B9%D9%84%D9%89-%D9%85%D9%88%D8%A7%D9%82%D8%B9-%D8%B9%D8%A7%D9%84%D9%8A%D8%A9-%D8%A7%D9%84%D8%AF%D9%88%D9%85%D9%8A%D9%86-%D8%A7%D8%AB%D9%88%D8%B1%D8%AA%D9%8A',
#      'https://askubuntu.com/questions/34702/how-do-i-set-up-android-adb',
#      'https://academy.hsoub.com/files/28-%D8%AF%D9%84%D9%8A%D9%84%D9%83-%D8%A5%D9%84%D9%89-%D8%AA%D8%AD%D8%B3%D9%8A%D9%86-%D9%85%D8%AD%D8%B1%D9%83%D8%A7%D8%AA-%D8%A7%D9%84%D8%A8%D8%AD%D8%AB-seo/',
#      'https://www.linkedin.com/in/abdelkareem-elkhateb-989a68294/',
#      'https://anwan.me/',
#      'https://kamcalorie.com',
#      'https://www.tanorfix.com/',
#      'https://www.smaagarden.com/',
#      'https://www.alainclean.com/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/minishlab/ctranslate_maswray.md',
#    'title_check': {'length': 52, 'optimal_lenth': True},
#    'description_check': {'length': 133, 'optimal_lenth': False},
#    'content_check': {'word_count': 1942, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 29,
#     'internal_count': 1,
#     'external_count': 26,
#     'internal_links': ['https://kareemai.com/blog/posts/mteb_encoding/my_little_dargon.html'],
#     'external_links': ['https://www.linkedin.com/in/ahmedwasfy/',
#      'https://www.linkedin.com/company/namaa-community/posts/?feedView=all',
#      'https://pytorch.org/get-started/pytorch-2-x/',
#      'https://docs.pytorch.org/ao/stable/serving.html',
#      'https://huggingface.co/Helsinki-NLP/opus-mt-tc-big-en-ar',
#      'https://marian-nmt.github.io/',
#      'https://docs.vllm.ai/en/latest/contributing/model/basic.html#1-bring-your-model-code',
#      'https://docs.vllm.ai/en/latest/models/supported_models.html#modelscope',
#      'https://opennmt.net/CTranslate2/quickstart.html',
#      'https://opennmt.net/CTranslate2/guides/opennmt_py.html',
#      'https://opennmt.net/CTranslate2/guides/opennmt_tf.html',
#      'https://opennmt.net/CTranslate2/guides/fairseq.html',
#      'https://opennmt.net/CTranslate2/guides/marian.html',
#      'https://opennmt.net/CTranslate2/guides/opus_mt.html',
#      'https://opennmt.net/CTranslate2/guides/transformers.html',
#      'https://github.com/OpenNMT/CTranslate2#benchmarks',
#      'https://opennmt.net/CTranslate2/quantization.html',
#      'https://software.intel.com/content/www/us/en/develop/tools/oneapi/components/onemkl.html',
#      'https://github.com/oneapi-src/oneDNN',
#      'https://www.openblas.net/',
#      'https://github.com/google/ruy',
#      'https://developer.apple.com/documentation/accelerate',
#      'https://opennmt.net/CTranslate2/python/overview.html',
#      'https://opennmt.net/CTranslate2/decoding.html',
#      'https://github.com/OpenNMT/CTranslate2/blob/master/docs/parallel.md#model-and-tensor-parallelism',
#      'https://huggingface.co/Abdelkareem/faster_masrawy']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/speech_recognition/my_dream_job_at_tarteel.md',
#    'title_check': {'length': 23, 'optimal_lenth': False},
#    'description_check': {'length': 91, 'optimal_lenth': False},
#    'content_check': {'word_count': 916, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 1,
#     'external_count': 5,
#     'internal_links': ['muaalm_quran_chance.html'],
#     'external_links': ['https://www.youtube.com/watch?v=100Qq-mLDbMo',
#      'https://huggingface.co/Abdelkareem',
#      'https://www.linkedin.com/in/kareemkobo/',
#      'https://x.com/AbdelkareemElk2',
#      'https://github.com/abdelkareemkobo']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/feed.qmd',
#    'title_check': {'length': 4, 'optimal_lenth': False},
#    'description_check': {'length': 167, 'optimal_lenth': False},
#    'content_check': {'word_count': 249, 'is_sufficient': False},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 3,
#     'internal_count': 3,
#     'external_count': 0,
#     'internal_links': ['../papers.qmd',
#      '../oss/opensource.qmd',
#      '../til/index.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-18-til.qmd',
#    'title_check': {'length': 46, 'optimal_lenth': False},
#    'description_check': {'length': 66, 'optimal_lenth': False},
#    'content_check': {'word_count': 730, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 1,
#     'external_count': 3,
#     'internal_links': ['https://kareemai.com/blog/posts/minishlab/zaraah.html'],
#     'external_links': ['https://qdrant.tech/blog/superlinked-multimodal-search/',
#      'https://qdrant.tech/blog/',
#      'https://qdrant.tech/blog/static-embeddings/']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-20-til.qmd',
#    'title_check': {'length': 60, 'optimal_lenth': True},
#    'description_check': {'length': 135, 'optimal_lenth': False},
#    'content_check': {'word_count': 563, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-23-til.qmd',
#    'title_check': {'length': 57, 'optimal_lenth': True},
#    'description_check': {'length': 149, 'optimal_lenth': False},
#    'content_check': {'word_count': 656, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 4,
#     'external_count': 1,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': ['https://support.brave.com/hc/en-us/articles/34070140231821-How-do-I-use-the-Bring-Your-Own-Model-BYOM-with-Brave-Leo']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-05-28-til.qmd',
#    'title_check': {'length': 61, 'optimal_lenth': False},
#    'description_check': {'length': 157, 'optimal_lenth': True},
#    'content_check': {'word_count': 835, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-10-21.md',
#    'title_check': {'length': 68, 'optimal_lenth': False},
#    'description_check': {'length': 187, 'optimal_lenth': False},
#    'content_check': {'word_count': 1051, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 3,
#     'external_count': 2,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd'],
#     'external_links': ['https://www.fast.ai/posts/2025-10-16-karpathy-tokenizers.html#token-efficiency',
#      'https://solve.it.com/?via_id=t1hpiqbn']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/tils/2025-12-14.md',
#    'title_check': {'length': 33, 'optimal_lenth': False},
#    'description_check': {'length': 64, 'optimal_lenth': False},
#    'content_check': {'word_count': 459, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 4,
#     'external_count': 1,
#     'internal_links': ['../../papers.qmd',
#      '../../oss/opensource.qmd',
#      '../index.qmd',
#      '../../blog/feed.qmd'],
#     'external_links': ['https://youtube.com/playlist?list=PLald6EODoOJU0GMuYHlkS9MLhTPE7HiaT&si=3O-9VHNwmSN5M13t']}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/til/index.qmd',
#    'title_check': {'length': 22, 'optimal_lenth': False},
#    'description_check': {'length': 147, 'optimal_lenth': False},
#    'content_check': {'word_count': 356, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['../blog/feed.qmd',
#      '../papers.qmd',
#      '../oss/opensource.qmd',
#      '../index.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/publish.qmd',
#    'title_check': {'length': 52, 'optimal_lenth': True},
#    'description_check': {'length': 140, 'optimal_lenth': False},
#    'content_check': {'word_count': 314, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['blog/feed.qmd',
#      'til/index.qmd',
#      'papers.qmd',
#      'index.qmd'],
#     'external_links': []}},
#   {'file_path': '/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/posts/dspy/Opencode.md',
#    'title_check': {'length': 58, 'optimal_lenth': True},
#    'description_check': {'length': 127, 'optimal_lenth': False},
#    'content_check': {'word_count': 1336, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 1,
#     'internal_count': 0,
#     'external_count': 1,
#     'internal_links': [],
#     'external_links': ['https://opencode.ai']}}],
#  'duplicate_titles': [],
#  'duplicate_descriptions': [],
#  'issues': ['/home/kobo/Desktop/obsidian_valuts/logseq/karem-site/blog/feed.qmd: Content too short'],
#  'summary': {'total_issues': 1,
#   'duplicate_titles_count': 0,
#   'duplicate_descriptions_count': 0}}
