# %%
# | default_exp seo_report

# %%
# | export
from sqlmodel import Session, select
from seo_rat.article import get_article_by_path, insert_article, Article
from seo_rat.sqlite_db import SQLiteDB
from seo_rat.models import Website
from seo_rat.content_mapper import map_all_urls_to_files,fetch_sitemap_urls
from seo_rat.content_parser import (
    parse_metadata,
    parse_notebook_metadata,
    remove_metadata,
    extract_headers,
    extract_images,
    extract_links,
    filter_external_links,
    filter_internal_links,
    check_desc_length,
    check_content_length,
    check_title_length,
    imgs_missing_alts,
    extract_notebook_content,
)
from seo_rat.seo_content_analysis import check_h1_count,check_keyword_placement

# %%
# | export
def sync_articles_to_db(
    session: Session, website_id: int, url_file_mapping: dict[str, str]
):
    """Insert all articles into database"""
    for url, file_path in url_file_mapping.items():
        if file_path:  # Only if file exists
            # Check if already exists
            existing = get_article_by_path(session, file_path)
            if not existing:
                insert_article(session, website_id, file_path,url=url)

# %%
# | hide
#| eval: false
from dotenv import load_dotenv
import os

db = SQLiteDB()
load_dotenv()
# BASE_PATH = os.environ["SEO_RAT_BASE_PATH"]
BASE_PATH = os.environ["AWAZLY_PATH"]

# %%
#| eval: false
#| hide
with db.get_session() as session:
    websites = session.exec(select(Website)).all()
    for w in websites:
        print(f"ID: {w.id}, URL: {w.url}")

    urls = fetch_sitemap_urls("https://awazly.com/sitemap.xml")
    url_mapping = map_all_urls_to_files(
                            base_path=f"{BASE_PATH}",
                            site_url="https://awazly.com/",
                            urls=urls,
                            use_slug_index=True
                        )

    sync_articles_to_db(session, website_id=1, url_file_mapping=url_mapping)
    articles = session.exec(select(Article)).all()
    for article in articles:
        print(article)
# Out:
# ID: 1, URL: https://awazly.com
# focus_keyword='طريقة تنظيف سيراميك الباركيه من البويه' id=1 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 457544) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_الدوادمي.md' target_goal=None url='https://awazly.com/malm-dhanat-aldwadmy'
# focus_keyword='معلم دهانات' id=2 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 469077) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_كفر_الشيخ.md' target_goal=None url='https://awazly.com/malm-dhanat-kfr-alshykh'
# focus_keyword='تنظيف قماش الخيش للكنب' id=3 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 477981) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/غسيل_كنب_بالدوادمي.md' target_goal=None url='https://awazly.com/ghsyl-knb-baldwadmy'
# focus_keyword='قوالب البناء' id=4 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 487074) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/الخرسانة_المعزولة.md' target_goal=None url='https://awazly.com/alkhrsanh-almazwlh'
# focus_keyword='الثقب الافقي' id=5 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 495999) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/الثقب_الأفقي.md' target_goal=None url='https://awazly.com/althqb-alafqy'
# focus_keyword='كشف الرطوبة بالجدران' id=6 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 505378) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_تسربات_المياه_بمكة.md' target_goal=None url='https://awazly.com/kshf_tsrbat_almyah_bmkh'
# focus_keyword='شركة كشف تسربات المياه صلالة عمان' id=7 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 513982) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_تسربات_المياه_في_مسقط.md' target_goal=None url='https://awazly.com/kshf-tsrbat-almyah-fy-msqt'
# focus_keyword='معلم دهانات جوتن' id=8 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 522418) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_بجدة.md' target_goal=None url='https://awazly.com/malm-dhanat-bjdh'
# focus_keyword='سباك بالمدينة المنورة' id=9 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 531124) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بالمدينة.md' target_goal=None url='https://awazly.com/sbak_balmdynh'
# focus_keyword='شركة عزل اسطح بمكة' id=10 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 540030) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بمكة.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-bmkh'
# focus_keyword='شركة عزل فوم بالاحساء' id=11 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 550852) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_فوم_بالاحساء.md' target_goal=None url='https://awazly.com/shrkh-azl-fwm-balahsaa'
# focus_keyword='شركة كشف تسربات المياه بالدوادمي' id=12 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 559552) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_كشف_تسربات_الدوادمي.md' target_goal=None url='https://awazly.com/shrkh-kshf-tsrbat-aldwadmy'
# focus_keyword='شركة تنظيف منازل رخيصة الكويت' id=13 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 568415) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_تنظيف_منازل_الكويت.md' target_goal=None url='https://awazly.com/shrkh-tnzyf-mnazl-alkwyt'
# focus_keyword='سعر لوح البورديوم' id=14 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 576660) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/بورديوم.md' target_goal=None url='https://awazly.com/bwrdywm'
# focus_keyword='سعر جي ار سي للواجهات' id=15 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 585128) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تركيب_جي_ار_سي.md' target_goal=None url='https://awazly.com/trkyb-jy-ar-sy'
# focus_keyword='شركات نقل الموبيليا فى القاهرة' id=16 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 593958) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_القاهرة.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-fy-alqahrh'
# focus_keyword='شركة عزل اسطح بمسقط عمان' id=17 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 602691) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بمسقط.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-bmsqt'
# focus_keyword='شركة تمديد الغاز المركزي بجدة' id=18 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 611428) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تمديد_غاز_مركزي_بجدة.md' target_goal=None url='https://awazly.com/tmdyd-ghaz-mrkzy-bjdh'
# focus_keyword='شركة نقل عفش بالدوادمي' id=19 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 620114) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_بالدوادمي.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-baldwadmy'
# focus_keyword='نقل عفش بالخبر' id=20 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 629322) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_الخبر.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-fy-alkhbr'
# focus_keyword='شركة نقل عفش بالقصيم' id=21 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 637437) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_القصيم.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-fy-alqsym'
# focus_keyword='المميز صفوى' id=22 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 646252) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_صفوي.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-sfwy'
# focus_keyword='شركة عزل اسطح بتبوك' id=23 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 655146) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بتبوك.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-btbwk'
# focus_keyword='شركة كشف تسربات المياه بالمدينة المنورة' id=24 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 664215) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_كشف_تسربات_المياه_بالمدينة_المنورة.md' target_goal=None url='https://awazly.com/shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh'
# focus_keyword='شركة نقل عفش بالمدينة المنورة تويتر' id=25 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 672759) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_بالمدينة_المنورة.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh'
# focus_keyword='شركة نقل اثاث بالجبيل' id=26 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 680944) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_الجبيل.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-fy-aljbyl'
# focus_keyword='شركة نقل عفش جازان' id=27 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 689790) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_جازان.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-fy-jazan'
# focus_keyword='المقابل المالي للفحص' id=28 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 700419) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/احتيال_الفحص_الفني.md' target_goal=None url='https://awazly.com/ahtyal-alfhs-alfny'
# focus_keyword='أسعار عازل الصوت للغرف' id=29 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 709319) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عازل_صوت_بالمدينة_المنورة.md' target_goal=None url='https://awazly.com/aazl_swt_balmdynh_almnwrh'
# focus_keyword='شركة كشف تسربات المياه بجازان' id=30 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 718336) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_تسربات_المياه_بجازان.md' target_goal=None url='https://awazly.com/kshf-tsrbat-almyah-bjazan'
# focus_keyword='اسطوانة غاز فايبر' id=31 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 726880) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/اسطوانة_الغاز_الفايبر.md' target_goal=None url='https://awazly.com/astwanh-alghaz-alfaybr'
# focus_keyword='نقل عفش المنطقه العاشره' id=32 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 735312) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_بالكويت.md' target_goal=None url='https://awazly.com/shrkh-nql-afsh-balkwyt'
# focus_keyword='عازل اسطح' id=33 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 743230) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عازل_اسطح_الكويت.md' target_goal=None url='https://awazly.com/aazl-asth-alkwyt'
# focus_keyword='كشف خرير المياه' id=34 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 751522) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_خرير_المياه_الكويت.md' target_goal=None url='https://awazly.com/kshf-khryr-almyah-alkwyt'
# focus_keyword='كهربائي بالمدينة المنورة' id=35 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 760256) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كهربائي_منازل_المدينة_المنورة.md' target_goal=None url='https://awazly.com/khrbaey-mnazl-almdynh-almnwrh'
# focus_keyword='شركة كشف تسربات المياه بالدوادمي' id=36 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 770310) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بالدوادمي.md' target_goal=None url='https://awazly.com/sbak-baldwadmy'
# focus_keyword='اسعار عزل الايبوكسي' id=37 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 779061) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تركيب_ايبوكسي_المدينة_المنورة.md' target_goal=None url='https://awazly.com/trkyb-aybwksy-almdynh-almnwrh'
# focus_keyword='كورنيش الخبر' id=38 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 788081) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/افضل_معالم_مدينة_الخبر.md' target_goal=None url='https://awazly.com/afdhl-maalm-mdynh-alkhbr'
# focus_keyword='شركة هياكل فولاذية في السعودية' id=39 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 796460) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تقنيات_البناء_الحديثة.md' target_goal=None url='https://awazly.com/tqnyat-albnaa-alhdythh'
# focus_keyword='ايبوكسي ارضيات جوتن' id=40 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 805274) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تركيب_ايبوكسي_جدة.md' target_goal=None url='https://awazly.com/trkyb-aybwksy-jdh'
# focus_keyword='شركة عزل بولي يوريا بجدة' id=41 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 814645) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/العزل_المائي_والحراري_للخرسانة.md' target_goal=None url='https://awazly.com/alazl-almaey-walhrary-llkhrsanh'
# focus_keyword='شركة عزل بولي يوريا بجدة' id=42 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 824068) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عزل_مائي_بولي_يوريا.md' target_goal=None url='https://awazly.com/azl-maey-bwly-ywrya'
# focus_keyword='فني بويه' id=43 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 834289) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_بالرياض.md' target_goal=None url='https://awazly.com/malm-dhanat-balryadh'
# focus_keyword='سباك الرياض تركيب وتأسيس وصيانة السباكه' id=44 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 843753) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بالرياض.md' target_goal=None url='https://awazly.com/sbak_balryadh'
# focus_keyword='شركة عزل اسطح بمسقط عمان' id=45 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 853429) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بالرياض.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-balryadh'
# focus_keyword='دهان ايبوكسي بالرياض' id=46 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 861952) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_ايبوكسي_ارضيات_بالرياض.md' target_goal=None url='https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh'
# focus_keyword=None id=47 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 872044) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_خزانات_بالرياض.md' target_goal=None url='https://awazly.com/shrkh-azl-khzanat-balryadh'
# focus_keyword='عزل بولي يوريثان فوم' id=48 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 881972) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/طريقة_رش_البولي_يوريثان_فوم.md' target_goal=None url='https://awazly.com/tryqh-rsh-albwly-ywrythan-fwm'
# focus_keyword='كهربائى بجده' id=49 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 893113) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كهربائي_منازل_بجدة.md' target_goal=None url='https://awazly.com/khrbaey-mnazl-bjdh'
# focus_keyword='معلم كهربائي بمكة' id=50 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 904438) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كهربائي_منازل_بمكة_المكرمة.md' target_goal=None url='https://awazly.com/khrbaey-mnazl-bmkh-almkrmh'
# focus_keyword='معلم دهان بمكة' id=51 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 916234) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_بمكة_المكرمة.md' target_goal=None url='https://awazly.com/malm-dhanat-bmkh-almkrmh'
# focus_keyword='مشروع الرياض الخضراء' id=52 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 926395) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/الرياض_الخضراء.md' target_goal=None url='https://awazly.com/alryadh-alkhdhraa'
# focus_keyword=None id=53 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 936699) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/السعودية_الخضراء.md' target_goal=None url='https://awazly.com/alsawdyh-alkhdhraa'
# focus_keyword=None id=54 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 947427) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/الطاقة_المتجددة_في_السعودية.md' target_goal=None url='https://awazly.com/altaqh-almtjddh-fy-alsawdyh'
# focus_keyword='طلب تشجير من البلدية' id=55 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 957635) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تشجير_المدينة_المنورة.md' target_goal=None url='https://awazly.com/tshjyr-almdynh-almnwrh'
# focus_keyword='شركة تنظيف كنب بجدة' id=56 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 969833) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/غسيل_كنب_بجدة.md' target_goal=None url='https://awazly.com/ghsyl-knb-bjdh'
# focus_keyword='شركة تنظيف كنب بمكة' id=57 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 980716) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/غسيل_كنب_بمكة_المكرمة.md' target_goal=None url='https://awazly.com/ghsyl-knb-bmkh-almkrmh'
# focus_keyword='معلم لياسة بالمدينة المنورة' id=58 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 990862) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_لياسة_المدينة_المنورة.md' target_goal=None url='https://awazly.com/malm-lyash-almdynh-almnwrh'
# focus_keyword='جهاز لرش الاسطح' id=59 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 953) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/أفضل_ماكينات_رش_وحقن_بولي_يوريثان_فوم.md' target_goal=None url='https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm'
# focus_keyword='سعر عزل فوم بولي يوريثان' id=60 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 10645) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/بولي_يوريثان_فوم.md' target_goal=None url='https://awazly.com/bwly-ywrythan-fwm'
# focus_keyword='شركة لحام خزانات الفيبر جلاس بجدة' id=61 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 19496) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/افضل_أنواع_خزانات_المياه_للمنازل.md' target_goal=None url='https://awazly.com/afdhl-anwaa-khzanat-almyah-llmnazl'
# focus_keyword='أنواع السباكة' id=62 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 28446) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/افضل_مواسير_السباكة.md' target_goal=None url='https://awazly.com/afdhl-mwasyr-alsbakh'
# focus_keyword='شركة عزل خزانات المياه بجدة' id=63 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 38843) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عزل_خزانات_المياه_بجدة.md' target_goal=None url='https://awazly.com/azl_khzanat_almyah_bjdh'
# focus_keyword='شركة عزل خزانات بمكة' id=64 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 48078) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عزل_خزانات_مكة.md' target_goal=None url='https://awazly.com/azl_khzanat_mkh'
# focus_keyword='معلم لياسة بالرياض' id=65 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 56828) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_لياسة_الرياض.md' target_goal=None url='https://awazly.com/malm_lyash_alryadh'
# focus_keyword='معلم لياسة بمكة' id=66 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 66332) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_لياسة_بمكة.md' target_goal=None url='https://awazly.com/malm-lyash-bmkh'
# focus_keyword='مليس بجدة' id=67 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 75389) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_لياسة_جدة.md' target_goal=None url='https://awazly.com/malm-lyash-jdh'
# focus_keyword='ايبوكسي ارضيات جوتن' id=68 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 84582) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تركيب_ايبوكسي_بمكة.md' target_goal=None url='https://awazly.com/trkyb-aybwksy-bmkh'
# focus_keyword='غسيل كنب بالمدينة المنورة' id=69 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 93186) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/غسيل_كنب_بالمدينة_المنورة.md' target_goal=None url='https://awazly.com/ghsyl-knb-balmdynh-almnwrh'
# focus_keyword='شركة عزل اسطح بالدوادمي' id=70 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 102944) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بالدوادمي.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-baldwadmy'
# focus_keyword='شركة عزل اسطح بجدة' id=71 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 111650) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بجدة.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-bjdh'
# focus_keyword='شركة عزل فوم بالدمام' id=72 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 121169) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_فوم_بالدمام.md' target_goal=None url='https://awazly.com/shrkh-azl-fwm-baldmam'
# focus_keyword='شركة عزل اسطح بالقطيف' id=73 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 131830) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_فوم_بالقطيف.md' target_goal=None url='https://awazly.com/shrkh-azl-fwm-balqtyf'
# focus_keyword='شركة عزل فوم بالطائف' id=74 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 140911) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_فوم_بالطائف.md' target_goal=None url='https://awazly.com/shrkh-azl-fwm-baltaef'
# focus_keyword='معلم دهانات بالمدينة المنورة' id=75 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 149557) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_بالمدينة_المنورة.md' target_goal=None url='https://awazly.com/malm-dhanat-balmdynh-almnwrh'
# focus_keyword='شركة عزل اسطح بالمدينة المنورة' id=76 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 159211) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بالمدينة.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-balmdynh'
# focus_keyword='شركة عزل فوم بابها' id=77 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 168034) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بعسير.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-basyr'
# focus_keyword='شركة عزل اسطح بجازان' id=78 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 177095) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بجازان.md' target_goal=None url='https://awazly.com/shrkh-azl-asth-bjazan'
# focus_keyword='شركة تنسيق حدائق بالمدينة المنورة' id=79 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 186031) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تنسيق_حدائق_المدينة_المنورة.md' target_goal=None url='https://awazly.com/tnsyq-hdaeq-almdynh-almnwrh'
# focus_keyword='تمديد غاز مركزي' id=80 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 195097) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تمديد_غاز_مركزي_بالمدينة_المنورة.md' target_goal=None url='https://awazly.com/tmdyd-ghaz-mrkzy-balmdynh-almnwrh'
# focus_keyword='ترميم منازل بالرياض' id=81 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 204489) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_ترميم_منازل_بالرياض.md' target_goal=None url='https://awazly.com/shrkh-trmym-mnazl-balryadh'
# focus_keyword='كشف تسربات المياه بالرياض' id=82 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 213345) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_كشف_تسربات_المياه_بالرياض.md' target_goal=None url='https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'
# focus_keyword='شركة كشف تسربات المياه بجدة' id=83 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 223451) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_كشف_تسربات_المياه_بجدة.md' target_goal=None url='https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh'
# focus_keyword='صيانة سباكة منازل بجدة' id=84 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 232305) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بجدة.md' target_goal=None url='https://awazly.com/sbak_bjdh'
# focus_keyword='سباك مكة' id=85 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 246926) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بمكة_.md' target_goal=None url='https://awazly.com/sbak_bmkh_'
# focus_keyword='شركة ترميم حمامات بمكة' id=86 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 256846) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_ترميم_مباني_في_مكة.md' target_goal=None url='https://awazly.com/shrkh_trmym_mbany_fy_mkh'
# focus_keyword='شركة تمديد الغاز المركزي بجدة' id=87 created_at=datetime.datetime(2026, 3, 29, 1, 29, 27, 266672) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تمديد_الغاز_المركزي_بمكة_عوازلي.md' target_goal=None url='https://awazly.com/tmdyd-alghaz-almrkzy-bmkh-awazly'

# %%
# | export


def find_duplicate_metadata(
    session: Session, field: str,website_id:int, similarity_threshold: float = 0.9,
) -> list[dict]:
    """Find pages with duplicate or very similar metadata fields"""
    from seo_rat.content_parser import parse_metadata, calculate_similarity

    articles = session.exec(select(Article).where(Article.website_id==website_id)).all()
    values = {}

    # Collect all field values
    for article in articles:
        with open(article.file_path, "r") as f:
            if article.file_path.endswith(".ipynb"):
                metadata = parse_notebook_metadata(f.read())
                values[article.file_path] = metadata.get(field, "")
            elif article.file_path.endswith(".md") or article.file_path.endswith(
                ".qmd"
            ):
                metadata = parse_metadata(f.read())
                values[article.file_path] = metadata.get(field, "")

    # Find duplicates
    duplicates = []
    checked = set()

    for path1, field1 in values.items():
        for path2, field2 in values.items():
            if path1 >= path2 or (path1, path2) in checked:
                continue
            if not field1 or not field2:
                continue


            similarity = calculate_similarity(field1, field2)
            if similarity >= similarity_threshold:
                duplicates.append(
                    {
                        "file1": path1,
                        "file2": path2,
                        f"{field}_1": field1,
                        f"{field}_2": field2,
                        "similarity": similarity,
                    }
                )
            checked.add((path1, path2))

    return duplicates

# %%
#| hide
from seo_rat.models import Website
from seo_rat.gsc_storage import GSCAnalytics,func
session.exec(select(Website)).all()
session.exec(
    select(GSCAnalytics.site_url, func.count().label("rows"))
    .group_by(GSCAnalytics.site_url)
).all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 from seo_rat.models import Website
#       3 from seo_rat.gsc_storage import GSCAnalytics,func
# ----> 4 session.exec(select(Website)).all()
#       5 session.exec(
#       6     select(GSCAnalytics.site_url, func.count().label("rows"))
#       7     .group_by(GSCAnalytics.site_url)
#       8 ).all()
#
# NameError: name 'session' is not defined

# %%
# | hide
website = Website(url="https://awazly.com", name="Awazly",lang="ar",desc="موقع متخصص لخدمات العوازل وخدمات المنازل في السعودية تحديدا وبعض خدمات في مصر والكويت و الإمارات")
with db.get_session() as session:
    session.add(website)
    session.commit()
    session.refresh(website)
    print(website.id)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: website.url
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[7], line 5
#       3 with db.get_session() as session:
#       4     session.add(website)
# ----> 5     session.commit()
#       6     session.refresh(website)
#       7     print(website.id)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1311, in SessionTransaction.commit(self, _to_root)
#    1309 if self._state is not SessionTransactionState.PREPARED:
#    1310     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1311         self._prepare_impl()
#    1313 if self._parent is None or self.nested:
#    1314     for conn, trans, should_commit, autoclose in set(
#    1315         self._connections.values()
#    1316     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1286, in SessionTransaction._prepare_impl(self)
#    1284     if self.session._is_clean():
#    1285         break
# -> 1286     self.session.flush()
#    1287 else:
#    1288     raise exc.FlushError(
#    1289         "Over 100 subsequent flushes have occurred within "
#    1290         "session.commit() - is an after_flush() hook "
#    1291         "creating new objects?"
#    1292     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4331, in Session.flush(self, objects)
#    4329 try:
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#    4333     self._flushing = False
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4466, in Session._flush(self, objects)
#    4463     transaction.commit()
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4427, in Session._flush(self, objects)
#    4425 self._warn_on_events = True
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#    4429     self._warn_on_events = False
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)     90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)    119     ),
#     120 )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: website.url
# [SQL: INSERT INTO website (url, name, "desc", lang, created_at) VALUES (?, ?, ?, ?, ?)]
# [parameters: ('https://awazly.com', 'Awazly', 'موقع متخصص لخدمات العوازل وخدمات المنازل في السعودية تحديدا وبعض خدمات في مصر والكويت و الإمارات', 'ar', '2026-03-31 01:26:14.292537')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# ## Make FocusKeyword to be Top query from GSC

# %%
#| export 
from seo_rat.gsc_storage import get_top_queries
from seo_rat.article import  get_articles_by_website
from seo_rat.gsc_client import get_date_range
from seo_rat.seo_content_analysis import   check_keyword_placement, content_freshness
from seo_rat.gsc_insights import find_missing_queries

# %%
#| export
path = "https://awazly.com/malm-dhanat-aldwadmy"
website_name="https://awazly.com/"

start, end = get_date_range("last_days", days=90*8)
print(start, end)

with db.get_session() as session:
    articles = get_articles_by_website(session, website_id=1)
    for article in articles: 
        page_path= article.url.removeprefix(website_name)
        print(page_path)
        top_query = get_top_queries(session=session,site_url="sc-domain:awazly.com",start_date=start,end_date=end,page_path=page_path,limit=1,sort_by="impressions")
        top_5_query = get_top_queries(session=session,site_url="sc-domain:awazly.com",start_date=start,end_date=end,page_path=page_path,limit=5,sort_by="impressions")
        try:
            print(top_query[0]['query'])
            article.focus_keyword = top_query[0]['query']
            article.secondary_keywords = [q["query"] for q in top_5_query[:5]]
            session.add(article)
            session.commit()
        except IndexError:
            print("No queries found for this page")
# Out:
# 2024-04-07 2026-03-28
# malm-dhanat-aldwadmy
# طريقة تنظيف سيراميك الباركيه من البويه
# malm-dhanat-kfr-alshykh
# معلم دهانات
# ghsyl-knb-baldwadmy
# تنظيف قماش الخيش للكنب
# alkhrsanh-almazwlh
# قوالب البناء
# althqb-alafqy
# الثقب الافقي
# kshf_tsrbat_almyah_bmkh
# كشف الرطوبة بالجدران
# kshf-tsrbat-almyah-fy-msqt
# شركة كشف تسربات المياه صلالة عمان
# malm-dhanat-bjdh
# معلم دهانات جوتن
# sbak_balmdynh
# سباك بالمدينة المنورة
# shrkh-azl-asth-bmkh
# شركة عزل اسطح بمكة
# shrkh-azl-fwm-balahsaa
# شركة عزل فوم بالاحساء
# shrkh-kshf-tsrbat-aldwadmy
# شركة كشف تسربات المياه بالدوادمي
# shrkh-tnzyf-mnazl-alkwyt
# شركة تنظيف منازل رخيصة الكويت
# bwrdywm
# سعر لوح البورديوم
# trkyb-jy-ar-sy
# سعر جي ار سي للواجهات
# shrkh-nql-afsh-fy-alqahrh
# شركات نقل الموبيليا فى القاهرة
# shrkh-azl-asth-bmsqt
# شركة عزل اسطح بمسقط عمان
# tmdyd-ghaz-mrkzy-bjdh
# شركة تمديد الغاز المركزي بجدة
# shrkh-nql-afsh-baldwadmy
# شركة نقل عفش بالدوادمي
# shrkh-nql-afsh-fy-alkhbr
# نقل عفش بالخبر
# shrkh-nql-afsh-fy-alqsym
# شركة نقل عفش بالقصيم
# shrkh-nql-afsh-sfwy
# المميز صفوى
# shrkh-azl-asth-btbwk
# شركة عزل اسطح بتبوك
# shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh
# شركة كشف تسربات المياه بالمدينة المنورة
# shrkh-nql-afsh-balmdynh-almnwrh
# شركة نقل عفش بالمدينة المنورة تويتر
# shrkh-nql-afsh-fy-aljbyl
# شركة نقل اثاث بالجبيل
# shrkh-nql-afsh-fy-jazan
# شركة نقل عفش جازان
# ahtyal-alfhs-alfny
# المقابل المالي للفحص
# aazl_swt_balmdynh_almnwrh
# أسعار عازل الصوت للغرف
# kshf-tsrbat-almyah-bjazan
# شركة كشف تسربات المياه بجازان
# astwanh-alghaz-alfaybr
# اسطوانة غاز فايبر
# shrkh-nql-afsh-balkwyt
# نقل عفش المنطقه العاشره
# aazl-asth-alkwyt
# عازل اسطح
# kshf-khryr-almyah-alkwyt
# كشف خرير المياه
# khrbaey-mnazl-almdynh-almnwrh
# كهربائي بالمدينة المنورة
# sbak-baldwadmy
# شركة كشف تسربات المياه بالدوادمي
# trkyb-aybwksy-almdynh-almnwrh
# اسعار عزل الايبوكسي
# afdhl-maalm-mdynh-alkhbr
# كورنيش الخبر
# tqnyat-albnaa-alhdythh
# شركة هياكل فولاذية في السعودية
# trkyb-aybwksy-jdh
# ايبوكسي ارضيات جوتن
# alazl-almaey-walhrary-llkhrsanh
# شركة عزل بولي يوريا بجدة
# azl-maey-bwly-ywrya
# شركة عزل بولي يوريا بجدة
# malm-dhanat-balryadh
# فني بويه
# sbak_balryadh
# سباك الرياض تركيب وتأسيس وصيانة السباكه
# shrkh-azl-asth-balryadh
# شركة عزل اسطح بمسقط عمان
# shrkh-azl-aybwksy-ardhyat-balryadh
# دهان ايبوكسي بالرياض
# shrkh-azl-khzanat-balryadh
# No queries found for this page
# tryqh-rsh-albwly-ywrythan-fwm
# عزل بولي يوريثان فوم
# khrbaey-mnazl-bjdh
# كهربائى بجده
# khrbaey-mnazl-bmkh-almkrmh
# معلم كهربائي بمكة
# malm-dhanat-bmkh-almkrmh
# معلم دهان بمكة
# alryadh-alkhdhraa
# مشروع الرياض الخضراء
# alsawdyh-alkhdhraa
# No queries found for this page
# altaqh-almtjddh-fy-alsawdyh
# No queries found for this page
# tshjyr-almdynh-almnwrh
# طلب تشجير من البلدية
# ghsyl-knb-bjdh
# شركة تنظيف كنب بجدة
# ghsyl-knb-bmkh-almkrmh
# شركة تنظيف كنب بمكة
# malm-lyash-almdynh-almnwrh
# معلم لياسة بالمدينة المنورة
# afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm
# جهاز لرش الاسطح
# bwly-ywrythan-fwm
# سعر عزل فوم بولي يوريثان
# afdhl-anwaa-khzanat-almyah-llmnazl
# شركة لحام خزانات الفيبر جلاس بجدة
# afdhl-mwasyr-alsbakh
# أنواع السباكة
# azl_khzanat_almyah_bjdh
# شركة عزل خزانات المياه بجدة
# azl_khzanat_mkh
# شركة عزل خزانات بمكة
# malm_lyash_alryadh
# معلم لياسة بالرياض
# malm-lyash-bmkh
# معلم لياسة بمكة
# malm-lyash-jdh
# مليس بجدة
# trkyb-aybwksy-bmkh
# ايبوكسي ارضيات جوتن
# ghsyl-knb-balmdynh-almnwrh
# غسيل كنب بالمدينة المنورة
# shrkh-azl-asth-baldwadmy
# شركة عزل اسطح بالدوادمي
# shrkh-azl-asth-bjdh
# شركة عزل اسطح بجدة
# shrkh-azl-fwm-baldmam
# شركة عزل فوم بالدمام
# shrkh-azl-fwm-balqtyf
# شركة عزل اسطح بالقطيف
# shrkh-azl-fwm-baltaef
# شركة عزل فوم بالطائف
# malm-dhanat-balmdynh-almnwrh
# معلم دهانات بالمدينة المنورة
# shrkh-azl-asth-balmdynh
# شركة عزل اسطح بالمدينة المنورة
# shrkh-azl-asth-basyr
# شركة عزل فوم بابها
# shrkh-azl-asth-bjazan
# شركة عزل اسطح بجازان
# tnsyq-hdaeq-almdynh-almnwrh
# شركة تنسيق حدائق بالمدينة المنورة
# tmdyd-ghaz-mrkzy-balmdynh-almnwrh
# تمديد غاز مركزي
# shrkh-trmym-mnazl-balryadh
# ترميم منازل بالرياض
# shrkh-kshf-tsrbat-almyah-balryadh
# كشف تسربات المياه بالرياض
# shrkh-kshf-tsrbat-almyah-bjdh
# شركة كشف تسربات المياه بجدة
# sbak_bjdh
# صيانة سباكة منازل بجدة
# sbak_bmkh_
# سباك مكة
# shrkh_trmym_mbany_fy_mkh
# شركة ترميم حمامات بمكة
# tmdyd-alghaz-almrkzy-bmkh-awazly
# شركة تمديد الغاز المركزي بجدة

# %%
# | export
def analyze_links(content: str, domain: str) -> dict:
    """Analyze internal and external links in content"""
    links = extract_links(content)
    all_urls = list(links.keys())

    internal = filter_internal_links(all_urls, domain)
    external = filter_external_links(all_urls, domain)

    return {
        "total_links": len(all_urls),
        "internal_count": len(internal),
        "external_count": len(external),
        "internal_links": internal,
        "external_links": external,
    }

# %%
# | test
#| eval: false

from seo_rat.content_parser import remove_metadata
with db.get_session() as session:
    article = session.exec(select(Article)).first()
    print(article)
    with open(article.file_path, "r") as f:
        content = remove_metadata(f.read())

link_analysis = analyze_links(content, "awazly.com")
print(link_analysis)

print(f"Total: {link_analysis['total_links']}")
print(f"Internal: {link_analysis['internal_count']}")
print(f"External: {link_analysis['external_count']}")
# Out:
# focus_keyword='طريقة تنظيف سيراميك الباركيه من البويه' id=1 created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 457544) last_optimized=None secondary_keywords=None website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_الدوادمي.md' target_goal=None url='https://awazly.com/malm-dhanat-aldwadmy'
# {'total_links': 5, 'internal_count': 5, 'external_count': 0, 'internal_links': ['https://awazly.com/trkyb-aybwksy-almdynh-almnwrh', 'https://awazly.com/trkyb-aybwksy-bmkh', 'https://awazly.com/trkyb-aybwksy-jdh', 'https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh', 'https://awazly.com/malm-dhanat-balryadh'], 'external_links': []}
# Total: 5
# Internal: 5
# External: 0

# %%
# | export
def check_heading_structure(headers):
    ans = {}
    has_h2 = any(h["type"] == "h2" for h in headers)
    ans["has_h2"] = has_h2
    levels = [int(h["type"][1]) for h in headers]
    ans["skipped_levels"] = []

    for l in range(len(levels) - 1):
        if levels[l + 1] - levels[l] > 1:
            ans["skipped_levels"].append({"from": headers[l], "to": headers[l + 1]})

    return ans

# %%
# | export
def analyze_article(
    article: Article,
    domain: str,
    is_quarto: bool,
    title_is_h1: bool = False,
    desc_field: str = "description",
    title_field: str = "title",
    date_field: str = "date"
) -> dict:
    """Run all SEO checks for a single article and return its report dict"""
    with open(article.file_path, "r") as f:
        raw_content = f.read()

    if article.file_path.endswith(".ipynb"):
        metadata = parse_notebook_metadata(raw_content)
        content = extract_notebook_content(raw_content, is_quarto=is_quarto)
    else:
        metadata = parse_metadata(raw_content)
        content = remove_metadata(raw_content)

    headers = extract_headers(article.file_path)
    images = extract_images(content)


    return {
        "file_path": article.file_path,
        "title_check": check_title_length(metadata.get(title_field, "")),
        "description_check": check_desc_length(metadata.get(desc_field, "")),
        "content_check": check_content_length(content),
        "h1_check": check_h1_count(
            headers, title=metadata.get("title", ""), title_is_h1=title_is_h1
        ),
        "missing_alts": imgs_missing_alts(images),
        "link_analysis": analyze_links(content, domain),
        "keyword_placement": check_keyword_placement(
            article.focus_keyword,
            metadata=metadata,
            headers=headers,
            content=content,
            url=article.url,
            desc_field=desc_field,
            title_is_h1=title_is_h1,
        ),
        "content_freshness": content_freshness(metadata.get(date_field, "")),
        "content_structure": check_heading_structure(headers),
    }

# %%
# | export
def generate_seo_report(
    session: Session,
    website_id: int,
    domain: str,
    is_quarto: bool,
    title_is_h1: bool = False,
    desc_field: str = "description",
    title_field: str = "title",
    date_field: str = "date",
) -> dict:
    """Generate comprehensive SEO report for all pages"""

    articles = session.exec(
        select(Article).where(Article.website_id == website_id)
    ).all()

    page_reports = []
    issues = {}
    start, end = get_date_range("last_days", days=90 * 8)

    for article in articles:
        try:
            report = analyze_article(
                article,
                domain,
                is_quarto,
                title_is_h1=title_is_h1,
                desc_field=desc_field,
                title_field=title_field,
                date_field=date_field,
            )

            queries = get_top_queries(
                session=session,
                site_url=f"sc-domain:{domain}",
                start_date=start,
                end_date=end,
                page_path=article.url.removeprefix(f"https://{domain}/"),
                limit=500,
                sort_by="impressions",
            )
            content = remove_metadata(open(article.file_path, "r").read())
            missing_queries = find_missing_queries(queries=queries, content=content)

            page_issues = []

            if not report["h1_check"]["has_single_h1"]:
                page_issues.append("Multiple or no H1")
            if not report["content_check"]["is_sufficient"]:
                page_issues.append("Content too short")
            if report["link_analysis"]["internal_count"] == 0:
                page_issues.append("No internal links, at least 3 recommended")
            if report["link_analysis"]["external_count"] == 0:
                page_issues.append("No external links")
            if report["missing_alts"]:
                page_issues.append(f"Images missing alt text ({len(report['missing_alts'])})")
            if report["content_structure"]["skipped_levels"]:
                for skip in report["content_structure"]["skipped_levels"]:
                    page_issues.append(
                        f"Skipped heading: {skip['from']['type']} → {skip['to']['type']} (line {skip['to']['line_number']})"
                    )
            if not report["content_structure"]["has_h2"]:
                page_issues.append("No H2 headings, at least one recommended")

            tc = report["title_check"]
            if tc["status"] != "optimal":
                page_issues.append(f"Title {tc['status']} ({tc['length']} chars, range {tc['min']}-{tc['max']})")

            dc = report["description_check"]
            if dc["status"] != "optimal":
                page_issues.append(f"Description {dc['status']} ({dc['length']} chars, range {dc['min']}-{dc['max']})")

            if not report["content_freshness"]["is_fresh"]:
                page_issues.append(f"Stale content ({report['content_freshness']['days_since_update']} days old)")

            if article.focus_keyword:
                if not report["keyword_placement"]["in_h1"]:
                    page_issues.append("Focus keyword not in H1")
                if not report["keyword_placement"]["keyword_in_meta"]["in_description"]:
                    page_issues.append("Focus keyword not in description")
                if not report["keyword_placement"]["keyword_in_meta"]["in_title"]:
                    page_issues.append("Focus keyword not in title")
                if not report["keyword_placement"]["keyword_at_first"]:
                    page_issues.append("Focus keyword not in first 100 words")

            if page_issues or missing_queries:
                issues[article.url or article.file_path] = {
                    "file_path": article.file_path,
                    "issues": page_issues,
                    "data": {
                        "missing_queries": missing_queries,
                        "keyword_placement": report.get("keyword_placement", {}),
                    }
                }

            page_reports.append(report)

        except Exception as e:
            print(f"Error analyzing {article.file_path}: {e}")

    duplicate_titles = find_duplicate_metadata(
        session, "title", website_id=website_id, similarity_threshold=0.9
    )
    duplicate_descriptions = find_duplicate_metadata(
        session, "description", website_id=website_id, similarity_threshold=0.9
    )

    total_issues = sum(len(v["issues"]) for v in issues.values())

    return {
        "total_pages": len(articles),
        "pages_analyzed": len(page_reports),
        "page_reports": page_reports,
        "duplicate_titles": duplicate_titles,
        "duplicate_descriptions": duplicate_descriptions,
        "issues": issues,
        "summary": {
            "total_issues": total_issues,
            "pages_with_issues": len(issues),
            "duplicate_titles_count": len(duplicate_titles),
            "duplicate_descriptions_count": len(duplicate_descriptions),
        },
    }

# %%
# | export
def print_issues_report(report: dict) -> None:
    """Print SEO issues sorted from most issues to fewest."""
    issues = report["issues"]
    summary = report["summary"]

    print(f"Pages analysed : {report['pages_analyzed']} / {report['total_pages']}")
    print(f"Pages with issues: {summary['pages_with_issues']}")
    print(f"Total issue count: {summary['total_issues']}")
    print(f"Duplicate titles : {summary['duplicate_titles_count']}")
    print(f"Duplicate descs  : {summary['duplicate_descriptions_count']}")
    print("=" * 70)

    sorted_issues = sorted(issues.items(), key=lambda x: len(x[1]["issues"]), reverse=True)

    for url, data in sorted_issues:
        count = len(data["issues"])
        print(f"\n[{count} issue{'s' if count != 1 else ''}] {url}")
        for i, issue in enumerate(data["issues"], 1):
            print(f"  {i}. {issue}")
        
        missing = data.get("data", {}).get("missing_queries", [])
        if missing:
            print(f" Missing queries ({len(missing)}):")
            for q in missing:
                print(f"      - {q['query']} (clicks: {q['total_clicks']}, impressions: {q['total_impressions']}, pos: {q['avg_position']:.1f})")

# %%
#| hide
from seo_rat.content_parser import get_markdown_files
from seo_rat.article import get_articles_by_website

# %%
#| hide
articles = get_articles_by_website(session, website_id=1)
print(len(articles))
# Out:
# 87

# %%
#| hide
#| eval: false
report = generate_seo_report(session, website_id=1, domain="awazly.com",is_quarto=False,title_is_h1=True,desc_field="excerpt",date_field="publishDate",)
print(f"Total pages: {report['total_pages']}")
print(f"Issues found: {report['summary']['total_issues']}")
# Out:
# Total pages: 87
# Issues found: 326

# %%
# | hide
#| eval: false
report
# Out:
# {'total_pages': 87,
#  'pages_analyzed': 87,
#  'page_reports': [{'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_الدوادمي.md',
#    'title_check': {'length': 44, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 131,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2118, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 5,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/trkyb-aybwksy-almdynh-almnwrh',
#      'https://awazly.com/trkyb-aybwksy-bmkh',
#      'https://awazly.com/trkyb-aybwksy-jdh',
#      'https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh',
#      'https://awazly.com/malm-dhanat-balryadh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_كفر_الشيخ.md',
#    'title_check': {'length': 52, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 152,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1873, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 5,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/trkyb-aybwksy-almdynh-almnwrh',
#      'https://awazly.com/trkyb-aybwksy-bmkh',
#      'https://awazly.com/trkyb-aybwksy-jdh',
#      'https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh',
#      'https://awazly.com/malm-dhanat-aldwadmy'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/غسيل_كنب_بالدوادمي.md',
#    'title_check': {'length': 79, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 126,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 3868, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 7,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/malm-dhanat-aldwadmy',
#      'https://awazly.com/sbak-baldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-aldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/ghsyl-knb-bjdh',
#      'https://awazly.com/ghsyl-knb-bmkh-almkrmh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/الخرسانة_المعزولة.md',
#    'title_check': {'length': 87, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 215,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1370, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 4,
#     'internal_count': 4,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com',
#      'https://awazly.com/alazl-almaey-walhrary-llkhrsanh',
#      'https://awazly.com/trkyb-jy-ar-sy',
#      'https://awazly.com/tqnyat-albnaa-alhdythh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/الثقب_الأفقي.md',
#    'title_check': {'length': 76, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 211,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1868, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 2,
#     'internal_count': 2,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_تسربات_المياه_بمكة.md',
#    'title_check': {'length': 82, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 182,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2175, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 5,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/shrkh-kshf-tsrbat-aldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh',
#      'https://awazly.com/kshf-tsrbat-almyah-bjazan'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_تسربات_المياه_في_مسقط.md',
#    'title_check': {'length': 69, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 195,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1648, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 12,
#     'internal_count': 11,
#     'external_count': 1,
#     'internal_links': ['https://awazly.com',
#      'https://awazly.com/',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/sbak_balmdynh',
#      'https://awazly.com/synh-ammh-msqt',
#      'https://awazly.com/shrkh-kshf-tsrbat-aldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh',
#      'https://awazly.com/kshf-tsrbat-almyah-bjazan'],
#     'external_links': ['https://azlzone.com/shrkh_mkafhh_hshrat']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_بجدة.md',
#    'title_check': {'length': 55, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 152,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1428, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 19,
#     'internal_count': 11,
#     'external_count': 1,
#     'internal_links': ['https://awazly.com/ghsyl-knb-bjdh',
#      'https://awazly.com/khrbaey-mnazl-bjdh',
#      'https://awazly.com/ghsyl-knb-bmkh-almkrmh',
#      'https://awazly.com/khrbaey-mnazl-bmkh-almkrmh',
#      'https://awazly.com/malm-dhanat-balmdynh-almnwrh',
#      'https://awazly.com/malm-dhanat-bmkh-almkrmh',
#      'https://awazly.com/trkyb-aybwksy-almdynh-almnwrh',
#      'https://awazly.com/trkyb-aybwksy-bmkh',
#      'https://awazly.com/trkyb-aybwksy-jdh',
#      'https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh',
#      'https://awazly.com/malm-dhanat-aldwadmy'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بالمدينة.md',
#    'title_check': {'length': 94, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 232,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2993, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 5,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/afdhl-mwasyr-alsbakh',
#      'https://awazly.com/sbak-baldwadmy',
#      'https://awazly.com/sbak_balryadh',
#      'https://awazly.com/sbak_bjdh',
#      'https://awazly.com/sbak_bmkh_'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True,
#     'skipped_levels': [{'from': {'type': 'h2',
#        'line_number': 292,
#        'content': '**رقم سباك بالمدينة المنورة** - طوارئ 24 ساعة',
#        'length': 45},
#       'to': {'type': 'h4',
#        'line_number': 304,
#        'content': 'الطوارئ العادية',
#        'length': 15}}]}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بمكة.md',
#    'title_check': {'length': 72, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 220,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2619, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 21,
#     'internal_count': 21,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com',
#      'https://awazly.com/azl_foam_makkah',
#      'https://awazly.com/azl_khzanat_makkah',
#      'https://awazly.com/azl_hrari_makkah',
#      'https://awazly.com/azl_maey_makkah',
#      'https://awazly.com/azl_shinko_makkah',
#      'https://awazly.com/kashf_tsrbat_makkah',
#      'https://awazly.com/trmym_mnazl_makkah',
#      'https://awazly.com/sbak_makkah',
#      'https://awazly.com/khrbaey_makkah',
#      'https://awazly.com/moalm_dhanat_makkah',
#      'https://awazly.com/azl_asth_jeddah',
#      'https://awazly.com/azl_asth_madinah',
#      'https://awazly.com/azl_asth_taif',
#      'https://awazly.com/azl_asth_riyadh',
#      'https://awazly.com/azl_asth_dammam',
#      'https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm',
#      'https://awazly.com/bwly-ywrythan-fwm',
#      'https://awazly.com/shrkh-azl-asth-baldwadmy',
#      'https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_فوم_بالاحساء.md',
#    'title_check': {'length': 82, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 206,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1024, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 10,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/azl_foam_dammam',
#      'https://awazly.com/azl_foam_khobar',
#      'https://awazly.com/azl_foam_jubail',
#      'https://awazly.com/azl_foam_hafr',
#      'https://awazly.com/azl_asth_qatif',
#      'https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm',
#      'https://awazly.com/bwly-ywrythan-fwm',
#      'https://awazly.com/shrkh-azl-fwm-baldmam',
#      'https://awazly.com/shrkh-azl-fwm-baltaef',
#      'https://awazly.com/shrkh-azl-fwm-balqtyf'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_كشف_تسربات_الدوادمي.md',
#    'title_check': {'length': 68, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 170,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 3409, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 11,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com',
#      'https://awazly.com/malm-dhanat-aldwadmy',
#      'https://awazly.com/ghsyl-knb-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/sbak-baldwadmy',
#      'https://awazly.com/shrkh-azl-asth-baldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh',
#      'https://awazly.com/kshf-tsrbat-almyah-bjazan',
#      'https://awazly.com/kshf_tsrbat_almyah_bmkh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_تنظيف_منازل_الكويت.md',
#    'title_check': {'length': 82, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 194,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1976, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 12,
#     'internal_count': 4,
#     'external_count': 8,
#     'internal_links': ['https://awazly.com/aazl-asth-alkwyt',
#      'https://awazly.com/kshf-khryr-almyah-alkwyt',
#      'https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'],
#     'external_links': ['https://shelid.com/',
#      'https://shelid.com/kshf_tsrbat_almyah_balkwyt',
#      'https://shelid.com/shrkh_ahwadh_sbahh',
#      'https://shelid.com/shrkh-asbagh-alkwyt',
#      'https://azlzone.com/shrkh-tnzyf-mnazl-alkwyt',
#      'https://shelid.com/cleaning_sofa_kuwait',
#      'https://shelid.com/kitchen_cleaning_kuwait',
#      'https://shelid.com/sanitization_kuwait']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/بورديوم.md',
#    'title_check': {'length': 62, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 149,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2557, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 2,
#     'internal_count': 2,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تركيب_جي_ار_سي.md',
#    'title_check': {'length': 58, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 151,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 992, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 3,
#     'internal_count': 3,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/alkhrsanh-almazwlh',
#      'https://awazly.com/alazl-almaey-walhrary-llkhrsanh',
#      'https://awazly.com/tqnyat-albnaa-alhdythh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': False},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_القاهرة.md',
#    'title_check': {'length': 55, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 176,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 3389, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 13,
#     'internal_count': 13,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/blog/packing-tips',
#      'https://awazly.com/blog/best-moving-times',
#      'https://awazly.com/blog/furniture-protection',
#      'https://awazly.com/shrkh-nql-afsh-balryadh',
#      'https://awazly.com/shrkh-nql-afsh-bjdh',
#      'https://awazly.com/shrkh-nql-afsh-bmkh',
#      'https://awazly.com/cleaning-services-cairo',
#      'https://awazly.com/home-maintenance',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بمسقط.md',
#    'title_check': {'length': 21, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 124,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2471, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 12,
#     'internal_count': 8,
#     'external_count': 4,
#     'internal_links': ['https://awazly.com/',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/sbak_balmdynh',
#      'https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm',
#      'https://awazly.com/bwly-ywrythan-fwm',
#      'https://awazly.com/shrkh-azl-asth-baldwadmy',
#      'https://awazly.com/shrkh-azl-asth-balryadh'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://azlzone.com/kshf_tsrbat_almyah_bmsqt',
#      'https://www.protienai.com/',
#      'https://shelid.com/shrkh-azl-asth-fy-msqt']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تمديد_غاز_مركزي_بجدة.md',
#    'title_check': {'length': 56, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 154,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 422, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 1,
#     'internal_count': 1,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/tmdyd-ghaz-mrkzy-balmdynh-almnwrh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_بالدوادمي.md',
#    'title_check': {'length': 51, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 133,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 581, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 9,
#     'internal_count': 9,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/malm-dhanat-aldwadmy',
#      'https://awazly.com/ghsyl-knb-baldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-aldwadmy',
#      'https://awazly.com/sbak-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl',
#      'https://awazly.com/shrkh-nql-afsh-fy-alkhbr'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_الخبر.md',
#    'title_check': {'length': 50, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 144,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 866, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 13,
#     'internal_count': 9,
#     'external_count': 4,
#     'internal_links': ['https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/khrbaey-mnazl-almdynh-almnwrh',
#      'https://awazly.com/tnsyq-hdaeq-almdynh-almnwrh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/',
#      'https://emdadelgaz.com/syanh-afran-ghaz-balmdynh-almnwrh',
#      'https://emdadelgaz.com/syanh-afran-alghaz-balryadh']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_القصيم.md',
#    'title_check': {'length': 54, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 134,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2269, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 5,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_صفوي.md',
#    'title_check': {'length': 48, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 120,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 613, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 13,
#     'internal_count': 9,
#     'external_count': 4,
#     'internal_links': ['https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/khrbaey-mnazl-almdynh-almnwrh',
#      'https://awazly.com/tnsyq-hdaeq-almdynh-almnwrh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl',
#      'https://awazly.com/shrkh-nql-afsh-fy-alkhbr'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/',
#      'https://emdadelgaz.com/syanh-afran-ghaz-balmdynh-almnwrh',
#      'https://emdadelgaz.com/syanh-afran-alghaz-balryadh']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_عزل_اسطح_بتبوك.md',
#    'title_check': {'length': 50, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 122,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2398, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 14,
#     'internal_count': 12,
#     'external_count': 2,
#     'internal_links': ['https://awazly.com/shrkh-azl-asth-baljwf',
#      'https://awazly.com/shrkh-azl-asth-barar',
#      'https://awazly.com/shrkh-azl-asth-btryf',
#      'https://awazly.com/shrkh-azl-asth-bjazan',
#      'https://awazly.com/shrkh-azl-asth-bnjran',
#      'https://awazly.com/azl_khzanat_mkh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh',
#      'https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm',
#      'https://awazly.com/bwly-ywrythan-fwm',
#      'https://awazly.com/shrkh-azl-asth-baldwadmy',
#      'https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh'],
#     'external_links': ['https://azlzone.com/shrkh-azl-asth-basyr',
#      'https://azlzone.com/kshf-tsrbat-almyah-basyr']},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_كشف_تسربات_المياه_بالمدينة_المنورة.md',
#    'title_check': {'length': 51, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 120,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 983, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 16,
#     'internal_count': 7,
#     'external_count': 4,
#     'internal_links': ['https://awazly.com/sbak_balryadh',
#      'https://awazly.com/azl_asth_mkh',
#      'https://awazly.com/shrkh-kshf-tsrbat-aldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh',
#      'https://awazly.com/kshf-tsrbat-almyah-bjazan',
#      'https://awazly.com/kshf_tsrbat_almyah_bmkh'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/',
#      'https://shelid.com/azl_asth_balkwyt',
#      'https://azlzone.com/kshf_tsrbat_almyah_bmsqt']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_بالمدينة_المنورة.md',
#    'title_check': {'length': 58, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 143,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 464, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 13,
#     'internal_count': 9,
#     'external_count': 4,
#     'internal_links': ['https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/khrbaey-mnazl-almdynh-almnwrh',
#      'https://awazly.com/tnsyq-hdaeq-almdynh-almnwrh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl',
#      'https://awazly.com/shrkh-nql-afsh-fy-alkhbr'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/',
#      'https://emdadelgaz.com/syanh-afran-ghaz-balmdynh-almnwrh',
#      'https://emdadelgaz.com/syanh-afran-alghaz-balryadh']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_الجبيل.md',
#    'title_check': {'length': 54, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 167,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1780, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 12,
#     'internal_count': 9,
#     'external_count': 3,
#     'internal_links': ['https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/khrbaey-mnazl-almdynh-almnwrh',
#      'https://awazly.com/tnsyq-hdaeq-almdynh-almnwrh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-alkhbr'],
#     'external_links': ['https://emdadelgaz.com/',
#      'https://emdadelgaz.com/syanh-afran-ghaz-balmdynh-almnwrh',
#      'https://emdadelgaz.com/syanh-afran-alghaz-balryadh']},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': False},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_في_جازان.md',
#    'title_check': {'length': 55, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 123,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2491, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 5,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balkwyt',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/احتيال_الفحص_الفني.md',
#    'title_check': {'length': 51, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 123,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 826, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 4,
#     'external_count': 2,
#     'internal_links': ['https://awazly.com/shrkh-azl-asth-bmkh',
#      'https://awazly.com/',
#      'https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'],
#     'external_links': ['http://pti.saso.gov.sa',
#      'https://hawamer.com/vb/hawamer2861996']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عازل_صوت_بالمدينة_المنورة.md',
#    'title_check': {'length': 55, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 229,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 3986, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 2,
#     'internal_count': 2,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_تسربات_المياه_بجازان.md',
#    'title_check': {'length': 29, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 181,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 815, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 12,
#     'internal_count': 9,
#     'external_count': 3,
#     'internal_links': ['https://awazly.com/azl_khzanat_mkh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/trkyb-aybwksy-jdh',
#      'https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-aldwadmy',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh',
#      'https://awazly.com/kshf_tsrbat_almyah_bmkh'],
#     'external_links': ['https://shelid.com/shrkh-nql-afsh-balkwyt',
#      'https://shelid.com/shrkh-tnzyf-mnazl-alkwyt',
#      'https://shelid.com/shrkh-azl-asth-abwzby']},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/اسطوانة_الغاز_الفايبر.md',
#    'title_check': {'length': 99, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 141,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1519, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 3,
#     'internal_count': 3,
#     'external_count': 0,
#     'internal_links': ['https://awazly.com',
#      'https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_نقل_عفش_بالكويت.md',
#    'title_check': {'length': 93, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 146,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2156, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 7,
#     'external_count': 4,
#     'internal_links': ['https://awazly.com/aazl-asth-alkwyt',
#      'https://awazly.com/kshf-khryr-almyah-alkwyt',
#      'https://awazly.com/shrkh-nql-afsh-baldwadmy',
#      'https://awazly.com/shrkh-nql-afsh-balmdynh-almnwrh',
#      'https://awazly.com/shrkh-nql-afsh-sfwy',
#      'https://awazly.com/shrkh-nql-afsh-fy-aljbyl',
#      'https://awazly.com/shrkh-nql-afsh-fy-alkhbr'],
#     'external_links': ['https://shelid.com/barkyh-alkwyt',
#      'https://shelid.com/jbs-bwrd-alkwyt',
#      'https://shelid.com/tmdyd_ghaz_bmsqt_aman',
#      'http://shelid.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/عازل_اسطح_الكويت.md',
#    'title_check': {'length': 70, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 154,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2802, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 6,
#     'external_count': 5,
#     'internal_links': ['https://awazly.com/aazl-asth-alkwyt',
#      'https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm',
#      'https://awazly.com/bwly-ywrythan-fwm',
#      'https://awazly.com/shrkh-azl-asth-baldwadmy',
#      'https://awazly.com/shrkh-azl-asth-balryadh',
#      'https://awazly.com/shrkh-azl-asth-balmdynh'],
#     'external_links': ['https://shelid.com/kshf_tsrbat_almyah_balkwyt',
#      'https://shelid.com/shrkh_ahwadh_sbahh',
#      'https://shelid.com/barkyh-alkwyt',
#      'https://shelid.com/jbs-bwrd-alkwyt',
#      'https://shelid.com/']},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كشف_خرير_المياه_الكويت.md',
#    'title_check': {'length': 99, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 155,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2559, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 14,
#     'internal_count': 8,
#     'external_count': 6,
#     'internal_links': ['https://awazly.com/kshf_tsrbat_almyah_bmkh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh',
#      'https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh',
#      'https://awazly.com/shrkh-azl-asth-bmkh',
#      'https://awazly.com/',
#      'https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/sbak_balmdynh',
#      'https://awazly.com/shrkh-azl-asth-balryadh'],
#     'external_links': ['https://shelid.com/kshf-tsrbat-almyah-fy-msqt',
#      'https://shelid.com/barkyh-alkwyt',
#      'https://shelid.com/jbs-bwrd-alkwyt',
#      'https://shelid.com/shrkh_ahwadh_sbahh',
#      'https://azlzone.com/',
#      'https://shelid.com/']},
#    'keyword_placement': {'in_h1': True,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': True, 'in_description': True},
#     'keyword_at_first': True},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/كهربائي_منازل_المدينة_المنورة.md',
#    'title_check': {'length': 55, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 172,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 491, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 7,
#     'external_count': 1,
#     'internal_links': ['https://awazly.com/shrkh-azl-asth-balmdynh',
#      'https://awazly.com/sbak_balmdynh',
#      'https://awazly.com/malm-lyash-almdynh-almnwrh',
#      'https://awazly.com/trkyb-aybwksy-almdynh-almnwrh',
#      'https://awazly.com/ghsyl-knb-balmdynh-almnwrh',
#      'https://awazly.com/khrbaey-mnazl-bjdh',
#      'https://awazly.com/khrbaey-mnazl-bmkh-almkrmh'],
#     'external_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 3, 29),
#     'days_since_update': 2,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بالدوادمي.md',
#    'title_check': {'length': 99, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 185,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
# ...
#       'avg_position': 9.0,
#       'avg_ctr': 0.0},
#      {'query': 'صيانه سباكه منازل',
#       'total_clicks': 0,
#       'total_impressions': 6,
#       'avg_position': 38.5,
#       'avg_ctr': 0.0},
#      {'query': 'فني سباكه بجده',
#       'total_clicks': 0,
#       'total_impressions': 5,
#       'avg_position': 15.6,
#       'avg_ctr': 0.0},
#      {'query': 'مؤسسة سباكة وكهرباء جدة',
#       'total_clicks': 0,
#       'total_impressions': 4,
#       'avg_position': 62.25,
#       'avg_ctr': 0.0},
#      {'query': 'سباك كهربائي جده',
#       'total_clicks': 0,
#       'total_impressions': 4,
#       'avg_position': 69.25,
#       'avg_ctr': 0.0},
#      {'query': 'معلم سباكة بجده',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 18.5,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'فني سباك بجده',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 60.0,
#       'avg_ctr': 0.0},
#      {'query': 'معلم سباك بجده جدة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 81.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز قريب من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'مجوهرات الصفا والمروة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 6.0,
#       'avg_ctr': 0.0},
#      {'query': 'كهربائي باكستاني جدة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 25.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركه الصفا والمروه',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 9.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 88.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك قريب من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 57.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك فى جده',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 76.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك شاطر',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 12.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك جدة مؤسسة تسنيم الانشائية لأعمال السباكة والكهرباء والمسابح',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 20.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك جدة حي السامر',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 62.0,
#       'avg_ctr': 0.0},
#      {'query': 'سباك جدة الحمدانية',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 76.0,
#       'avg_ctr': 0.0},
#      {'query': 'خدمات السباكة و الكهرباء',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 74.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل غاز ٢٤ ساعة الصفا جدة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'ارقام سباكين',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 28.0,
#       'avg_ctr': 0.0},
#      {'query': 'ارقام حي الصفا جدة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 92.0,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل غاز من موقعي جدة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'i want person',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0}],
#     'Title too_short (46 chars, range 50-60)',
#     'Description too_short (129 chars, range 150-160)',
#     'Focus keyword not in H1',
#     'Focus keyword not in description',
#     'Focus keyword not in title',
#     'Focus keyword not in first 100 words']},
#   'https://awazly.com/sbak_bmkh_': {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/سباك_بمكة_.md',
#    'issues': [[{'query': 'مكه الشوقيه',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 7.0,
#       'avg_ctr': 0.0},
#      {'query': 'سسباك',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 11.0,
#       'avg_ctr': 0.0}],
#     'Title too_short (43 chars, range 50-60)',
#     'Description too_short (140 chars, range 150-160)']},
#   'https://awazly.com/shrkh_trmym_mbany_fy_mkh': {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/شركة_ترميم_مباني_في_مكة.md',
#    'issues': [[{'query': 'شركة ترميم عمائر بمكة',
#       'total_clicks': 0,
#       'total_impressions': 61,
#       'avg_position': 28.40909090909091,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم خزانات بمكة',
#       'total_clicks': 0,
#       'total_impressions': 45,
#       'avg_position': 72.73423423423424,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم منازل و فلل في مكة خدمات سريعة 0532470285',
#       'total_clicks': 0,
#       'total_impressions': 23,
#       'avg_position': 9.863636363636363,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم منازل بمكة خدمات احترافية خدمة 24 ساعة',
#       'total_clicks': 0,
#       'total_impressions': 21,
#       'avg_position': 53.63690476190476,
#       'avg_ctr': 0.0},
#      {'query': 'مقاول ترميم بمكة المكرمة',
#       'total_clicks': 0,
#       'total_impressions': 10,
#       'avg_position': 85.94444444444444,
#       'avg_ctr': 0.0},
#      {'query': 'افضل شركة ترميم حمامات بمسقط عمان',
#       'total_clicks': 0,
#       'total_impressions': 10,
#       'avg_position': 22.3,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم منازل في مكة حلول ذكية بأسعار تنافسية 0532470285',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 4.125,
#       'avg_ctr': 0.0},
#      {'query': '3.شركة ترميم شقق بمكة – بأعلى جودة وأسعار مناسبة – 0532470285!',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 6.428571428571429,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم حمامات بمسقط عمان',
#       'total_clicks': 0,
#       'total_impressions': 4,
#       'avg_position': 21.0,
#       'avg_ctr': 0.0},
#      {'query': 'أفضل شركة ترميم منازل شركة ابراج مكة خصم يصل الي35%',
#       'total_clicks': 0,
#       'total_impressions': 4,
#       'avg_position': 27.5,
#       'avg_ctr': 0.0},
#      {'query': 'كوخ مكه',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 8.666666666666666,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم شقق بمكة بأعلى جودة وأسعار مناسبة 0532470285',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 22.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم بابها',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 81.66666666666667,
#       'avg_ctr': 0.0},
#      {'query': 'تكلفة ترميم المنازل في مكة بأفضل سعر وضمان جودة 2025',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 62.333333333333336,
#       'avg_ctr': 0.0},
#      {'query': '46.شركة ترميم منازل في مكة – حلول ذكية بأسعار تنافسية 0532470285',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 101.0,
#       'avg_ctr': 0.0},
#      {'query': '46.شركة ترميم منازل في مكة حلول ذكية بأسعار تنافسية 0532470285',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 3.0,
#       'avg_ctr': 0.0},
#      {'query': '43.ترميم المنازل شركة ابراج مكة اتصل بنا 0553247028',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 34.0,
#       'avg_ctr': 0.0},
#      {'query': 'طاقيه شغل مكه',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 5.5,
#       'avg_ctr': 0.0},
#      {'query': '44.ترميم منازل قبل وبعد مؤسسة ابراج مكة 0532470285',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 19.5,
#       'avg_ctr': 0.0},
#      {'query': '41.أفضل شركة ترميم منازل: شركة ابراج مكة خصم يصل الي35%',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 21.5,
#       'avg_ctr': 0.0},
#      {'query': '"شركة ترميم المنازل"',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 93.0,
#       'avg_ctr': 0.0},
#      {'query': 'مقاول ترميم مكة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 97.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة ترميم عمائر بمكة أعلى جودة وأقل تكلفة وخصم 40 %',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'ترميم شقه',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 93.0,
#       'avg_ctr': 0.0},
#      {'query': '5 أسباب لاختيار أفضل شركة ترميم منازل بمكة بأسعار تنافسية',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 22.0,
#       'avg_ctr': 0.0}],
#     'Title too_short (46 chars, range 50-60)',
#     'Description too_short (130 chars, range 150-160)',
#     'Focus keyword not in H1',
#     'Focus keyword not in description',
#     'Focus keyword not in title']},
#   'https://awazly.com/tmdyd-alghaz-almrkzy-bmkh-awazly': {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/تمديد_الغاز_المركزي_بمكة_عوازلي.md',
#    'issues': [[{'query': 'شركة تمديد الغاز المركزي بجدة',
#       'total_clicks': 0,
#       'total_impressions': 445,
#       'avg_position': 84.58407738095238,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد خطوط غاز مكة',
#       'total_clicks': 0,
#       'total_impressions': 130,
#       'avg_position': 23.9106529209622,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بجدة',
#       'total_clicks': 0,
#       'total_impressions': 46,
#       'avg_position': 73.6219512195122,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز بجدة',
#       'total_clicks': 0,
#       'total_impressions': 37,
#       'avg_position': 88.64583333333333,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز بمدينة المنورة',
#       'total_clicks': 0,
#       'total_impressions': 33,
#       'avg_position': 44.82051282051282,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بحفر الباطن',
#       'total_clicks': 0,
#       'total_impressions': 29,
#       'avg_position': 88.69642857142857,
#       'avg_ctr': 0.0},
#      {'query': 'ماصورة غاز',
#       'total_clicks': 0,
#       'total_impressions': 18,
#       'avg_position': 52.333333333333336,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بسراة عبيدة',
#       'total_clicks': 0,
#       'total_impressions': 14,
#       'avg_position': 67.92857142857143,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز بالقصيم',
#       'total_clicks': 0,
#       'total_impressions': 14,
#       'avg_position': 98.20833333333333,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بمحايل عسير',
#       'total_clicks': 0,
#       'total_impressions': 13,
#       'avg_position': 91.76923076923077,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بخميس مشيط',
#       'total_clicks': 0,
#       'total_impressions': 12,
#       'avg_position': 84.83333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز بخميس مشيط',
#       'total_clicks': 0,
#       'total_impressions': 12,
#       'avg_position': 91.16666666666667,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بحائل',
#       'total_clicks': 0,
#       'total_impressions': 11,
#       'avg_position': 94.81818181818181,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى راس تنورة',
#       'total_clicks': 0,
#       'total_impressions': 10,
#       'avg_position': 93.33333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي بمحايل عسير',
#       'total_clicks': 0,
#       'total_impressions': 9,
#       'avg_position': 83.55555555555556,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بنجران',
#       'total_clicks': 0,
#       'total_impressions': 8,
#       'avg_position': 80.5,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى بالقطيف',
#       'total_clicks': 0,
#       'total_impressions': 8,
#       'avg_position': 98.21428571428571,
#       'avg_ctr': 0.0},
#      {'query': 'سعر ماسورة حديد 1.5 بوصة',
#       'total_clicks': 0,
#       'total_impressions': 8,
#       'avg_position': 63.5,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى براس تنورة',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 94.0,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي بنجران',
#       'total_clicks': 0,
#       'total_impressions': 6,
#       'avg_position': 75.16666666666667,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي بسراة عبيدة',
#       'total_clicks': 0,
#       'total_impressions': 6,
#       'avg_position': 70.0,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي بخميس مشيط',
#       'total_clicks': 0,
#       'total_impressions': 6,
#       'avg_position': 92.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى بالدمام',
#       'total_clicks': 0,
#       'total_impressions': 5,
#       'avg_position': 83.2,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بابها',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 73.33333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز بالمنازل',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 66.66666666666667,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي بجدة',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 83.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى الجبيل',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 97.5,
#       'avg_ctr': 0.0},
#      {'query': 'رقم توصيل اسطوانات الغاز للمنازل بالمدينة المنورة',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 44.5,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي بابها',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 94.5,
#       'avg_ctr': 0.0},
#      {'query': 'انواع مواسير تمديد الغاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 34.5,
#       'avg_ctr': 0.0},
#      {'query': 'صور مطعم الحوش',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 3.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة كشف تسربات الغاز بجدة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 119.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بظهران',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 67.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى بالجبيل',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 101.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى بالاحساء',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 81.0,
#       'avg_ctr': 0.0},
#      {'query': 'رقم توصيل اسطوانات الغاز للمنازل مكة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 78.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل انابيب غاز مكة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 29.0,
#       'avg_ctr': 0.0},
#      {'query': 'تأسيس غاز مركزي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 85.0,
#       'avg_ctr': 0.0},
#      {'query': 'اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 61.0,
#       'avg_ctr': 0.0},
#      {'query': 'أنواع أنابيب الغاز المنزلي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0}],
#     'Description too_short (136 chars, range 150-160)',
#     'Focus keyword not in H1',
#     'Focus keyword not in description',
#     'Focus keyword not in title',
#     'Focus keyword not in first 100 words']}},
#  'summary': {'total_issues': 168,
#   'pages_with_issues': 84,
#   'duplicate_titles_count': 3,
#   'duplicate_descriptions_count': 0}}

# %%
#| hide
#| eval: false
print_issues_report(report)
# Out:
# Pages analysed : 87 / 87
# Pages with issues: 87
# Total issue count: 326
# Duplicate titles : 3
# Duplicate descs  : 0
# ======================================================================
#
# [7 issues] https://awazly.com/malm-dhanat-aldwadmy
#   1. No external links
#   2. Title too_short (44 chars, range 50-60)
#   3. Description too_short (131 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (6):
#       - طريقة تنظيف سيراميك الباركيه من البويه (clicks: 0, impressions: 25, pos: 75.2)
#       - تصميم بوثات بالدوادمي (clicks: 0, impressions: 4, pos: 20.2)
#       - شركة عزل مائى بالدوادمي (clicks: 0, impressions: 2, pos: 101.0)
#       - بويه ارضيه على شكل سيراميك (clicks: 0, impressions: 2, pos: 87.5)
#       - شغل دهانات ترخيم (clicks: 0, impressions: 1, pos: 84.0)
#       - بوية ستيكو (clicks: 0, impressions: 1, pos: 47.0)
#
# [7 issues] https://awazly.com/ghsyl-knb-baldwadmy
#   1. No external links
#   2. Title too_long (79 chars, range 50-60)
#   3. Description too_short (126 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (11):
#       - طريقة تنظيف الكنب الخيش المتسخ جدا (clicks: 0, impressions: 51, pos: 44.3)
#       - خلطة لتنظيف الكنب المخمل (clicks: 0, impressions: 40, pos: 50.9)
#       - شركة تنظيف بالدوادمى (clicks: 0, impressions: 7, pos: 89.3)
#       - تقييمات شركة اللمسة الاخيرة للنظافة (clicks: 0, impressions: 6, pos: 21.0)
#       - طريقة تنظيف كنب ستان (clicks: 0, impressions: 3, pos: 91.3)
#       - خدمات شركة اللمسة الاخيرة لتنظيف المنازل (clicks: 0, impressions: 3, pos: 23.0)
#       - غسل كنب (clicks: 0, impressions: 1, pos: 59.0)
#       - شركة عزل مائى بالدوادمي (clicks: 0, impressions: 1, pos: 79.0)
#       - شركة اللمسة الاخيرة لخدمات النظافة (clicks: 0, impressions: 1, pos: 30.0)
#       - تجاربكم مع تنظيف الكنب المخمل (clicks: 0, impressions: 1, pos: 1.0)
#       - أرقى احياء الدوادمي (clicks: 0, impressions: 1, pos: 1.0)
#
# [7 issues] https://awazly.com/alkhrsanh-almazwlh
#   1. No external links
#   2. Title too_long (87 chars, range 50-60)
#   3. Description too_long (215 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (2):
#       - كم تبلغ تكلفة بناء منزل في السعودية (clicks: 0, impressions: 2, pos: 75.5)
#       - تكلفة البناء لكل متر مربع السعودية (clicks: 0, impressions: 1, pos: 85.0)
#
# [7 issues] https://awazly.com/althqb-alafqy
#   1. No external links
#   2. Title too_long (76 chars, range 50-60)
#   3. Description too_long (211 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (4):
#       - شركات الثقب الافقي بالسعودية (clicks: 1, impressions: 9, pos: 5.4)
#       - سعر طن الأسفلت في السعودية 2025 (clicks: 0, impressions: 1, pos: 88.0)
#       - trenchless crossing (clicks: 0, impressions: 1, pos: 5.0)
#       - horizontal directional drilling companies in saudi arabia (clicks: 0, impressions: 1, pos: 6.0)
#
# [7 issues] https://awazly.com/astwanh-alghaz-alfaybr
#   1. No external links
#   2. Title too_long (99 chars, range 50-60)
#   3. Description too_short (141 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (371):
#       - اسطوانة غاز فايبر (clicks: 167, impressions: 14577, pos: 7.2)
#       - اسطوانة غاز فايبر كم سعرها (clicks: 70, impressions: 6913, pos: 4.6)
#       - عيوب اسطوانة غاز فايبر (clicks: 171, impressions: 3284, pos: 3.0)
#       - استبدال اسطوانة الغاز الحديد بالفايبر (clicks: 104, impressions: 1922, pos: 5.5)
#       - سعر اسطوانة الغاز الفايبر (clicks: 23, impressions: 1489, pos: 5.6)
#       - سعر أسطوانة الغاز السعودية 2025 (clicks: 2, impressions: 1036, pos: 3.0)
#       - اسطوانه فايبر (clicks: 9, impressions: 825, pos: 8.4)
#       - دبة غاز فايبر (clicks: 13, impressions: 808, pos: 8.6)
#       - سعر تعبئة أسطوانة الغاز 2025 (clicks: 1, impressions: 803, pos: 6.2)
#       - وزن اسطوانة الغاز الحديد (clicks: 1, impressions: 671, pos: 4.0)
#       - اسطوانة غاز فايبر ساكو (clicks: 8, impressions: 607, pos: 8.2)
#       - استبدال اسطوانة الغاز الحديد بالفايبر الرياض (clicks: 30, impressions: 542, pos: 4.7)
#       - سعر اسطوانة الغاز جديدة (clicks: 1, impressions: 531, pos: 4.2)
#       - سعر تعبئة اسطوانة الغاز 2025 (clicks: 4, impressions: 497, pos: 8.2)
#       - كم سعر اسطوانة الغاز جديدة (clicks: 2, impressions: 473, pos: 7.6)
#       - سعر اسطوانة غاز حديد (clicks: 0, impressions: 461, pos: 7.2)
#       - اسطوانة غاز فايبر كم سعرها ساكو (clicks: 2, impressions: 443, pos: 7.0)
#       - تبديل اسطوانة غاز فايبر (clicks: 4, impressions: 406, pos: 9.3)
#       - كم وزن اسطوانة الغاز (clicks: 0, impressions: 393, pos: 4.1)
#       - اسطوانه غاز فايبر (clicks: 12, impressions: 393, pos: 8.3)
#       - سعر اسطوانة غاز فايبر (clicks: 5, impressions: 388, pos: 5.8)
#       - سعر الاسطوانه الحديد (clicks: 1, impressions: 352, pos: 8.4)
#       - كم سعر اسطوانة الغاز الجديدة في السعودية (clicks: 1, impressions: 299, pos: 1.4)
#       - اسطوانة غاز (clicks: 0, impressions: 299, pos: 30.1)
#       - سعر الاسطوانة الجديدة (clicks: 1, impressions: 296, pos: 5.2)
#       - كم سعر الاسطوانه (clicks: 0, impressions: 292, pos: 2.3)
#       - سعر تعبئة اسطوانة الغاز في السعودية 2025 (clicks: 1, impressions: 286, pos: 3.2)
#       - اسطوانة الغاز الفايبر (clicks: 9, impressions: 255, pos: 6.3)
#       - سعر استبدال اسطوانة الغاز (clicks: 1, impressions: 252, pos: 4.0)
#       - الفرق بين اسطوانة الغاز الفايبر والحديد (clicks: 8, impressions: 248, pos: 3.6)
#       - تبديل اسطوانة غاز حديد بفايبر (clicks: 13, impressions: 245, pos: 7.9)
#       - اسطوانة غاز حديد (clicks: 0, impressions: 237, pos: 12.6)
#       - كم سعر اسطوانة الغاز الجديدة (clicks: 4, impressions: 229, pos: 5.0)
#       - اسعار اسطوانات الغاز الجديدة (clicks: 3, impressions: 225, pos: 3.1)
#       - كم وزن اسطوانة الغاز الحديد (clicks: 0, impressions: 216, pos: 4.4)
#       - اسطوانة فايبر (clicks: 4, impressions: 212, pos: 12.6)
#       - انابيب غاز فايبر (clicks: 5, impressions: 210, pos: 7.1)
#       - وزن الاسطوانه الحديد (clicks: 0, impressions: 206, pos: 2.3)
#       - سعر الاسطوانة الفايبر (clicks: 3, impressions: 206, pos: 5.9)
#       - كم سعر اسطوانة الغاز الفايبر (clicks: 4, impressions: 205, pos: 4.0)
#       - سعر دبة الغاز الفايبر (clicks: 4, impressions: 200, pos: 3.9)
#       - كم وزن اسطوانة الغاز في السعودية (clicks: 0, impressions: 196, pos: 3.0)
#       - كم سعر الاسطوانه الجديده (clicks: 0, impressions: 194, pos: 5.1)
#       - سعر اسطوانة الغاز السعودية 2025 (clicks: 1, impressions: 190, pos: 8.5)
#       - سعر دبة الغاز الجديدة (clicks: 0, impressions: 186, pos: 5.1)
#       - سعر اسطوانة الغاز (clicks: 1, impressions: 179, pos: 18.1)
#       - سعر اسطوانة الغاز الحديد (clicks: 0, impressions: 169, pos: 7.1)
#       - سعر اسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 166, pos: 5.8)
#       - اسعار اسطوانات الغاز الفايبر (clicks: 3, impressions: 165, pos: 3.5)
#       - غازكو اسطوانة فايبر (clicks: 1, impressions: 152, pos: 8.7)
#       - كم سعر اسطوانة الغاز (clicks: 0, impressions: 150, pos: 8.9)
#       - تبديل اسطوانة غاز حديد بفايبر الرياض (clicks: 8, impressions: 143, pos: 2.4)
#       - وزن اسطوانة الغاز الفايبر (clicks: 1, impressions: 139, pos: 5.7)
#       - كم سعر اسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 130, pos: 2.2)
#       - سعر اسطوانة الغاز الجديدة (clicks: 0, impressions: 116, pos: 5.9)
#       - تعبئة اسطوانة غاز فايبر (clicks: 1, impressions: 116, pos: 3.9)
#       - مواصفات اسطوانة الغاز المنزلي (clicks: 0, impressions: 115, pos: 8.1)
#       - كم وزن الاسطوانة الغاز (clicks: 0, impressions: 113, pos: 1.0)
#       - سعر الانبوبة الحديد (clicks: 0, impressions: 113, pos: 13.7)
#       - سعر اسطوانة الغاز الرياض (clicks: 0, impressions: 111, pos: 2.1)
#       - اسطوانة فايبر ساكو (clicks: 1, impressions: 109, pos: 8.8)
#       - سعر الاسطوانه الغاز الجديده (clicks: 0, impressions: 107, pos: 4.6)
#       - كم وزن اسطوانه الغاز في السعودية (clicks: 0, impressions: 105, pos: 1.7)
#       - اسطوانة غاز فيبر (clicks: 4, impressions: 103, pos: 10.0)
#       - غاز فيبر (clicks: 2, impressions: 102, pos: 10.1)
#       - كم وزن اسطوانة الغاز الفايبر (clicks: 4, impressions: 101, pos: 3.6)
#       - انبوبة غاز كم سعرها (clicks: 0, impressions: 100, pos: 4.3)
#       - اسعار اسطوانة الغاز الفايبر (clicks: 0, impressions: 90, pos: 3.8)
#       - اسطوانة غاز فايبر صغيرة (clicks: 3, impressions: 90, pos: 12.7)
#       - سعر تعبئة اسطوانة الغاز الفايبر (clicks: 0, impressions: 89, pos: 2.4)
#       - سعر اسطوانة الغاز حديد (clicks: 1, impressions: 88, pos: 8.1)
#       - قيمة اسطوانة الغاز الجديدة (clicks: 1, impressions: 87, pos: 5.2)
#       - سعر تعبئة اسطوانة الغاز السعودية 2025 (clicks: 0, impressions: 83, pos: 5.1)
#       - سعر اسطوانة غاز جديدة (clicks: 0, impressions: 82, pos: 6.1)
#       - وزن دبة الغاز الحديد (clicks: 0, impressions: 81, pos: 2.4)
#       - الفرق بين اسطوانة الغاز الحديدية والبلاستيكية (clicks: 0, impressions: 81, pos: 2.7)
#       - استبدال اسطوانة الغاز الحديد بالفايبر جدة (clicks: 9, impressions: 80, pos: 1.5)
#       - عروض اسطوانة غاز فايبر (clicks: 1, impressions: 78, pos: 11.4)
#       - بدلها غاز (clicks: 1, impressions: 78, pos: 9.5)
#       - كم وزن الاسطوانه (clicks: 0, impressions: 77, pos: 1.1)
#       - سعر الاسطوانة الغاز (clicks: 0, impressions: 76, pos: 2.3)
#       - اسطوانة غاز فايبر للبيع (clicks: 2, impressions: 76, pos: 12.0)
#       - اسطوانة غاز جديدة (clicks: 0, impressions: 76, pos: 15.6)
#       - وزن اسطوانة الغاز مليانه (clicks: 0, impressions: 75, pos: 2.8)
#       - وزن اسطوانة الغاز الحديد في السعودية (clicks: 0, impressions: 75, pos: 3.0)
#       - تبديل اسطوانة الغاز الحديد بالفايبر (clicks: 4, impressions: 74, pos: 7.8)
#       - اسطوانه غاز فيبر (clicks: 0, impressions: 74, pos: 8.0)
#       - كم وزن دبة الغاز (clicks: 0, impressions: 73, pos: 2.1)
#       - اسطوانة الفايبر (clicks: 9, impressions: 73, pos: 4.8)
#       - سعر اسطوانة الغاز في السعودية (clicks: 0, impressions: 71, pos: 14.2)
#       - كم سعر الاسطوانة الغاز (clicks: 1, impressions: 70, pos: 3.3)
#       - سعر دبة الغاز (clicks: 0, impressions: 70, pos: 15.4)
#       - سعر أسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 70, pos: 6.0)
#       - اسطوانة الغاز البلاستيكية (clicks: 6, impressions: 70, pos: 6.0)
#       - كم سعر دبة الغاز (clicks: 0, impressions: 67, pos: 2.1)
#       - سعر اسطوانة الغاز فارغة (clicks: 0, impressions: 65, pos: 8.4)
#       - سلندر غاز فايبر (clicks: 0, impressions: 63, pos: 5.6)
#       - وزن انبوبة الغاز مليانه (clicks: 0, impressions: 62, pos: 1.0)
#       - شراء اسطوانة غاز فايبر (clicks: 2, impressions: 61, pos: 8.4)
#       - سعر تعبئة اسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 61, pos: 8.0)
#       - كم سعر استبدال اسطوانة الغاز في السعودية (clicks: 0, impressions: 59, pos: 1.2)
#       - سعر أسطوانة الغاز فارغة 2025 (clicks: 0, impressions: 58, pos: 5.9)
#       - انبوبه فايبر (clicks: 2, impressions: 58, pos: 3.7)
#       - اسطوانة الغاز الجديدة (clicks: 2, impressions: 58, pos: 11.9)
#       - كم سعر انبوبه الغاز في السعوديه (clicks: 0, impressions: 57, pos: 1.5)
#       - سعر الاسطوانه (clicks: 0, impressions: 56, pos: 5.0)
#       - سعر أنبوبة البوتاجاز الحديد (clicks: 1, impressions: 56, pos: 15.0)
#       - استبدال أسطوانة الغاز الحديد بالفايبر جدة (clicks: 2, impressions: 55, pos: 2.4)
#       - كم سعر اسطوانة الغاز في السعودية (clicks: 0, impressions: 53, pos: 9.5)
#       - سعر اسطوانة الغاز الجديدة في السعودية (clicks: 0, impressions: 53, pos: 4.3)
#       - استبدال اسطوانه حديد باسطوانه فايبر (clicks: 4, impressions: 53, pos: 2.7)
#       - سعر اسطوانة الغاز كاملة (clicks: 0, impressions: 51, pos: 6.2)
#       - كم سعر اسطوانة الغاز الحديد (clicks: 0, impressions: 50, pos: 5.9)
#       - طلب اسطوانة غاز فايبر (clicks: 2, impressions: 50, pos: 5.2)
#       - سعر تعبئة أسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 50, pos: 7.6)
#       - سعر تعبئة اسطوانة الغاز (clicks: 0, impressions: 50, pos: 18.2)
#       - اسطوانة الغاز (clicks: 0, impressions: 50, pos: 22.4)
#       - كم لتر اسطوانة الغاز الحديد (clicks: 0, impressions: 49, pos: 4.8)
#       - دبات غاز فايبر (clicks: 0, impressions: 49, pos: 9.2)
#       - عيوب اسطوانات الغاز البلاستيكية (clicks: 0, impressions: 48, pos: 3.7)
#       - سعر اسطوانه الغاز الجديد (clicks: 0, impressions: 47, pos: 1.5)
#       - سعر اسطوانة الغاز الفايبر في السعودية (clicks: 0, impressions: 47, pos: 3.6)
#       - ساكو اسطوانة غاز فايبر (clicks: 1, impressions: 47, pos: 7.8)
#       - استبدال اسطوانة الغاز الحديد بالفايبر الدمام (clicks: 5, impressions: 47, pos: 1.1)
#       - ساكو اسطوانة غاز فايبر كم سعرها (clicks: 3, impressions: 45, pos: 6.3)
#       - دبة غاز فايبر ساكو (clicks: 0, impressions: 44, pos: 8.3)
#       - دبة الغاز الجديدة (clicks: 0, impressions: 44, pos: 8.9)
#       - الاسطوانة الجديدة (clicks: 0, impressions: 44, pos: 8.9)
#       - سعر تبديل اسطوانة الغاز 2025 (clicks: 0, impressions: 43, pos: 5.0)
#       - سعر انبوبه الغاز الحديد (clicks: 0, impressions: 42, pos: 11.1)
#       - سعر الاسطوانات الجديده (clicks: 0, impressions: 42, pos: 2.6)
#       - احجام اسطوانات الغاز الفايبر (clicks: 0, impressions: 42, pos: 5.7)
#       - دبة غاز فايبر صغيرة (clicks: 0, impressions: 41, pos: 12.0)
#       - كم سعر انبوبه الغاز (clicks: 0, impressions: 40, pos: 2.7)
#       - سعر انبوبة الغاز في جدة 2025 (clicks: 0, impressions: 40, pos: 7.2)
#       - اسطوانه فايبر غاز (clicks: 0, impressions: 40, pos: 6.4)
#       - سعر اسطوانة غاز منزلي في السعودية 2025 (clicks: 0, impressions: 39, pos: 8.3)
#       - اسطوانة غاز بلاستيك (clicks: 2, impressions: 39, pos: 12.4)
#       - سعر اسطوانة غاز في السعودية 2025 (clicks: 0, impressions: 38, pos: 7.5)
#       - وزن اسطوانة الغاز الكبيرة فارغة (clicks: 0, impressions: 37, pos: 3.6)
#       - كم وزن انبوبه الغاز مليانه (clicks: 0, impressions: 37, pos: 1.4)
#       - سعر تعبئة اسطوانة غاز منزلي في السعودية 2025 (clicks: 0, impressions: 37, pos: 5.9)
#       - سعر اسطوانة غاز منزلي السعودية 2025 (clicks: 0, impressions: 37, pos: 8.2)
#       - اسعار انابيب الغاز الجديدة (clicks: 0, impressions: 37, pos: 7.2)
#       - انبوبه غاز فايبر (clicks: 1, impressions: 36, pos: 8.2)
#       - اسعار الاسطوانات الجديده (clicks: 0, impressions: 36, pos: 4.8)
#       - اسطوانات الغاز البلاستيكية (clicks: 2, impressions: 36, pos: 4.5)
#       - سعر اسطوانة غاز فايبر السعودية (clicks: 0, impressions: 35, pos: 5.3)
#       - دبة غاز فيبر (clicks: 3, impressions: 35, pos: 9.9)
#       - انواع اسطوانات الغاز (clicks: 0, impressions: 35, pos: 8.7)
#       - كم سعر تغيير اسطوانة الغاز (clicks: 0, impressions: 34, pos: 1.0)
#       - سعر امبوبة الغاز (clicks: 0, impressions: 34, pos: 7.6)
#       - سعر اسطوانة الغاز في جدة (clicks: 0, impressions: 34, pos: 10.2)
#       - ساكو اسطوانة غاز (clicks: 1, impressions: 34, pos: 13.8)
#       - اسطوانه فيبر (clicks: 0, impressions: 33, pos: 5.6)
#       - اسطوانةًغاز فايبر (clicks: 1, impressions: 33, pos: 8.8)
#       - كم سعر اسطوانة الغاز في جدة (clicks: 0, impressions: 32, pos: 2.0)
#       - سعر تغيير اسطوانة الغاز في السعودية (clicks: 0, impressions: 32, pos: 1.4)
#       - سعر اسطوانة الغاز المنزلي السعودية 2025 (clicks: 0, impressions: 32, pos: 8.4)
#       - اسطوانة حديد (clicks: 0, impressions: 32, pos: 9.4)
#       - كم سعر دبه الغاز في السعوديه (clicks: 0, impressions: 31, pos: 1.0)
#       - سعر اسطوانة الغاز فايبر (clicks: 1, impressions: 31, pos: 4.0)
#       - بدلها اسطوانة غاز (clicks: 0, impressions: 31, pos: 10.6)
#       - عرض اسطوانة غاز فايبر (clicks: 0, impressions: 30, pos: 10.0)
#       - سعر تعبئة اسطوانة غاز منزلي السعودية 2025 (clicks: 0, impressions: 30, pos: 5.5)
#       - سعر انبوبه الغاز (clicks: 0, impressions: 30, pos: 2.7)
#       - سعر الاسطوانة (clicks: 0, impressions: 30, pos: 5.0)
#       - اسطوانه غاز (clicks: 0, impressions: 30, pos: 23.1)
#       - كم سعر الاسطوانه الغاز (clicks: 0, impressions: 29, pos: 3.8)
#       - كم سعر اسطوانة الغاز جديدة في السعودية (clicks: 0, impressions: 29, pos: 1.0)
#       - اسطوانة الغاز الجديدة في السعودية (clicks: 0, impressions: 29, pos: 9.6)
#       - كم سعر تعبئة اسطوانة الغاز (clicks: 0, impressions: 28, pos: 15.0)
#       - سعر اسطوانة الغاز المنزلي في السعودية 2025 (clicks: 0, impressions: 28, pos: 9.8)
#       - حجم اسطوانة الغاز الحديد (clicks: 0, impressions: 28, pos: 4.3)
#       - تبديل أسطوانة غاز فايبر (clicks: 0, impressions: 28, pos: 3.4)
#       - اسطوانة فيبر (clicks: 0, impressions: 28, pos: 7.8)
#       - اسطوانة الغاز فايبر (clicks: 1, impressions: 28, pos: 4.8)
#       - كم سعر الاسطوانه الفايبر (clicks: 1, impressions: 27, pos: 5.9)
#       - سعر اسطوانة غاز (clicks: 0, impressions: 27, pos: 3.6)
#       - كم سعر تبديل الغاز (clicks: 0, impressions: 26, pos: 2.3)
#       - اسطوانة فايبر غازكو (clicks: 0, impressions: 26, pos: 10.1)
#       - اسطوانة غاز صغيرة فايبر (clicks: 0, impressions: 26, pos: 7.2)
#       - سعر اسطوانة غاز 2025 السعودية (clicks: 0, impressions: 25, pos: 8.1)
#       - دبه غاز فايبر (clicks: 0, impressions: 25, pos: 11.2)
#       - دبة غاز (clicks: 0, impressions: 25, pos: 88.6)
#       - دبات الغاز الفايبر (clicks: 0, impressions: 25, pos: 4.8)
#       - استبدال اسطوانة غاز حديد بفايبر (clicks: 2, impressions: 25, pos: 4.4)
#       - سعر اسطوانة الغاز السعودية (clicks: 0, impressions: 24, pos: 19.4)
#       - جرة الغاز البلاستيك (clicks: 2, impressions: 24, pos: 2.9)
#       - وزن دبة الغاز (clicks: 0, impressions: 23, pos: 2.9)
#       - كم سعر استبدال اسطوانة الغاز (clicks: 0, impressions: 23, pos: 7.9)
#       - سعر الاسطوانه الزرقاء (clicks: 0, impressions: 23, pos: 5.6)
#       - سعر اسطوانة غاز جديدة السعودية (clicks: 0, impressions: 23, pos: 9.1)
#       - اسطوانة غاز كم سعرها (clicks: 0, impressions: 23, pos: 6.8)
#       - اسطوانة غاز فايبر سعر (clicks: 0, impressions: 23, pos: 5.6)
#       - دبة الغاز الفايبر (clicks: 1, impressions: 22, pos: 4.8)
#       - منتجات غازكو (clicks: 0, impressions: 21, pos: 6.1)
#       - اسطوانه الغاز (clicks: 0, impressions: 21, pos: 7.9)
#       - اسطوانة (clicks: 0, impressions: 21, pos: 42.6)
#       - وزن اسطوانة الغاز في السعودية (clicks: 0, impressions: 20, pos: 10.3)
#       - كم سعر الاسطوانه الغاز في السعوديه (clicks: 0, impressions: 20, pos: 1.4)
#       - كم سعر اسطوانة الغاز جديدة 2025 (clicks: 0, impressions: 20, pos: 6.0)
#       - سعر تعبئة أسطوانة الغاز السعودية 2025 (clicks: 0, impressions: 20, pos: 7.8)
#       - سعر اسطوانة الفايبر (clicks: 1, impressions: 20, pos: 3.2)
#       - انابيب فايبر (clicks: 0, impressions: 20, pos: 8.8)
#       - اسعار اسطوانات الغاز (clicks: 0, impressions: 20, pos: 21.1)
#       - اسطوانة غاز فايبر 11 كيلو (clicks: 0, impressions: 20, pos: 17.8)
#       - وزن الانبوبه الغاز مليانه (clicks: 0, impressions: 19, pos: 1.0)
#       - كم اسطوانة الغاز (clicks: 0, impressions: 19, pos: 5.4)
#       - سعر اسطوانة الغاز جديدة في السعودية (clicks: 0, impressions: 19, pos: 1.2)
#       - بكم اسطوانة الغاز (clicks: 0, impressions: 19, pos: 19.6)
#       - الاسطوانات الجديدة (clicks: 1, impressions: 19, pos: 5.4)
#       - كم سعر اسطوانة الغاز الفارغة (clicks: 0, impressions: 18, pos: 15.2)
#       - دبه غاز فيبر (clicks: 0, impressions: 18, pos: 9.6)
#       - اسطوانة غاز فايبر الرياض (clicks: 0, impressions: 18, pos: 11.2)
#       - سعر تعبئة اسطوانة غاز في السعودية 2025 (clicks: 0, impressions: 17, pos: 8.6)
#       - سعر تبديل اسطوانة الغاز الفايبر (clicks: 0, impressions: 17, pos: 1.4)
#       - سعر أسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 17, pos: 7.8)
#       - اسطوانة غاز كبيرة (clicks: 0, impressions: 17, pos: 45.2)
#       - أسطوانة غاز فايبر 5 كيلو (clicks: 0, impressions: 17, pos: 17.4)
#       - سعر أنبوبة الغاز الحديد (clicks: 0, impressions: 16, pos: 12.5)
#       - سرندل غاز فايبر (clicks: 0, impressions: 16, pos: 7.6)
#       - انبوبه غاز (clicks: 0, impressions: 16, pos: 19.1)
#       - اسعار الغاز (clicks: 0, impressions: 16, pos: 2.6)
#       - اسطوانة غاز الجديدة (clicks: 0, impressions: 16, pos: 12.2)
#       - استبدال اسطوانة غاز فايبر (clicks: 0, impressions: 16, pos: 10.6)
#       - سعر تعبئة أسطوانة الغاز السعودية 2025 (clicks: 0, impressions: 15, pos: 5.0)
#       - دبة غاز صغيرة فايبر (clicks: 1, impressions: 15, pos: 13.6)
#       - انابيب غاز (clicks: 1, impressions: 15, pos: 44.3)
#       - اسعار اسطوانة الغاز الجديدة (clicks: 0, impressions: 15, pos: 4.2)
#       - اسطوانة غاز فايبر عروض اليوم الوطني (clicks: 0, impressions: 15, pos: 3.0)
#       - ابعاد انبوبة البوتاجاز (clicks: 0, impressions: 15, pos: 3.6)
#       - سعر انبوبة الغاز في جدة (clicks: 0, impressions: 14, pos: 22.9)
#       - سعر انبوبة البوتاجاز في السعودية (clicks: 0, impressions: 14, pos: 1.4)
#       - سعر الانبوبة الجديدة في السعودية (clicks: 0, impressions: 14, pos: 1.3)
#       - سعر اسطوانه الغاز الجديده (clicks: 0, impressions: 14, pos: 8.1)
#       - سعر أنبوبة الغاز (clicks: 0, impressions: 14, pos: 8.4)
#       - انبوبة غاز بلاستيك (clicks: 0, impressions: 14, pos: 28.9)
#       - انابيب الغاز الجديدة (clicks: 0, impressions: 14, pos: 6.3)
#       - اسطوانة غاز فايبر غازكو (clicks: 0, impressions: 14, pos: 4.4)
#       - اسطوانة غاز ساكو (clicks: 0, impressions: 14, pos: 21.5)
#       - مقاسات اسطوانة الغاز المنزلي (clicks: 0, impressions: 13, pos: 15.0)
#       - شراء اسطوانة غاز جديدة (clicks: 0, impressions: 13, pos: 15.6)
#       - سعر تبديل أسطوانة الغاز في السعودية (clicks: 0, impressions: 13, pos: 1.2)
#       - اسعار انبوبة الغاز الجديدة (clicks: 0, impressions: 13, pos: 6.2)
#       - اسطوانة غاز فايبر جدة (clicks: 0, impressions: 13, pos: 18.8)
#       - استبدال اسطوانة الغاز (clicks: 0, impressions: 13, pos: 10.1)
#       - سعر تغيير اسطوانة الغاز (clicks: 0, impressions: 12, pos: 5.0)
#       - سعر الانبوبه الحديد (clicks: 0, impressions: 12, pos: 18.2)
#       - سعر اسطوانة الغاز في الرياض (clicks: 0, impressions: 12, pos: 1.5)
#       - سعر اسطوانة الغاز جدة (clicks: 0, impressions: 12, pos: 9.8)
#       - تغيير انبوبة الغاز (clicks: 0, impressions: 12, pos: 15.8)
#       - اسطوانه (clicks: 0, impressions: 12, pos: 57.1)
#       - غازكو اسعار الغاز (clicks: 0, impressions: 11, pos: 2.6)
#       - غاز اسطوانة (clicks: 0, impressions: 11, pos: 8.6)
#       - عيوب أسطوانات الغاز البلاستيكية (clicks: 0, impressions: 11, pos: 3.4)
#       - سعر شراء اسطوانة الغاز الجديدة (clicks: 0, impressions: 11, pos: 5.7)
#       - سعر انبوبة الغاز في السعودية 2025 (clicks: 0, impressions: 11, pos: 6.5)
#       - سعر الاسطوانه في السعوديه (clicks: 0, impressions: 11, pos: 1.0)
#       - سعر اسطوانة الغاز في جدة 2025 (clicks: 0, impressions: 11, pos: 3.2)
#       - سعر اسطوانة الغاز في الرياض 2025 (clicks: 0, impressions: 11, pos: 4.8)
#       - سرندل غاز (clicks: 0, impressions: 11, pos: 34.8)
#       - ساكو اسطوانة فايبر (clicks: 0, impressions: 11, pos: 6.9)
#       - جرة غاز بلاستيك (clicks: 0, impressions: 11, pos: 2.3)
#       - انبوبه الغاز (clicks: 0, impressions: 11, pos: 4.4)
#       - الاسطوانه الزرقاء (clicks: 0, impressions: 11, pos: 2.7)
#       - الاسطوانه الخفيفه (clicks: 0, impressions: 11, pos: 2.0)
#       - اسعار تبديل الغاز (clicks: 0, impressions: 11, pos: 2.1)
#       - اسعار الغاز في السعودية (clicks: 0, impressions: 11, pos: 2.8)
#       - اسطوانة غاز صغيرة (clicks: 0, impressions: 11, pos: 45.2)
#       - استبدال اسطوانة غاز (clicks: 1, impressions: 11, pos: 12.4)
#       - محل غاز محايل عسير (clicks: 0, impressions: 10, pos: 2.3)
#       - كم وزن اسطوانه الغاز (clicks: 0, impressions: 10, pos: 1.3)
#       - كم سعر دبة الغاز الفايبر (clicks: 1, impressions: 10, pos: 3.6)
#       - كم سعر انبوبة الغاز في جدة (clicks: 0, impressions: 10, pos: 1.2)
#       - سلندر غاز (clicks: 0, impressions: 10, pos: 51.4)
#       - سعر تبديل اسطوانة الغاز (clicks: 0, impressions: 10, pos: 18.8)
#       - سعر اسطوانة الغاز جديده (clicks: 0, impressions: 10, pos: 3.4)
#       - دبة فايبر (clicks: 0, impressions: 10, pos: 10.5)
#       - تبديل غاز فايبر (clicks: 0, impressions: 10, pos: 3.6)
#       - اسعار اسطوانة الغاز في السعودية (clicks: 0, impressions: 10, pos: 4.6)
#       - اسعار اسطوانة الغاز (clicks: 0, impressions: 10, pos: 18.5)
#       - اسطوانة غاز فايبر 5 كيلو (clicks: 0, impressions: 10, pos: 23.4)
#       - اسطوانة غاز طويله (clicks: 0, impressions: 10, pos: 15.1)
#       - اسطوانة الغاز كم لتر (clicks: 0, impressions: 10, pos: 55.6)
#       - ارخص اسطوانة غاز فايبر (clicks: 0, impressions: 10, pos: 4.7)
#       - أسطوانة غاز فايبر 11 كيلو (clicks: 0, impressions: 10, pos: 18.6)
#       - كم سعر دبة الغاز الجديدة (clicks: 0, impressions: 9, pos: 4.1)
#       - غاز بلاستيك (clicks: 0, impressions: 9, pos: 2.6)
#       - سعر تعبئة اسطوانة الغاز السعودية 2025 (clicks: 0, impressions: 9, pos: 8.8)
#       - سعر اسطوانه الغاز (clicks: 0, impressions: 9, pos: 2.8)
#       - اسطوانة غاز قطر (clicks: 0, impressions: 9, pos: 1.0)
#       - اسطوانة غاز فايبر من ساكو (clicks: 0, impressions: 9, pos: 3.8)
#       - احجام اسطوانات الغاز (clicks: 0, impressions: 9, pos: 23.9)
#       - أسطوانة غاز مضغوط (clicks: 0, impressions: 9, pos: 84.2)
#       - fiber gas cylinder (clicks: 0, impressions: 9, pos: 8.1)
#       - وزن اسطوانة الغاز الكويت (clicks: 0, impressions: 8, pos: 1.0)
#       - غاز الفيبر (clicks: 0, impressions: 8, pos: 7.6)
#       - شراء اسطوانة غاز (clicks: 0, impressions: 8, pos: 18.8)
#       - سعر تبديل الغاز (clicks: 0, impressions: 8, pos: 5.9)
#       - سعر أنبوبة الغاز الجديدة في السعودية 2024 (clicks: 0, impressions: 8, pos: 9.6)
#       - سعر اسطوانة الغاز في مصر (clicks: 0, impressions: 8, pos: 2.2)
#       - سعر اسطوانة الغاز الجديدة السعودية (clicks: 0, impressions: 8, pos: 8.2)
#       - سعر أسطوانة غاز فايبر جلاس مصر 2026 (clicks: 0, impressions: 8, pos: 10.6)
#       - دبة الغاز (clicks: 0, impressions: 8, pos: 43.5)
#       - حجم اسطوانة الغاز (clicks: 0, impressions: 8, pos: 46.0)
#       - جرار غاز (clicks: 0, impressions: 8, pos: 8.6)
#       - اسطوانه الغاز البلاستيك (clicks: 2, impressions: 8, pos: 3.8)
#       - اسطوانة غاز كبيره (clicks: 0, impressions: 8, pos: 68.8)
#       - اسطوانة غاز فايبر عرض (clicks: 0, impressions: 8, pos: 12.5)
#       - اسطوانة غاز فايبر 24 لتر (clicks: 0, impressions: 8, pos: 20.6)
#       - اسطوانة الغاز كم كيلو (clicks: 0, impressions: 8, pos: 8.5)
#       - اسطوانات غاز بلاستيكية (clicks: 1, impressions: 8, pos: 3.6)
#       - وزن الجرة فارغة (clicks: 0, impressions: 7, pos: 1.8)
#       - مقاسات اسطوانة الغاز (clicks: 0, impressions: 7, pos: 29.9)
#       - كم وزن اسطوانة الغاز فارغة (clicks: 0, impressions: 7, pos: 16.9)
#       - فايبر اسطوانة (clicks: 0, impressions: 7, pos: 3.4)
#       - غاز اسطوانه (clicks: 0, impressions: 7, pos: 41.0)
#       - سعر دبة الغاز في السعودية (clicks: 0, impressions: 7, pos: 9.5)
#       - سعر تعبئة اسطوانة غاز منزلي في السعودية (clicks: 0, impressions: 7, pos: 8.8)
#       - سعر تعبئة اسطوانة غاز في جدة 2025 (clicks: 0, impressions: 7, pos: 2.5)
#       - سعر تعبئة اسطوانة غاز السعودية (clicks: 0, impressions: 7, pos: 9.7)
#       - سعر تعبئة أسطوانة الغاز في السعودية 2025 (clicks: 0, impressions: 7, pos: 1.0)
#       - سعر الغاز في جدة (clicks: 0, impressions: 7, pos: 2.7)
#       - سعر الانبوبه غاز (clicks: 0, impressions: 7, pos: 3.0)
#       - سعر اسطوانة غاز في السعودية (clicks: 0, impressions: 7, pos: 5.3)
#       - سعر اسطوانة غاز صغيرة (clicks: 0, impressions: 7, pos: 1.9)
#       - سعر اسطوانة الغاز بعد الضريبة ١٥٪ (clicks: 0, impressions: 7, pos: 4.0)
#       - سعر اسطوانة الغاز المنزلي السعودية (clicks: 0, impressions: 7, pos: 10.6)
#       - سعر استبدال اسطوانة الغاز في السعودية (clicks: 0, impressions: 7, pos: 10.9)
#       - دبه غاز (clicks: 0, impressions: 7, pos: 64.7)
#       - دبات الغاز الجديده (clicks: 0, impressions: 7, pos: 4.9)
#       - تغيير اسطوانة الغاز (clicks: 0, impressions: 7, pos: 37.6)
#       - تبديل اسطوانة الغاز (clicks: 0, impressions: 7, pos: 54.2)
#       - بكم تعبئة اسطوانة الغاز (clicks: 0, impressions: 7, pos: 41.7)
#       - اسعار الاسطوانات الغاز (clicks: 0, impressions: 7, pos: 15.4)
#       - اسطوانه جديده (clicks: 0, impressions: 7, pos: 19.7)
#       - اسطوانة غاز فايبر حراج (clicks: 0, impressions: 7, pos: 5.0)
#       - اسطوانة الغاز البلاستيك (clicks: 1, impressions: 7, pos: 2.2)
#       - إسطوانة غاز (clicks: 0, impressions: 7, pos: 49.1)
#       - أسطوانة غاز بلاستيك سعرها (clicks: 0, impressions: 7, pos: 10.0)
#       - وزن انبوبه البوتاجاز مليانه (clicks: 0, impressions: 6, pos: 1.0)
#       - وزن الاسطوانة الغاز (clicks: 0, impressions: 6, pos: 1.0)
#       - وزن اسطوانة الغاز (clicks: 0, impressions: 6, pos: 35.5)
#       - كم وزن جرة الغاز مليانه (clicks: 0, impressions: 6, pos: 1.0)
#       - كم سعر تعبئة اسطوانة الغاز في السعودية (clicks: 0, impressions: 6, pos: 28.0)
#       - كم سعر تبديل اسطوانة الغاز (clicks: 0, impressions: 6, pos: 1.2)
#       - كم سعر اسطوانه الغاز (clicks: 0, impressions: 6, pos: 3.2)
#       - كم سعة اسطوانة الغاز الحديد (clicks: 0, impressions: 6, pos: 9.3)
#       - غاز بلاستيك ساكو (clicks: 0, impressions: 6, pos: 3.3)
#       - سعر دبة غاز فايبر (clicks: 0, impressions: 6, pos: 3.3)
#       - سعر تعبئة اسطوانة غاز منزلي في الرياض 2025 (clicks: 0, impressions: 6, pos: 6.0)
#       - سعر تعبئة اسطوانة غاز في جدة (clicks: 0, impressions: 6, pos: 10.8)
#       - سعر تعبئة اسطوانة غاز في الرياض 2025 (clicks: 0, impressions: 6, pos: 5.2)
#       - سعر اسطوانة الغاز السعودية جديده (clicks: 0, impressions: 6, pos: 2.3)
#       - دبة فيبر (clicks: 0, impressions: 6, pos: 11.2)
#       - تغيير الغاز (clicks: 0, impressions: 6, pos: 64.8)
#       - اسعار الاسطوانه الغاز (clicks: 0, impressions: 6, pos: 2.0)
#       - اسعار اسطوانات الغاز الجديدة في السعودية (clicks: 0, impressions: 6, pos: 1.0)
#       - اسطوانة غاز فايبر عروض (clicks: 0, impressions: 6, pos: 20.8)
#       - اسطوانة غاز جديده (clicks: 0, impressions: 6, pos: 12.2)
#       - اسطوانة غاز بلاستيكية (clicks: 0, impressions: 6, pos: 4.3)
#       - اسطوانة بلاستيك (clicks: 0, impressions: 6, pos: 15.0)
#       - استبدال إسطوانة الغاز الحديد بالفايبر جدة (clicks: 1, impressions: 6, pos: 13.3)
#       - fiber cylinder (clicks: 0, impressions: 6, pos: 5.5)
#       - كم كيلو اسطوانة الغاز (clicks: 0, impressions: 5, pos: 5.4)
#       - كم سعر اسطوانه (clicks: 0, impressions: 5, pos: 6.8)
#       - كم سعر اسطوانة غاز (clicks: 0, impressions: 5, pos: 5.6)
#       - كم سعر أنبوبة الغاز (clicks: 0, impressions: 5, pos: 3.4)
#       - كم سعر أسطوانة الغاز جديدة في السعوديه (clicks: 0, impressions: 5, pos: 1.0)
#       - قنينة غاز بلاستيك (clicks: 2, impressions: 5, pos: 2.0)
#
# [7 issues] https://awazly.com/malm-lyash-jdh
#   1. Skipped heading: h2 → h4 (line 49)
#   2. Title too_short (46 chars, range 50-60)
#   3. Description too_short (143 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (6):
#       - لياسه ملونه خارجيه (clicks: 0, impressions: 6, pos: 45.7)
#       - لياسة ملونه (clicks: 0, impressions: 5, pos: 45.6)
#       - سعر متر اللياسة في السعودية 2025 (clicks: 0, impressions: 5, pos: 10.0)
#       - لياسه ملونه (clicks: 0, impressions: 2, pos: 39.0)
#       - خلط الجبس مع الاسمنت في اللياسة (clicks: 0, impressions: 1, pos: 55.0)
#       - الياسه (clicks: 0, impressions: 1, pos: 1.0)
#
# [7 issues] https://awazly.com/trkyb-aybwksy-bmkh
#   1. No external links
#   2. Title too_short (45 chars, range 50-60)
#   3. Description too_short (138 chars, range 150-160)
#   4. Focus keyword not in H1
#   5. Focus keyword not in description
#   6. Focus keyword not in title
#   7. Focus keyword not in first 100 words
#  Missing queries (72):
#       - شركات تركيب أرضيات اليوريثين (clicks: 0, impressions: 244, pos: 58.9)
#       - اسعار دهانات epoxy جوتن (clicks: 1, impressions: 154, pos: 6.7)
#       - ايبوكسي جوتن للارضيات (clicks: 0, impressions: 29, pos: 9.8)
#       - اسعار ارضيات ايبوكسي (clicks: 0, impressions: 13, pos: 1.0)
#       - ابوكسي جوتن (clicks: 0, impressions: 11, pos: 14.0)
#       - أفضل الدهانات الإبوكسي (clicks: 0, impressions: 10, pos: 81.2)
#       - سعر برميل ايبوكسي جوتن (clicks: 0, impressions: 7, pos: 20.9)
#       - سعر جالون الايبوكسي ١٠ كيلو (clicks: 0, impressions: 6, pos: 2.8)
#       - دهانات أرضيات إيبوكسي بمكة المكرمة (clicks: 0, impressions: 4, pos: 16.8)
#       - ايبوكسي ارضيات سعر المتر (clicks: 0, impressions: 4, pos: 1.0)
#       - اسعار ايبوكسي الارضيات (clicks: 0, impressions: 4, pos: 1.2)
#       - سعر متر الايبوكسى (clicks: 0, impressions: 3, pos: 2.0)
#       - سعر جالون الايبوكسي 2024 (clicks: 0, impressions: 3, pos: 12.7)
#       - تكلفة متر الايبوكسي للارضيات (clicks: 0, impressions: 3, pos: 33.0)
#       - كم سعر الجالون الايبوكسي (clicks: 0, impressions: 2, pos: 1.0)
#       - سعر المتر ايبوكسي ارضيات (clicks: 0, impressions: 2, pos: 49.0)
#       - سعر الابوكسي (clicks: 0, impressions: 2, pos: 1.0)
#       - سطل ايبوكسي (clicks: 0, impressions: 2, pos: 2.0)
#       - دهان ارضيات ايبوكسى (clicks: 0, impressions: 2, pos: 98.0)
#       - اسعار ارضيات الايبوكسي (clicks: 0, impressions: 2, pos: 1.0)
#       - معلم ابوكسي (clicks: 0, impressions: 1, pos: 161.0)
#       - كم يكلف تقريبا (clicks: 0, impressions: 1, pos: 3.0)
#       - كم سعره؟ (clicks: 0, impressions: 1, pos: 5.0)
#       - كم سعره في السعودية (clicks: 0, impressions: 1, pos: 2.0)
#       - كم سعره (clicks: 0, impressions: 1, pos: 3.0)
#       - كم سعر الابوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - كم الاسعار (clicks: 0, impressions: 1, pos: 2.0)
#       - طيب في السعوديه (clicks: 0, impressions: 1, pos: 2.0)
#       - طلاء الأرضيات دهانات epoxy جوتن (clicks: 0, impressions: 1, pos: 1.0)
#       - شركه جوتن (clicks: 1, impressions: 1, pos: 3.0)
#       - سعرها كام (clicks: 0, impressions: 1, pos: 9.0)
#       - سعر متر الفوم مكة (clicks: 0, impressions: 1, pos: 70.0)
#       - سعر ماده الايبوكسي (clicks: 0, impressions: 1, pos: 2.0)
#       - سعر مادة الايبوكسي للارضيات (clicks: 0, impressions: 1, pos: 1.0)
#       - سعر كيمابوكسى 101 (clicks: 0, impressions: 1, pos: 21.0)
#       - سعر صبغ جوتن (clicks: 0, impressions: 1, pos: 2.0)
#       - سعر دهان عازل للرطوبة من جوتن (clicks: 0, impressions: 1, pos: 42.0)
#       - سعر دهان الايبوكسي للارضيات (clicks: 0, impressions: 1, pos: 75.0)
#       - سعر جردل ايبوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - سعر جالون الايبوكسي 25 كيلو (clicks: 0, impressions: 1, pos: 2.0)
#       - سعر جالون الإيبوكسي بديل السيراميك (clicks: 0, impressions: 1, pos: 66.0)
#       - سعر بوية جوتن (clicks: 0, impressions: 1, pos: 2.0)
#       - سعر المتر الايبوكسي (clicks: 0, impressions: 1, pos: 2.0)
#       - سعر الجالون الايبوكسي (clicks: 0, impressions: 1, pos: 2.0)
#       - سعر الايبوكسي للارضيات (clicks: 0, impressions: 1, pos: 1.0)
#       - سعر الابوكسى (clicks: 0, impressions: 1, pos: 1.0)
#       - سعر اديبوند 65 في السعودية (clicks: 0, impressions: 1, pos: 1.0)
#       - دهانات جوتن للارضيات (clicks: 0, impressions: 1, pos: 17.0)
#       - دهانات epoxy للارضيات (clicks: 0, impressions: 1, pos: 95.0)
#       - دهان البلاط ايبوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - جوتن ابوكسي (clicks: 0, impressions: 1, pos: 27.0)
#       - تكلفته كام (clicks: 0, impressions: 1, pos: 1.0)
#       - تكلفة الايبوكسي للارضيات (clicks: 0, impressions: 1, pos: 85.0)
#       - بروكسي ارضيات ايبوكسي (clicks: 0, impressions: 1, pos: 2.0)
#       - الوان ايبوكسي جوتن (clicks: 0, impressions: 1, pos: 9.0)
#       - التكلفه (clicks: 0, impressions: 1, pos: 8.0)
#       - اسعار جوتن (clicks: 0, impressions: 1, pos: 2.0)
#       - اسعار جالون الايبوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار بويات جوتن (clicks: 0, impressions: 1, pos: 3.0)
#       - اسعار ايبوكسي ارضيات (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار الايبوكسي ميتاليك (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار الايبوكسي في السعودية (clicks: 0, impressions: 1, pos: 2.0)
#       - اسعار الايبوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار الايبوكسى (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار أرضيات ايبوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار epoxy في السعودية (clicks: 0, impressions: 1, pos: 82.0)
#       - استخدامات اديبوند 65 (clicks: 0, impressions: 1, pos: 1.0)
#       - اديبوند 65 في السعودية (clicks: 0, impressions: 1, pos: 30.0)
#       - اتش بي فاين جوتن (clicks: 0, impressions: 1, pos: 11.0)
#       - أسعار دهانات جوتن ٢٠٢٤ (clicks: 0, impressions: 1, pos: 3.0)
#       - jotun self levelling epoxy (clicks: 0, impressions: 1, pos: 8.0)
#       - jota floor paint (clicks: 0, impressions: 1, pos: 3.0)
#
# [6 issues] https://awazly.com/kshf-tsrbat-almyah-fy-msqt
#   1. Title too_long (69 chars, range 50-60)
#   2. Description too_long (195 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (7):
#       - شركة كشف تسربات المياة بمسقط عمان (clicks: 0, impressions: 151, pos: 37.5)
#       - أفضل خدمات إصلاح خزانات المياه ومعالجة التسربات في مسقط (clicks: 0, impressions: 150, pos: 25.9)
#       - افضل شركة عزل مسابح بمسقط عمان (clicks: 0, impressions: 46, pos: 55.3)
#       - افضل شركة فحص منازل بمسقط عمان (clicks: 0, impressions: 13, pos: 62.4)
#       - شركة كشف تسربات المياه بصلالة (clicks: 0, impressions: 2, pos: 25.5)
#       - شركة كشف تسربات المياه بصحار (clicks: 0, impressions: 2, pos: 30.0)
#       - شركة كشف تسربات المياه بالقطيف (clicks: 0, impressions: 1, pos: 116.0)
#
# [6 issues] https://awazly.com/shrkh-nql-afsh-fy-alqahrh
#   1. No external links
#   2. Description too_long (176 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (64):
#       - اسعار شركات نقل العفش بالقاهرة (clicks: 0, impressions: 110, pos: 9.3)
#       - شركات نقل العفش فى الاقهرة (clicks: 0, impressions: 104, pos: 68.9)
#       - اسعار نقل العفش (clicks: 0, impressions: 96, pos: 39.4)
#       - شركه نقل عفش بالقاهره (clicks: 0, impressions: 94, pos: 75.2)
#       - شركات نقل الاثاث بالقاهره (clicks: 0, impressions: 89, pos: 61.9)
#       - شركات نقل اثاث بالقاهره (clicks: 0, impressions: 87, pos: 58.1)
#       - دليلك لاختيار افضل كراتين نقل عفش (clicks: 0, impressions: 76, pos: 27.8)
#       - شركات نقل عفش بالقاهره (clicks: 0, impressions: 58, pos: 44.5)
#       - شركه نقل عفش (clicks: 0, impressions: 57, pos: 53.2)
#       - شركات نقل الاثاث في القاهره (clicks: 0, impressions: 53, pos: 81.4)
#       - افضل شركه نقل اثاث في مصر (clicks: 0, impressions: 52, pos: 57.4)
#       - ارخص شركة نقل عفش (clicks: 0, impressions: 50, pos: 54.4)
#       - شركات نقل اثاث في القاهره (clicks: 0, impressions: 44, pos: 65.1)
#       - افضل شركه نقل اثاث (clicks: 0, impressions: 44, pos: 81.6)
#       - افضل شركه نقل عفش (clicks: 0, impressions: 43, pos: 65.3)
#       - شركه نقل اثاث (clicks: 0, impressions: 26, pos: 56.2)
#       - شركات نقل وتغليف الاثاث فى مصر (clicks: 0, impressions: 25, pos: 71.1)
#       - شركات نقل عفش في القاهره (clicks: 0, impressions: 21, pos: 7.9)
#       - شركة نقل اثاث بالقاهره (clicks: 0, impressions: 17, pos: 72.9)
#       - شركات نقل ألأثاث بمصر (clicks: 0, impressions: 17, pos: 36.9)
#       - اسعار نقل الاثاث فى مصر (clicks: 0, impressions: 14, pos: 47.6)
#       - شركات نقل اثاث التجمع الخامس، المنطقة الصناعية، قسم أول القاهرة الجديدة (clicks: 0, impressions: 13, pos: 6.2)
#       - اسعار شركات نقل الاثاث (clicks: 0, impressions: 10, pos: 22.5)
#       - افضل شركه نقل عفش في مصر (clicks: 0, impressions: 9, pos: 68.9)
#       - نقل العفش والاثاث (clicks: 0, impressions: 8, pos: 45.4)
#       - ارخص شركه نقل اثاث (clicks: 0, impressions: 8, pos: 41.6)
#       - نقل اثاث مصر اسعار (clicks: 0, impressions: 7, pos: 12.7)
#       - ارخص شركات نقل الاثاث (clicks: 0, impressions: 6, pos: 75.5)
#       - نقل وتغليف اثاث (clicks: 0, impressions: 5, pos: 55.2)
#       - اسعار نقل العفش في مصر (clicks: 0, impressions: 5, pos: 28.4)
#       - ارخص شركه نقل عفش (clicks: 0, impressions: 5, pos: 63.8)
#       - شركه نقل اثاث في مصر (clicks: 0, impressions: 4, pos: 72.5)
#       - شركة نقل وتغليف الاثاث (clicks: 0, impressions: 4, pos: 63.2)
#       - ارخص شركة نقل اثاث (clicks: 0, impressions: 4, pos: 66.2)
#       - نقل وتغليف الاثاث (clicks: 0, impressions: 3, pos: 39.3)
#       - نقل عفش حولي (clicks: 0, impressions: 3, pos: 48.7)
#       - نقل عفش بارخص الاسعار (clicks: 0, impressions: 3, pos: 56.0)
#       - عربية نقل عفش القاهرة (clicks: 0, impressions: 3, pos: 37.5)
#       - شركة نقل عفش التجملع الخامس (clicks: 0, impressions: 3, pos: 98.3)
#       - شركه نقل موبيليا (clicks: 0, impressions: 2, pos: 63.5)
#       - شركه نقل اثاث بمصر الجديده (clicks: 0, impressions: 2, pos: 93.0)
#       - شركه نقل اثاث بالقاهره (clicks: 0, impressions: 2, pos: 25.0)
#       - شركة نقل عفش بجاردن سيتي (clicks: 0, impressions: 2, pos: 55.5)
#       - سهل لنقل العفش والأثاث (clicks: 0, impressions: 2, pos: 60.0)
#       - تريلا نقل عفش (clicks: 0, impressions: 2, pos: 79.0)
#       - ارقام شركات نقل عفش (clicks: 0, impressions: 2, pos: 38.5)
#       - ادوات نقل الاثاث (clicks: 0, impressions: 2, pos: 59.0)
#       - نقليات عفش (clicks: 0, impressions: 1, pos: 22.0)
#       - نقل غرفة نوم (clicks: 0, impressions: 1, pos: 1.0)
#       - نقل عفش واثاث (clicks: 0, impressions: 1, pos: 59.0)
#       - نقل عفش سلوى (clicks: 0, impressions: 1, pos: 30.0)
#       - نقل عفش القاهره (clicks: 0, impressions: 1, pos: 8.0)
#       - نجوم الرياضي فرع حدائق الاهرام الهرم (clicks: 0, impressions: 1, pos: 1.0)
#       - شركه نقل اثاث في التجمع الخامس (clicks: 0, impressions: 1, pos: 27.0)
#       - شركه لنقل الاثاث (clicks: 0, impressions: 1, pos: 93.0)
#       - شركة نقل عفش بالتجمع الخامس (clicks: 0, impressions: 1, pos: 160.0)
#       - شركة نقل عفش الحويه (clicks: 0, impressions: 1, pos: 81.0)
#       - شركات نقل الاثاث بالتجمع الاول (clicks: 0, impressions: 1, pos: 103.0)
#       - انقلي (clicks: 0, impressions: 1, pos: 28.0)
#       - اسعار نقل عفش (clicks: 0, impressions: 1, pos: 18.0)
#       - اسعار نقل الاثاث (clicks: 0, impressions: 1, pos: 1.0)
#       - ارقام نقل العفش (clicks: 0, impressions: 1, pos: 64.0)
#       - ارقام شركات نقل اثاث (clicks: 0, impressions: 1, pos: 40.0)
#       - ارخص شركات نقل اثاث (clicks: 0, impressions: 1, pos: 67.0)
#
# [6 issues] https://awazly.com/shrkh-azl-asth-bmsqt
#   1. Title too_short (21 chars, range 50-60)
#   2. Description too_short (124 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (20):
#       - ارخص شركة عوازل بعمان (clicks: 0, impressions: 171, pos: 57.6)
#       - تركيب وتر بروف للسطح (clicks: 0, impressions: 156, pos: 29.4)
#       - عزل اسطح بصحار (clicks: 0, impressions: 135, pos: 27.0)
#       - وتربروف للسطح (clicks: 0, impressions: 26, pos: 39.5)
#       - شركة عزل اسطح بصحار (clicks: 0, impressions: 8, pos: 13.5)
#       - شركة عزل فوم بصحار (clicks: 0, impressions: 6, pos: 14.2)
#       - شركة عزل اسطح بنزوي (clicks: 0, impressions: 6, pos: 51.8)
#       - شركة عزل اسطح ببهلاء (clicks: 0, impressions: 6, pos: 57.7)
#       - شركة عزل فوم ببركاء (clicks: 0, impressions: 5, pos: 24.0)
#       - عزل فوم بصحار (clicks: 0, impressions: 4, pos: 44.8)
#       - شركة كشف تسربات المياه صلالة عمان (clicks: 0, impressions: 4, pos: 63.0)
#       - شركة عزل اسطح بالبريمي (clicks: 0, impressions: 4, pos: 67.5)
#       - مؤسسة عزل فوم بمسقط (clicks: 0, impressions: 3, pos: 10.8)
#       - وتر بروف للسطح (clicks: 0, impressions: 2, pos: 20.5)
#       - شركة عزل اسطح بمسلية (clicks: 0, impressions: 2, pos: 38.0)
#       - شركة عزل اسطح ببركاء (clicks: 0, impressions: 2, pos: 62.5)
#       - عزل اسطح بنزوي (clicks: 0, impressions: 1, pos: 87.0)
#       - عزل اسطح بالبريمي (clicks: 0, impressions: 1, pos: 86.0)
#       - سعر العازل للسطح (clicks: 0, impressions: 1, pos: 6.0)
#       - أهمية القراءة (clicks: 0, impressions: 1, pos: 160.0)
#
# [6 issues] https://awazly.com/shrkh-nql-afsh-sfwy
#   1. Title too_short (48 chars, range 50-60)
#   2. Description too_short (120 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (2):
#       - المميز صفوى (clicks: 0, impressions: 3, pos: 24.3)
#       - الصفوة لنقل العفش (clicks: 0, impressions: 2, pos: 92.5)
#
# [6 issues] https://awazly.com/shrkh-nql-afsh-balkwyt
#   1. Title too_long (93 chars, range 50-60)
#   2. Description too_short (146 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (10):
#       - نقل عفش المنطقه العاشره (clicks: 0, impressions: 819, pos: 57.0)
#       - شركه نقل عفش وتغليف الكويت (clicks: 0, impressions: 388, pos: 79.9)
#       - ارقام نقل عفش الكويت (clicks: 0, impressions: 386, pos: 82.8)
#       - شركه نقل عفش الكويت (clicks: 0, impressions: 253, pos: 55.3)
#       - تغليف ونقل الاثاث (clicks: 0, impressions: 54, pos: 56.2)
#       - شركه نقل (clicks: 0, impressions: 46, pos: 75.7)
#       - ارقام شركات نقل عفش في الكويت (clicks: 0, impressions: 29, pos: 75.1)
#       - شركة الكوٌت لنقل الأغراض (clicks: 0, impressions: 24, pos: 71.2)
#       - تغليف ونقل عفش (clicks: 0, impressions: 22, pos: 47.7)
#       - شركة لنقل الاثاث (clicks: 0, impressions: 6, pos: 69.0)
#
# [6 issues] https://awazly.com/sbak-baldwadmy
#   1. Title too_long (99 chars, range 50-60)
#   2. Description too_long (185 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (9):
#       - صيانة وتصليح جميع انواع سباكة (clicks: 0, impressions: 42, pos: 88.0)
#       - سباك محترف لجيمع انواع السباكة (clicks: 0, impressions: 42, pos: 68.6)
#       - سباك محترف لجميع انواع السباكة (clicks: 0, impressions: 7, pos: 77.3)
#       - اضرار الجاكوزي الحار (clicks: 0, impressions: 3, pos: 78.0)
#       - اقرب محل سباك (clicks: 0, impressions: 2, pos: 76.0)
#       - محل سباكة وكهرباء مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#       - فلتر الدوادمي (clicks: 0, impressions: 1, pos: 54.0)
#       - المستلزمات الطبية (clicks: 0, impressions: 1, pos: 1.0)
#       - السباكة والكهرباء (clicks: 0, impressions: 1, pos: 1.0)
#
# [6 issues] https://awazly.com/trkyb-aybwksy-almdynh-almnwrh
#   1. Title too_long (62 chars, range 50-60)
#   2. Description too_long (169 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (13):
#       - شركة تنفيذ ايبوكسي ارضيات بالدمام (clicks: 0, impressions: 32, pos: 75.4)
#       - شركة ايبوكسي أرضيات بالدمام (clicks: 0, impressions: 4, pos: 71.3)
#       - تنفيذ اعمال الايبوكسي (clicks: 0, impressions: 4, pos: 82.0)
#       - سعر كيمابوكسي 131 (clicks: 0, impressions: 3, pos: 9.5)
#       - سعر جالون epoxy في الكويت (clicks: 0, impressions: 2, pos: 30.5)
#       - وكم سعرها (clicks: 0, impressions: 1, pos: 2.0)
#       - معلم تركيب باركيه بالمدينة المنورة (clicks: 0, impressions: 1, pos: 82.0)
#       - كم سعر علبه (clicks: 0, impressions: 1, pos: 11.0)
#       - شركه عزل خزانات بالمدينة المنورة (clicks: 0, impressions: 1, pos: 99.0)
#       - سعر كيمابوكسي 101 (clicks: 0, impressions: 1, pos: 12.0)
#       - سعر بوية الايبوكسي (clicks: 0, impressions: 1, pos: 1.0)
#       - اين يباع في السعودية (clicks: 0, impressions: 1, pos: 3.0)
#       - ابوكسي خارجي (clicks: 0, impressions: 1, pos: 83.0)
#
# [6 issues] https://awazly.com/afdhl-maalm-mdynh-alkhbr
#   1. Title too_short (47 chars, range 50-60)
#   2. Description missing (0 chars, range 150-160)
#   3. Focus keyword not in H1
#   4. Focus keyword not in description
#   5. Focus keyword not in title
#   6. Focus keyword not in first 100 words
#  Missing queries (19):
#       - مركز سايتك للعلوم والتقنية بالمملكة العربية السعودية (clicks: 0, impressions: 37, pos: 69.8)
#       - الأنشطة السياحية في الخبر (clicks: 0, impressions: 25, pos: 89.3)
#       - مركز سلطان بن عبد العزيز للعلوم والتقنية سايتك بالسعودية (clicks: 0, impressions: 18, pos: 76.9)
#       - أفضل الأماكن في الخبر (clicks: 0, impressions: 9, pos: 11.0)
#       - صور الواجهه البحريه الخبر (clicks: 0, impressions: 8, pos: 3.8)
#       - جزيرة الدغيثر بالخبر (clicks: 0, impressions: 7, pos: 61.8)
#       - كورنيش الراكة (clicks: 0, impressions: 3, pos: 53.0)
#       - صور برج الخبر (clicks: 0, impressions: 3, pos: 5.3)
#       - جلسات شاطئ نصف القمر (clicks: 0, impressions: 2, pos: 91.5)
#       - الواجهه البحريه الخبر (clicks: 0, impressions: 2, pos: 16.0)
# ...
#       - عزل مائي اكريليك (clicks: 0, impressions: 2, pos: 33.5)
#       - عزل اسطح بمسقط (clicks: 0, impressions: 2, pos: 79.5)
#       - شركة كشف تسربات المياه بالمدينة المنورة (clicks: 0, impressions: 2, pos: 2.0)
#       - شركة عزل اسطح بسراة عبيدة (clicks: 0, impressions: 2, pos: 80.0)
#       - شركة عزل اسطح ببيشة (clicks: 0, impressions: 2, pos: 83.0)
#       - سعر عزل الاكريليك (clicks: 0, impressions: 2, pos: 33.0)
#       - دهان أكريليك عازل (clicks: 0, impressions: 2, pos: 1.0)
#       - تريمكو امريكي (clicks: 0, impressions: 2, pos: 31.5)
#       - ارخص شركة عوازل بعمان (clicks: 0, impressions: 2, pos: 94.5)
#       - مؤسسة أحلام المدن للعزل المائي والحراري المدينة المنورة (clicks: 0, impressions: 1, pos: 13.0)
#       - كم عمره الافتراضي (clicks: 0, impressions: 1, pos: 1.0)
#       - عزل مائي للاسطح (clicks: 0, impressions: 1, pos: 13.0)
#       - عزل الاكريليك (clicks: 0, impressions: 1, pos: 1.0)
#       - عزل الاسطح بالاكريليك (clicks: 0, impressions: 1, pos: 1.0)
#       - عازل فوم امريكي (clicks: 0, impressions: 1, pos: 11.0)
#       - عازل زفت (clicks: 0, impressions: 1, pos: 71.0)
#       - عازل امريكي للحمامات (clicks: 0, impressions: 1, pos: 36.0)
#       - شركة عزل مسابح بمسقط عمان (clicks: 0, impressions: 1, pos: 35.0)
#       - شركة عزل مائى براس تنورة (clicks: 0, impressions: 1, pos: 89.0)
#       - شركة عزل فوم بالجوف (clicks: 0, impressions: 1, pos: 86.0)
#       - شركة عزل اسطح بروضة سدير (clicks: 0, impressions: 1, pos: 54.0)
#       - شركة عزل أسطح بمسقط (clicks: 0, impressions: 1, pos: 62.0)
#       - سعر عزل الفوم للاسطح (clicks: 0, impressions: 1, pos: 97.0)
#       - سعر رولات البيتومين في السعودية (clicks: 0, impressions: 1, pos: 2.0)
#       - أسعار خدمات عزل الأسطح بسكاكا (clicks: 0, impressions: 1, pos: 61.0)
#
# [2 issues] https://awazly.com/shrkh-trmym-mnazl-balryadh
#   1. Title too_short (49 chars, range 50-60)
#   2. Description too_short (133 chars, range 150-160)
#  Missing queries (6):
#       - افضل شركة ترميم منازل بالرياض (clicks: 0, impressions: 255, pos: 86.8)
#       - افضل شركة ترميم بالرياض (clicks: 0, impressions: 106, pos: 81.6)
#       - شركة منازل للصيانة (clicks: 0, impressions: 4, pos: 91.8)
#       - شركه ترميم فلل بالرياض (clicks: 0, impressions: 2, pos: 49.0)
#       - صيانه منازل فى جده (clicks: 0, impressions: 1, pos: 78.0)
#       - شركه ترميم منازل بالرياض (clicks: 0, impressions: 1, pos: 111.0)
#
# [2 issues] https://awazly.com/shrkh-kshf-tsrbat-almyah-bjdh
#   1. Description too_long (171 chars, range 150-160)
#   2. Focus keyword not in description
#  Missing queries (21):
#       - شركة كشف تسربات المياة بجدة (clicks: 0, impressions: 144, pos: 89.2)
#       - كشف تسربات المياه بجده (clicks: 0, impressions: 105, pos: 76.2)
#       - شركه كشف تسربات المياه بجدة (clicks: 0, impressions: 91, pos: 81.6)
#       - كشف تسربات المياة بجدة (clicks: 0, impressions: 87, pos: 82.3)
#       - شركه كشف تسربات المياه بجده (clicks: 0, impressions: 84, pos: 73.3)
#       - كشف تسريب المياه بجده (clicks: 0, impressions: 60, pos: 88.0)
#       - شركة كشف تسربات المياه بجده (clicks: 0, impressions: 54, pos: 78.6)
#       - شركة كشف تسربات الغاز بجدة (clicks: 0, impressions: 50, pos: 81.4)
#       - كشف تسرب المياه بجده (clicks: 0, impressions: 26, pos: 87.3)
#       - ارخص شركة سباكة بمكة جودة عالية بأسعار منافسة خدمة 24 ساعة (clicks: 0, impressions: 20, pos: 50.1)
#       - كشف تسربات بجده (clicks: 0, impressions: 14, pos: 76.9)
#       - كشف تسربات الخزانات بجده (clicks: 0, impressions: 11, pos: 71.6)
#       - شركة كشف تسربات المياة بجدة حل ارتفاع فاتورة المياة عزل اسطح وخزانات (clicks: 0, impressions: 9, pos: 10.2)
#       - كشف تسربات المياه في جده (clicks: 0, impressions: 6, pos: 105.3)
#       - شركة كشف تسربات المياة بمسقط عمان (clicks: 0, impressions: 5, pos: 62.8)
#       - شركة تسريب المياه والعوازل جدة (clicks: 0, impressions: 4, pos: 87.8)
#       - شركه كشف تسرب المياه بجده (clicks: 0, impressions: 2, pos: 124.0)
#       - شركة كشف تسربات المياة بجده (clicks: 0, impressions: 2, pos: 95.0)
#       - ارقام شركات كشف تسرب المياه بجده (clicks: 0, impressions: 2, pos: 42.5)
#       - شركه كشف تسربات المياه في جده (clicks: 0, impressions: 1, pos: 79.0)
#       - saشركة كشف تسربات المياه بجدة اصلاح تسربات الحمامات والمطابخ بجدة (clicks: 0, impressions: 1, pos: 81.0)
#
# [2 issues] https://awazly.com/sbak_bmkh_
#   1. Title too_short (43 chars, range 50-60)
#   2. Description too_short (140 chars, range 150-160)
#  Missing queries (2):
#       - مكه الشوقيه (clicks: 0, impressions: 1, pos: 7.0)
#       - سسباك (clicks: 0, impressions: 1, pos: 11.0)
#
# [1 issue] https://awazly.com/malm-dhanat-kfr-alshykh
#   1. No external links
#  Missing queries (10):
#       - افضل معلم دهانات (clicks: 0, impressions: 49, pos: 10.4)
#       - ما هي عيوب الدهان البلاستيك (clicks: 0, impressions: 4, pos: 77.2)
#       - معلم دهنات (clicks: 0, impressions: 3, pos: 7.0)
#       - محل بويه قريب مني (clicks: 0, impressions: 3, pos: 8.7)
#       - محل بويات قريب مني (clicks: 0, impressions: 3, pos: 6.5)
#       - معلم دهات (clicks: 0, impressions: 1, pos: 6.0)
#       - سعر سيلر حراري جوتن (clicks: 0, impressions: 1, pos: 1.0)
#       - اقرب محل دهانات جوتن (clicks: 0, impressions: 1, pos: 27.0)
#       - اقرب محل دهانات (clicks: 0, impressions: 1, pos: 42.0)
#       - أقرب محل دهانات من موقعي (clicks: 0, impressions: 1, pos: 5.0)
#
# [1 issue] https://awazly.com/shrkh-azl-asth-btbwk
#   1. Description too_short (122 chars, range 150-160)
#  Missing queries (2):
#       - شركه عزل اسطح بتبوك (clicks: 0, impressions: 31, pos: 61.2)
#       - شركه عزل خزانات بتبوك (clicks: 0, impressions: 1, pos: 72.0)
#
# [1 issue] https://awazly.com/aazl-asth-alkwyt
#   1. Title too_long (70 chars, range 50-60)
#  Missing queries (39):
#       - شركة الكويت للعوازل (clicks: 0, impressions: 54, pos: 33.8)
#       - جيتي روف (clicks: 0, impressions: 18, pos: 9.4)
#       - سعر عازل حراري للسقف (clicks: 1, impressions: 12, pos: 5.2)
#       - اسعار العزل المائي (clicks: 1, impressions: 8, pos: 4.5)
#       - شركات العزل في الكويت (clicks: 0, impressions: 7, pos: 19.7)
#       - اسعار عزل الاسطح (clicks: 0, impressions: 5, pos: 2.4)
#       - عازل للسقف (clicks: 0, impressions: 4, pos: 7.0)
#       - اسعار عوازل الاسطح (clicks: 0, impressions: 4, pos: 3.2)
#       - اسعار العازل الحراري للاسطح (clicks: 0, impressions: 4, pos: 4.5)
#       - 20. تكلفة شهادة الايزو في الكويت (clicks: 0, impressions: 4, pos: 49.2)
#       - شركات عزل الاسطح (clicks: 0, impressions: 3, pos: 30.5)
#       - اسعار العوازل (clicks: 0, impressions: 3, pos: 14.7)
#       - أفضل مادة عازلة للرطوبة في الجدران (clicks: 0, impressions: 3, pos: 1.3)
#       - كم يكلف عزل السطح (clicks: 0, impressions: 2, pos: 1.0)
#       - عازل الاسقف (clicks: 0, impressions: 2, pos: 22.5)
#       - سعر العازل للسطح (clicks: 0, impressions: 2, pos: 7.5)
#       - افضل شركات عزل الاسطح (clicks: 0, impressions: 2, pos: 15.0)
#       - اسعار عازل حراري للاسطح (clicks: 0, impressions: 2, pos: 6.0)
#       - كم سعره بالكويت (clicks: 0, impressions: 1, pos: 2.0)
#       - كم سعر المتر عزل الاسطح (clicks: 0, impressions: 1, pos: 12.0)
#       - كم سعر المتر (clicks: 0, impressions: 1, pos: 2.0)
#       - كم تكلفة عزل الخزان الارضي (clicks: 0, impressions: 1, pos: 52.0)
#       - كاس العزل (clicks: 0, impressions: 1, pos: 1.0)
#       - شركه عوازل (clicks: 0, impressions: 1, pos: 34.0)
#       - شركه عزل اسطح (clicks: 0, impressions: 1, pos: 21.0)
#       - شركات عزل اسطح (clicks: 0, impressions: 1, pos: 22.0)
#       - شركات العزل (clicks: 0, impressions: 1, pos: 33.0)
#       - سعر مادة عزل الاسطح (clicks: 0, impressions: 1, pos: 1.0)
#       - سعر رولات العزل (clicks: 0, impressions: 1, pos: 1.0)
#       - جيتروف (clicks: 0, impressions: 1, pos: 4.0)
#       - تكلفة عزل سطح ١٠٠ متر (clicks: 0, impressions: 1, pos: 1.0)
#       - السعر التقريبي (clicks: 0, impressions: 1, pos: 1.0)
#       - افضل عازل حراري ومائي للاسطح (clicks: 0, impressions: 1, pos: 8.0)
#       - اسعار مواد عزل الاسطح (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار مواد العزل المائي (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار عزل الأسطح (clicks: 0, impressions: 1, pos: 87.0)
#       - اسعار عازل مائي للاسطح (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار العزل الحراري للاسطح (clicks: 0, impressions: 1, pos: 1.0)
#       - 10. أفضل شركة ايزو في الكويت (clicks: 0, impressions: 1, pos: 19.0)
#
# [1 issue] https://awazly.com/kshf-khryr-almyah-alkwyt
#   1. Title too_long (99 chars, range 50-60)
#  Missing queries (7):
#       - ارخص شركة كشف خرير ماء الكويت (clicks: 0, impressions: 9, pos: 51.9)
#       - الخرير صوت ماذا (clicks: 0, impressions: 2, pos: 61.5)
#       - ارخص (clicks: 0, impressions: 2, pos: 4.0)
#       - سقوط الماء من السقف في المنام (clicks: 0, impressions: 1, pos: 3.0)
#       - جهاز اكتشاف تسريب المياه (clicks: 0, impressions: 1, pos: 1.0)
#       - تفسير حلم نزول المطر داخل البيت للمتزوجة (clicks: 0, impressions: 1, pos: 2.0)
#       - تصليح محبس المياه الرئيسي (clicks: 0, impressions: 1, pos: 1.0)
#
# [1 issue] https://awazly.com/alryadh-alkhdhraa
#   1. Description too_long (180 chars, range 150-160)
#  Missing queries (1):
#       - برنامج الرياض الخضراء (clicks: 0, impressions: 2, pos: 63.0)
#
# [1 issue] https://awazly.com/alsawdyh-alkhdhraa
#   1. Description too_long (179 chars, range 150-160)
#
# [1 issue] https://awazly.com/altaqh-almtjddh-fy-alsawdyh
#   1. Description too_short (146 chars, range 150-160)
#
# [1 issue] https://awazly.com/malm_lyash_alryadh
#   1. Skipped heading: h2 → h4 (line 49)
#  Missing queries (7):
#       - لياسه ملونه (clicks: 0, impressions: 12, pos: 5.8)
#       - معلم لياسه بالدمام (clicks: 0, impressions: 5, pos: 84.8)
#       - معلم لياسة بالدمام (clicks: 0, impressions: 2, pos: 85.0)
#       - لياسه ملونه خارجيه (clicks: 0, impressions: 1, pos: 97.0)
#       - لياسه اسمنتيه (clicks: 0, impressions: 1, pos: 100.0)
#       - انواع اللياسه (clicks: 0, impressions: 1, pos: 70.0)
#       - الياسه (clicks: 0, impressions: 1, pos: 1.0)
#
# [1 issue] https://awazly.com/shrkh-azl-fwm-baltaef
#   1. Description too_long (206 chars, range 150-160)
#  Missing queries (6):
#       - شركه عزل اسطح بالطائف (clicks: 0, impressions: 164, pos: 86.7)
#       - شركة صبة رغوية بالرياض (clicks: 0, impressions: 116, pos: 75.0)
#       - شركة صبة رغوية بجدة (clicks: 0, impressions: 34, pos: 66.5)
#       - افضل شركه عزل بالطائف (clicks: 0, impressions: 25, pos: 94.0)
#       - صبة رغوية الرياض (clicks: 0, impressions: 3, pos: 87.2)
#       - افضل شركة عزل اسطح بالطائف (clicks: 0, impressions: 1, pos: 74.0)
#
# [1 issue] https://awazly.com/shrkh-kshf-tsrbat-almyah-balryadh
#   1. Description too_short (148 chars, range 150-160)
#  Missing queries (34):
#       - شركة كشف تسربات وعوازل بالرياض (clicks: 0, impressions: 313, pos: 58.8)
#       - كشف تسربات المياه بالرياض حراج (clicks: 0, impressions: 91, pos: 79.4)
#       - شركه كشف تسربات المياه بالرياض (clicks: 0, impressions: 69, pos: 73.1)
#       - شركة كشف تسربات المياه بالرياض حراج (clicks: 0, impressions: 56, pos: 79.7)
#       - كشف تسربات المياه والعوازل (clicks: 0, impressions: 46, pos: 78.3)
#       - كشف تسربات المياه بالرياض | شركة عنادل السفارات المعتمدة لفحص وكشف التسربات (clicks: 0, impressions: 35, pos: 24.6)
#       - شركه كشف تسربات بالرياض (clicks: 0, impressions: 22, pos: 75.3)
#       - ارخص شركة كشف تسربات المياه بالرياض (clicks: 0, impressions: 21, pos: 66.5)
#       - شركة كشف تسربات املج (clicks: 0, impressions: 18, pos: 93.5)
#       - شركه فحص تسربات المياه بالرياض (clicks: 0, impressions: 17, pos: 119.6)
#       - افضل شركات كشف تسربات المياه والعوازل بالرياض 0581553706 (clicks: 0, impressions: 15, pos: 21.1)
#       - أقوي شركة كشف تسربات بالرياض (clicks: 0, impressions: 7, pos: 68.8)
#       - شركة كشف تسربات المياه بالجبيلة (clicks: 0, impressions: 5, pos: 93.4)
#       - كشف تسريات المياه بالرياض (clicks: 0, impressions: 4, pos: 90.5)
#       - كشف تسربات المياه بالرياض مجانا (clicks: 0, impressions: 4, pos: 97.3)
#       - كشف تسربات المياه املج (clicks: 0, impressions: 4, pos: 93.2)
#       - شركة كشف تسربات المياه بالرياض بأحدث الاجهزة المتطورة بدون تكسير بالرياض (clicks: 0, impressions: 4, pos: 38.5)
#       - شركة كشف تسربات المياه املج (clicks: 0, impressions: 4, pos: 92.8)
#       - افضل شركه كشف تسربات المياه بالرياض (clicks: 0, impressions: 4, pos: 66.5)
#       - كشف تسربات المياه غرب الرياض مسودة (clicks: 0, impressions: 3, pos: 84.0)
#       - مؤسسة المدار كشف تسربات المياه بالرياض (clicks: 0, impressions: 2, pos: 26.0)
#       - كشف تسربات المياة بالرياض (clicks: 0, impressions: 2, pos: 101.5)
#       - شركة كشف تسربات المياه بوادي الدواسر (clicks: 0, impressions: 2, pos: 97.5)
#       - شركة كشف تسربات المياة بالرياض (clicks: 0, impressions: 2, pos: 56.5)
#       - كشف تسريبات المياة بالرياض (clicks: 0, impressions: 1, pos: 45.0)
#       - كشف تسربات المياه بحي الزهور الرياض (clicks: 0, impressions: 1, pos: 96.0)
#       - كشف تسربات المياه بالرياض مع الضمان (clicks: 0, impressions: 1, pos: 156.0)
#       - كشف تسربات المياه بالرياض شركة عنادل السفارات المعتمدة لفحص وكشف التسربات (clicks: 0, impressions: 1, pos: 29.0)
#       - شركه كشف تسريب المياه بالرياض (clicks: 0, impressions: 1, pos: 71.0)
#       - شركه كشف تسربات مياه بالرياض (clicks: 0, impressions: 1, pos: 92.0)
#       - شركة كشف تسربات امياه (clicks: 0, impressions: 1, pos: 83.0)
#       - شركة كشف تسربات المياه بحي العليا (clicks: 0, impressions: 1, pos: 80.0)
#       - شركة كشف تسربات المياه بالعليا (clicks: 0, impressions: 1, pos: 82.0)
#       - شركة كشف تسربات المياه بالرياض عزل اسطح بالرياض esus (clicks: 0, impressions: 1, pos: 2.0)
#
# [0 issues] https://awazly.com/tmdyd-ghaz-mrkzy-balmdynh-almnwrh
#  Missing queries (35):
#       - شركة تمديد غاز بمدينة المنورة (clicks: 0, impressions: 128, pos: 11.1)
#       - شركه الغاز المركزي الطائف (clicks: 0, impressions: 94, pos: 47.9)
#       - شركة تمديد غاز مركزى بالاحساء (clicks: 0, impressions: 52, pos: 78.1)
#       - شركة تمديد غاز بالمنازل (clicks: 0, impressions: 36, pos: 65.9)
#       - شركة تمديد غاز مركزي بحفر الباطن (clicks: 0, impressions: 35, pos: 83.5)
#       - شركة تمديد غاز مركزى راس تنورة (clicks: 0, impressions: 14, pos: 89.7)
#       - شركة تمديد غاز مركزى بالدمام (clicks: 0, impressions: 12, pos: 81.7)
#       - تمديد غاز مركزي بابها (clicks: 0, impressions: 9, pos: 68.9)
#       - شركة تمديد غاز مركزى براس تنورة (clicks: 0, impressions: 8, pos: 76.0)
#       - تمديد غاز مركزي بنجران (clicks: 0, impressions: 8, pos: 70.1)
#       - شركه تمديد المكيفات بالمدينة المنورة (clicks: 0, impressions: 7, pos: 68.3)
#       - شركة تمديد غاز مركزي بنجران (clicks: 0, impressions: 6, pos: 71.7)
#       - شركة تمديد غاز مركزي بالباحة (clicks: 0, impressions: 5, pos: 91.8)
#       - شركة تمديد غاز مركزي بابها (clicks: 0, impressions: 5, pos: 89.2)
#       - شركة تمديد الغاز المركزي بى الطائف (clicks: 0, impressions: 5, pos: 47.6)
#       - شركة الغاز المدينه المنوره (clicks: 0, impressions: 5, pos: 11.0)
#       - توصيل غاز ٢٤ ساعة الطائف (clicks: 0, impressions: 5, pos: 32.9)
#       - تمديد غاز مركزي بالباحة (clicks: 0, impressions: 5, pos: 84.4)
#       - توصيل غاز ٢٤ ساعة المدينة المنورة (clicks: 0, impressions: 4, pos: 39.5)
#       - تمديد غاز مركزي بظهران (clicks: 0, impressions: 4, pos: 90.8)
#       - محل غاز. المدينة المنورة (clicks: 0, impressions: 3, pos: 13.2)
#       - شركة تمديد غاز مركزي مكة (clicks: 0, impressions: 2, pos: 84.5)
#       - تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 2, pos: 65.0)
#       - تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 2, pos: 70.0)
#       - اسطوانة غاز مركزي (clicks: 0, impressions: 2, pos: 91.0)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 1, pos: 133.0)
#       - شركه الغاز المركزي (clicks: 0, impressions: 1, pos: 24.0)
#       - شركة تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 1, pos: 100.0)
#       - شركة تمديد غاز مركزى بالقطيف (clicks: 0, impressions: 1, pos: 104.0)
#       - شركة تمديد غاز بمكة (clicks: 0, impressions: 1, pos: 101.0)
#       - شركة تمديد غاز بخميس مشيط (clicks: 0, impressions: 1, pos: 102.0)
#       - شركة تمديد خطوط غاز مكة (clicks: 0, impressions: 1, pos: 101.0)
#       - شركة تركيب صمامات أمان للغاز بالرياض (clicks: 0, impressions: 1, pos: 64.0)
#       - رقم توصيل اسطوانات الغاز للمنازل بالمدينة المنورة (clicks: 0, impressions: 1, pos: 55.0)
#       - الغاز المركزي في البيت (clicks: 0, impressions: 1, pos: 67.0)

# %%
#| hide
report['issues']['https://awazly.com/afdhl-makynat-rsh-whqn-bwly-ywrythan-fwm']
# Out:
# {'file_path': '/home/kobo/Desktop/astro_hacking/awazl/src/content/post/أفضل_ماكينات_رش_وحقن_بولي_يوريثان_فوم.md',
#  'issues': ['No external links',
#   'Title too_long (67 chars, range 50-60)',
#   'Description too_short (131 chars, range 150-160)'],
#  'data': {'missing_queries': [{'query': 'اسعار ماكينة رش الفوم',
#     'total_clicks': 2,
#     'total_impressions': 22,
#     'avg_position': 4.388888888888889,
#     'avg_ctr': 0.1111111111111111},
#    {'query': 'مكينة فوم',
#     'total_clicks': 0,
#     'total_impressions': 5,
#     'avg_position': 23.4,
#     'avg_ctr': 0.0},
#    {'query': 'شركات بولى يوريثان فوم',
#     'total_clicks': 0,
#     'total_impressions': 2,
#     'avg_position': 86.0,
#     'avg_ctr': 0.0},
#    {'query': 'اسعار تأجير اسطح المنازل لشركات المحمول',
#     'total_clicks': 0,
#     'total_impressions': 2,
#     'avg_position': 50.5,
#     'avg_ctr': 0.0},
#    {'query': 'ماكينه',
#     'total_clicks': 0,
#     'total_impressions': 1,
#     'avg_position': 8.0,
#     'avg_ctr': 0.0},
#    {'query': 'ماكينة رش الدهانات للبيع',
#     'total_clicks': 0,
#     'total_impressions': 1,
#     'avg_position': 44.0,
#     'avg_ctr': 0.0},
#    {'query': 'whqn',
#     'total_clicks': 0,
#     'total_impressions': 1,
#     'avg_position': 53.0,
#     'avg_ctr': 0.0},
#    {'query': 'insulation foam machine',
#     'total_clicks': 0,
#     'total_impressions': 1,
#     'avg_position': 6.0,
#     'avg_ctr': 0.0}],
#   'keyword_placement': {'in_h1': True,
#    'in_url': False,
#    'keyword_in_meta': {'in_title': True, 'in_description': True},
#    'keyword_at_first': True}}}
