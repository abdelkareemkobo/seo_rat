# %%
# | default_exp seo_report

# %%
# | export
from sqlmodel import Session, select
from seo_rat.article import get_article_by_path, insert_article, Article
from seo_rat.sqlite_db import SQLiteDB
from seo_rat.models import Website
from seo_rat.content_mapper import map_all_urls_to_files, fetch_sitemap_urls
from seo_rat.content_parser import (
    parse_metadata,
    parse_notebook_metadata,
    remove_metadata,
    extract_headers,
    extract_images,
    extract_links,
    filter_external_links,
    filter_internal_links,
    check_desc_length,
    check_content_length,
    check_title_length,
    imgs_missing_alts,
    extract_notebook_content,
)
from seo_rat.seo_content_analysis import check_h1_count, check_keyword_placement

# %%
# | export
def sync_articles_to_db(
        session: Session, website_id: int, url_file_mapping: dict[str, str]
):
    """Insert all articles into database"""
    for url, file_path in url_file_mapping.items():
        # print(f"Inserting {url} -> {file_path}")
        if file_path:  # Only if file exists
            existing = session.exec(
                select(Article).where(
                    Article.file_path == file_path,
                    Article.website_id == website_id
                )
            ).first()
            if not existing:
                insert_article(session, website_id, file_path, url=url)

# %%
# | hide
#| eval: false
from dotenv import load_dotenv
import os

db = SQLiteDB()
load_dotenv()
# BASE_PATH = os.environ["SEO_RAT_BASE_PATH"]
# BASE_PATH = os.environ["AWAZLY_PATH"]
# BASE_PATH = os.environ["emdadelgaz_PATH"]
BASE_PATH = os.environ["EMDAD_PATH"]

# %%
#| eval: false
#| hide
with db.get_session() as session:
    websites = session.exec(select(Website)).all()
    for w in websites:
        print(f"ID: {w.id}, URL: {w.url}")

    urls = fetch_sitemap_urls("https://emdadelgaz.com/sitemap-0.xml")
    url_mapping = map_all_urls_to_files(
        base_path=f"{BASE_PATH}",
        site_url="https://emdadelgaz.com/",
        urls=urls,
        use_limax=True,
        use_slug_index=False
    )
    sync_articles_to_db(session, website_id=3, url_file_mapping=url_mapping)
    articles = session.exec(select(Article).where(Article.website_id == 3)).all()
    for article in articles:
        print(article)
# Out:
# ID: 1, URL: https://awazly.com
# ID: 2, URL: https://shelid.com
# ID: 3, URL: https://emdadelgaz.com
# id=185 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 23, 934209) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/عازل اسطح الكويت.md' target_goal=None url='https://emdadelgaz.com/aazl-asth-alkwyt'
# id=186 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 51873) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/انواع مواسير الغاز.md' target_goal=None url='https://emdadelgaz.com/anwaa-mwasyr-alghaz'
# id=187 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 63630) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/اسطوانة الغاز فايبر.md' target_goal=None url='https://emdadelgaz.com/astwanh-alghaz-faybr'
# id=188 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 73527) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/خزان الغاز المركزي.md' target_goal=None url='https://emdadelgaz.com/khzan-alghaz-almrkzy'
# id=189 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 83875) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/شركة تمديد غاز بالقصيم.md' target_goal=None url='https://emdadelgaz.com/shrkh-tmdyd-ghaz-balqsym'
# id=190 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 100187) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/شركة تمديد غاز مركزي بالدمام.md' target_goal=None url='https://emdadelgaz.com/shrkh-tmdyd-ghaz-mrkzy-baldmam'
# id=191 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 124039) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة  افران الغاز بالرياض.md' target_goal=None url='https://emdadelgaz.com/syanh-afran-alghaz-balryadh'
# id=192 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 141882) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة أفران الغاز بجدة.md' target_goal=None url='https://emdadelgaz.com/syanh-afran-alghaz-bjdh'
# id=193 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 152480) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة أفران الغاز بمكة.md' target_goal=None url='https://emdadelgaz.com/syanh-afran-alghaz-bmkh'
# id=194 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 163799) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة افران غاز بالمدينة المنورة.md' target_goal=None url='https://emdadelgaz.com/syanh-afran-ghaz-balmdynh-almnwrh'
# id=195 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 175247) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد_الغاز_المركزي_بالطائف.md' target_goal=None url='https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef'
# id=196 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 186463) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي الاحساء.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-alahsaa'
# id=197 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 197354) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/ تمديد الغاز المركزي بالعلا .md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balala'
# id=198 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 208379) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بالمدنية.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh'
# id=199 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 219202) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بالقطيف.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balqtyf'
# id=200 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 228825) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بالرياض.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh'
# id=201 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 239508) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بمكة.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh'
# id=202 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 249829) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بمصر.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr'
# id=203 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 260104) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بيشة.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-byshh'
# id=204 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 270468) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي جدة.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh'
# id=205 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 281605) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي خميس مشيط.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-khmys-mshyt'
# id=206 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 292123) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي تبوك.md' target_goal=None url='https://emdadelgaz.com/tmdyd-alghaz-almrkzy-tbwk'
# id=207 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 302727) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي أبو ظبي.md' target_goal=None url='https://emdadelgaz.com/tmdyd-ghaz-mrkzy-abw-zby'
# id=208 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 313481) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بابها.md' target_goal=None url='https://emdadelgaz.com/tmdyd-ghaz-mrkzy-babha'
# id=209 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 323394) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بالخرج.md' target_goal=None url='https://emdadelgaz.com/tmdyd-ghaz-mrkzy-balkhrj'
# id=210 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 333466) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي للمطاعم.md' target_goal=None url='https://emdadelgaz.com/tmdyd-ghaz-mrkzy-llmtaam'
# id=211 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 354282) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي محايل عسير.md' target_goal=None url='https://emdadelgaz.com/tmdyd-ghaz-mrkzy-mhayl-asyr'
# id=212 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 24, 364327) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد مواسير الغاز للمطبخ.md' target_goal=None url='https://emdadelgaz.com/tmdyd-mwasyr-alghaz-llmtbkh'

# %% [markdown]
# ## Delete Articles in wrong Website

# %%
# from sqlmodel import delete
# session.exec(
#     delete(Article).where(
#         Article.website_id == 2,
#         Article.file_path.contains("emdadgaz")
#     )
# )
# session.commit()

# %%
# | export


def find_duplicate_metadata(
        session: Session, field: str, website_id: int, similarity_threshold: float = 0.9,
) -> list[dict]:
    """Find pages with duplicate or very similar metadata fields"""
    from seo_rat.content_parser import parse_metadata, calculate_similarity

    articles = session.exec(select(Article).where(Article.website_id == website_id)).all()
    values = {}

    # Collect all field values
    for article in articles:
        with open(article.file_path, "r") as f:
            if article.file_path.endswith(".ipynb"):
                metadata = parse_notebook_metadata(f.read())
                values[article.file_path] = metadata.get(field, "")
            elif article.file_path.endswith(".md") or article.file_path.endswith(
                    ".qmd"
            ):
                metadata = parse_metadata(f.read())
                values[article.file_path] = metadata.get(field, "")

    # Find duplicates
    duplicates = []
    checked = set()

    for path1, field1 in values.items():
        for path2, field2 in values.items():
            if path1 >= path2 or (path1, path2) in checked:
                continue
            if not field1 or not field2:
                continue

            similarity = calculate_similarity(field1, field2)
            if similarity >= similarity_threshold:
                duplicates.append(
                    {
                        "file1": path1,
                        "file2": path2,
                        f"{field}_1": field1,
                        f"{field}_2": field2,
                        "similarity": similarity,
                    }
                )
            checked.add((path1, path2))

    return duplicates

# %%
#| hide
from seo_rat.models import Website
from seo_rat.gsc_storage import GSCAnalytics, func

session.exec(select(Website)).all()
session.exec(
    select(GSCAnalytics.site_url, func.count().label("rows"))
    .group_by(GSCAnalytics.site_url)
).all()
# Out:
# [('sc-domain:emdadelgaz.com', 147806),
#  ('sc-domain:gpuvec.com', 121675),
#  ('sc-domain:kareemai.com', 83463),
#  ('sc-domain:shelid.com', 166540)]

# %%
from seo_rat.gsc_storage import GSCAnalytics, func
from sqlmodel import select

with db.get_session() as session:
    result = session.exec(
        select(
            GSCAnalytics.site_url,
            func.count().label("rows"),
            func.count(func.distinct(GSCAnalytics.query)).label("unique_queries"),
            func.count(func.distinct(GSCAnalytics.page)).label("unique_pages"),
            func.min(GSCAnalytics.date).label("earliest"),
            func.max(GSCAnalytics.date).label("latest"),
        ).group_by(GSCAnalytics.site_url)
    ).all()
    for r in result:
        print(r)
# Out:
# ('sc-domain:emdadelgaz.com', 147806, 2894, 46, '2024-11-17', '2026-03-29')
# ('sc-domain:gpuvec.com', 121675, 8389, 921, '2025-03-12', '2026-03-29')
# ('sc-domain:kareemai.com', 83463, 3212, 58, '2024-11-17', '2026-03-29')
# ('sc-domain:shelid.com', 166540, 3918, 77, '2024-11-17', '2026-03-29')

# %%
# | hide
website = Website(url="https://emdadelgaz.com", name="emdadelgaz", lang="ar",
                  desc="موقع متخصص في خدمات تمديد الغاز المركزي في كافة المملكة العربية السعودية وبعض الدول الاخري")
with db.get_session() as session:
    session.add(website)
    session.commit()
    session.refresh(website)
    print(website.id)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: website.url
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[10], line 6
#       4 with db.get_session() as session:
#       5     session.add(website)
# ----> 6     session.commit()
#       7     session.refresh(website)
#       8     print(website.id)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:2030, in Session.commit(self)
#    2027 if trans is None:
#    2028     trans = self._autobegin_t()
# -> 2030 trans.commit(_to_root=True)
#
# File <string>:2, in commit(self, _to_root)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1311, in SessionTransaction.commit(self, _to_root)
#    1309 if self._state is not SessionTransactionState.PREPARED:
#    1310     with self._expect_state(SessionTransactionState.PREPARED):
# -> 1311         self._prepare_impl()
#    1313 if self._parent is None or self.nested:
#    1314     for conn, trans, should_commit, autoclose in set(
#    1315         self._connections.values()
#    1316     ):
#
# File <string>:2, in _prepare_impl(self)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/state_changes.py:137, in _StateChange.declare_states.<locals>._go(fn, self, *arg, **kw)
#     135 self._next_state = _StateChangeStates.CHANGE_IN_PROGRESS
#     136 try:
# --> 137     ret_value = fn(self, *arg, **kw)
#     138 except:
#     139     raise
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:1286, in SessionTransaction._prepare_impl(self)
#    1284     if self.session._is_clean():
#    1285         break
# -> 1286     self.session.flush()
#    1287 else:
#    1288     raise exc.FlushError(
#    1289         "Over 100 subsequent flushes have occurred within "
#    1290         "session.commit() - is an after_flush() hook "
#    1291         "creating new objects?"
#    1292     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4331, in Session.flush(self, objects)
#    4329 try:
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#    4333     self._flushing = False
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4466, in Session._flush(self, objects)
#    4463     transaction.commit()
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     119     assert exc_value is not None
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#     123     self._exc_info = None  # remove potential circular references
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/session.py:4427, in Session._flush(self, objects)
#    4425 self._warn_on_events = True
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#    4429     self._warn_on_events = False
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     464 else:
#     465     for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466         rec.execute(self)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      81     update = _collect_update_commands(
#      82         uowtransaction, table, states_to_update
#      83     )
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)     90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)    119     ),
#     120 )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/orm/persistence.py:1233, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1227     result = connection.execute(
#    1228         statement.values(value_params),
#    1229         params,
#    1230         execution_options=execution_options,
#    1231     )
#    1232 else:
# -> 1233     result = connection.execute(
#    1234         statement,
#    1235         params,
#    1236         execution_options=execution_options,
#    1237     )
#    1239 primary_key = result.inserted_primary_key
#    1240 if primary_key is None:
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     525     if TYPE_CHECKING:
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#     531     raise exc.ObjectNotExecutableError(self)
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1629 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1630     "compiled_cache", self.engine._compiled_cache
#    1631 )
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)   1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#    1654     self.dispatch.after_execute(
#    1655         self,
#    1656         elem,
#    (...)   1660         ret,
#    1661     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2361 elif should_wrap:
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#    2365     assert exc_info[1] is not None
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1965                 break
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#    1972     self.dispatch.after_cursor_execute(
#    1973         self,
#    1974         cursor,
#    (...)   1978         context.executemany,
#    1979     )
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: website.url
# [SQL: INSERT INTO website (url, name, "desc", lang, created_at) VALUES (?, ?, ?, ?, ?)]
# [parameters: ('https://emdadelgaz.com', 'emdadelgaz', 'موقع متخصص في خدمات تمديد الغاز المركزي في كافة المملكة العربية السعودية وبعض الدول الاخري', 'ar', '2026-04-01 08:46:15.574339')]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %% [markdown]
# ## Make FocusKeyword to be Top query from GSC

# %%
#| export 
from seo_rat.gsc_storage import get_top_queries
from seo_rat.article import get_articles_by_website
from seo_rat.gsc_client import get_date_range
from seo_rat.seo_content_analysis import check_keyword_placement, content_freshness
from seo_rat.gsc_insights import find_missing_queries

# %%
#| export
website_name = "https://emdadelgaz.com/"

start, end = get_date_range("last_days", days=90 * 8)
print(start, end)

with db.get_session() as session:
    articles = get_articles_by_website(session, website_id=3)
    for article in articles:
        page_path = article.url.removeprefix(website_name)
        print(page_path)
        print(article)
        break
        top_query = get_top_queries(session=session, site_url="sc-domain:emdadelgaz.com", start_date=start,
                                    end_date=end, page_path=page_path, limit=1, sort_by="impressions")
        top_5_query = get_top_queries(session=session, site_url="sc-domain:emdadelgaz.com", start_date=start,
                                      end_date=end, page_path=page_path, limit=5, sort_by="impressions")
        try:
            print(top_query[0]['query'])
            article.focus_keyword = top_query[0]['query']
            article.secondary_keywords = [q["query"] for q in top_5_query[:5]]
            session.add(article)
            session.commit()
        except IndexError:
            print("No queries found for this page")
# Out:
# 2024-04-08 2026-03-29
# aazl-asth-alkwyt
# id=185 focus_keyword=None created_at=datetime.datetime(2026, 4, 1, 7, 47, 23, 934209) last_optimized=None secondary_keywords=None website_id=3 file_path='/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/عازل اسطح الكويت.md' target_goal=None url='https://emdadelgaz.com/aazl-asth-alkwyt'

# %%
# | export
def analyze_links(content: str, domain: str) -> dict:
    """Analyze internal and external links in content"""
    links = extract_links(content)
    all_urls = list(links.keys())

    internal = filter_internal_links(all_urls, domain)
    external = filter_external_links(all_urls, domain)

    return {
        "total_links": len(all_urls),
        "internal_count": len(internal),
        "external_count": len(external),
        "internal_links": internal,
        "external_links": external,
    }

# %%
# | test
#| eval: false

from seo_rat.content_parser import remove_metadata

with db.get_session() as session:
    article = session.exec(select(Article)).first()
    print(article)
    with open(article.file_path, "r") as f:
        content = remove_metadata(f.read())

link_analysis = analyze_links(content, "emdadelgaz.com")
print(link_analysis)

print(f"Total: {link_analysis['total_links']}")
print(f"Internal: {link_analysis['internal_count']}")
print(f"External: {link_analysis['external_count']}")
# Out:
# id=1 focus_keyword='طريقة تنظيف سيراميك الباركيه من البويه' created_at=datetime.datetime(2026, 3, 29, 1, 29, 26, 457544) last_optimized=None secondary_keywords=['طريقة تنظيف سيراميك الباركيه من البويه', 'عامل بويه', 'معلم تركيب باركيه بالمدينة المنورة', 'عمائر في الدوادمي', 'عمائر تجارية في الدوادمي'] website_id=1 file_path='/home/kobo/Desktop/astro_hacking/awazl/src/content/post/معلم_دهانات_الدوادمي.md' target_goal=None url='https://awazly.com/malm-dhanat-aldwadmy'
# {'total_links': 5, 'internal_count': 0, 'external_count': 5, 'internal_links': [], 'external_links': ['https://awazly.com/trkyb-aybwksy-almdynh-almnwrh', 'https://awazly.com/trkyb-aybwksy-bmkh', 'https://awazly.com/trkyb-aybwksy-jdh', 'https://awazly.com/shrkh-azl-aybwksy-ardhyat-balryadh', 'https://awazly.com/malm-dhanat-balryadh']}
# Total: 5
# Internal: 0
# External: 5

# %%
# | export
def check_heading_structure(headers):
    ans = {}
    has_h2 = any(h["type"] == "h2" for h in headers)
    ans["has_h2"] = has_h2
    levels = [int(h["type"][1]) for h in headers]
    ans["skipped_levels"] = []

    for l in range(len(levels) - 1):
        if levels[l + 1] - levels[l] > 1:
            ans["skipped_levels"].append({"from": headers[l], "to": headers[l + 1]})

    return ans

# %%
# | export
def analyze_article(
        article: Article,
        domain: str,
        is_quarto: bool,
        title_is_h1: bool = False,
        desc_field: str = "description",
        title_field: str = "title",
        date_field: str = "date"
) -> dict:
    """Run all SEO checks for a single article and return its report dict"""
    with open(article.file_path, "r") as f:
        raw_content = f.read()

    if article.file_path.endswith(".ipynb"):
        metadata = parse_notebook_metadata(raw_content)
        content = extract_notebook_content(raw_content, is_quarto=is_quarto)
    else:
        metadata = parse_metadata(raw_content)
        content = remove_metadata(raw_content)

    headers = extract_headers(article.file_path)
    images = extract_images(content)

    return {
        "file_path": article.file_path,
        "title_check": check_title_length(metadata.get(title_field, "")),
        "description_check": check_desc_length(metadata.get(desc_field, "")),
        "content_check": check_content_length(content),
        "h1_check": check_h1_count(
            headers, title=metadata.get("title", ""), title_is_h1=title_is_h1
        ),
        "missing_alts": imgs_missing_alts(images),
        "link_analysis": analyze_links(content, domain),
        "keyword_placement": check_keyword_placement(
            article.focus_keyword,
            metadata=metadata,
            headers=headers,
            content=content,
            url=article.url,
            desc_field=desc_field,
            title_is_h1=title_is_h1,
        ),
        "content_freshness": content_freshness(metadata.get(date_field, "")),
        "content_structure": check_heading_structure(headers),
    }

# %%
# | export
def generate_seo_report(
        session: Session,
        website_id: int,
        domain: str,
        is_quarto: bool,
        title_is_h1: bool = False,
        desc_field: str = "description",
        title_field: str = "title",
        date_field: str = "date",
) -> dict:
    """Generate comprehensive SEO report for all pages"""

    articles = session.exec(
        select(Article).where(Article.website_id == website_id)
    ).all()

    page_reports = []
    issues = {}
    start, end = get_date_range("last_days", days=90 * 8)

    for article in articles:
        try:
            report = analyze_article(
                article,
                domain,
                is_quarto,
                title_is_h1=title_is_h1,
                desc_field=desc_field,
                title_field=title_field,
                date_field=date_field,
            )

            queries = get_top_queries(
                session=session,
                site_url=f"sc-domain:{domain}",
                start_date=start,
                end_date=end,
                page_path=article.url.removeprefix(f"https://{domain}/"),
                limit=500,
                sort_by="impressions",
            )
            content = remove_metadata(open(article.file_path, "r").read())
            missing_queries = find_missing_queries(queries=queries, content=content)

            page_issues = []

            if not report["h1_check"]["has_single_h1"]:
                page_issues.append("Multiple or no H1")
            if not report["content_check"]["is_sufficient"]:
                page_issues.append("Content too short")
            if report["link_analysis"]["internal_count"] == 0:
                page_issues.append("No internal links, at least 3 recommended")
            if report["link_analysis"]["external_count"] == 0:
                page_issues.append("No external links")
            if report["missing_alts"]:
                page_issues.append(f"Images missing alt text ({len(report['missing_alts'])})")
            if report["content_structure"]["skipped_levels"]:
                for skip in report["content_structure"]["skipped_levels"]:
                    page_issues.append(
                        f"Skipped heading: {skip['from']['type']} → {skip['to']['type']} (line {skip['to']['line_number']})"
                    )
            if not report["content_structure"]["has_h2"]:
                page_issues.append("No H2 headings, at least one recommended")

            tc = report["title_check"]
            if tc["status"] != "optimal":
                page_issues.append(f"Title {tc['status']} ({tc['length']} chars, range {tc['min']}-{tc['max']})")

            dc = report["description_check"]
            if dc["status"] != "optimal":
                page_issues.append(f"Description {dc['status']} ({dc['length']} chars, range {dc['min']}-{dc['max']})")

            if not report["content_freshness"]["is_fresh"]:
                page_issues.append(f"Stale content ({report['content_freshness']['days_since_update']} days old)")

            if article.focus_keyword:
                if not report["keyword_placement"]["in_h1"]:
                    page_issues.append("Focus keyword not in H1")
                if not report["keyword_placement"]["keyword_in_meta"]["in_description"]:
                    page_issues.append("Focus keyword not in description")
                if not report["keyword_placement"]["keyword_in_meta"]["in_title"]:
                    page_issues.append("Focus keyword not in title")
                if not report["keyword_placement"]["keyword_at_first"]:
                    page_issues.append("Focus keyword not in first 100 words")

            if page_issues or missing_queries:
                issues[article.url or article.file_path] = {
                    "file_path": article.file_path,
                    "issues": page_issues,
                    "data": {
                        "missing_queries": missing_queries,
                        "keyword_placement": report.get("keyword_placement", {}),
                    }
                }

            page_reports.append(report)

        except Exception as e:
            print(f"Error analyzing {article.file_path}: {e}")

    duplicate_titles = find_duplicate_metadata(
        session, "title", website_id=website_id, similarity_threshold=0.9
    )
    duplicate_descriptions = find_duplicate_metadata(
        session, "description", website_id=website_id, similarity_threshold=0.9
    )

    total_issues = sum(len(v["issues"]) for v in issues.values())

    return {
        "total_pages": len(articles),
        "pages_analyzed": len(page_reports),
        "page_reports": page_reports,
        "duplicate_titles": duplicate_titles,
        "duplicate_descriptions": duplicate_descriptions,
        "issues": issues,
        "summary": {
            "total_issues": total_issues,
            "pages_with_issues": len(issues),
            "duplicate_titles_count": len(duplicate_titles),
            "duplicate_descriptions_count": len(duplicate_descriptions),
        },
    }

# %%
# | export
def print_issues_report(report: dict) -> None:
    """Print SEO issues sorted from most issues to fewest."""
    issues = report["issues"]
    summary = report["summary"]

    print(f"Pages analysed : {report['pages_analyzed']} / {report['total_pages']}")
    print(f"Pages with issues: {summary['pages_with_issues']}")
    print(f"Total issue count: {summary['total_issues']}")
    print(f"Duplicate titles : {summary['duplicate_titles_count']}")
    print(f"Duplicate descs  : {summary['duplicate_descriptions_count']}")
    print("=" * 70)

    sorted_issues = sorted(issues.items(), key=lambda x: len(x[1]["issues"]), reverse=True)

    for url, data in sorted_issues:
        count = len(data["issues"])
        print(f"\n[{count} issue{'s' if count != 1 else ''}] {url}")
        for i, issue in enumerate(data["issues"], 1):
            print(f"  {i}. {issue}")

        missing = data.get("data", {}).get("missing_queries", [])
        if missing:
            print(f" Missing queries ({len(missing)}):")
            for q in missing:
                print(
                    f"      - {q['query']} (clicks: {q['total_clicks']}, impressions: {q['total_impressions']}, pos: {q['avg_position']:.1f})")

# %%
#| hide
from seo_rat.content_parser import get_markdown_files
from seo_rat.article import get_articles_by_website
from seo_rat.seo_content_analysis import  find_cannibalized

# %%
#| hide
articles = get_articles_by_website(session, website_id=3)
print(len(articles))
# Out:
# 28

# %%
#| hide
start, end = get_date_range("last_days", days=60)
find_cannibalized(session, 1, "sc-domain:emdadelgaz.com", start, end)

# %%
#| hide
#| eval: false
report = generate_seo_report(session, website_id=3, domain="emdadelgaz.com", is_quarto=False, title_is_h1=True,
                             desc_field="excerpt", date_field="publishDate", )
print(f"Total pages: {report['total_pages']}")
print(f"Issues found: {report['summary']['total_issues']}")
# Out:
# Total pages: 28
# Issues found: 64

# %%
# | hide
#| eval: false
report
# Out:
# {'total_pages': 28,
#  'pages_analyzed': 28,
#  'page_reports': [{'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/عازل اسطح الكويت.md',
#    'title_check': {'length': 54, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 130,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1035, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 16,
#     'internal_count': 11,
#     'external_count': 5,
#     'internal_links': ['/عوازل-الكويت',
#      '/عازل-جيتاروف-للاسقف',
#      '/كشف-تسربات-مياه-الكويت',
#      '/عازل-امريكي-للاسقف',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/',
#      'https://emdadelgaz.com/shrkh-tmdyd-ghaz-mrkzy-baldmam',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef',
#      'https://emdadelgaz.com/shrkh-tmdyd-ghaz-balqsym'],
#     'external_links': ['https://oudhmotors.com/',
#      'https://www.protienai.com/',
#      'http://www.kuwaitdrain.com/',
#      'https://www.colorkuwait.com/',
#      'https://leakdetectionkw.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/انواع مواسير الغاز.md',
#    'title_check': {'length': 52, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 135,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1708, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 14,
#     'internal_count': 9,
#     'external_count': 5,
#     'internal_links': ['https://emdadelgaz.com/',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef',
#      'https://emdadelgaz.com/tmdyd-ghaz-mrkzy-balkhrj',
#      'https://emdadelgaz.com/tmdyd-mwasyr-alghaz-llmtbkh',
#      'https://emdadelgaz.com/tmdyd-ghaz-mrkzy-llmtaam',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh'],
#     'external_links': ['https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 12, 15),
#     'days_since_update': 472,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/اسطوانة الغاز فايبر.md',
#    'title_check': {'length': 64, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 147,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 961, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 16,
#     'internal_count': 10,
#     'external_count': 6,
#     'internal_links': ['https://emdadelgaz.com',
#      '/tmdyd-alghaz-almrkzy-bmkh',
#      '/tmdyd-alghaz-almrkzy-jdh',
#      '/tmdyd-alghaz-almrkzy-balryadh',
#      '/tmdyd_alghaz_almrkzy_baltaef',
#      '/tmdyd-ghaz-mrkzy-balkhrj',
#      '/tmdyd-mwasyr-alghaz-llmtbkh',
#      '/tmdyd-ghaz-mrkzy-llmtaam',
#      '/tmdyd-alghaz-almrkzy-balmdnyh',
#      '/كشف-تسربات-غاز'],
#     'external_links': ['https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://www.protienai.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/خزان الغاز المركزي.md',
#    'title_check': {'length': 61, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 149,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1537, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 8,
#     'external_count': 3,
#     'internal_links': ['/astwanh-alghaz-faybr',
#      '/khzan-alghaz-almrkzy',
#      '/tmdyd-alghaz-almrkzy-bmkh',
#      '/tmdyd-alghaz-almrkzy-balmdnyh',
#      '/tmdyd-alghaz-almrkzy-balryadh',
#      '/tmdyd-alghaz-almrkzy-jdh',
#      '/tmdyd_alghaz_almrkzy_baltaef',
#      '/anwaa-mwasyr-alghaz'],
#     'external_links': ['https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%d8%b4%d8%b1%d9%83%d8%a9-%d8%b9%d8%b2%d9%84-%d9%81%d9%88%d9%85-%d8%a8%d9%85%d9%83%d8%a9/',
#      'https://manaraazel.sa/%d8%b4%d8%b1%d9%83%d8%a9-%d8%b9%d8%b2%d9%84-%d9%81%d9%88%d9%85-%d8%a8%d8%a7%d9%84%d8%b7%d8%a7%d8%a6%d9%81/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/شركة تمديد غاز بالقصيم.md',
#    'title_check': {'length': 76, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 166,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2033, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 3,
#     'external_count': 8,
#     'internal_links': ['/كشف-تسربات-غاز-بالقصيم',
#      '/صيانة-شبكات-غاز-بالقصيم',
#      '/تركيب-خزانات-غاز-مركزي'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://azlhofuf.com/',
#      'https://www.protienai.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/شركة تمديد غاز مركزي بالدمام.md',
#    'title_check': {'length': 52, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 113,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 966, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 7,
#     'external_count': 3,
#     'internal_links': ['https://emdadelgaz.com/anwaa-mwasyr-alghaz',
#      'https://emdadelgaz.com/khzan-alghaz-almrkzy',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef'],
#     'external_links': ['https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%d8%b4%d8%b1%d9%83%d8%a9-%d8%b9%d8%b2%d9%84-%d9%81%d9%88%d9%85-%d8%a8%d9%85%d9%83%d8%a9/',
#      'https://manaraazel.sa/%d8%b4%d8%b1%d9%83%d8%a9-%d8%b9%d8%b2%d9%84-%d9%81%d9%88%d9%85-%d8%a8%d8%a7%d9%84%d8%b7%d8%a7%d8%a6%d9%81/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 9, 17),
#     'days_since_update': 561,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة  افران الغاز بالرياض.md',
#    'title_check': {'length': 53, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 135,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1039, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 11,
#     'external_count': 0,
#     'internal_links': ['/syanh-afran-alghaz-balryadh',
#      '/tmdyd-alghaz-almrkzy-jdh',
#      '/tmdyd-alghaz-almrkzy-bmkh',
#      '/',
#      '/shrkh-tmdyd-ghaz-mrkzy-baldmam',
#      '/tmdyd_alghaz_almrkzy_baltaef',
#      '/tmdyd-ghaz-mrkzy-abw-zby',
#      '/tmdyd-alghaz-almrkzy-balmdnyh',
#      '/syanh-afran-ghaz-balmdynh-almnwrh',
#      '/tmdyd-alghaz-almrkzy-balryadh',
#      '/كشف-تسربات-غاز'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة أفران الغاز بجدة.md',
#    'title_check': {'length': 50, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 122,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 796, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 10,
#     'external_count': 0,
#     'internal_links': ['/tmdyd-alghaz-almrkzy-jdh',
#      '/tmdyd-alghaz-almrkzy-bmkh',
#      '/shrkh-tmdyd-ghaz-mrkzy-baldmam',
#      '/tmdyd_alghaz_almrkzy_baltaef',
#      '/tmdyd-ghaz-mrkzy-abw-zby',
#      '/syanh-afran-ghaz-balmdynh-almnwrh',
#      '/syanh-afran-alghaz-balryadh',
#      '/shrkh-tmdyd-ghaz-balqsym',
#      '/كشف-تسربات-غاز',
#      '/syanh-afran-alghaz-bjdh'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة أفران الغاز بمكة.md',
#    'title_check': {'length': 52, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 164,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 677, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 8,
#     'external_count': 2,
#     'internal_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/shrkh-tmdyd-ghaz-mrkzy-baldmam',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef',
#      'https://emdadelgaz.com/tmdyd-ghaz-mrkzy-abw-zby',
#      'https://emdadelgaz.com/syanh-afran-ghaz-balmdynh-almnwrh',
#      'https://emdadelgaz.com/syanh-afran-alghaz-balryadh',
#      'https://emdadelgaz.com/shrkh-tmdyd-ghaz-balqsym'],
#     'external_links': ['https://www.protienai.com/',
#      'https://www.tanorfix.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 12, 22),
#     'days_since_update': 465,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة افران غاز بالمدينة المنورة.md',
#    'title_check': {'length': 57, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 130,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1366, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 11,
#     'external_count': 0,
#     'internal_links': ['/syanh-afran-ghaz-balmdynh-almnwrh',
#      '/tmdyd-alghaz-almrkzy-jdh',
#      '/tmdyd-alghaz-almrkzy-bmkh',
#      '/',
#      '/shrkh-tmdyd-ghaz-mrkzy-baldmam',
#      '/tmdyd_alghaz_almrkzy_baltaef',
#      '/tmdyd-alghaz-almrkzy-balmdnyh',
#      '/syanh-afran-alghaz-balryadh',
#      '/كشف-تسربات-غاز',
#      '/shrkh-tmdyd-ghaz-balqsym',
#      '/khzan-alghaz-almrkzy'],
#     'external_links': []},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد_الغاز_المركزي_بالطائف.md',
#    'title_check': {'length': 54, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 146,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2953, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 13,
#     'internal_count': 8,
#     'external_count': 5,
#     'internal_links': ['/كشف-تسربات-غاز',
#      '/anwaa-mwasyr-alghaz',
#      '/khzan-alghaz-almrkzy',
#      '/tmdyd-alghaz-almrkzy-bmkh',
#      '/tmdyd-alghaz-almrkzy-jdh',
#      '/tmdyd-alghaz-almrkzy-balmdnyh',
#      '/tmdyd-alghaz-almrkzy-balryadh',
#      '/aazl-asth-alkwyt'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي الاحساء.md',
#    'title_check': {'length': 53, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 120,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 882, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 6,
#     'internal_count': 4,
#     'external_count': 2,
#     'internal_links': ['https://emdadelgaz.com/',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://www.protienai.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/ تمديد الغاز المركزي بالعلا .md',
#    'title_check': {'length': 39, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 138,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2829, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 1,
#     'external_count': 6,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 6, 8),
#     'days_since_update': 662,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بالمدنية.md',
#    'title_check': {'length': 71, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 103,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2772, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 2,
#     'internal_count': 1,
#     'external_count': 1,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بالقطيف.md',
#    'title_check': {'length': 34, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 101,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2821, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 5,
#     'internal_count': 4,
#     'external_count': 1,
#     'internal_links': ['https://emdadelgaz.com/',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بالرياض.md',
#    'title_check': {'length': 40, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 144,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2934, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 1,
#     'external_count': 6,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بمكة.md',
#    'title_check': {'length': 32, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 150,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 3185, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 2,
#     'external_count': 8,
#     'internal_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/khzan-alghaz-almrkzy'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://oudhmotors.com/',
#      'https://www.protienai.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بمصر.md',
#    'title_check': {'length': 32, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 113,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2509, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 5,
#     'external_count': 2,
#     'internal_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/khzan-alghaz-almrkzy',
#      'https://emdadelgaz.com/',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://www.protienai.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 10, 26),
#     'days_since_update': 522,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بيشة.md',
#    'title_check': {'length': 38, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 138,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2829, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 7,
#     'internal_count': 1,
#     'external_count': 6,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 6, 8),
#     'days_since_update': 662,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي جدة.md',
#    'title_check': {'length': 55, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 112,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 1716, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 9,
#     'internal_count': 2,
#     'external_count': 7,
#     'internal_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-alahsaa',
#      'https://emdadelgaz.com/shrkh-tmdyd-ghaz-mrkzy-baldmam'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://oudhmotors.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي خميس مشيط.md',
#    'title_check': {'length': 43, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 158,
#     'status': 'optimal',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2879, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 1,
#     'external_count': 7,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://azlhofuf.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 6, 8),
#     'days_since_update': 662,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي تبوك.md',
#    'title_check': {'length': 53, 'status': 'optimal', 'min': 50, 'max': 60},
#    'description_check': {'length': 144,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2809, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 6,
#     'external_count': 4,
#     'internal_links': ['/كشف-تسربات-غاز',
#      '/anwaa-mwasyr-alghaz',
#      '/khzan-alghaz-almrkzy',
#      '/tmdyd-alghaz-almrkzy-tbwk',
#      '/aazl-asth-alkwyt',
#      '/shrkh-tmdyd-ghaz-balqsym'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي أبو ظبي.md',
#    'title_check': {'length': 62, 'status': 'too_long', 'min': 50, 'max': 60},
#    'description_check': {'length': 147,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2846, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 11,
#     'internal_count': 7,
#     'external_count': 4,
#     'internal_links': ['/كشف-تسربات-غاز',
#      '/anwaa-mwasyr-alghaz',
#      '/khzan-alghaz-almrkzy',
#      '/tmdyd-ghaz-mrkzy-abw-zby',
#      '/shrkh-tmdyd-ghaz-balqsym',
#      '/tmdyd_alghaz_almrkzy_baltaef',
#      '/aazl-asth-alkwyt'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://www.protienai.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2026, 4, 1),
#     'days_since_update': 0,
#     'is_fresh': True},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بابها.md',
#    'title_check': {'length': 38, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 138,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2989, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 1,
#     'external_count': 7,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://azlhofuf.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 6, 8),
#     'days_since_update': 662,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بالخرج.md',
#    'title_check': {'length': 39, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 143,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2852, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 8,
#     'internal_count': 1,
#     'external_count': 7,
#     'internal_links': ['https://emdadelgaz.com'],
#     'external_links': ['https://www.gasco.com.sa/ar/Pages/default.aspx',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D8%A7%D9%84%D8%B7%D8%A7%D8%A6%D9%81/',
#      'https://manaraazel.sa/%D8%B4%D8%B1%D9%83%D8%A9-%D8%B9%D8%B2%D9%84-%D9%81%D9%88%D9%85-%D8%A8%D9%85%D9%83%D8%A9/',
#      'http://manaraazel.sa/',
#      'https://manaraazel.sa/restoration-company-in-madinah/',
#      'https://azlhofuf.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 1, 9),
#     'days_since_update': 813,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي للمطاعم.md',
#    'title_check': {'length': 36, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 94,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 379, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 7,
#     'external_count': 3,
#     'internal_links': ['https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh',
#      'https://emdadelgaz.com/anwaa-mwasyr-alghaz',
#      'https://emdadelgaz.com/khzan-alghaz-almrkzy',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef'],
#     'external_links': ['https://www.gasco.com.sa/',
#      'https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/restoration-company-in-madinah/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 2, 16),
#     'days_since_update': 775,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي محايل عسير.md',
#    'title_check': {'length': 44, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 162,
#     'status': 'too_long',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 2914, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 13,
#     'internal_count': 8,
#     'external_count': 5,
#     'internal_links': ['https://emdadelgaz.com',
#      'https://emdadelgaz.com/anwaa-mwasyr-alghaz',
#      'https://emdadelgaz.com/khzan-alghaz-almrkzy',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef'],
#     'external_links': ['https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://manaraazel.sa/%d8%b4%d8%b1%d9%83%d8%a9-%d8%b9%d8%b2%d9%84-%d9%81%d9%88%d9%85-%d8%a8%d9%85%d9%83%d8%a9/',
#      'https://manaraazel.sa/%d8%b4%d8%b1%d9%83%d8%a9-%d8%b9%d8%b2%d9%84-%d9%81%d9%88%d9%85-%d8%a8%d8%a7%d9%84%d8%b7%d8%a7%d8%a6%d9%81/',
#      'https://manaraazel.sa/',
#      'https://www.gasco.com.sa/ar/Pages/default.aspx']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 6, 8),
#     'days_since_update': 662,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}},
#   {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد مواسير الغاز للمطبخ.md',
#    'title_check': {'length': 40, 'status': 'too_short', 'min': 50, 'max': 60},
#    'description_check': {'length': 86,
#     'status': 'too_short',
#     'min': 150,
#     'max': 160},
#    'content_check': {'word_count': 533, 'is_sufficient': True},
#    'h1_check': {'h1_count': 1, 'has_single_h1': True, 'h1_source': 'title'},
#    'missing_alts': [],
#    'link_analysis': {'total_links': 10,
#     'internal_count': 8,
#     'external_count': 2,
#     'internal_links': ['https://emdadelgaz.com/',
#      'https://emdadelgaz.com/anwaa-mwasyr-alghaz',
#      'https://emdadelgaz.com/khzan-alghaz-almrkzy',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmkh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-jdh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh',
#      'https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh',
#      'https://emdadelgaz.com/tmdyd_alghaz_almrkzy_baltaef'],
#     'external_links': ['https://manaraazel.sa/services/foam-insulation-company-in-medina/',
#      'https://oudhmotors.com/']},
#    'keyword_placement': {'in_h1': False,
#     'in_url': False,
#     'keyword_in_meta': {'in_title': False, 'in_description': False},
#     'keyword_at_first': False},
#    'content_freshness': {'last_updated': datetime.date(2024, 2, 16),
#     'days_since_update': 775,
#     'is_fresh': False},
#    'content_structure': {'has_h2': True, 'skipped_levels': []}}],
#  'duplicate_titles': [{'file1': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة  افران الغاز بالرياض.md',
#    'file2': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/صيانة أفران الغاز بجدة.md',
#    'title_1': 'صيانة افران الغاز بالرياض - تصليح احترافي 01012097813',
#    'title_2': 'صيانة افران الغاز بجدة - تصليح احترافي 01012097813',
#    'similarity': 0.912621359223301},
#   {'file1': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/ تمديد الغاز المركزي بالعلا .md',
#    'file2': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بابها.md',
#    'title_1': '01012097813 شركة تمديد غاز مركزي بالعلا',
#    'title_2': '01012097813 شركة تمديد غاز مركزي بابها',
#    'similarity': 0.935064935064935},
#   {'file1': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/ تمديد الغاز المركزي بالعلا .md',
#    'file2': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بالخرج.md',
#    'title_1': '01012097813 شركة تمديد غاز مركزي بالعلا',
#    'title_2': '01012097813 شركة تمديد غاز مركزي بالخرج',
#    'similarity': 0.9230769230769231},
#   {'file1': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد الغاز المركزي بيشة.md',
#    'file2': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بابها.md',
#    'title_1': '01012097813 شركة تمديد غاز مركزي ببيشه',
#    'title_2': '01012097813 شركة تمديد غاز مركزي بابها',
#    'similarity': 0.9473684210526315},
#   {'file1': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بابها.md',
#    'file2': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي بالخرج.md',
#    'title_1': '01012097813 شركة تمديد غاز مركزي بابها',
#    'title_2': '01012097813 شركة تمديد غاز مركزي بالخرج',
#    'similarity': 0.9090909090909091}],
#  'duplicate_descriptions': [],
#  'issues': {'https://emdadelgaz.com/aazl-asth-alkwyt': {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/عازل اسطح الكويت.md',
#    'issues': ['Description too_short (130 chars, range 150-160)'],
#    'data': {'missing_queries': [{'query': 'شركة عازل الاسطح الخارجيه',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 64.0,
#       'avg_ctr': 0.0}],
#     'keyword_placement': {'in_h1': False,
#      'in_url': False,
#      'keyword_in_meta': {'in_title': False, 'in_description': False},
#      'keyword_at_first': False}}},
#   'https://emdadelgaz.com/anwaa-mwasyr-alghaz': {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/انواع مواسير الغاز.md',
#    'issues': ['Description too_short (135 chars, range 150-160)',
#     'Stale content (472 days old)'],
#    'data': {'missing_queries': [{'query': 'أين تباع مواسير الغاز',
#       'total_clicks': 21,
#       'total_impressions': 695,
#       'avg_position': 7.788099339649728,
#       'avg_ctr': 0.026012058570198105},
#      {'query': 'المواسير بجميع أنواعها',
#       'total_clicks': 0,
#       'total_impressions': 420,
#       'avg_position': 46.43460648148148,
#       'avg_ctr': 0.0},
#      {'query': 'أنواع أنابيب الغاز المنزلي',
#       'total_clicks': 0,
#       'total_impressions': 137,
#       'avg_position': 6.963302752293578,
#       'avg_ctr': 0.0},
#      {'query': 'مواصير غاز',
#       'total_clicks': 3,
#       'total_impressions': 129,
#       'avg_position': 8.06060606060606,
#       'avg_ctr': 0.02727272727272727},
#      {'query': 'شكل مواسير الغاز',
#       'total_clicks': 0,
#       'total_impressions': 114,
#       'avg_position': 7.357751937984496,
#       'avg_ctr': 0.0},
#      {'query': 'سعر متر مواسير الغاز في مصر',
#       'total_clicks': 1,
#       'total_impressions': 103,
#       'avg_position': 4.869047619047619,
#       'avg_ctr': 0.014285714285714285},
#      {'query': 'مواسير غاز طبيعى',
#       'total_clicks': 0,
#       'total_impressions': 101,
#       'avg_position': 6.125435540069686,
#       'avg_ctr': 0.0},
#      {'query': 'شركة عزل بولي ايثيلين hdpe بجدة',
#       'total_clicks': 0,
#       'total_impressions': 92,
#       'avg_position': 56.08720930232558,
#       'avg_ctr': 0.0},
#      {'query': 'انظمة غاز',
#       'total_clicks': 0,
#       'total_impressions': 85,
#       'avg_position': 49.845238095238095,
#       'avg_ctr': 0.0},
#      {'query': 'انواع انابيب الغاز',
#       'total_clicks': 0,
#       'total_impressions': 74,
#       'avg_position': 5.470149253731344,
#       'avg_ctr': 0.0},
#      {'query': 'ماصورة غاز',
#       'total_clicks': 2,
#       'total_impressions': 72,
#       'avg_position': 18.611940298507463,
#       'avg_ctr': 0.029850746268656716},
#      {'query': 'مواسير غاز للبيع',
#       'total_clicks': 0,
#       'total_impressions': 71,
#       'avg_position': 9.842261904761903,
#       'avg_ctr': 0.0},
#      {'query': 'أنابيب الغاز المنزلي',
#       'total_clicks': 0,
#       'total_impressions': 48,
#       'avg_position': 4.186046511627907,
#       'avg_ctr': 0.0},
#      {'query': 'مواسير غاز بلاستيك',
#       'total_clicks': 2,
#       'total_impressions': 42,
#       'avg_position': 6.847222222222222,
#       'avg_ctr': 0.05555555555555555},
#      {'query': 'انابيب الغاز',
#       'total_clicks': 0,
#       'total_impressions': 41,
#       'avg_position': 1.1971153846153846,
#       'avg_ctr': 0.0},
#      {'query': 'انابيب غاز',
#       'total_clicks': 0,
#       'total_impressions': 35,
#       'avg_position': 1.8529411764705883,
#       'avg_ctr': 0.0},
#      {'query': 'اسعار مواسير الحديد في السعودية',
#       'total_clicks': 0,
#       'total_impressions': 21,
#       'avg_position': 50.71052631578947,
#       'avg_ctr': 0.0},
#      {'query': 'اسعار الغاز المركزي',
#       'total_clicks': 0,
#       'total_impressions': 19,
#       'avg_position': 33.9375,
#       'avg_ctr': 0.0},
#      {'query': 'مواسير الغاز في المطبخ',
#       'total_clicks': 0,
#       'total_impressions': 17,
#       'avg_position': 3.0588235294117645,
#       'avg_ctr': 0.0},
#      {'query': 'ماصوره غاز',
#       'total_clicks': 0,
#       'total_impressions': 17,
#       'avg_position': 7.433333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'ماسوره غاز',
#       'total_clicks': 1,
#       'total_impressions': 17,
#       'avg_position': 8.117647058823529,
#       'avg_ctr': 0.058823529411764705},
#      {'query': 'سعر متر مواسير الغاز الطبيعي في مصر',
#       'total_clicks': 0,
#       'total_impressions': 17,
#       'avg_position': 1.3636363636363635,
#       'avg_ctr': 0.0},
#      {'query': 'مواسير غاز تدفئة مركزية',
#       'total_clicks': 0,
#       'total_impressions': 11,
#       'avg_position': 63.54545454545455,
#       'avg_ctr': 0.0},
#      {'query': 'اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن',
#       'total_clicks': 0,
#       'total_impressions': 11,
#       'avg_position': 57.0,
#       'avg_ctr': 0.0},
#      {'query': 'وصلة غاز نحاس',
#       'total_clicks': 0,
#       'total_impressions': 10,
#       'avg_position': 14.9,
#       'avg_ctr': 0.0},
#      {'query': 'خزانات ستانلس ستيل للبيع بالرياض',
#       'total_clicks': 0,
#       'total_impressions': 8,
#       'avg_position': 39.53333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'تعديل مواسير الغاز الطبيعي',
#       'total_clicks': 0,
#       'total_impressions': 8,
#       'avg_position': 1.3333333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'مواسير استانلس ستيل جدول 10 جدول 40 وجدول 80',
#       'total_clicks': 0,
# ...
#       'avg_position': 37.92857142857143,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزي بالدمام',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 92.42857142857143,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد الغاز المركزي بالدمام',
#       'total_clicks': 0,
#       'total_impressions': 5,
#       'avg_position': 81.4,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد غاز مركزى بالدمام',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 93.0,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزى بجده',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 32.0,
#       'avg_ctr': 0.0},
#      {'query': 'شركة تمديد خطوط غاز مكة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 94.0,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز مركزي الكويت',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 38.0,
#       'avg_ctr': 0.0}],
#     'keyword_placement': {'in_h1': False,
#      'in_url': False,
#      'keyword_in_meta': {'in_title': False, 'in_description': False},
#      'keyword_at_first': False}}},
#   'https://emdadelgaz.com/tmdyd-ghaz-mrkzy-mhayl-asyr': {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد غاز مركزي محايل عسير.md',
#    'issues': ['Title too_short (44 chars, range 50-60)',
#     'Description too_long (162 chars, range 150-160)',
#     'Stale content (662 days old)'],
#    'data': {'missing_queries': [{'query': 'مؤسسة الغامدي لتوزيع الغاز محايل عسير',
#       'total_clicks': 6,
#       'total_impressions': 130,
#       'avg_position': 4.7566210045662105,
#       'avg_ctr': 0.0410958904109589},
#      {'query': 'اقرب محل غاز',
#       'total_clicks': 1,
#       'total_impressions': 45,
#       'avg_position': 2.9078947368421053,
#       'avg_ctr': 0.02631578947368421},
#      {'query': 'محل غاز من موقعي',
#       'total_clicks': 1,
#       'total_impressions': 30,
#       'avg_position': 3.9305555555555554,
#       'avg_ctr': 0.041666666666666664},
#      {'query': 'اقرب محل غاز من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 27,
#       'avg_position': 3.022727272727273,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز قريب من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 4.857142857142857,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل غاز من موقعي مفتوح',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 3.4,
#       'avg_ctr': 0.0},
#      {'query': 'عمائر تجارية للايجار في محايل',
#       'total_clicks': 0,
#       'total_impressions': 6,
#       'avg_position': 45.0,
#       'avg_ctr': 0.0},
#      {'query': 'محلات غاز قريبه من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 5,
#       'avg_position': 3.3333333333333335,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز مفتوح الآن',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 4.666666666666667,
#       'avg_ctr': 0.0},
#      {'query': 'محل الغاز قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 3.6666666666666665,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز بالخرج',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 70.0,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل غاز من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 2.5,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل غاز مفتوح الآن',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 4.333333333333333,
#       'avg_ctr': 0.0},
#      {'query': 'مستودع غاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'محلات غاز قريبه مني',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 10.5,
#       'avg_ctr': 0.0},
#      {'query': 'محل اسطوانات غاز قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل اسطوانات غاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب محل غاز من موقعي مفتوح الآن',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 6.5,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب محل غاز من موقعي في 1.6 كم',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 10.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب محل بيع غاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 3.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب غاز من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 6.0,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل غاز من موقعي مفتوح الآن',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 11.0,
#       'avg_ctr': 0.0},
#      {'query': 'مكتب الخطوط السعودية محايل عسير',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 12.0,
#       'avg_ctr': 0.0},
#      {'query': 'مكان غاز قريب من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 12.0,
#       'avg_ctr': 0.0},
#      {'query': 'مستودع الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'مستشفى مزايا محايل',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 11.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز مفتوح',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز قريب من موقعي مفتوح الآن',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 12.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز فاتح الان',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 6.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل غاز بالقرب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل تعبئة غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل بيع غاز قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 4.0,
#       'avg_ctr': 0.0},
#      {'query': 'محل اسطوانة غاز قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 5.0,
#       'avg_ctr': 0.0},
#      {'query': 'محطة غاز بالقرب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 7.0,
#       'avg_ctr': 0.0},
#      {'query': 'محبس غاز مركزي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'متى يقفل محل الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'غاز بالقرب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 5.0,
#       'avg_ctr': 0.0},
#      {'query': 'عمائر للايجار في محايل عسير',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 49.0,
#       'avg_ctr': 0.0},
#      {'query': 'سنترال غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 9.0,
#       'avg_ctr': 0.0},
#      {'query': 'سعر تبديل اسطوانة الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 7.0,
#       'avg_ctr': 0.0},
#      {'query': 'رقم توصيل اسطوانات الغاز للمنازل',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل غاز ٢٤ ساعة مكة المكرمة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 15.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل غاز ٢٤ ساعة',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل اسطوانات',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'تعبئة غاز توصيل',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'تعبئة اسطوانة غاز توصيل',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'تعبئة اسطوانة غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'بيع غاز قريب مني',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 3.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب مكان غاز من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 3.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب مكان غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب محل غاز من موقعي هذا',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب محل غاز مفتوح الآن',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 11.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب محل اسطوانات غاز من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 3.0,
#       'avg_ctr': 0.0},
#      {'query': 'اقرب فرع غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'اسطوانة غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'اسطوانات غاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'أقرب محل بيع غاز من موقعي',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 4.0,
#       'avg_ctr': 0.0}],
#     'keyword_placement': {'in_h1': False,
#      'in_url': False,
#      'keyword_in_meta': {'in_title': False, 'in_description': False},
#      'keyword_at_first': False}}},
#   'https://emdadelgaz.com/tmdyd-mwasyr-alghaz-llmtbkh': {'file_path': '/home/kobo/Desktop/astro_hacking/emdadgaz/src/content/post/تمديد مواسير الغاز للمطبخ.md',
#    'issues': ['Title too_short (40 chars, range 50-60)',
#     'Description too_short (86 chars, range 150-160)',
#     'Stale content (775 days old)'],
#    'data': {'missing_queries': [{'query': 'سعر تمديد مواسير الغاز',
#       'total_clicks': 1,
#       'total_impressions': 151,
#       'avg_position': 4.069306930693069,
#       'avg_ctr': 0.0049504950495049506},
#      {'query': 'تمديدات الغاز وكشف خطوط الحريق',
#       'total_clicks': 0,
#       'total_impressions': 83,
#       'avg_position': 59.49702380952381,
#       'avg_ctr': 0.0},
#      {'query': 'ماسورة غاز فرن',
#       'total_clicks': 0,
#       'total_impressions': 22,
#       'avg_position': 3.263157894736842,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل انابيب غاز',
#       'total_clicks': 0,
#       'total_impressions': 16,
#       'avg_position': 6.426666666666667,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد انابيب الغاز',
#       'total_clicks': 0,
#       'total_impressions': 16,
#       'avg_position': 9.642857142857142,
#       'avg_ctr': 0.0},
#      {'query': '\u200fالغاز',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 12.0,
#       'avg_ctr': 0.0},
#      {'query': 'كيفية تركيب أنابيب الغاز في المنزل',
#       'total_clicks': 0,
#       'total_impressions': 7,
#       'avg_position': 4.0,
#       'avg_ctr': 0.0},
#      {'query': 'ماسورة غاز',
#       'total_clicks': 0,
#       'total_impressions': 6,
#       'avg_position': 11.8,
#       'avg_ctr': 0.0},
#      {'query': 'تمديدات الغاز في المنزل',
#       'total_clicks': 0,
#       'total_impressions': 4,
#       'avg_position': 1.25,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد غاز للمطاعم',
#       'total_clicks': 0,
#       'total_impressions': 4,
#       'avg_position': 39.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيلات الغاز في المطبخ',
#       'total_clicks': 1,
#       'total_impressions': 3,
#       'avg_position': 11.666666666666666,
#       'avg_ctr': 0.3333333333333333},
#      {'query': 'تركيب مواسير الحريق بجدة',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 82.0,
#       'avg_ctr': 0.0},
#      {'query': 'تركيب غاز الطبخ',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 18.0,
#       'avg_ctr': 0.0},
#      {'query': 'تركيب شبكات غاز مركزي',
#       'total_clicks': 0,
#       'total_impressions': 3,
#       'avg_position': 89.5,
#       'avg_ctr': 0.0},
#      {'query': 'مواسير غاز طبيعى',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 10.0,
#       'avg_ctr': 0.0},
#      {'query': 'ماسورة الغاز في المطبخ',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 29.0,
#       'avg_ctr': 0.0},
#      {'query': 'اللغاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 11.5,
#       'avg_ctr': 0.0},
#      {'query': 'الاغاز',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 22.5,
#       'avg_ctr': 0.0},
#      {'query': 'hgyh.',
#       'total_clicks': 0,
#       'total_impressions': 2,
#       'avg_position': 10.5,
#       'avg_ctr': 0.0},
#      {'query': 'ماسورة مطبخ',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 61.0,
#       'avg_ctr': 0.0},
#      {'query': 'كيفية توصيل الغاز الطبيعى للبوتاجاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'غاز للمطبخ',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 90.0,
#       'avg_ctr': 0.0},
#      {'query': 'صور',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 19.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل انابيب الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'توصيل الغاز الطبيعي للبوتجاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'تمديد الغاز للمطبخ',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 2.0,
#       'avg_ctr': 0.0},
#      {'query': 'تكلفة تركيب الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 1.0,
#       'avg_ctr': 0.0},
#      {'query': 'تسليك غاز الطبخ',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 15.0,
#       'avg_ctr': 0.0},
#      {'query': 'امثلة بالصور',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 44.0,
#       'avg_ctr': 0.0},
#      {'query': 'اماكن بيع أنابيب البوتاجاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 70.0,
#       'avg_ctr': 0.0},
#      {'query': 'الغزا',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 10.0,
#       'avg_ctr': 0.0},
#      {'query': 'أين تباع مواسير الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 78.0,
#       'avg_ctr': 0.0},
#      {'query': 'أنواع محابس الغاز',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 94.0,
#       'avg_ctr': 0.0},
#      {'query': 'norme ventilation gaz cuisine',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 11.0,
#       'avg_ctr': 0.0},
#      {'query': 'norme installation gaz dans une cuisine',
#       'total_clicks': 0,
#       'total_impressions': 1,
#       'avg_position': 4.0,
#       'avg_ctr': 0.0}],
#     'keyword_placement': {'in_h1': False,
#      'in_url': False,
#      'keyword_in_meta': {'in_title': False, 'in_description': False},
#      'keyword_at_first': False}}}},
#  'summary': {'total_issues': 64,
#   'pages_with_issues': 28,
#   'duplicate_titles_count': 5,
#   'duplicate_descriptions_count': 0}}

# %%
#| hide
#| eval: false
print_issues_report(report)
# Out:
# Pages analysed : 28 / 28
# Pages with issues: 28
# Total issue count: 64
# Duplicate titles : 5
# Duplicate descs  : 0
# ======================================================================
#
# [3 issues] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balala
#   1. Title too_short (39 chars, range 50-60)
#   2. Description too_short (138 chars, range 150-160)
#   3. Stale content (662 days old)
#  Missing queries (42):
#       - تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 8, pos: 30.6)
#       - تمديد غاز مركزي بالباحة (clicks: 0, impressions: 8, pos: 34.6)
#       - تطبيق غاز تبوك (clicks: 0, impressions: 8, pos: 69.0)
#       - شركة تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 6, pos: 46.8)
#       - شركة تمديد غاز مركزي بحفر الباطن (clicks: 0, impressions: 6, pos: 59.5)
#       - شركة تمديد غاز مركزي بالباحة (clicks: 0, impressions: 5, pos: 17.9)
#       - شركة تمديد غاز مركزي بنجران (clicks: 0, impressions: 4, pos: 61.5)
#       - شركة تمديد غاز مركزي بالخرج (clicks: 0, impressions: 4, pos: 60.8)
#       - محل اسطوانات غاز (clicks: 0, impressions: 3, pos: 1.0)
#       - محل اسطوانات (clicks: 0, impressions: 3, pos: 1.3)
#       - رقم توصيل اسطوانات الغاز للمنازل (clicks: 0, impressions: 3, pos: 1.0)
#       - تمديد غاز مركزي بنجران (clicks: 0, impressions: 3, pos: 44.0)
#       - محل الغاز العزيزيه (clicks: 0, impressions: 2, pos: 1.0)
#       - محل الاسطوانات (clicks: 0, impressions: 2, pos: 1.0)
#       - محل اسطوانه الغاز (clicks: 0, impressions: 2, pos: 1.0)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 2, pos: 48.5)
#       - شركة تمديد غاز مركزي بحائل (clicks: 0, impressions: 2, pos: 65.0)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 2, pos: 1.0)
#       - تمديد مواسير الغاز بالخرج (clicks: 0, impressions: 2, pos: 68.5)
#       - تمديد غاز مركزي بظهران (clicks: 0, impressions: 2, pos: 57.5)
#       - اسطوانة غاز (clicks: 0, impressions: 2, pos: 3.0)
#       - أقرب محل غاز من موقعي توصيل (clicks: 0, impressions: 2, pos: 1.0)
#       - نعم (clicks: 0, impressions: 1, pos: 5.0)
#       - مستودع غاز قريب مني مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محل تعبئة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل تعبئة اسطوانات الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات قريب مني (clicks: 0, impressions: 1, pos: 1.0)
#       - شركه تمديد (clicks: 0, impressions: 1, pos: 91.0)
#       - شركة تمديد مواسير الغاز بالخرج (clicks: 0, impressions: 1, pos: 86.0)
#       - شركة تمديد غاز مركزي بظهران (clicks: 0, impressions: 1, pos: 94.0)
#       - شركة تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 1, pos: 119.0)
#       - شركة تمديد غاز مركزي بالرياض (clicks: 0, impressions: 1, pos: 13.0)
#       - توصيل غاز ٢٤ ساعة تبوك (clicks: 0, impressions: 1, pos: 6.0)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 1, pos: 59.0)
#       - تمديد غاز مركزي بالخرج (clicks: 0, impressions: 1, pos: 51.0)
#       - تمديد غاز مركزي الكويت (clicks: 0, impressions: 1, pos: 77.0)
#       - تمديد غاز مركزى بجده (clicks: 0, impressions: 1, pos: 39.0)
#       - تمديد غاز بالخرج (clicks: 0, impressions: 1, pos: 89.0)
#       - تعبئه اسطوانه (clicks: 0, impressions: 1, pos: 1.0)
#       - الاسطوانات الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - أقرب مستودع غاز من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balmdnyh
#   1. Title too_long (71 chars, range 50-60)
#   2. Description too_short (103 chars, range 150-160)
#   3. Stale content (813 days old)
#  Missing queries (312):
#       - رقم توصيل اسطوانات الغاز للمنازل بالمدينة المنورة (clicks: 4, impressions: 1368, pos: 9.6)
#       - اقرب محل غاز من موقعي (clicks: 0, impressions: 1032, pos: 5.9)
#       - شركة تمديد غاز بالمنازل (clicks: 0, impressions: 733, pos: 16.7)
#       - اقرب محل غاز (clicks: 0, impressions: 675, pos: 9.9)
#       - توصيل اسطوانات غاز المدينة المنورة (clicks: 0, impressions: 244, pos: 11.1)
#       - غاز المدينه (clicks: 0, impressions: 189, pos: 7.0)
#       - توصيل غاز المدينة المنورة العزيزية (clicks: 1, impressions: 189, pos: 12.1)
#       - أقرب محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 182, pos: 10.0)
#       - شركة تمديد غاز بمدينة المنورة (clicks: 0, impressions: 174, pos: 1.8)
#       - شركة الغاز المدينه المنوره (clicks: 4, impressions: 163, pos: 4.7)
#       - اقرب غاز من موقعي (clicks: 0, impressions: 141, pos: 6.2)
#       - محل غاز مفتوح الآن (clicks: 0, impressions: 114, pos: 8.2)
#       - شركه الغاز المركزي (clicks: 0, impressions: 114, pos: 22.6)
#       - أقرب محطة غاز من موقعي (clicks: 0, impressions: 84, pos: 4.6)
#       - ارقام توصيل غاز المدينة (clicks: 1, impressions: 62, pos: 9.2)
#       - محلات غاز المدينه (clicks: 0, impressions: 61, pos: 6.8)
#       - تأسيس غاز مركزي (clicks: 1, impressions: 61, pos: 15.1)
#       - شركة تمديد غاز مركزى براس تنورة (clicks: 0, impressions: 54, pos: 50.7)
#       - محل غاز قريب من موقعي (clicks: 0, impressions: 52, pos: 4.6)
#       - محل غاز باقدو (clicks: 0, impressions: 52, pos: 10.1)
#       - توصيل غاز المدينة المنورة شوران (clicks: 0, impressions: 50, pos: 3.6)
#       - رقم توصيل اسطوانات الغاز للمنازل المدينة المنورة (clicks: 0, impressions: 49, pos: 9.7)
#       - محلات غاز قريبه من موقعي (clicks: 0, impressions: 44, pos: 5.3)
#       - شركة تمديد غاز مركزى راس تنورة (clicks: 0, impressions: 40, pos: 60.8)
#       - شركة تمديد الغاز المركزى (clicks: 0, impressions: 40, pos: 14.3)
#       - اقرب موقع غاز من موقعي (clicks: 0, impressions: 40, pos: 4.3)
#       - غاز باقدو المدينة المنورة (clicks: 0, impressions: 38, pos: 10.1)
#       - شركة تمديد غاز مركزى بالجبيل (clicks: 0, impressions: 38, pos: 61.9)
#       - اقرب مكان غاز من موقعي (clicks: 0, impressions: 35, pos: 5.1)
#       - أقرب محل غاز من موقعي مفتوح (clicks: 0, impressions: 35, pos: 9.2)
#       - اقرب مركز غاز من موقعي (clicks: 0, impressions: 34, pos: 4.2)
#       - أين تباع مواسير الغاز (clicks: 0, impressions: 33, pos: 13.9)
#       - الغاز المركزي في البيت (clicks: 1, impressions: 32, pos: 11.1)
#       - محلات الغاز متى تفتح (clicks: 0, impressions: 31, pos: 6.7)
#       - شركه تمديد المكيفات بالمدينة المنورة (clicks: 0, impressions: 28, pos: 82.0)
#       - متى يفتح محل الغاز (clicks: 0, impressions: 27, pos: 8.6)
#       - محلات الغاز متى تقفل (clicks: 0, impressions: 26, pos: 5.1)
#       - محل غاز بالقرب مني (clicks: 0, impressions: 26, pos: 6.9)
#       - محل غاز قريب (clicks: 0, impressions: 25, pos: 8.9)
#       - غاز الجابري (clicks: 0, impressions: 25, pos: 6.1)
#       - اقرب محطة غاز (clicks: 0, impressions: 24, pos: 6.4)
#       - محطة غاز بالقرب مني (clicks: 0, impressions: 23, pos: 6.0)
#       - اقرب مستودع انابيب غاز (clicks: 0, impressions: 23, pos: 9.1)
#       - أقرب محل غاز مفتوح الآن (clicks: 0, impressions: 22, pos: 8.3)
#       - اقرب مكان غاز (clicks: 0, impressions: 21, pos: 5.1)
#       - اقرب محل غاز مفتوح (clicks: 0, impressions: 21, pos: 11.7)
#       - اقرب محل اسطوانات غاز (clicks: 0, impressions: 21, pos: 7.6)
#       - محل غاز قريب من موقعي مفتوح الآن (clicks: 0, impressions: 20, pos: 11.0)
#       - اقرب محل بيع غاز (clicks: 0, impressions: 19, pos: 6.0)
#       - رقم شركة الغاز الموحد (clicks: 0, impressions: 18, pos: 1.7)
#       - شركة تمديد الغاز المركزي بالقصيم (clicks: 0, impressions: 17, pos: 90.5)
#       - رقم تعبئة الغاز (clicks: 0, impressions: 17, pos: 5.7)
#       - تعبئة غاز المدينة المنورة (clicks: 0, impressions: 17, pos: 1.1)
#       - اقرب محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 17, pos: 15.8)
#       - غاز بالقرب مني (clicks: 0, impressions: 16, pos: 5.4)
#       - شركة تمديد غاز مركزى الجبيل (clicks: 0, impressions: 16, pos: 57.1)
#       - اقرب محل لبيع الغاز (clicks: 0, impressions: 16, pos: 6.4)
#       - اقرب محل غاز لموقعي (clicks: 0, impressions: 16, pos: 5.0)
#       - 30.شركة تمديد غاز مركزي اتصل بنا 0532470285 (clicks: 0, impressions: 16, pos: 8.2)
#       - محلات غاز قريبه مني (clicks: 0, impressions: 15, pos: 5.7)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 15, pos: 30.5)
#       - اقرب غاز (clicks: 0, impressions: 15, pos: 6.9)
#       - محل الغاز قريب مني (clicks: 0, impressions: 14, pos: 9.4)
#       - توصيل اسطوانة غاز المدينة المنورة (clicks: 0, impressions: 14, pos: 9.9)
#       - محلات غاز بالقرب مني (clicks: 0, impressions: 13, pos: 3.9)
#       - شركه تمديد (clicks: 0, impressions: 13, pos: 32.2)
#       - توصيل غاز ٢٤ ساعة العزيزية المدينة المنورة (clicks: 0, impressions: 13, pos: 2.5)
#       - أقرب مستودع غاز من موقعي (clicks: 0, impressions: 13, pos: 9.5)
#       - أقرب مستودع انابيب غاز من موقعي (clicks: 0, impressions: 13, pos: 9.0)
#       - شركات تمديد تدفئة مركزية (clicks: 0, impressions: 12, pos: 72.1)
#       - اقرب محل الغاز (clicks: 0, impressions: 12, pos: 5.9)
#       - اقرب محل اسطوانات (clicks: 0, impressions: 12, pos: 5.1)
#       - محل اسطوانات غاز (clicks: 0, impressions: 11, pos: 2.5)
#       - اقرب محطه غاز (clicks: 0, impressions: 11, pos: 5.5)
#       - اقرب غاز من موقعي مفتوح الآن (clicks: 0, impressions: 11, pos: 6.0)
#       - محل غاز فاتح (clicks: 0, impressions: 10, pos: 5.4)
#       - محل انابيب غاز قريب من موقعي (clicks: 0, impressions: 10, pos: 11.4)
#       - محل الغاز مفتوح الآن (clicks: 0, impressions: 10, pos: 8.4)
#       - شركه الغاز (clicks: 0, impressions: 10, pos: 7.8)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 10, pos: 25.0)
#       - اقرب محل انابيب غاز من موقعي (clicks: 0, impressions: 10, pos: 5.4)
#       - rallonge gaz de ville (clicks: 0, impressions: 10, pos: 10.7)
#       - محل غاز مفتوح (clicks: 0, impressions: 9, pos: 17.1)
#       - محل غاز فاتح الان (clicks: 0, impressions: 9, pos: 5.8)
#       - شركة تمديد غاز مركزي بالباحة (clicks: 0, impressions: 9, pos: 65.7)
#       - اقرب موقع غاز (clicks: 0, impressions: 9, pos: 5.4)
#       - محل غار (clicks: 0, impressions: 8, pos: 5.2)
#       - غاز الخالدية (clicks: 0, impressions: 8, pos: 10.2)
#       - شركة تمديد غاز مركزي اتصل بنا 0532470285 (clicks: 0, impressions: 8, pos: 13.2)
#       - رقم توصيل اسطوانات الغاز للمنازل (clicks: 0, impressions: 8, pos: 2.1)
#       - شركة صيانة غاز بحي الروضة (clicks: 0, impressions: 7, pos: 84.8)
#       - تمديد غاز مركزي بجازان (clicks: 0, impressions: 7, pos: 67.3)
#       - اقرب مستودع انابيب (clicks: 0, impressions: 7, pos: 10.9)
#       - محل غاز شوران (clicks: 0, impressions: 6, pos: 25.0)
#       - محل غاز الخالدية (clicks: 0, impressions: 6, pos: 14.3)
#       - محل غاز الحربي (clicks: 0, impressions: 6, pos: 12.1)
#       - محل غاز 24 ساعه (clicks: 0, impressions: 6, pos: 4.9)
#       - متى يفتح الغاز (clicks: 0, impressions: 6, pos: 7.0)
#       - غاز ابو مرخه (clicks: 0, impressions: 6, pos: 10.1)
#       - شركة صيانة خزانات الغاز (clicks: 0, impressions: 6, pos: 31.2)
#       - تمديد مواسير نحاس امريكى بالمدينه المنوره (clicks: 0, impressions: 6, pos: 56.7)
#       - تمديد غاز مركزي بالباحة (clicks: 0, impressions: 6, pos: 84.2)
#       - اقرب وكالة غاز من موقعي (clicks: 0, impressions: 6, pos: 2.4)
#       - اقرب محل لبيع الغاز من موقعي (clicks: 0, impressions: 6, pos: 4.6)
#       - ‏محل غاز (clicks: 0, impressions: 5, pos: 4.8)
#       - مستودع انابيب قريب مني (clicks: 0, impressions: 5, pos: 10.0)
#       - محل غاز العوالي (clicks: 0, impressions: 5, pos: 12.5)
#       - محل غاز البوادي (clicks: 0, impressions: 5, pos: 9.2)
#       - محل الغاز مفتوح (clicks: 0, impressions: 5, pos: 23.2)
#       - غاز العزيزية (clicks: 0, impressions: 5, pos: 1.0)
#       - شركة تمديد غاز مركزي بظهران (clicks: 0, impressions: 5, pos: 81.2)
#       - شركة تمديد غاز بمكة (clicks: 0, impressions: 5, pos: 65.0)
#       - رقم شركه الغاز للتعبئه (clicks: 0, impressions: 5, pos: 1.0)
#       - رقم تزويد الغاز (clicks: 0, impressions: 5, pos: 8.1)
#       - رقم الغاز الموحد (clicks: 0, impressions: 5, pos: 1.0)
#       - دوام محلات الغاز (clicks: 0, impressions: 5, pos: 3.8)
#       - اقرب محل مواد بناء من موقعي (clicks: 0, impressions: 5, pos: 57.6)
#       - اقرب محل غاز مني (clicks: 0, impressions: 5, pos: 16.0)
#       - اقرب محل غاز من موقعي هذا (clicks: 0, impressions: 5, pos: 4.6)
#       - اقرب محل تبديل غاز (clicks: 0, impressions: 5, pos: 4.7)
#       - اقرب محطه غاز من موقعي (clicks: 0, impressions: 5, pos: 5.4)
#       - اقرب فرع غاز من موقعي (clicks: 0, impressions: 5, pos: 11.0)
#       - أقرب مستودع أنابيب غاز من موقعي (clicks: 0, impressions: 5, pos: 5.8)
#       - أقرب محل غاز من موقعي توصيل مفتوح الآن (clicks: 0, impressions: 5, pos: 11.0)
#       - أقرب محطة غاز من موقعي مفتوح الآن (clicks: 0, impressions: 5, pos: 9.4)
#       - مخل غاز (clicks: 0, impressions: 4, pos: 6.5)
#       - محل غاز قريب مني (clicks: 0, impressions: 4, pos: 9.0)
#       - محل تبديل غاز (clicks: 0, impressions: 4, pos: 7.3)
#       - محل الغاز العزيزيه (clicks: 0, impressions: 4, pos: 1.0)
#       - متى تفتح محلات الغاز (clicks: 0, impressions: 4, pos: 6.5)
#       - غاز الاسكان (clicks: 0, impressions: 4, pos: 2.2)
#       - غاز 24 ساعة (clicks: 0, impressions: 4, pos: 6.0)
#       - شركات الغاز في السعودية (clicks: 0, impressions: 4, pos: 1.0)
#       - توصيل غاز ٢٤ ساعة مفتوح الآن (clicks: 0, impressions: 4, pos: 9.0)
#       - توصيل غاز العزيزية (clicks: 0, impressions: 4, pos: 1.0)
#       - تمديد غاز مركزي بظهران (clicks: 0, impressions: 4, pos: 89.5)
#       - تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 4, pos: 74.5)
#       - اقرب مستودع غاز (clicks: 0, impressions: 4, pos: 8.5)
#       - اقرب محل توزيع غاز من موقعي (clicks: 0, impressions: 4, pos: 5.7)
#       - اقرب محل اسطوانات غاز من موقعي (clicks: 0, impressions: 4, pos: 7.3)
#       - اقرب شركة غاز من موقعي (clicks: 0, impressions: 4, pos: 4.5)
#       - مواصير غاز (clicks: 0, impressions: 3, pos: 9.3)
#       - مدار لمواد البناء المدينة المنورة (clicks: 0, impressions: 3, pos: 62.7)
#       - محل غاز مفتوح ٢٤ ساعة (clicks: 0, impressions: 3, pos: 8.0)
#       - محل غاز فاتح 24 ساعه (clicks: 0, impressions: 3, pos: 4.0)
#       - غاز قريب (clicks: 0, impressions: 3, pos: 8.0)
#       - غاز المحمدي (clicks: 0, impressions: 3, pos: 12.0)
#       - غاز الخالدية المدينة المنورة (clicks: 0, impressions: 3, pos: 12.7)
#       - غاز البدوي (clicks: 0, impressions: 3, pos: 4.0)
#       - طلب تعبئة غاز (clicks: 0, impressions: 3, pos: 1.0)
#       - صيانه الغاز (clicks: 0, impressions: 3, pos: 8.3)
#       - شركة تمديد غاز مركزي بمكة (clicks: 0, impressions: 3, pos: 57.0)
#       - شركة تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 3, pos: 112.3)
#       - شركة الغاز تعبئة (clicks: 0, impressions: 3, pos: 1.0)
#       - شركات تعبئة غاز (clicks: 0, impressions: 3, pos: 1.3)
#       - توصيل غاز ٢٤ ساعة الرياض (clicks: 0, impressions: 3, pos: 56.0)
#       - تمديد غاز مركزي بنجران (clicks: 0, impressions: 3, pos: 62.0)
#       - تمديد غاز مركزي بابها (clicks: 0, impressions: 3, pos: 81.7)
#       - تعبئة غاز (clicks: 0, impressions: 3, pos: 2.3)
#       - تركيب cvp (clicks: 0, impressions: 3, pos: 1.0)
#       - اقرب مطعم صيني من موقعي (clicks: 0, impressions: 3, pos: 50.3)
#       - اقرب محل غاز من موقعي في 1.6 كم (clicks: 0, impressions: 3, pos: 9.3)
#       - اقرب محل غاز مفتوح الآن (clicks: 0, impressions: 3, pos: 9.0)
#       - اقرب محل تبديل غاز من موقعي (clicks: 0, impressions: 3, pos: 6.8)
#       - اسطوانات غاز المدينة المنورة (clicks: 0, impressions: 3, pos: 9.3)
#       - اسطوانات الغاز (clicks: 0, impressions: 3, pos: 1.8)
#       - أقرب مستودع انابيب من موقعي (clicks: 0, impressions: 3, pos: 6.5)
#       - rallonge tuyau gaz de ville (clicks: 0, impressions: 3, pos: 7.0)
#       - gasable (clicks: 0, impressions: 3, pos: 10.0)
#       - مواعيد مستودع الغاز في رمضان (clicks: 0, impressions: 2, pos: 1.0)
#       - مستودع غاز قريب مني مفتوح الآن (clicks: 0, impressions: 2, pos: 11.5)
#       - مستودع غاز قريب مني (clicks: 0, impressions: 2, pos: 1.5)
#       - مستودع انابيب غاز قريب من موقعي (clicks: 0, impressions: 2, pos: 7.5)
#       - محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 2, pos: 11.0)
#       - محل الغاز قريب من موقعي (clicks: 0, impressions: 2, pos: 9.5)
#       - محل اسطوانة غاز قريب مني (clicks: 0, impressions: 2, pos: 4.5)
#       - محل اسطوانات قريب مني (clicks: 0, impressions: 2, pos: 6.0)
#       - محل اسطوانات غاز قريب مني (clicks: 0, impressions: 2, pos: 8.5)
#       - غاز قريب مني (clicks: 0, impressions: 2, pos: 11.5)
#       - غاز قريب من موقعي (clicks: 0, impressions: 2, pos: 6.0)
#       - غاز القايدي (clicks: 0, impressions: 2, pos: 5.5)
#       - غاز العزيزيه (clicks: 0, impressions: 2, pos: 1.0)
#       - عروض شركة الغاز (clicks: 0, impressions: 2, pos: 77.0)
#       - شركه تمديد غاز (clicks: 0, impressions: 2, pos: 30.5)
#       - شركة دخيلكم للغاز المركزي و الصناعي - تمديد غاز و خزانات الغاز (clicks: 0, impressions: 2, pos: 13.0)
#       - شركة تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 2, pos: 89.0)
#       - شركة تمديد غاز مركزي بابها (clicks: 0, impressions: 2, pos: 87.0)
#       - شركة الغاز الجناح رقم هاتف (clicks: 0, impressions: 2, pos: 4.0)
#       - شركات صيانة خزانات الغاز (clicks: 0, impressions: 2, pos: 7.0)
#       - رقم شركه الغاز (clicks: 0, impressions: 2, pos: 3.5)
#       - رقم شركة الغاز المجاني (clicks: 0, impressions: 2, pos: 11.0)
#       - توصيل غاز للمنازل مفتوح الآن (clicks: 0, impressions: 2, pos: 40.5)
#       - تمديد مواسير غاز للمطابخ وصيانة الغاز المركزي (clicks: 0, impressions: 2, pos: 24.5)
#       - تعبئة غاز قريب مني (clicks: 0, impressions: 2, pos: 43.5)
#       - تسليك غاز (clicks: 0, impressions: 2, pos: 7.0)
#       - تبديل غاز قريب مني (clicks: 0, impressions: 2, pos: 6.0)
#       - العزيزية الماسي للغاز المدينة المنورة (clicks: 0, impressions: 2, pos: 9.0)
#       - اقرب موزع غاز من موقعي (clicks: 0, impressions: 2, pos: 6.5)
#       - اقرب مستودع انابيب غاز من موقعي (clicks: 0, impressions: 2, pos: 9.5)
#       - اقرب مركز غاز (clicks: 0, impressions: 2, pos: 5.0)
#       - اقرب محل للغاز (clicks: 0, impressions: 2, pos: 4.5)
#       - اقرب محل غاز فاتح (clicks: 0, impressions: 2, pos: 5.5)
#       - اقرب محل بيع الغاز (clicks: 0, impressions: 2, pos: 7.0)
#       - اقرب محل اسطوانه غاز (clicks: 0, impressions: 2, pos: 7.5)
#       - اقرب محطة غاز من موقعي (clicks: 0, impressions: 2, pos: 5.0)
#       - اسطوانة غاز (clicks: 0, impressions: 2, pos: 1.5)
#       - اسطوانات غاز (clicks: 0, impressions: 2, pos: 1.0)
#       - أقرب مستودع غاز من موقعي مفتوح الآن (clicks: 0, impressions: 2, pos: 6.5)
#       - أقرب محطة غاز طبيعي من موقعي (clicks: 0, impressions: 2, pos: 3.0)
#       - أقرب فرع غاز مفتوح (clicks: 0, impressions: 2, pos: 7.0)
#       - gaz de ville installation (clicks: 0, impressions: 2, pos: 4.0)
#       - موقع غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 12.0)
#       - موزع اسطوانات غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - مواقد غاز (clicks: 0, impressions: 1, pos: 3.0)
#       - مواعيد مستودع الغاز (clicks: 0, impressions: 1, pos: 12.0)
#       - مكان غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 11.0)
#       - مستودع غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - مستودع الغاز (clicks: 0, impressions: 1, pos: 5.0)
#       - مركز غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 8.0)
#       - محلات غاز مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#       - محلات بيع اسطوانات الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب مني مفتوح الآن (clicks: 0, impressions: 1, pos: 7.0)
#       - محل غاز قريب من موقعي في 1.6 كم (clicks: 0, impressions: 1, pos: 11.0)
#       - محل غاز توصيل قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز المصيف (clicks: 0, impressions: 1, pos: 6.0)
#       - محل غاز العزيزيه (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز الدرب (clicks: 0, impressions: 1, pos: 7.0)
#       - محل غاز الخالديه (clicks: 0, impressions: 1, pos: 6.0)
#       - محل تعبئة غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 47.0)
#       - محل تعبئة غاز (clicks: 0, impressions: 1, pos: 3.0)
#       - محل تبديل الغاز (clicks: 0, impressions: 1, pos: 7.0)
#       - محل تبديل اسطوانات الغاز (clicks: 0, impressions: 1, pos: 10.0)
#       - محل بيع الغاز قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محل انابيب قريب مني (clicks: 0, impressions: 1, pos: 7.0)
#       - محل الاسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - محطه غاز بالقرب مني (clicks: 0, impressions: 1, pos: 4.0)
#       - محطة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محبس غاز مركزي (clicks: 0, impressions: 1, pos: 8.0)
#       - متى يقفل محل الغاز (clicks: 0, impressions: 1, pos: 3.0)
#       - مؤسسة الشعلة (clicks: 0, impressions: 1, pos: 2.0)
#       - غاز يوصل للبيت (clicks: 0, impressions: 1, pos: 1.0)
#       - غاز مفتوح الآن (clicks: 0, impressions: 1, pos: 6.0)
#       - غاز المحمدي الجرف (clicks: 0, impressions: 1, pos: 12.0)
#       - غاز القادسية (clicks: 0, impressions: 1, pos: 11.0)
#       - غاز الشهداء (clicks: 0, impressions: 1, pos: 3.0)
#       - غاز الدار البيضاء (clicks: 0, impressions: 1, pos: 95.0)
#       - غاز الجرف (clicks: 0, impressions: 1, pos: 9.0)
#       - غاز اسطوانه (clicks: 0, impressions: 1, pos: 13.0)
#       - طوندور غاز المدينة (clicks: 0, impressions: 1, pos: 40.0)
#       - طواري الغاز (clicks: 0, impressions: 1, pos: 4.0)
#       - صيانة خزانات الغاز المركزية (clicks: 0, impressions: 1, pos: 6.0)
#       - صيانة خزانات الغاز (clicks: 0, impressions: 1, pos: 3.0)
#       - شركه غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - شركة تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 1, pos: 69.0)
#       - شركة تمديد غاز مركزي بالدمام (clicks: 0, impressions: 1, pos: 226.0)
#       - شركة تمديد غاز مركزى بالقطيف (clicks: 0, impressions: 1, pos: 91.0)
#       - شركة تعبئة الغاز (clicks: 0, impressions: 1, pos: 75.0)
#       - شركة العاز (clicks: 0, impressions: 1, pos: 3.0)
#       - سعر تعبئة أسطوانة الغاز في السعودية (clicks: 0, impressions: 1, pos: 3.0)
#       - سعر اسطوانة الغاز في المدينة المنورة (clicks: 0, impressions: 1, pos: 12.0)
#       - رقم محل غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 4.0)
#       - رقم غاز الخفجي (clicks: 0, impressions: 1, pos: 4.0)
#       - رقم صيانه الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - رقم شركه غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - رقم شركة الغاز والتصنيع الأهلية (clicks: 0, impressions: 1, pos: 2.0)
#       - رقم شركة الغاز الوطنية (clicks: 0, impressions: 1, pos: 1.0)
#       - رقم راعي الغاز (clicks: 0, impressions: 1, pos: 4.0)
#       - رقم تعبئة غاز (clicks: 0, impressions: 1, pos: 66.0)
#       - خدمة غاز ٢٤ ساعه (clicks: 0, impressions: 1, pos: 8.0)
#       - حديدة غاز (clicks: 0, impressions: 1, pos: 7.0)
#       - جينكو (clicks: 0, impressions: 1, pos: 27.0)
#       - توصيلات الغاز (clicks: 0, impressions: 1, pos: 98.0)
#       - توصيل غاز ٢٤ ساعة القريات (clicks: 0, impressions: 1, pos: 2.0)
#       - توصيل غاز الرانوناء (clicks: 0, impressions: 1, pos: 13.0)
#       - توصيل اسطوانة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - توصيل اسطوانات غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 1, pos: 42.0)
#       - تعديل وصلات الغاز (clicks: 0, impressions: 1, pos: 5.0)
#       - تعبية غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة غاز مركزي (clicks: 0, impressions: 1, pos: 75.0)
#       - تعبئة غاز توصيل (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة خزان غاز (clicks: 0, impressions: 1, pos: 97.0)
#       - تعبئة اسطوانة غاز توصيل (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة اسطوانة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة اسطوانة الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - تسليك انابيب الغاز (clicks: 0, impressions: 1, pos: 43.0)
#       - تسليك الغاز في المطبخ (clicks: 0, impressions: 1, pos: 41.0)
#       - تركيبات الغاز (clicks: 0, impressions: 1, pos: 60.0)
#       - بيع غاز قريب مني (clicks: 0, impressions: 1, pos: 5.0)
#       - بتاع انابيب قريب مني (clicks: 0, impressions: 1, pos: 2.0)
#       - بالمدينه المنوره (clicks: 0, impressions: 1, pos: 8.0)
#       - المدينه المنوره (clicks: 0, impressions: 1, pos: 9.0)
#       - اقرب محل غاز من موقعي الان (clicks: 0, impressions: 1, pos: 1.0)
#       - اقرب محطة غاز طبيعى (clicks: 0, impressions: 1, pos: 10.0)
#       - اقرب فرع غاز (clicks: 0, impressions: 1, pos: 10.0)
#       - اقرب تعبئة غاز من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - اقرب تعبئة غاز (clicks: 0, impressions: 1, pos: 72.0)
#       - اقرب بنزينه غاز من موقعي الحالي (clicks: 0, impressions: 1, pos: 9.0)
#       - اقرب بنزين غاز طبيعي (clicks: 0, impressions: 1, pos: 5.0)
#       - اطوانه (clicks: 0, impressions: 1, pos: 2.0)
#       - اسم شركة الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار خزانات الغاز (clicks: 0, impressions: 1, pos: 90.0)
#       - اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - ارقام شركة الغاز الطبيعي (clicks: 0, impressions: 1, pos: 2.0)
#       - ابغا صور (clicks: 0, impressions: 1, pos: 17.0)
#       - أقرب مستودع أنابيب من موقعي (clicks: 0, impressions: 1, pos: 7.0)
#       - أقرب محل تعبئة غاز من موقعي (clicks: 0, impressions: 1, pos: 10.0)
#       - أقرب محطة غاز (clicks: 0, impressions: 1, pos: 11.0)
#       - أسعار خزانات الغاز غازكو (clicks: 0, impressions: 1, pos: 84.0)
#       - tuyau gaz de ville (clicks: 0, impressions: 1, pos: 10.0)
#       - raccord tuyau gaz de ville (clicks: 0, impressions: 1, pos: 7.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balqtyf
#   1. Title too_short (34 chars, range 50-60)
#   2. Description too_short (101 chars, range 150-160)
#   3. Stale content (813 days old)
#  Missing queries (20):
#       - شركة تمديد غاز مركزى بالقطيف (clicks: 0, impressions: 448, pos: 6.6)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 62, pos: 27.8)
#       - المواسير بجميع أنواعها (clicks: 0, impressions: 30, pos: 79.5)
#       - تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 8, pos: 73.3)
#       - عمائر تجارية للايجار في القطيف (clicks: 0, impressions: 6, pos: 42.7)
#       - أين تباع مواسير الغاز (clicks: 0, impressions: 5, pos: 9.0)
#       - شركة تمديد غاز بالمنازل (clicks: 0, impressions: 4, pos: 88.2)
#       - محلات الغاز متى تقفل (clicks: 0, impressions: 2, pos: 8.5)
#       - شركة تمديد غاز مركزي بالدمام (clicks: 0, impressions: 2, pos: 167.0)
#       - شركة تمديد غاز مركزي بالخرج (clicks: 0, impressions: 2, pos: 60.5)
#       - نعم (clicks: 0, impressions: 1, pos: 3.0)
#       - مواصير غاز (clicks: 0, impressions: 1, pos: 10.0)
#       - مواسير غاز طبيعى (clicks: 0, impressions: 1, pos: 10.0)
#       - ماسوره غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - كيفية تركيب أنابيب الغاز في المنزل (clicks: 0, impressions: 1, pos: 1.0)
#       - شركة تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 1, pos: 30.0)
#       - تمديد مواسير الغاز بالخرج (clicks: 0, impressions: 1, pos: 4.0)
#       - تطويل خرطوم الغاز الطبيعي (clicks: 0, impressions: 1, pos: 3.0)
#       - النهدي للغاز (clicks: 0, impressions: 1, pos: 4.0)
#       - gasband (clicks: 0, impressions: 1, pos: 2.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-balryadh
#   1. Title too_short (40 chars, range 50-60)
#   2. Description too_short (144 chars, range 150-160)
#   3. Stale content (813 days old)
#  Missing queries (33):
#       - المواسير بجميع أنواعها (clicks: 0, impressions: 84, pos: 68.7)
#       - شركة تمديد الغاز المركزي بانظمة متكاملة للحماية بالرياض (clicks: 0, impressions: 65, pos: 46.6)
#       - شركة تمديد مواسير الغاز بالخرج (clicks: 0, impressions: 39, pos: 77.6)
#       - تمديد مواسير الغاز بالخرج (clicks: 0, impressions: 28, pos: 84.8)
#       - شركه تمديد غاز مركزي بالرياض (clicks: 0, impressions: 27, pos: 47.6)
#       - تمديد غاز مركزى بالرياض (clicks: 0, impressions: 27, pos: 47.8)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 18, pos: 34.7)
#       - شركة تمديد غاز مركزى بالجبيل (clicks: 0, impressions: 12, pos: 72.7)
#       - أين تباع مواسير الغاز (clicks: 0, impressions: 10, pos: 9.9)
#       - رقم توصيل اسطوانات الغاز للمنازل بالرياض (clicks: 0, impressions: 7, pos: 1.0)
#       - معلم تمديد غاز بالرياض (clicks: 0, impressions: 6, pos: 61.8)
#       - شركة تمديد الغاز المركزي بالقصيم (clicks: 0, impressions: 6, pos: 98.2)
#       - مواصير غاز (clicks: 0, impressions: 4, pos: 1.0)
#       - تكلفة تعديل مواسير الغاز (clicks: 0, impressions: 4, pos: 3.5)
#       - يستخدم الغاز الطبيعي في :(اختيار أكثر من إجابة) (clicks: 0, impressions: 3, pos: 8.2)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 3, pos: 20.7)
#       - شركة معالجة تشققات الجدران بمكة جودة عالية وسرعة 24 ساعة (clicks: 0, impressions: 3, pos: 75.0)
#       - شركة تمديد الغاز المركزى بالرياض (clicks: 0, impressions: 3, pos: 92.0)
#       - تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 3, pos: 82.3)
#       - تمديد غاز مركزي بجازان (clicks: 0, impressions: 3, pos: 63.0)
#       - اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن (clicks: 0, impressions: 3, pos: 68.7)
#       - اسعار مواسير الحديد في السعودية (clicks: 0, impressions: 3, pos: 76.3)
#       - ألوان مواسير الغازات الطبية (clicks: 0, impressions: 3, pos: 1.0)
#       - غاز شركه تمديد غاز بالرياض (clicks: 0, impressions: 2, pos: 64.5)
#       - شركة تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 2, pos: 81.5)
#       - اسعار مواسير الحديد (clicks: 0, impressions: 2, pos: 73.5)
#       - وصلة غاز نحاس (clicks: 0, impressions: 1, pos: 65.0)
#       - مواسير غاز طبيعى (clicks: 0, impressions: 1, pos: 12.0)
#       - مواسير غاز تدفئة مركزية (clicks: 0, impressions: 1, pos: 99.0)
#       - رقم توصيل اسطوانات الغاز للمنازل بالمدينة المنورة (clicks: 0, impressions: 1, pos: 17.0)
#       - رقم توصيل اسطوانات الغاز للمنازل الرياض (clicks: 0, impressions: 1, pos: 48.0)
#       - ارقام توصيل غاز بالرياض (clicks: 0, impressions: 1, pos: 79.0)
#       - ارخص تطبيق توصيل غاز (clicks: 0, impressions: 1, pos: 72.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-bmsr
#   1. Title too_short (32 chars, range 50-60)
#   2. Description too_short (113 chars, range 150-160)
#   3. Stale content (522 days old)
#  Missing queries (29):
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 124, pos: 45.6)
#       - شركات تمديد تدفئة مركزية (clicks: 0, impressions: 102, pos: 62.9)
#       - شركة تمديد غاز بالمنازل (clicks: 0, impressions: 54, pos: 79.0)
#       - أين تباع مواسير الغاز (clicks: 0, impressions: 25, pos: 4.0)
#       - تكلفة تعديل مواسير الغاز (clicks: 0, impressions: 18, pos: 19.4)
#       - مواسير غاز تدفئة مركزية (clicks: 0, impressions: 15, pos: 86.1)
#       - تركيبات الغاز (clicks: 0, impressions: 13, pos: 34.4)
#       - شركه تمديد خطوط غاز مركزي (clicks: 0, impressions: 7, pos: 1.0)
#       - مواسير غاز طبيعى (clicks: 0, impressions: 6, pos: 22.0)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 5, pos: 2.8)
#       - شركات تركيب خزانات الغاز (clicks: 1, impressions: 5, pos: 2.8)
#       - تركيبات الغاز الطبيعى القاهرة (clicks: 0, impressions: 5, pos: 62.8)
#       - شركة صيانة خزانات الغاز (clicks: 0, impressions: 2, pos: 61.0)
#       - تركيبات غاز مصر (clicks: 0, impressions: 2, pos: 68.5)
#       - تركيبات الغاز الطبيعي (clicks: 0, impressions: 2, pos: 2.0)
#       - كيفية تركيب أنابيب الغاز في المنزل (clicks: 0, impressions: 1, pos: 1.0)
#       - طوارئ الغاز اسكندرية (clicks: 0, impressions: 1, pos: 9.0)
#       - صيانة شبكات غاز طبية (clicks: 0, impressions: 1, pos: 96.0)
#       - شركه تمديد غاز مركزي بالرياض (clicks: 0, impressions: 1, pos: 7.0)
#       - شركه تمديد (clicks: 0, impressions: 1, pos: 1.0)
#       - تمديد غاز بالخرج (clicks: 0, impressions: 1, pos: 172.0)
#       - تمديد انابيب الغاز (clicks: 0, impressions: 1, pos: 2.0)
#       - تركيبات الغاز القاهرة (clicks: 0, impressions: 1, pos: 71.0)
#       - تركيبات الغاز الطبيعي القاهرة (clicks: 0, impressions: 1, pos: 85.0)
#       - امثلة بالصور (clicks: 0, impressions: 1, pos: 41.0)
#       - اسعار مواسير حديد مجلفن في مصر (clicks: 0, impressions: 1, pos: 31.0)
#       - اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن (clicks: 0, impressions: 1, pos: 57.0)
#       - gas supply installation (clicks: 0, impressions: 1, pos: 8.0)
#       - gas boot (clicks: 0, impressions: 1, pos: 7.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-byshh
#   1. Title too_short (38 chars, range 50-60)
#   2. Description too_short (138 chars, range 150-160)
#   3. Stale content (662 days old)
#  Missing queries (39):
#       - شركة تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 19, pos: 25.1)
#       - اقرب محل غاز (clicks: 0, impressions: 19, pos: 4.4)
#       - تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 14, pos: 34.5)
#       - محل غاز من موقعي (clicks: 0, impressions: 12, pos: 7.3)
#       - اقرب محل غاز من موقعي (clicks: 0, impressions: 7, pos: 4.8)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 6, pos: 41.5)
#       - محل غاز فاتح الان (clicks: 0, impressions: 4, pos: 3.8)
#       - تمديد غاز مركزي بالباحة (clicks: 0, impressions: 4, pos: 46.5)
#       - اقرب غاز من موقعي (clicks: 0, impressions: 4, pos: 6.3)
#       - كيفية تركيب أنابيب الغاز في المنزل (clicks: 0, impressions: 3, pos: 1.0)
#       - كهربائي منازل ببيشة (clicks: 0, impressions: 3, pos: 49.3)
#       - شركة تمديد غاز مركزي بنجران (clicks: 0, impressions: 3, pos: 76.7)
#       - شركة تمديد غاز مركزى بالجبيل (clicks: 0, impressions: 3, pos: 35.2)
#       - مستشفى المستقبل بيشه (clicks: 0, impressions: 2, pos: 8.0)
#       - محل غاز قريب (clicks: 0, impressions: 2, pos: 4.0)
#       - شركة تمديد غاز مركزي بالباحة (clicks: 0, impressions: 2, pos: 15.5)
#       - شركة تمديد غاز مركزي بابها (clicks: 0, impressions: 2, pos: 59.0)
#       - تمديد غاز مركزي بابها (clicks: 0, impressions: 2, pos: 58.5)
#       - تمديد الغاز للمطبخ (clicks: 0, impressions: 2, pos: 4.0)
#       - اقرب موقع غاز من موقعي (clicks: 0, impressions: 2, pos: 8.5)
#       - محلات غاز قريبه من موقعي (clicks: 0, impressions: 1, pos: 4.0)
#       - محل غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز فاتح 24 ساعه (clicks: 0, impressions: 1, pos: 7.0)
#       - محل غاز بالقرب مني (clicks: 0, impressions: 1, pos: 7.0)
#       - محل اسطوانات غاز مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات غاز قريب مني (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - متى يفتح محل الغاز (clicks: 0, impressions: 1, pos: 6.0)
#       - غاز بالقرب مني (clicks: 0, impressions: 1, pos: 6.0)
#       - شركة تمديد غاز مركزى براس تنورة (clicks: 0, impressions: 1, pos: 65.0)
#       - شركة تمديد الغاز المركزي بى الطائف (clicks: 0, impressions: 1, pos: 14.0)
#       - سعر متر مواسير المياه البلاستيك الخضراء (clicks: 0, impressions: 1, pos: 54.0)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 1, pos: 2.0)
#       - تنظيف الخزانات ببيشة السعودية (clicks: 0, impressions: 1, pos: 65.0)
#       - الغاز ارقام (clicks: 0, impressions: 1, pos: 40.0)
#       - اقرب موقع غاز (clicks: 0, impressions: 1, pos: 4.0)
#       - اسطوانة غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - ارخص تطبيق توصيل غاز (clicks: 0, impressions: 1, pos: 61.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-ghaz-mrkzy-babha
#   1. Title too_short (38 chars, range 50-60)
#   2. Description too_short (138 chars, range 150-160)
#   3. Stale content (662 days old)
#  Missing queries (59):
#       - توصيل غاز ٢٤ ساعة ابها (clicks: 0, impressions: 100, pos: 11.0)
#       - اقرب محل غاز من موقعي ابها (clicks: 0, impressions: 64, pos: 10.3)
#       - اقرب محل غاز في ابها (clicks: 0, impressions: 64, pos: 11.9)
#       - شركة تمديد غاز مركزى بالاحساء (clicks: 0, impressions: 38, pos: 48.7)
#       - شركة تمديد غاز بالرياض (clicks: 0, impressions: 31, pos: 1.4)
#       - توصيل غاز ٢٤ ساعة أبها (clicks: 1, impressions: 16, pos: 10.4)
#       - شركة تمديد الغاز المركزى (clicks: 0, impressions: 15, pos: 2.5)
#       - اسعار مواسير المياه الحديد المجلفن مواسير حديد مجلفن (clicks: 0, impressions: 12, pos: 56.8)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 8, pos: 22.4)
#       - اسعار خزانات الغاز (clicks: 0, impressions: 8, pos: 75.2)
#       - شركة تمديد غاز مركزى بالجبيل (clicks: 0, impressions: 7, pos: 10.0)
#       - شركة تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 6, pos: 36.7)
#       - شركة تمديد غاز مركزى براس تنورة (clicks: 0, impressions: 6, pos: 3.3)
#       - شركة تمديد غاز بالمنازل (clicks: 0, impressions: 6, pos: 1.0)
#       - تمديد غاز مركزي بنجران (clicks: 0, impressions: 6, pos: 69.7)
#       - تمديد غاز مركزي بسراة عبيدة (clicks: 0, impressions: 5, pos: 21.4)
#       - محلات غاز قريبه من موقعي (clicks: 0, impressions: 4, pos: 11.5)
#       - شركة تمديد غاز مركزي بالباحة (clicks: 0, impressions: 4, pos: 41.2)
#       - جازان شركة تمديد غاز مركزي بجازان (clicks: 0, impressions: 4, pos: 96.0)
#       - تمديد غاز مركزي بالباحة (clicks: 0, impressions: 4, pos: 41.5)
#       - كيفية تركيب أنابيب الغاز في المنزل (clicks: 0, impressions: 3, pos: 1.0)
#       - شركة تمديد غاز مركزي بنجران (clicks: 0, impressions: 3, pos: 65.0)
#       - مواصير غاز (clicks: 0, impressions: 2, pos: 4.5)
#       - شركه تمديد (clicks: 0, impressions: 2, pos: 64.5)
#       - شركة تمديد غاز مركزي بظهران (clicks: 0, impressions: 2, pos: 30.5)
#       - شركة تمديد غاز بخميس مشيط (clicks: 0, impressions: 2, pos: 60.0)
#       - شركة تمديد الغاز بالرياض (clicks: 0, impressions: 2, pos: 1.0)
#       - تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 2, pos: 112.0)
#       - تمديد غاز مركزي الكويت (clicks: 0, impressions: 2, pos: 1.5)
#       - القلاووظ وانواعه (clicks: 0, impressions: 2, pos: 1.0)
#       - محل غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب (clicks: 0, impressions: 1, pos: 1.0)
#       - محبس غاز مركزي (clicks: 0, impressions: 1, pos: 1.0)
#       - شركه تمديد غاز مركزي بالرياض (clicks: 0, impressions: 1, pos: 12.0)
#       - شركة صيانة خزانات الغاز (clicks: 0, impressions: 1, pos: 2.0)
#       - شركة تمديد مواسير الغاز بالخرج (clicks: 0, impressions: 1, pos: 10.0)
#       - شركة تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 1, pos: 1.0)
#       - شركة تمديد غاز مركزي بالرياض (clicks: 0, impressions: 1, pos: 12.0)
#       - شركة تمديد غاز مركزي بالدمام (clicks: 0, impressions: 1, pos: 248.0)
#       - شركة تمديد غاز بمدينة المنورة (clicks: 0, impressions: 1, pos: 69.0)
#       - شركة تمديد غاز بالقصيم (clicks: 0, impressions: 1, pos: 12.0)
#       - شركة تمديد الغاز بالدمام (clicks: 0, impressions: 1, pos: 12.0)
#       - شركة تمديد الغاز المركزي بالدمام (clicks: 0, impressions: 1, pos: 11.0)
#       - شركة تركيب صمامات أمان للغاز بالرياض (clicks: 0, impressions: 1, pos: 56.0)
#       - شركات تركيب خزانات الغاز (clicks: 0, impressions: 1, pos: 56.0)
#       - ساعة غاز مركزي (clicks: 0, impressions: 1, pos: 88.0)
#       - رقم توصيل اسطوانات الغاز للمنازل بالاحساء (clicks: 0, impressions: 1, pos: 35.0)
#       - توصيل غاز ٢٤ ساعة جدة (clicks: 0, impressions: 1, pos: 16.0)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 1, pos: 1.0)
#       - تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 1, pos: 92.0)
#       - تمديد غاز مركزي بجازان (clicks: 0, impressions: 1, pos: 88.0)
#       - تمديد الغاز للمطبخ (clicks: 0, impressions: 1, pos: 5.0)
#       - تعديل وصلات الغاز (clicks: 0, impressions: 1, pos: 38.0)
#       - المصنع السعودي لاسطوانات الغاز (clicks: 0, impressions: 1, pos: 9.0)
#       - الفرق بين المواسير السيملس والحديد (clicks: 0, impressions: 1, pos: 35.0)
#       - اسعار الغاز المركزي (clicks: 0, impressions: 1, pos: 55.0)
#       - ارتفاع الغاز (clicks: 0, impressions: 1, pos: 8.0)
#       - أين تباع مواسير الغاز (clicks: 0, impressions: 1, pos: 70.0)
#       - أفضل شركة تمديد غاز مركزي بالرياض (clicks: 0, impressions: 1, pos: 3.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-ghaz-mrkzy-balkhrj
#   1. Title too_short (39 chars, range 50-60)
#   2. Description too_short (143 chars, range 150-160)
#   3. Stale content (813 days old)
#  Missing queries (42):
#       - توصيل غاز ٢٤ ساعة الخرج (clicks: 0, impressions: 292, pos: 10.6)
#       - شركة فحص الغاز المركزى بالخرج (clicks: 0, impressions: 223, pos: 10.2)
#       - شركة تركيب انظمه الامان الغاز بالخرج (clicks: 0, impressions: 190, pos: 9.5)
#       - توريد خزانات الغاز بالخرج (clicks: 0, impressions: 124, pos: 29.0)
#       - توصيل غاز ٢٤ ساعه الخرج (clicks: 0, impressions: 15, pos: 10.6)
#       - شركة تمديد غاز مركزى بالاحساء (clicks: 0, impressions: 14, pos: 39.2)
#       - شركه تمديد (clicks: 0, impressions: 8, pos: 10.2)
#       - شركة تمديد غاز مركزي بمحايل عسير (clicks: 0, impressions: 5, pos: 82.8)
#       - شركة تمديد غاز مركزى راس تنورة (clicks: 0, impressions: 5, pos: 83.2)
#       - رقم توصيل اسطوانات الغاز للمنازل الخرج (clicks: 0, impressions: 5, pos: 11.8)
#       - شركة تمديد غاز مركزي بالباحة (clicks: 0, impressions: 3, pos: 69.7)
#       - اقرب محل غاز من موقعي (clicks: 0, impressions: 3, pos: 1.0)
#       - شركة تمديد غاز مركزي بحفر الباطن (clicks: 0, impressions: 2, pos: 71.5)
#       - شركة تمديد غاز مركزي بحائل (clicks: 0, impressions: 2, pos: 74.5)
#       - شركة تمديد غاز مركزى بالجبيل (clicks: 0, impressions: 2, pos: 53.5)
#       - تمديد غاز مركزي بالباحة (clicks: 0, impressions: 2, pos: 84.5)
#       - أقرب محل غاز من موقعي توصيل (clicks: 0, impressions: 2, pos: 1.0)
#       - riyadh pipes trading co. شركة أنابيب الرياض للتجارة (clicks: 0, impressions: 2, pos: 11.5)
#       - مستودع غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب من موقعي مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محل بيع غاز قريب (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - شركه غاز (clicks: 0, impressions: 1, pos: 10.0)
#       - شركة تمديد غاز مركزى بالقصيم (clicks: 0, impressions: 1, pos: 64.0)
#       - شركات تمديد تدفئة مركزية (clicks: 0, impressions: 1, pos: 79.0)
#       - سيارة تعبئة الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - خدمة توصيل اسطوانات الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 1, pos: 1.0)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 1, pos: 48.0)
#       - تمديد غاز مركزي بنجران (clicks: 0, impressions: 1, pos: 81.0)
#       - تعبية الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة غاز توصيل (clicks: 0, impressions: 1, pos: 1.0)
#       - تأسيس غاز مركزي (clicks: 0, impressions: 1, pos: 6.0)
#       - المسافه بين الخرج وجده (clicks: 0, impressions: 1, pos: 34.0)
#       - الفرق بين المواسير السيملس والحديد (clicks: 0, impressions: 1, pos: 47.0)
#       - اقرب محل غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - اسعار تركيب الغاز الطبيعى للمنازل (clicks: 0, impressions: 1, pos: 62.0)
#       - اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - أين تباع مواسير الغاز (clicks: 0, impressions: 1, pos: 13.0)
#       - ألوان مواسير الغازات الطبية (clicks: 0, impressions: 1, pos: 33.0)
#       - أقرب محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-ghaz-mrkzy-llmtaam
#   1. Title too_short (36 chars, range 50-60)
#   2. Description too_short (94 chars, range 150-160)
#   3. Stale content (775 days old)
#  Missing queries (9):
#       - شركه الغاز المركزي الطائف (clicks: 0, impressions: 76, pos: 37.2)
#       - شركة تمديد الغاز المركزي بى الطائف (clicks: 0, impressions: 48, pos: 14.6)
#       - شركة تمديد غاز بمدينة المنورة (clicks: 0, impressions: 16, pos: 37.9)
#       - شركة تمديد غاز مركزي بالدمام (clicks: 0, impressions: 7, pos: 92.4)
#       - شركة تمديد الغاز المركزي بالدمام (clicks: 0, impressions: 5, pos: 81.4)
#       - شركة تمديد غاز مركزى بالدمام (clicks: 0, impressions: 2, pos: 93.0)
#       - تمديد غاز مركزى بجده (clicks: 0, impressions: 2, pos: 32.0)
#       - شركة تمديد خطوط غاز مكة (clicks: 0, impressions: 1, pos: 94.0)
#       - تمديد غاز مركزي الكويت (clicks: 0, impressions: 1, pos: 38.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-ghaz-mrkzy-mhayl-asyr
#   1. Title too_short (44 chars, range 50-60)
#   2. Description too_long (162 chars, range 150-160)
#   3. Stale content (662 days old)
#  Missing queries (58):
#       - مؤسسة الغامدي لتوزيع الغاز محايل عسير (clicks: 6, impressions: 130, pos: 4.8)
#       - اقرب محل غاز (clicks: 1, impressions: 45, pos: 2.9)
#       - محل غاز من موقعي (clicks: 1, impressions: 30, pos: 3.9)
#       - اقرب محل غاز من موقعي (clicks: 0, impressions: 27, pos: 3.0)
#       - محل غاز قريب من موقعي (clicks: 0, impressions: 7, pos: 4.9)
#       - أقرب محل غاز من موقعي مفتوح (clicks: 0, impressions: 7, pos: 3.4)
#       - عمائر تجارية للايجار في محايل (clicks: 0, impressions: 6, pos: 45.0)
#       - محلات غاز قريبه من موقعي (clicks: 0, impressions: 5, pos: 3.3)
#       - محل غاز مفتوح الآن (clicks: 0, impressions: 3, pos: 4.7)
#       - محل الغاز قريب مني (clicks: 0, impressions: 3, pos: 3.7)
#       - تمديد غاز بالخرج (clicks: 0, impressions: 3, pos: 70.0)
#       - أقرب محل غاز من موقعي (clicks: 0, impressions: 3, pos: 2.5)
#       - أقرب محل غاز مفتوح الآن (clicks: 0, impressions: 3, pos: 4.3)
#       - مستودع غاز (clicks: 0, impressions: 2, pos: 1.0)
#       - محلات غاز قريبه مني (clicks: 0, impressions: 2, pos: 1.0)
#       - محل غاز قريب مني (clicks: 0, impressions: 2, pos: 10.5)
#       - محل اسطوانات غاز قريب مني (clicks: 0, impressions: 2, pos: 1.0)
#       - محل اسطوانات غاز (clicks: 0, impressions: 2, pos: 1.0)
#       - اقرب محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 2, pos: 6.5)
#       - اقرب محل غاز من موقعي في 1.6 كم (clicks: 0, impressions: 2, pos: 10.0)
#       - اقرب محل بيع غاز (clicks: 0, impressions: 2, pos: 3.0)
#       - اقرب غاز من موقعي (clicks: 0, impressions: 2, pos: 6.0)
#       - أقرب محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 2, pos: 11.0)
#       - مكتب الخطوط السعودية محايل عسير (clicks: 0, impressions: 1, pos: 12.0)
#       - مكان غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 12.0)
#       - مستودع الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - مستشفى مزايا محايل (clicks: 0, impressions: 1, pos: 11.0)
#       - محل غاز مفتوح (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب من موقعي مفتوح الآن (clicks: 0, impressions: 1, pos: 12.0)
#       - محل غاز فاتح الان (clicks: 0, impressions: 1, pos: 6.0)
#       - محل غاز بالقرب مني (clicks: 0, impressions: 1, pos: 2.0)
#       - محل تعبئة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل بيع غاز قريب مني (clicks: 0, impressions: 1, pos: 4.0)
#       - محل اسطوانة غاز قريب مني (clicks: 0, impressions: 1, pos: 5.0)
#       - محطة غاز بالقرب مني (clicks: 0, impressions: 1, pos: 7.0)
#       - محبس غاز مركزي (clicks: 0, impressions: 1, pos: 1.0)
#       - متى يقفل محل الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - غاز بالقرب مني (clicks: 0, impressions: 1, pos: 5.0)
#       - عمائر للايجار في محايل عسير (clicks: 0, impressions: 1, pos: 49.0)
#       - سنترال غاز (clicks: 0, impressions: 1, pos: 9.0)
#       - سعر تبديل اسطوانة الغاز (clicks: 0, impressions: 1, pos: 7.0)
#       - رقم توصيل اسطوانات الغاز للمنازل (clicks: 0, impressions: 1, pos: 1.0)
#       - توصيل غاز ٢٤ ساعة مكة المكرمة (clicks: 0, impressions: 1, pos: 15.0)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 1, pos: 1.0)
#       - توصيل اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة غاز توصيل (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة اسطوانة غاز توصيل (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة اسطوانة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - بيع غاز قريب مني (clicks: 0, impressions: 1, pos: 3.0)
#       - اقرب مكان غاز من موقعي (clicks: 0, impressions: 1, pos: 3.0)
#       - اقرب مكان غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - اقرب محل غاز من موقعي هذا (clicks: 0, impressions: 1, pos: 2.0)
#       - اقرب محل غاز مفتوح الآن (clicks: 0, impressions: 1, pos: 11.0)
#       - اقرب محل اسطوانات غاز من موقعي (clicks: 0, impressions: 1, pos: 3.0)
#       - اقرب فرع غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - اسطوانة غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - اسطوانات غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - أقرب محل بيع غاز من موقعي (clicks: 0, impressions: 1, pos: 4.0)
#
# [3 issues] https://emdadelgaz.com/tmdyd-mwasyr-alghaz-llmtbkh
#   1. Title too_short (40 chars, range 50-60)
#   2. Description too_short (86 chars, range 150-160)
#   3. Stale content (775 days old)
#  Missing queries (35):
#       - سعر تمديد مواسير الغاز (clicks: 1, impressions: 151, pos: 4.1)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 83, pos: 59.5)
#       - ماسورة غاز فرن (clicks: 0, impressions: 22, pos: 3.3)
#       - توصيل انابيب غاز (clicks: 0, impressions: 16, pos: 6.4)
#       - تمديد انابيب الغاز (clicks: 0, impressions: 16, pos: 9.6)
#       - ‏الغاز (clicks: 0, impressions: 7, pos: 12.0)
#       - كيفية تركيب أنابيب الغاز في المنزل (clicks: 0, impressions: 7, pos: 4.0)
#       - ماسورة غاز (clicks: 0, impressions: 6, pos: 11.8)
#       - تمديدات الغاز في المنزل (clicks: 0, impressions: 4, pos: 1.2)
#       - تمديد غاز للمطاعم (clicks: 0, impressions: 4, pos: 39.0)
# ...
#       - اقرب مكان غاز من موقعي (clicks: 0, impressions: 19, pos: 3.9)
#       - محل غاز بالقرب مني (clicks: 0, impressions: 17, pos: 3.8)
#       - اقرب مستودع غاز (clicks: 0, impressions: 17, pos: 6.5)
#       - محطة غاز بالقرب مني (clicks: 0, impressions: 16, pos: 6.5)
#       - اقرب مستودع انابيب غاز (clicks: 0, impressions: 16, pos: 9.8)
#       - محلات الغاز متى تفتح (clicks: 0, impressions: 14, pos: 5.4)
#       - محل اسطوانة غاز قريب مني (clicks: 0, impressions: 14, pos: 6.0)
#       - توصيل اسطوانات غاز الطائف (clicks: 0, impressions: 14, pos: 7.3)
#       - محل الغاز مفتوح (clicks: 0, impressions: 13, pos: 5.7)
#       - اقرب محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 13, pos: 9.2)
#       - اقرب محل اسطوانات غاز من موقعي (clicks: 0, impressions: 13, pos: 5.1)
#       - أقرب محل غاز مفتوح الآن (clicks: 0, impressions: 12, pos: 5.7)
#       - محل تعبئة غاز قريب من موقعي (clicks: 0, impressions: 11, pos: 4.2)
#       - محل انابيب غاز قريب من موقعي (clicks: 1, impressions: 11, pos: 6.0)
#       - غاز قريب مني (clicks: 0, impressions: 11, pos: 11.0)
#       - اقرب مكان غاز (clicks: 0, impressions: 11, pos: 3.9)
#       - اقرب محل غاز مفتوح (clicks: 0, impressions: 11, pos: 7.6)
#       - اقرب محل غاز لموقعي (clicks: 0, impressions: 11, pos: 4.2)
#       - اقرب غاز (clicks: 0, impressions: 11, pos: 3.7)
#       - محل بيع غاز قريب مني (clicks: 0, impressions: 10, pos: 5.9)
#       - محل الغاز مفتوح الآن (clicks: 0, impressions: 10, pos: 6.4)
#       - غاز بالقرب مني (clicks: 0, impressions: 10, pos: 3.4)
#       - اقرب موقع غاز من موقعي (clicks: 0, impressions: 10, pos: 3.3)
#       - مستودع غاز (clicks: 0, impressions: 9, pos: 6.5)
#       - محلات غاز قريبه مني (clicks: 0, impressions: 9, pos: 4.4)
#       - شركة صيانة غاز بحي الروضة (clicks: 0, impressions: 9, pos: 61.0)
#       - توصيل غاز قريب من موقعي (clicks: 0, impressions: 9, pos: 5.0)
#       - محلات الغاز متى تقفل (clicks: 0, impressions: 8, pos: 6.6)
#       - محل تعبئة الغاز (clicks: 0, impressions: 8, pos: 5.2)
#       - محل اسطوانات غاز (clicks: 0, impressions: 8, pos: 5.3)
#       - تعبئة غاز الطائف (clicks: 0, impressions: 8, pos: 6.2)
#       - اقرب محل تعبئه غاز (clicks: 0, impressions: 8, pos: 6.8)
#       - اقرب محل تعبئة غاز (clicks: 0, impressions: 8, pos: 6.4)
#       - اقرب محطه غاز (clicks: 0, impressions: 8, pos: 5.2)
#       - محلات تعبئة غاز (clicks: 0, impressions: 7, pos: 7.0)
#       - محل اسطوانه قريب مني (clicks: 0, impressions: 7, pos: 5.4)
#       - شركة تمديد غاز مركزى بالجبيل (clicks: 0, impressions: 7, pos: 68.9)
#       - اقرب محل بيع غاز (clicks: 0, impressions: 7, pos: 4.8)
#       - اقرب محطة غاز (clicks: 0, impressions: 7, pos: 6.8)
#       - محل غار (clicks: 0, impressions: 6, pos: 4.2)
#       - توصيل غاز الحوية (clicks: 0, impressions: 6, pos: 8.2)
#       - اقرب موقع غاز (clicks: 0, impressions: 6, pos: 4.4)
#       - اقرب محل انابيب غاز من موقعي (clicks: 0, impressions: 6, pos: 3.3)
#       - موزع غاز قريب (clicks: 0, impressions: 5, pos: 4.6)
#       - محلات غاز بالقرب مني (clicks: 0, impressions: 5, pos: 8.4)
#       - شركه تمديد غاز مركزي (clicks: 0, impressions: 5, pos: 82.0)
#       - اقرب محل غاز مفتوح الآن (clicks: 0, impressions: 5, pos: 8.0)
#       - اقرب محل الغاز (clicks: 0, impressions: 5, pos: 4.0)
#       - اقرب تعبئة غاز من موقعي (clicks: 0, impressions: 5, pos: 7.4)
#       - أقرب مستودع انابيب غاز من موقعي (clicks: 0, impressions: 5, pos: 5.2)
#       - أقرب غاز من موقعي (clicks: 0, impressions: 5, pos: 5.0)
#       - مكان غاز قريب من موقعي (clicks: 0, impressions: 4, pos: 3.2)
#       - مستودع غاز قريب مني (clicks: 0, impressions: 4, pos: 8.5)
#       - محل غاز توصيل قريب من موقعي (clicks: 0, impressions: 4, pos: 7.0)
#       - غاز مفتوح الآن (clicks: 0, impressions: 4, pos: 2.0)
#       - شركه تمديد (clicks: 0, impressions: 4, pos: 27.0)
#       - شركة تمديد الغاز المركزى (clicks: 0, impressions: 4, pos: 72.2)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 4, pos: 4.8)
#       - تمديدات الغاز وكشف خطوط الحريق (clicks: 0, impressions: 4, pos: 91.0)
#       - اقرب مكان تعبئه غاز (clicks: 0, impressions: 4, pos: 6.7)
#       - اقرب مركز غاز من موقعي (clicks: 0, impressions: 4, pos: 4.0)
#       - اقرب غاز من موقعي مفتوح الآن (clicks: 0, impressions: 4, pos: 6.2)
#       - أقرب مستودع أنابيب غاز من موقعي (clicks: 0, impressions: 4, pos: 5.3)
#       - أقرب محل تعبئة غاز من موقعي (clicks: 0, impressions: 4, pos: 5.0)
#       - ‏محل غاز (clicks: 0, impressions: 3, pos: 2.0)
#       - محل غاز مفتوح الان (clicks: 0, impressions: 3, pos: 8.3)
#       - محل غاز فاتح (clicks: 0, impressions: 3, pos: 3.3)
#       - محل غاز الهدا (clicks: 0, impressions: 3, pos: 11.0)
#       - محل انبوبة غاز مفتوح الآن (clicks: 0, impressions: 3, pos: 8.0)
#       - محل اسطوانه الغاز (clicks: 0, impressions: 3, pos: 6.3)
#       - شركة تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 3, pos: 89.0)
#       - شركة تمديد غاز مركزي بابها (clicks: 0, impressions: 3, pos: 90.3)
#       - رقم تزويد للغاز (clicks: 0, impressions: 3, pos: 9.0)
#       - تمديدات الغاز المركزى شركة تاون جاس (clicks: 0, impressions: 3, pos: 12.7)
#       - تعبئة غاز (clicks: 0, impressions: 3, pos: 1.0)
#       - الطلحي للغاز توصيل (clicks: 0, impressions: 3, pos: 16.0)
#       - اقرب محل لبيع الغاز (clicks: 0, impressions: 3, pos: 4.0)
#       - اقرب محل بيع الغاز (clicks: 0, impressions: 3, pos: 7.5)
#       - ارقام توصيل الغاز بجدة (clicks: 0, impressions: 3, pos: 17.0)
#       - موقع غاز قريب من موقعي (clicks: 0, impressions: 2, pos: 4.0)
#       - مستودع انابيب قريب مني (clicks: 0, impressions: 2, pos: 12.0)
#       - مستودع انابيب غاز قريب من موقعي (clicks: 0, impressions: 2, pos: 6.0)
#       - محل غاز ٢٤ ساعة (clicks: 0, impressions: 2, pos: 5.0)
#       - محل غاز مفتوح الآن مفتوح الآن (clicks: 0, impressions: 2, pos: 5.0)
#       - محل غاز قريب من موقعي مفتوح الآن مفتوح الآن (clicks: 0, impressions: 2, pos: 9.5)
#       - محل غاز فاتح الان (clicks: 2, impressions: 2, pos: 3.5)
#       - محل تعبئة غاز قريب مني مفتوح الآن (clicks: 0, impressions: 2, pos: 11.5)
#       - محل بيع غاز قريب (clicks: 0, impressions: 2, pos: 5.0)
#       - محل اسطوانات قريب مني (clicks: 0, impressions: 2, pos: 4.5)
#       - محبس غاز مركزي (clicks: 0, impressions: 2, pos: 47.5)
#       - شركة تمديد غاز مركزى بالقطيف (clicks: 0, impressions: 2, pos: 84.5)
#       - شركة تمديد غاز بمدينة المنورة (clicks: 0, impressions: 2, pos: 94.0)
#       - رقم صاحب الغاز (clicks: 0, impressions: 2, pos: 8.5)
#       - دوام محلات الغاز (clicks: 0, impressions: 2, pos: 3.0)
#       - تمديد غاز مركزي بابها (clicks: 0, impressions: 2, pos: 90.0)
#       - اقرب محل غاز فاتح (clicks: 0, impressions: 2, pos: 2.5)
#       - اقرب محل تعبئة الغاز من موقعي (clicks: 0, impressions: 2, pos: 4.0)
#       - اقرب محل اسطوانات (clicks: 0, impressions: 2, pos: 4.0)
#       - اقرب محطة غاز من موقعي (clicks: 0, impressions: 2, pos: 4.0)
#       - أقرب مستودع غاز من موقعي (clicks: 0, impressions: 2, pos: 6.0)
#       - أقرب محل غاز من موقعي توصيل مفتوح الآن (clicks: 0, impressions: 2, pos: 9.0)
#       - أقرب محل بيع غاز من موقعي (clicks: 0, impressions: 2, pos: 3.5)
#       - أقرب محطة غاز (clicks: 0, impressions: 2, pos: 3.0)
#       - موزع غاز (clicks: 0, impressions: 1, pos: 34.0)
#       - مندوب غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - مستودع غاز مفتوح الآن (clicks: 0, impressions: 1, pos: 7.0)
#       - مستودع غاز قريب مني مفتوح الآن (clicks: 0, impressions: 1, pos: 5.0)
#       - مخل غاز (clicks: 0, impressions: 1, pos: 3.0)
#       - محل غازات قريب مني (clicks: 0, impressions: 1, pos: 11.0)
#       - محل غاز يوصل للبيت (clicks: 0, impressions: 1, pos: 4.0)
#       - محل غاز من موقعي مفتوح الآن (clicks: 0, impressions: 1, pos: 1.0)
#       - محل غاز قريب من موقعي في 8.1 كم (clicks: 0, impressions: 1, pos: 5.0)
#       - محل غاز قريب من موقعي في 1.6 كم (clicks: 0, impressions: 1, pos: 6.0)
#       - محل غاز بن خلف (clicks: 0, impressions: 1, pos: 10.0)
#       - محل غاز السنابل (clicks: 0, impressions: 1, pos: 7.0)
#       - محل غاز الخبر (clicks: 0, impressions: 1, pos: 58.0)
#       - محل تعبئة الغاز قريب من موقعي (clicks: 0, impressions: 1, pos: 5.0)
#       - محل تبديل غاز (clicks: 0, impressions: 1, pos: 3.0)
#       - محل تبديل اسطوانات الغاز (clicks: 0, impressions: 1, pos: 4.0)
#       - محل بيع غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 12.0)
#       - محل بيع الغاز قريب من موقعي (clicks: 0, impressions: 1, pos: 2.0)
#       - محل الغاز قريب من موقعي (clicks: 0, impressions: 1, pos: 4.0)
#       - محل الاسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 6.0)
#       - محطه غاز بالقرب مني (clicks: 0, impressions: 1, pos: 11.0)
#       - محطات للايجار في الطائف (clicks: 0, impressions: 1, pos: 38.0)
#       - مثل اخذنا عازتنا (clicks: 0, impressions: 1, pos: 5.0)
#       - متى يفتح محل الغاز (clicks: 0, impressions: 1, pos: 5.0)
#       - فني افران غاز الطائف (clicks: 0, impressions: 1, pos: 57.0)
#       - غاز مفتوح (clicks: 0, impressions: 1, pos: 9.0)
#       - غاز قريب (clicks: 0, impressions: 1, pos: 12.0)
#       - غاز الصفا (clicks: 0, impressions: 1, pos: 7.0)
#       - شركه (clicks: 0, impressions: 1, pos: 2.0)
#       - شركة تمديد غاز مركزي بالدمام (clicks: 0, impressions: 1, pos: 276.0)
#       - شركة تمديد غاز مركزي بالخرج (clicks: 0, impressions: 1, pos: 2.0)
#       - شركة تمديد غاز بخميس مشيط (clicks: 0, impressions: 1, pos: 78.0)
#       - شركة تمديد غاز بالقصيم (clicks: 0, impressions: 1, pos: 82.0)
#       - شركة تمديد الغاز المركزي بالدمام (clicks: 0, impressions: 1, pos: 3.0)
#       - سعر محبس الغاز الطبيعي (clicks: 0, impressions: 1, pos: 69.0)
#       - رمز (clicks: 0, impressions: 1, pos: 4.0)
#       - رقم شركه الغاز (clicks: 0, impressions: 1, pos: 9.0)
#       - رقم شركة الغاز المجاني (clicks: 0, impressions: 1, pos: 8.0)
#       - رقم توصيل اسطوانات الغاز للمنازل مكة (clicks: 0, impressions: 1, pos: 64.0)
#       - رقم توصيل اسطوانات الغاز للمنازل بالمدينة المنورة (clicks: 0, impressions: 1, pos: 33.0)
#       - رقم توصيل أنابيب البوتاجاز للمنازل (clicks: 0, impressions: 1, pos: 3.0)
#       - رقم تعبئة غاز (clicks: 0, impressions: 1, pos: 77.0)
#       - رقم تزويد الغاز (clicks: 0, impressions: 1, pos: 11.0)
#       - درجة حرارة الغاز المنزلي (clicks: 0, impressions: 1, pos: 3.0)
#       - درجة حرارة الطايف (clicks: 0, impressions: 1, pos: 59.0)
#       - توصيل غاز مفتوح الآن (clicks: 0, impressions: 1, pos: 5.0)
#       - توصيل غاز للمنازل مفتوح الآن (clicks: 0, impressions: 1, pos: 10.0)
#       - توصيل اسطوانات غاز المدينة المنورة (clicks: 0, impressions: 1, pos: 64.0)
#       - تمديد نحاس مكيفات بالطائف (clicks: 0, impressions: 1, pos: 86.0)
#       - تمديد غاز مركزي بالقصيم (clicks: 0, impressions: 1, pos: 48.0)
#       - تعبئة غاز توصيل (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة اسطوانة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - بيع غاز قريب مني (clicks: 0, impressions: 1, pos: 7.0)
#       - بيع اسطوانة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - الطلحي للغاز الطائف (clicks: 0, impressions: 1, pos: 12.0)
#       - اقرب موزع غاز من موقعي (clicks: 0, impressions: 1, pos: 5.0)
#       - اقرب مستودع انابيب (clicks: 0, impressions: 1, pos: 12.0)
#       - اقرب محل للغاز (clicks: 0, impressions: 1, pos: 4.0)
#       - اقرب محل توصيل غاز من موقعي (clicks: 0, impressions: 1, pos: 6.0)
#       - اقرب محل توزيع غاز من موقعي (clicks: 0, impressions: 1, pos: 4.0)
#       - اقرب محل تبديل غاز (clicks: 0, impressions: 1, pos: 4.0)
#       - اقرب محل اسطوانات من موقعي (clicks: 0, impressions: 1, pos: 4.0)
#       - اقرب فرع غاز (clicks: 0, impressions: 1, pos: 9.0)
#       - اقرب توصيل غاز (clicks: 0, impressions: 1, pos: 6.0)
#       - اقرب تعبئة غاز (clicks: 0, impressions: 1, pos: 4.0)
#       - اسطوانة غاز (clicks: 0, impressions: 1, pos: 2.0)
#       - اسطوانات الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - ارقام شركة الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - أقرب محل بيع غاز من موقعي مفتوح الآن (clicks: 0, impressions: 1, pos: 12.0)
#       - gas near me (clicks: 0, impressions: 1, pos: 2.0)
#       - cooking gas near me open now (clicks: 0, impressions: 1, pos: 4.0)
#       - 920009911 (clicks: 0, impressions: 1, pos: 12.0)
#
# [1 issue] https://emdadelgaz.com/tmdyd-alghaz-almrkzy-tbwk
#   1. Description too_short (144 chars, range 150-160)
#  Missing queries (57):
#       - محل غاز تبوك الدخل (clicks: 0, impressions: 170, pos: 10.2)
#       - توصيل غاز ٢٤ ساعة تبوك (clicks: 0, impressions: 157, pos: 11.2)
#       - رقم توصيل اسطوانات الغاز للمنازل تبوك (clicks: 0, impressions: 136, pos: 10.8)
#       - محل اسطوانات غاز تبوك (clicks: 0, impressions: 118, pos: 12.3)
#       - شركة مسارات تبوك للغاز (clicks: 0, impressions: 50, pos: 12.5)
#       - توصيل غاز ٢٤ ساعة العليا، تبوك (clicks: 0, impressions: 43, pos: 12.1)
#       - صور شركة مسارات تبوك للغاز (clicks: 0, impressions: 27, pos: 10.3)
#       - توصيل اسطوانات غاز تبوك (clicks: 0, impressions: 11, pos: 16.3)
#       - شركة تمديد غاز مركزي بالخرج (clicks: 0, impressions: 10, pos: 91.7)
#       - محل غاز تبوك المروج (clicks: 0, impressions: 8, pos: 13.0)
#       - سعر اسطوانة الغاز تبوك (clicks: 0, impressions: 6, pos: 14.4)
#       - غاز المصيف تبوك (clicks: 0, impressions: 5, pos: 32.4)
#       - محل اسطوانات تبوك (clicks: 0, impressions: 4, pos: 11.0)
#       - توصيل اسطوانات تبوك (clicks: 0, impressions: 4, pos: 20.0)
#       - محلات الغاز متى تفتح (clicks: 0, impressions: 3, pos: 10.7)
#       - محل غاز تبوك القادسيه (clicks: 0, impressions: 3, pos: 20.0)
#       - محطة غاز بالقرب مني (clicks: 0, impressions: 3, pos: 4.5)
#       - شركة تمديد غاز مركزي بنجران (clicks: 0, impressions: 3, pos: 62.0)
#       - توصيل غاز ٢٤ ساعه العليا تبوك (clicks: 0, impressions: 3, pos: 11.2)
#       - تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 3, pos: 82.0)
#       - تمديد غاز مركزي بابها (clicks: 0, impressions: 3, pos: 87.0)
#       - اسطوانات غاز تبوك (clicks: 0, impressions: 3, pos: 13.0)
#       - مستودع غاز (clicks: 0, impressions: 2, pos: 1.0)
#       - متى تفتح محلات الغاز (clicks: 0, impressions: 2, pos: 4.0)
#       - شركة تمديد غاز مركزي بابها (clicks: 0, impressions: 2, pos: 94.0)
#       - توصيل غاز تبوك الروضة (clicks: 0, impressions: 2, pos: 29.5)
#       - تمديد غاز مركزي بمحايل عسير (clicks: 0, impressions: 2, pos: 69.0)
#       - اسطوانات تبوك (clicks: 0, impressions: 2, pos: 10.0)
#       - مستودع غاز قريب مني (clicks: 0, impressions: 1, pos: 1.0)
#       - مستودع غاز قريب من موقعي (clicks: 0, impressions: 1, pos: 1.0)
#       - محلات غاز بالقرب مني (clicks: 0, impressions: 1, pos: 6.0)
#       - محل تعبئة غاز قريب مني (clicks: 0, impressions: 1, pos: 1.0)
#       - محل اسطوانات غاز تبوك توصيل (clicks: 0, impressions: 1, pos: 12.0)
#       - محل اسطوانات غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - غاز القايدي (clicks: 0, impressions: 1, pos: 7.0)
#       - غاز اسطوانات (clicks: 0, impressions: 1, pos: 1.0)
#       - شركة تمديد غاز مركزي بمحايل عسير (clicks: 0, impressions: 1, pos: 77.0)
#       - شركة تمديد غاز مركزي بخميس مشيط (clicks: 0, impressions: 1, pos: 72.0)
#       - سعر اسطوانة الغاز في تبوك (clicks: 0, impressions: 1, pos: 12.0)
#       - ساعة غاز مركزي (clicks: 0, impressions: 1, pos: 83.0)
#       - رقم شركة الغاز الموحد (clicks: 0, impressions: 1, pos: 7.0)
#       - رقم خدمه عملاء الغاز الطبيعي (clicks: 0, impressions: 1, pos: 6.0)
#       - تونتي فور تبوك (clicks: 0, impressions: 1, pos: 11.0)
#       - توصيل غاز ٢٤ ساعة (clicks: 0, impressions: 1, pos: 2.0)
#       - توصيل غاز تبوك المصيف (clicks: 0, impressions: 1, pos: 18.0)
#       - توصيل غاز تبوك الصفا (clicks: 0, impressions: 1, pos: 27.0)
#       - تمديد غاز مركزي بنجران (clicks: 0, impressions: 1, pos: 30.0)
#       - تعبئة غاز قريب مني (clicks: 0, impressions: 1, pos: 1.0)
#       - تعبئة غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - بيع اسطوانات الغاز (clicks: 0, impressions: 1, pos: 1.0)
#       - اقرب مستودع غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - اقرب مركز غاز (clicks: 0, impressions: 1, pos: 5.0)
#       - اقرب محل غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - اسطوانه غاز (clicks: 0, impressions: 1, pos: 14.0)
#       - اسطوانة غاز تبوك (clicks: 0, impressions: 1, pos: 12.0)
#       - اسطوانات غاز (clicks: 0, impressions: 1, pos: 1.0)
#       - اسطوانات (clicks: 0, impressions: 1, pos: 2.0)

# %%
#| hide
report['issues']['https://emdadelgaz.com/ahwadh-sbahh-bnzam-alawfr-flw']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 #| hide
# ----> 2 report['issues']['https://emdadelgaz.com/ahwadh-sbahh-bnzam-alawfr-flw']
#
# KeyError: 'https://emdadelgaz.com/ahwadh-sbahh-bnzam-alawfr-flw'
