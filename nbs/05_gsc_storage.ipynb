# %%
# | default_exp gsc_storage

# %%
# | export
from sqlmodel import Session, select
from seo_rat.models import GSCAnalytics
from datetime import datetime,timedelta
from seo_rat.gsc_client import GSCAuth
from functools import partial
from fastcore.basics import compose
from sqlalchemy import func, not_, or_

# %%
# | export
def filter_site(query, site_url: str):
    return query.where(GSCAnalytics.site_url == site_url)


def filter_dates(query, start: str, end: str):
    return query.where(GSCAnalytics.date.between(start, end))

# %%
# | export
def filter_dimension(query, dimension: str, value: str):
    return query.where(getattr(GSCAnalytics, dimension) == value)

# %%
# | export
from sqlmodel import SQLModel


class AnalyticsSummary(SQLModel):
    query: str
    clicks: int
    impressions: int

# %%
#| export 
from urllib.parse import unquote

def normalize_url(url: str) -> str:
    """Normalize URL by decoding percent-encoding and standardizing separators"""
    url = unquote(url)
    url = url.replace("-", " ").replace("_", " ")
    return url

# %%
# | export
def parse_gsc_row(row, site_url, date) -> GSCAnalytics:
    keys = row["keys"]
    fields = ("query", "page", "country", "device")
    dims = dict(zip(fields, keys))


    return GSCAnalytics(
        site_url=site_url,
        date=date,
        query=dims.get("query"),
        page=dims.get("page"),
        country=dims.get("country"),
        device=dims.get("device"),
        clicks=row["clicks"],
        impressions=row["impressions"],
        ctr=row["ctr"],
        position=row["position"],
    )

# %%
# | export
def store_gsc_data(session: Session, site_url: str, date: str, rows: list[dict]):
    """Store GSC data with upsert (update or insert)"""
    for row in rows:
        record = parse_gsc_row(row, site_url, date)
        existing = session.exec(
            select(GSCAnalytics).where(
                GSCAnalytics.site_url == record.site_url,
                GSCAnalytics.date == record.date,
                GSCAnalytics.query == record.query,
                GSCAnalytics.page == record.page,
                GSCAnalytics.country == record.country,
                GSCAnalytics.device == record.device,
            )
        ).first()
        if existing:
            record.id = existing.id
        session.merge(record)
    session.commit()

# %%
# | hide
#| eval: false
from fastcore.test import test_eq
from seo_rat.gsc_client import GSCAuth, fetch_gsc_data, get_date_range
from seo_rat.sqlite_db import SQLiteDB
from sqlmodel import Session
from pprint import pprint
auth = GSCAuth()
start, end = get_date_range("last_days", days=30)
data = fetch_gsc_data(auth, "sc-domain:kareemai.com", start, end)

# %%
# | hide
#| eval: false
db = SQLiteDB()
with db.get_session() as session:
    store_gsc_data(session, "sc-domain:kareemai.com", start, data[:5])
    # verfiy stored
    test_eq(len(session.exec(select(GSCAnalytics)).all()) > 4, True)

# %%
# | export
def get_top_queries(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    country: str | None = None,
    page_path: str | None = None,
    limit: int = 10,
    sort_by:str = "clicks"
) -> list[dict]:
    """Get top performing queries, optionally filtered by page"""
    base_query = select(
        GSCAnalytics.query,
        func.sum(GSCAnalytics.clicks).label("total_clicks"),
        func.sum(GSCAnalytics.impressions).label("total_impressions"),
        func.avg(GSCAnalytics.position).label("avg_position"),
        func.avg(GSCAnalytics.ctr).label("avg_ctr"),
    )
    filters = [
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
    ]
    if country:
        filters.append(partial(filter_dimension, dimension="country", value=country))
    if page_path:
        filters.append(lambda q: q.where(GSCAnalytics.page.contains(page_path)))
    sort_col = func.sum(GSCAnalytics.impressions) if sort_by =="impressions" else func.sum(GSCAnalytics.clicks)

    query = (compose(*filters)(base_query)
        .where(GSCAnalytics.query.isnot(None))
        .group_by(GSCAnalytics.query)
        .order_by(sort_col.desc())
        .limit(limit))

    return [row._asdict() for row in session.exec(query)]

# %%
# | hide
#| eval: false

test_top_queries = get_top_queries(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    country="egy",
)

# %%
# | export
def filter_exclude_pages(query, exclude_pages: list[str]):
    filters = [GSCAnalytics.page.contains(page) for page in exclude_pages]
    return query.where(not_(or_(*filters)))

# %%
# | export
def get_top_queries_excluding_pages(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    exclude_pages: list[str],
    country: str | None = None,
    limit: int = 10,
) -> list[dict]:
    """Get top queries excluding certain pages"""
    base_query = select(
        GSCAnalytics.query,
        func.sum(GSCAnalytics.clicks).label("total_clicks"),
        func.sum(GSCAnalytics.impressions).label("total_impressions"),
    )
    filters = [
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
        partial(filter_exclude_pages, exclude_pages=exclude_pages),
    ]
    if country:
        filters.append(partial(filter_dimension, dimension="country", value=country))

    query = (
        compose(*filters)(base_query)
        .where(GSCAnalytics.query.isnot(None))
        .group_by(GSCAnalytics.query)
        .order_by(func.sum(GSCAnalytics.clicks).desc())
        .limit(limit)
    )

    return [row._asdict() for row in session.exec(query)]

# %%
# | hide
#| eval: false
from sqlalchemy.testing.exclusions import exclude

test_exclude_page_from_top_queries = get_top_queries_excluding_pages(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    exclude_pages=[
        "https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html",
        "https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html",
    ],
    country="egy",
)
pprint(test_exclude_page_from_top_queries)
# Out:
# [{'query': 'math for ai', 'total_clicks': 0, 'total_impressions': 1}]

# %%
# | export
def get_page_analytics(
    session: Session, site_url: str, page_path: str, start_date: str, end_date: str
) -> dict:
    """Get analytics for a specific page"""
    base_query = select(
        func.sum(GSCAnalytics.clicks).label("total_clicks"),
        func.sum(GSCAnalytics.impressions).label("total_impressions"),
        func.avg(GSCAnalytics.position).label("avg_position"),
        func.avg(GSCAnalytics.ctr).label("avg_ctr"),
    )
    filters = compose(
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
    )
    query = filters(base_query).where(GSCAnalytics.page.contains(page_path))

    row = session.exec(query).first()

    # Top queries need a separate query
    q_query = filters(select(GSCAnalytics.query)).where(
        GSCAnalytics.page.contains(page_path),
        GSCAnalytics.query.isnot(None),
    )
    top_queries = list(set(session.exec(q_query)))[:10]

    return {
        "page_path": page_path,
        "total_clicks": row.total_clicks or 0,
        "total_impressions": row.total_impressions or 0,
        "avg_position": row.avg_position or 0,
        "avg_ctr": row.avg_ctr or 0,
        "top_queries": top_queries,
    }

# %%
# | hide
#| eval: false
test_page_analytics = get_page_analytics(
    session,
    site_url="sc-domain:kareemai.com",
    page_path="https://kareemai.com",
    start_date=start,
    end_date=end,
)
pprint(test_page_analytics)
# Out:
# {'avg_ctr': 0.005373065611170666,
#  'avg_position': 5.117296428455412,
#  'page_path': 'https://kareemai.com',
#  'top_queries': ['huawei 7i earbuds',
#                  'paperspace gpu cloud pricing 2025',
#                  'huawei buds i7',
#                  'huawei freebuds 7i earbuds specs',
#                  'huawei freebuds 7i specs earbuds',
#                  'فري بودز 7i',
#                  'freebuds 7i cover',
#                  'huawei freebuds 7i call quality',
#                  'huawei freebuds 7i specs',
#                  'math for ai'],
#  'total_clicks': 17,
#  'total_impressions': 1512}

# %%
# | export
def get_analytics_by_date_range(
    session: Session, site_url: str, start_date: str, end_date: str
) -> list[GSCAnalytics]:
    """Get all analytics for date range"""
    base_query = select(GSCAnalytics)
    build_query = compose(
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
    )
    query = build_query(base_query)

    return session.exec(query).all()

# %%
# | hide
#| eval: false

test_get_analytics_by_date_range = get_analytics_by_date_range(
    session, site_url="sc-domain:kareemai.com", start_date=start, end_date=end
)
pprint(test_get_analytics_by_date_range)
# Out:
# [GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=8.0, query='anc', id=246386, country='mus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 471712)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='anker liberty 5 vs huawei freebuds 7i', id=246387, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 473968)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='audífonos huawei freebuds 7i', id=246388, country='chl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 475278)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='audífonos huawei freebuds 7i', id=246389, country='col', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 476842)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=1.0, query='audífonos huawei freebuds 7i', id=246390, country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 478304)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='buds 7i huawei', id=246391, country='jor', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 479854)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/minishlab/ctranslate_maswray.html', device='DESKTOP', impressions=1, position=8.0, query='ctranslate2 documentation quantization int8 int16 float16', id=246392, country='isr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 481600)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/minishlab/ctranslate_maswray.html', device='DESKTOP', impressions=1, position=12.0, query='ctranslate2 documentation quantization int8 int16 float16', id=246393, country='sgp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 483580)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei_mate_pad_11.html', device='MOBILE', impressions=1, position=11.0, query='does huawei matepad support google', id=246394, country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 485297)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='frebuds 7i', id=246395, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 486445)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=3.0, query='free buds 7', id=246396, country='svk', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 487571)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=8.0, query='freebuds 4i vs 7i', id=246397, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 488878)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=3.0, query='freebuds 5i review anc', id=246398, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 490144)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=3.0, query='freebuds 5i vs 7i', id=246399, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 491437)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=11.0, query='freebuds 7', id=246400, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 492631)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='freebuds 7', id=246401, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 493718)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=3.0, query='freebuds 7', id=246402, country='irn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 494803)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=8.0, query='freebuds 7', id=246403, country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 496147)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='freebuds 7i', id=246404, country='alb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 497841)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=2, position=3.5, query='freebuds 7i', id=246405, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 499751)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='freebuds 7i', id=246406, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 501740)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='freebuds 7i', id=246407, country='aze', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 503057)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=15, position=6.733333333333333, query='freebuds 7i', id=246408, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 504464)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=9.0, query='freebuds 7i', id=246409, country='est', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 505868)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='TABLET', impressions=1, position=9.0, query='freebuds 7i', id=246410, country='grc', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 507434)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=6.0, query='freebuds 7i', id=246411, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 508982)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=9.0, query='freebuds 7i', id=246412, country='irl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 510212)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='TABLET', impressions=1, position=4.0, query='freebuds 7i', id=246413, country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 511496)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=2, position=3.5, query='freebuds 7i', id=246414, country='mus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 512717)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=7.0, query='freebuds 7i', id=246415, country='omn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 514016)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=6.0, query='freebuds 7i', id=246416, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 515614)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=9.0, query='freebuds 7i', id=246417, country='rou', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 517586)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=7.0, query='freebuds 7i', id=246418, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 519405)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=4, position=7.25, query='freebuds 7i', id=246419, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 520975)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='freebuds 7i', id=246420, country='srb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 522281)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=2.0, query='freebuds 7i', id=246421, country='svn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 523459)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='freebuds 7i', id=246422, country='syr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 524952)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=8.0, query='freebuds 7i', id=246423, country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 526200)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=30, position=9.133333333333333, query='freebuds 7i', id=246379, country='tur', clicks=3, ctr=0.1, created_at=datetime.datetime(2026, 3, 31, 6, 7, 54, 197340)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=4.0, query='freebuds 7i', id=246424, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 527303)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='freebuds 7i', id=246425, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 528404)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=4.0, query='freebuds 7i características', id=246426, country='chl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 529549)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=11.0, query='freebuds 7i cover', id=246427, country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 531294)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='freebuds 7i price', id=246428, country='bgd', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 533594)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=9.0, query='freebuds 7i price', id=246429, country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 535457)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=3.0, query='freebuds 7i review', id=246430, country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 536747)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='freebuds 7i review', id=246431, country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 537908)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=2.0, query='freebuds 7i review', id=246432, country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 539005)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='freebuds 7i review', id=246433, country='rou', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 540147)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=1.0, query='freebuds 7i review', id=246434, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 541596)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=2.0, query='freebuds 7i review', id=246435, country='svn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 542924)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=1.0, query='freebuds 7i review', id=246436, country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 544105)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='freebuds 7i review', id=246437, country='vnm', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 545250)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='freebuds 7i vs 5i', id=246438, country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 546406)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=3.0, query='freebuds 7i vs 5i', id=246439, country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 548113)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei 5i vs 7i', id=246440, country='bra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 550328)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='huawei 7i buds', id=246441, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 552266)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='huawei 7i buds', id=246442, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 553706)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=9.0, query='huawei 7i earbuds', id=246443, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 555089)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=5.5, query='huawei 7i earbuds', id=246444, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 556226)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=8.0, query='huawei 7i earbuds', id=246445, country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 557725)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=4.333333333333334, query='huawei 7i earbuds', id=246446, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 559340)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=5.5, query='huawei 7i earbuds', id=246447, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 560697)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='huawei 7i earbuds', id=246448, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 562002)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei 7i earbuds review', id=246449, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 563428)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei 7i freebuds', id=246450, country='bgd', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 564983)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=9.0, query='huawei 7i freebuds', id=246451, country='bgr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 570200)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=6.0, query='huawei 7i freebuds', id=246452, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 571369)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='huawei 7i freebuds', id=246453, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 572486)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=10.0, query='huawei 7i freebuds', id=246454, country='prt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 573747)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei 7i freebuds', id=246455, country='srb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 575602)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei 7i review', id=246456, country='grc', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 577006)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=9.0, query='huawei 7i review', id=246457, country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 578349)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=6.0, query='huawei buds 7', id=246458, country='syc', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 579876)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='huawei buds 7i', id=246459, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 581202)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei buds 7i', id=246460, country='mus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 582550)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=3.5, query='huawei buds 7i', id=246461, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 584052)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=5.5, query='huawei buds 7i', id=246462, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 585223)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=6.0, query='huawei buds 7i', id=246463, country='srb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 586480)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei buds 7i', id=246464, country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 587611)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei buds i7', id=246465, country='col', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 588706)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei buds i7', id=246466, country='mys', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 589806)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei buds i7', id=246467, country='vnm', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 591461)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/life_style/gpuvec.html', device='DESKTOP', impressions=3, position=4.666666666666666, query='huawei cloud gpu instances specifications pricing', id=246468, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 592917)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=10.0, query='huawei earbuds 7i', id=246469, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 594236)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='huawei earbuds 7i', id=246470, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 595530)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=5.666666666666667, query='huawei earbuds 7i', id=246471, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 596980)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=6.0, query='huawei earbuds 7i', id=246472, country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 598194)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=3.0, query='huawei earbuds 7i', id=246473, country='gha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 599874)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei earbuds 7i', id=246474, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 601226)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=2, position=4.0, query='huawei earbuds 7i', id=246475, country='mus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 602348)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei earbuds 7i', id=246476, country='mys', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 603416)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=5.0, query='huawei earbuds 7i', id=246477, country='omn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 604465)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=6.0, query='huawei earbuds 7i', id=246478, country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 605513)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=4.0, query='huawei earbuds 7i', id=246479, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 606639)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=7.0, query='huawei earbuds 7i', id=246480, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 608599)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=8.0, query='huawei earbuds 7i', id=246481, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 610001)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=8.0, query='huawei earbuds 7i', id=246482, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 611338)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=6.0, query='huawei earbuds 7i', id=246483, country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 613230)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=6.0, query='huawei earbuds 7i', id=246484, country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 614845)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='huawei free buds 7i', id=246485, country='bgr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 616352)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=9.0, query='huawei free buds 7i', id=246486, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 617875)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei free buds 7i', id=246487, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 619262)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei free buds 7i', id=246488, country='omn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 620432)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei free buds 7i', id=246489, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 621653)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=6.0, query='huawei free buds 7i', id=246490, country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 622838)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=2.0, query='huawei freebids 7i', id=246491, country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 624167)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=5.0, query='huawei freebuds 5i anc review', id=246492, country='bra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 625495)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=2.0, query='huawei freebuds 5i anc review', id=246493, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 626621)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=3.0, query='huawei freebuds 5i anc review', id=246494, country='dom', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 627736)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=6.0, query='huawei freebuds 5i call quality review', id=246495, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 629378)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=9.0, query='huawei freebuds 5i microphone call quality review', id=246496, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 631259)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=7.0, query='huawei freebuds 5i microphone call quality review', id=246497, country='ltu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 633260)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=9.0, query='huawei freebuds 5i microphone call quality review', id=246498, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 635142)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='TABLET', impressions=1, position=2.0, query='huawei freebuds 5i review', id=246499, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 636303)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=1.0, query='huawei freebuds 5i review', id=246500, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 637418)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 5i review', id=246501, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 638535)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=1.0, query='huawei freebuds 5i review', id=246502, country='grc', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 639841)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 5i review', id=246503, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 641311)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=4.0, query='huawei freebuds 5i review', id=246504, country='irl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 642505)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='TABLET', impressions=1, position=3.0, query='huawei freebuds 5i review', id=246505, country='lbn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 643779)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=4.0, query='huawei freebuds 5i review', id=246506, country='mkd', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 645215)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=2.0, query='huawei freebuds 5i review', id=246507, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 646472)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=10, position=2.0, query='huawei freebuds 5i review', id=246508, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 648095)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=4.0, query='huawei freebuds 5i review', id=246509, country='vnm', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 650401)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='DESKTOP', impressions=1, position=2.0, query='huawei freebuds 5i sound quality review', id=246510, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 652245)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 5i specs review', id=246511, country='ecu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 653504)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='MOBILE', impressions=1, position=2.0, query='huawei freebuds 5i specs review', id=246512, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 654650)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 5i specs review', id=246513, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 656359)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 5i vs 6i vs 7i', id=246514, country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 657925)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei freebuds 5i vs 7i', id=246515, country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 659162)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=1.0, query='huawei freebuds 5i vs 7i', id=246516, country='rus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 660302)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 5i vs 7i', id=246517, country='srb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 661761)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 6 vs 7i', id=246518, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 663035)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=8.0, query='huawei freebuds 6 vs huawei freebuds 7i', id=246519, country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 664787)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='huawei freebuds 7', id=246520, country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 666841)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=4.0, query='huawei freebuds 7', id=246521, country='mac', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 668602)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=11.0, query='huawei freebuds 7', id=246522, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 670101)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='DESKTOP', impressions=1, position=4.0, query='huawei freebuds 7i', id=246523, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 671841)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=240, position=4.816666666666666, query='huawei freebuds 7i', id=246380, country='are', clicks=3, ctr=0.0125, created_at=datetime.datetime(2026, 3, 31, 6, 7, 54, 202432)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 7i', id=246524, country='aus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 675569)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=8.0, query='huawei freebuds 7i', id=246525, country='bel', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 677264)),
# ...
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei freebuds 7i true wireless earbuds', id=246667, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 957205)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=9.0, query='huawei freebuds 7i vs 4i', id=246668, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 958567)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 7i vs 6i', id=246669, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 959994)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='huawei freebuds 7i vs soundcore liberty 5', id=246670, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 961284)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=5.0, query='huawei freebuds 7i wireless earbuds', id=246671, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 962390)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=3.0, query='huawei freebuds 7i отзывы', id=246672, country='blr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 963460)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei freebuds i7', id=246673, country='bra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 964577)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei freebuds i7', id=246674, country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 965690)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=2.0, query='huawei freebuds i7', id=246675, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 967144)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=4.0, query='huawei freebuds i7', id=246676, country='rou', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 968583)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=2.5, query='huawei freebuds i7', id=246677, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 969900)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=2, position=7.0, query='huawei i7 earbuds', id=246678, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 971062)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=9.0, query='huawei i7 earbuds', id=246679, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 972172)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei_mate_pad_11.html', device='DESKTOP', impressions=2, position=8.5, query='huawei matepad 11 disadvantages', id=246680, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 973269)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei_mate_pad_11.html', device='MOBILE', impressions=1, position=4.0, query='huawei matepad se 11 kids edition', id=246681, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 974382)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei_watch_gt_4_experience.html', device='DESKTOP', impressions=1, position=43.0, query='huawei watch gt 4 review', id=246682, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 975852)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=5, position=7.0, query='huawei7i', id=246683, country='uga', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 977152)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='huawi freebuds 7i', id=246684, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 978306)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=8.0, query='huawie 7i', id=246685, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 979383)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei_mate_pad_11.html', device='MOBILE', impressions=1, position=11.0, query='is huawei matepad android', id=246686, country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 980480)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/math/math_skills_for_AI.html', device='DESKTOP', impressions=1, position=11.0, query='math for ai', id=246687, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 981627)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/math/math_skills_for_AI.html', device='MOBILE', impressions=1, position=12.0, query='mathematics for ai', id=246688, country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 982796)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/life_style/gpuvec.html', device='DESKTOP', impressions=1, position=8.0, query='modal labs gpu pricing 2025', id=246689, country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 984395)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', device='MOBILE', impressions=1, position=54.0, query='mteb', id=246690, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 985689)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='MOBILE', impressions=1, position=6.0, query='oneplus pad 3 battery capacity mah', id=246691, country='bgd', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 986821)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='MOBILE', impressions=1, position=6.0, query='oneplus pad 3 battery capacity mah', id=246692, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 987860)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='MOBILE', impressions=2, position=7.5, query='oneplus pad 3 processor antutu score', id=246693, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 988891)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='DESKTOP', impressions=1, position=9.0, query='oneplus pad 3 review 2025', id=246694, country='dom', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 989936)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='MOBILE', impressions=1, position=6.0, query='oneplus pad 3 specifications 2025', id=246695, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 990983)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='DESKTOP', impressions=1, position=9.0, query='oneplus pad 3 specs review', id=246696, country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 992396)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='MOBILE', impressions=1, position=13.0, query='oneplus pad review 2024 or 2025', id=246697, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 993563)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', device='MOBILE', impressions=1, position=8.0, query='oneplus pad review 2025', id=246698, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 994611)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/life_style/gpuvec.html', device='DESKTOP', impressions=1, position=11.0, query='paperspace gpu cloud pricing 2025', id=246699, country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 995605)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/til/tils/2025-05-20-til.html', device='DESKTOP', impressions=1, position=9.0, query='railway cloudflare domain', id=246700, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 996663)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=3, position=1.3333333333333333, query='soundcore liberty 5 vs huawei freebuds 7i', id=246701, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 997707)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', device='DESKTOP', impressions=1, position=37.0, query='super productivity', id=246702, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 998746)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', device='MOBILE', impressions=1, position=9.0, query='super productivity app review', id=246703, country='nor', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 54, 999981)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', device='MOBILE', impressions=1, position=11.0, query='super productivity app review', id=246704, country='rou', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 1212)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', device='DESKTOP', impressions=2, position=10.0, query='super productivity app review', id=246705, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 2377)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', device='MOBILE', impressions=1, position=9.0, query='tarteel ai careers', id=246706, country='bgd', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 3473)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', device='DESKTOP', impressions=1, position=9.0, query='tarteel ai careers', id=246707, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 4438)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', device='MOBILE', impressions=1, position=10.0, query='tarteel ai careers', id=246708, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 5400)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', device='DESKTOP', impressions=2, position=8.0, query='tarteel ai jobs', id=246709, country='aus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 6361)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', device='MOBILE', impressions=1, position=11.0, query='tarteel careers', id=246710, country='nga', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 7373)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=7.0, query='فري بودز 7i', id=246711, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 8620)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=3.0, query='هواوي فري بودز 7i', id=246712, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 9798)),
#  GSCAnalytics(site_url='sc-domain:kareemai.com', date='2026-02-26', page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', device='MOBILE', impressions=1, position=1.0, query='ได้', id=246713, country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 3, 31, 6, 2, 55, 10879))]

# %%
# | export
def get_trends(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    dimension: str | None = None,
) -> list[dict]:
    """Get trends over time, optionally grouped by dimension"""
    columns = [
        GSCAnalytics.date,
        func.sum(GSCAnalytics.clicks).label("clicks"),
        func.sum(GSCAnalytics.impressions).label("impressions"),
        func.avg(GSCAnalytics.position).label("avg_position"),
        func.avg(GSCAnalytics.ctr).label("avg_ctr"),
    ]
    group_by = [GSCAnalytics.date]

    if dimension:
        dim_col = getattr(GSCAnalytics, dimension)
        columns.insert(1, dim_col)
        group_by.append(dim_col)

    base_query = select(*columns)
    filters = compose(
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
    )
    query = filters(base_query).group_by(*group_by).order_by(GSCAnalytics.date)

    return [row._asdict() for row in session.exec(query)]

# %%
# | hide
#| eval: false
test_get_trends = get_trends(
    session, site_url="sc-domain:kareemai.com", start_date=start, end_date=end
)
pprint(test_get_trends)
# Out:
# [{'avg_ctr': 0.005373065611170666,
#   'avg_position': 5.117296428455412,
#   'clicks': 17,
#   'date': '2026-02-26',
#   'impressions': 1512}]

# %%
# | export
def get_analytics_by(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    dimension: str,
    value: str,
) -> list[AnalyticsSummary]:

    base_query = select(
        GSCAnalytics.query,
        func.sum(GSCAnalytics.clicks).label("clicks"),
        func.sum(GSCAnalytics.impressions).label("impressions"),
    )

    build_query = compose(
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
        partial(filter_dimension, dimension=dimension, value=value),
    )
    return [
        AnalyticsSummary(**row._asdict())
        for row in session.exec(build_query(base_query).group_by(GSCAnalytics.query))
    ]

# %%
# | hide
#| eval: false
test_result = get_analytics_by(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    dimension="country",
    value="egy",
)

pprint(test_result)
# Out:
# [AnalyticsSummary(query='anker liberty 5 vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i', clicks=0, impressions=15),
#  AnalyticsSummary(query='huawei 7i buds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i freebuds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei earbuds 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei free buds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i', clicks=3, impressions=736),
#  AnalyticsSummary(query='huawei freebuds 7i earbuds specs', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i review', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i soundguys', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i specs', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs 6i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs soundcore liberty 5', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei i7 earbuds', clicks=0, impressions=2),
#  AnalyticsSummary(query='math for ai', clicks=0, impressions=1),
#  AnalyticsSummary(query='soundcore liberty 5 vs huawei freebuds 7i', clicks=0, impressions=3)]

# %%
# | hide
#| eval: false
test_get_analytics_by_device = get_analytics_by(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    dimension="device",
    value="MOBILE",
)
pprint(test_get_analytics_by_device)
# Out:
# [AnalyticsSummary(query='anker liberty 5 vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='audífonos huawei freebuds 7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='buds 7i huawei', clicks=0, impressions=1),
#  AnalyticsSummary(query='does huawei matepad support google', clicks=0, impressions=1),
#  AnalyticsSummary(query='frebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebuds 7i', clicks=3, impressions=62),
#  AnalyticsSummary(query='freebuds 7i cover', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i price', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 7i review', clicks=0, impressions=4),
#  AnalyticsSummary(query='freebuds 7i vs 5i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei 5i vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i buds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei 7i earbuds', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei 7i earbuds review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i freebuds', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei 7i review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei buds 7', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei buds 7i', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei buds i7', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei earbuds 7i', clicks=0, impressions=16),
#  AnalyticsSummary(query='huawei free buds 7i', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebids 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 5i review', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 5i specs review', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 5i vs 6i vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i vs 7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 6 vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i', clicks=7, impressions=1033),
#  AnalyticsSummary(query='huawei freebuds 7i - true wireless earphones with mic - in-ear - bluetooth - active noise canceling - black', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i anc', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i battery life', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i buy', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i call quality', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i características', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i earbuds', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i especificaciones', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i official specs', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i price', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i price in india', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i review', clicks=3, impressions=52),
#  AnalyticsSummary(query='huawei freebuds 7i reviews', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i soundguys', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i specifications', clicks=0, impressions=11),
#  AnalyticsSummary(query='huawei freebuds 7i specifications review', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i specs', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i test', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i true wireless earbuds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs 4i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs 6i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs soundcore liberty 5', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i wireless earbuds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i отзывы', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds i7', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei i7 earbuds', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei matepad se 11 kids edition', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawi freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawie 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='is huawei matepad android', clicks=0, impressions=1),
#  AnalyticsSummary(query='mathematics for ai', clicks=0, impressions=1),
#  AnalyticsSummary(query='mteb', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 battery capacity mah', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 processor antutu score', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 specifications 2025', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad review 2024 or 2025', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad review 2025', clicks=0, impressions=1),
#  AnalyticsSummary(query='soundcore liberty 5 vs huawei freebuds 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='super productivity app review', clicks=0, impressions=2),
#  AnalyticsSummary(query='tarteel ai careers', clicks=0, impressions=2),
#  AnalyticsSummary(query='tarteel careers', clicks=0, impressions=1),
#  AnalyticsSummary(query='فري بودز 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='هواوي فري بودز 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='ได้', clicks=0, impressions=1)]

# %%
# | export
from seo_rat.gsc_client import fetch_gsc_data
import time

def store_single_date(session: Session, auth: GSCAuth, site_url: str, date: str) -> int:
    """Store GSC data for a single date"""

    rows = fetch_gsc_data(auth, site_url, date, date)
    store_gsc_data(session, site_url, date, rows)
    return len(rows)

# %%
# | hide
# | test
#| eval: false
count = store_single_date(session, auth, "sc-domain:kareemai.com", start)
test_eq(count > 0, True)

# %%
# | test
#| eval: false
# Check what's actually stored
stored = session.exec(select(GSCAnalytics).limit(1)).first()
print(f"Query: {stored.query}")
print(f"Clicks: {stored.clicks}")
print(f"Date: {stored.date}")
test_eq(stored.site_url, "sc-domain:kareemai.com")
# Out:
# Query: أنواع السباكة
# Clicks: 0
# Date: 2024-11-11
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[27], line 8
#       6 print(f"Clicks: {stored.clicks}")
#       7 print(f"Date: {stored.date}")
# ----> 8 test_eq(stored.site_url, "sc-domain:kareemai.com")
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/fastcore/test.py:40, in test_eq(a, b)
#      38 def test_eq(a,b):
#      39     "`test` that `a==b`"
# ---> 40     test(a,b,equals, cname='==')
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/fastcore/test.py:30, in test(a, b, cmp, cname)
#      28 "`assert` that `cmp(a,b)`; display inputs and `cname or cmp.__name__` if it fails"
#      29 if cname is None: cname=cmp.__name__
# ---> 30 assert cmp(a,b),f"{cname}:\n{a}\n{b}"
#
# AssertionError: ==:
# sc-domain:awazly.com
# sc-domain:kareemai.com

# %%
# | export
def store_date_range(
    session: Session, auth: GSCAuth, site_url: str, start_date: str, end_date: str
) -> dict:
    """Store GSC data for a date range with progress"""
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    total_days = (end - start).days + 1

    results = {"successful": [], "failed": [], "total_records": 0}

    for day_num in range(total_days):
        date_str = (start + timedelta(days=day_num)).strftime("%Y-%m-%d")
        print(f"Processing {date_str} ({day_num + 1}/{total_days})...")

        try:
            count = store_single_date(session, auth, site_url, date_str)
            results["successful"].append(date_str)
            results["total_records"] += count
        except Exception as e:
            results["failed"].append({"date": date_str, "error": str(e)})

        time.sleep(1)

    return results

# %%
# | test
#| eval: false
result = store_date_range(session, auth, "sc-domain:kareemai.com", start, start)
test_eq(len(result["successful"]), 1)
print(f"Stored {result['total_records']} records")
# Out:
# Processing 2026-02-21 (1/1)...
# Stored 271 records

# %%
#| test
#| eval: false
r = session.exec(select(GSCAnalytics).limit(1)).first()
print(f"Query: {r.query}")
print(f"Page: {r.page}")
print(f"Country: {r.country}")
print(f"Device: {r.device}")
print(f"Clicks: {r.clicks}")
print(f"Impressions: {r.impressions}")
print(f"CTR: {r.ctr}")
print(f"Position: {r.position}")
# Out:
# Query: huawei freebuds 7i
# Page: https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html
# Country: egy
# Device: MOBILE
# Clicks: 0
# Impressions: 23
# CTR: 0.0
# Position: 7.130434782608695

# %%
# | test
#| eval: false
top = get_top_queries(session, "sc-domain:kareemai.com", start, start, limit=5)
for q in top:
    print(
        f"{q['query']}: {q['total_clicks']} clicks, {q['total_impressions']} impressions"
    )
# Out:
# huawei freebuds 7i review: 7 clicks, 65 impressions
# huawei freebuds 7i: 5 clicks, 177 impressions
# freebuds 7i: 4 clicks, 67 impressions
# huawei freebuds 7i wired charging black: 1 clicks, 1 impressions
# huawei freebuds 7i vs 5i: 1 clicks, 6 impressions

# %%
from seo_rat.sqlite_db import SQLiteDB
from seo_rat.models import GSCAnalytics

# %%
from sqlalchemy import delete

# %%
# | hide
#| eval: false

db = SQLiteDB()
session = db.get_session()

session.exec(delete(GSCAnalytics))
session.commit()

# %%
# | hide
#| eval: false

# delay 3 because GSC api limitation
end = datetime.now() - timedelta(days=3)
start = end - timedelta(days=365 * 3)

result = store_date_range(
    session,
    auth,
    "sc-domain:awazly.com",
    start.strftime("%Y-%m-%d"),
    end.strftime("%Y-%m-%d"),
)
# Out:
# Processing 2023-03-24 (1/1096)...
# Processing 2023-03-25 (2/1096)...
# Processing 2023-03-26 (3/1096)...
# Processing 2023-03-27 (4/1096)...
# Processing 2023-03-28 (5/1096)...
# Processing 2026-03-02 (1075/1096)...
# Processing 2026-03-03 (1076/1096)...
# Processing 2026-03-04 (1077/1096)...
# Processing 2026-03-05 (1078/1096)...
# Processing 2026-03-06 (1079/1096)...
# Processing 2026-03-07 (1080/1096)...
# Processing 2026-03-08 (1081/1096)...
# Processing 2026-03-09 (1082/1096)...
# Processing 2026-03-10 (1083/1096)...
# Processing 2026-03-11 (1084/1096)...
# Processing 2026-03-12 (1085/1096)...
# Processing 2026-03-13 (1086/1096)...
# Processing 2026-03-14 (1087/1096)...
# Processing 2026-03-15 (1088/1096)...
# Processing 2026-03-16 (1089/1096)...
# Processing 2026-03-17 (1090/1096)...
# Processing 2026-03-18 (1091/1096)...
# Processing 2026-03-19 (1092/1096)...
# Processing 2026-03-20 (1093/1096)...
# Processing 2026-03-21 (1094/1096)...
# Processing 2026-03-22 (1095/1096)...
# Processing 2026-03-23 (1096/1096)...

# %%
# |export
from datetime import date, timedelta


def get_missing_dates(session, site_url, start_date, end_date):
    start_date = datetime.strptime(start_date, "%Y-%m-%d").date()
    end_date = datetime.strptime(end_date, "%Y-%m-%d").date()
    stored = set(session.exec(
        select(GSCAnalytics.date).where(GSCAnalytics.site_url == site_url).distinct()
    ).all())
    all_dates = set()
    current = start_date
    while current <= end_date:
        all_dates.add(current.strftime("%Y-%m-%d"))
        current += timedelta(days=1)
    return sorted(all_dates - stored)

# %%
#| hide 
with db.get_session() as session:
    missing = get_missing_dates(session, "sc-domain:awazly.com", "2026-01-01", "2026-03-28")
    print(len(missing), missing[:5])
# Out:
# 0 []

# %%
#| export
def sync_missing_dates(session, auth, site_url, start_date, end_date):
    missing = get_missing_dates(session, site_url, start_date, end_date)
    results = {"successful": [], "failed": [], "total_records": 0}
    print(f"Found {len(missing)} missing dates")
    for date in missing:
        try:
            count = store_single_date(session, auth, site_url, date)
            time.sleep(1)
            print(f"Synced {date} with {count} records")
            results["successful"].append(date)
            results["total_records"] += count
        except Exception as e:
            print(f"Failed to sync {date}: {e}")
            results["failed"].append(date)
    return {
        "synced": len(missing),
        "failed": len(results["failed"]),
        "total_records": results["total_records"]
    }

# %%
# | export
def daily_sync(session, auth, sites: list[str]) -> dict:
    """Sync missing GSC data for all sites up to today."""
    _, end = get_date_range("today")

    results = {}
    for site_url in sites:
        stored_dates = set(session.exec(
            select(GSCAnalytics.date).where(GSCAnalytics.site_url == site_url).distinct()
        ).all())
        start = min(stored_dates) if stored_dates else end
        print(f"\nSyncing {site_url} from {start} to {end}...")
        results[site_url] = sync_missing_dates(session, auth, site_url, start, end)
    return results

# %%
#| hide 
daily_sync_result = daily_sync(session, auth, ["sc-domain:awazly.com"])
print(daily_sync_result)
# Out:
# Syncing sc-domain:awazly.com from 2024-11-11 to 2026-03-28...
# Found 5 missing dates
# Synced 2026-03-24 with 522 records
# Synced 2026-03-25 with 443 records
# Synced 2026-03-26 with 493 records
# Synced 2026-03-27 with 439 records
# Synced 2026-03-28 with 462 records
# {'sc-domain:awazly.com': {'synced': 5, 'failed': 0, 'total_records': 2359}}
