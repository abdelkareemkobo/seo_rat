# %%
# | default_exp gsc_storage

# %%
# | export
from sqlmodel import Session, select
from seo_rat.models import GSCAnalytics
from datetime import datetime, timedelta
from functools import partial
from fastcore.basics import compose
from sqlalchemy import func, not_, or_
from seo_rat.sqlite_db import  get_session
from seo_rat.models import GSCAnalytics
from seo_rat.gsc_client import GSCAuth

# %%
# | export
def filter_site(query,  # SQLModel query
                site_url: str  # GSC property URL
                ):
    "Filter query by site URL."
    return query.where(GSCAnalytics.site_url == site_url)


def filter_dates(query,  # SQLModel query
                 start: str,  # Start date (YYYY-MM-DD)
                 end: str  # End date (YYYY-MM-DD)
                 ):
    "Filter query by date range."
    return query.where(GSCAnalytics.date.between(start, end))


def filter_dimension(query,  # SQLModel query
                     dimension: str,  # GSCAnalytics field name
                     value: str  # Value to match
                     ):
    "Filter query by a specific dimension value."
    return query.where(getattr(GSCAnalytics, dimension) == value)


def filter_exclude_pages(query,  # SQLModel query
                         exclude_pages: list[str]  # Page path substrings to exclude
                         ):
    "Exclude rows where page contains any of the given substrings."
    return query.where(not_(or_(*[GSCAnalytics.page.contains(p) for p in exclude_pages])))

# %%
# | export
from sqlmodel import SQLModel


class AnalyticsSummary(SQLModel):
    query: str
    clicks: int
    impressions: int

# %%
#| export 
from urllib.parse import unquote


def normalize_url(url: str) -> str:
    """Normalize URL by decoding percent-encoding and standardizing separators"""
    url = unquote(url)
    url = url.replace("-", " ").replace("_", " ")
    return url

# %%
# | export
def parse_gsc_row(row:dict,      # Raw GSC API row
                  site_url:str,  # GSC property URL
                  date:str       # Date of the row (YYYY-MM-DD)
                 ) -> GSCAnalytics:
    "Parse a raw GSC API row into a GSCAnalytics instance."
    dims = dict(zip(("query", "page", "country", "device"), row["keys"]))
    return GSCAnalytics(site_url=site_url, date=date,
                        query=dims.get("query"), page=dims.get("page"),
                        country=dims.get("country"), device=dims.get("device"),
                        clicks=row["clicks"], impressions=row["impressions"],
                        ctr=row["ctr"], position=row["position"])

# %%
# | export
from sqlalchemy.dialects.sqlite import insert

def store_gsc_data(session:Session,  # Active database session
                   site_url:str,     # GSC property URL
                   date:str,         # Date of the data (YYYY-MM-DD)
                   rows:list[dict]   # Raw GSC API rows
                  ) -> None:
    "Store GSC rows with upsert (update on conflict)."
    for row in rows:
        record = parse_gsc_row(row, site_url, date)
        stmt = insert(GSCAnalytics).values(**record.model_dump(exclude={"id"}))
        stmt = stmt.on_conflict_do_update(
            index_elements=["site_url", "date", "query", "page", "country", "device"],
            set_={"clicks": record.clicks, "impressions": record.impressions,
                  "ctr": record.ctr, "position": record.position}
        )
        session.exec(stmt)
    session.commit()

# %%
# | hide
#| eval: false
from fastcore.test import test_eq
from seo_rat.gsc_client import GSCAuth, fetch_gsc_data, get_date_range
from sqlmodel import Session
from pprint import pprint

auth = GSCAuth()
start, end = get_date_range("last_days", days=30)
data = fetch_gsc_data(auth, "sc-domain:kareemai.com", start, end)

# %%
# | hide
#| eval: false
session = get_session()
# store_gsc_data(session, "sc-domain:kareemai.com", start, data[:5])
# # verfiy stored
# test_eq(len(session.exec(select(GSCAnalytics)).all()) > 4, True)

# %%
# | export
def get_top_queries(session: Session,  # Active database session
                    site_url: str,  # GSC property URL
                    start_date: str,  # Start date (YYYY-MM-DD)
                    end_date: str,  # End date (YYYY-MM-DD)
                    country: str | None = None,  # Filter by country code
                    page_path: str | None = None,  # Filter by page path substring
                    limit: int = 10,  # Max rows to return
                    sort_by: str = "clicks"  # Sort by 'clicks' or 'impressions'
                    ) -> list[dict]:
    "Get top performing queries, optionally filtered by country and page."
    base = select(GSCAnalytics.query,
                  func.sum(GSCAnalytics.clicks).label("total_clicks"),
                  func.sum(GSCAnalytics.impressions).label("total_impressions"),
                  func.avg(GSCAnalytics.position).label("avg_position"),
                  func.avg(GSCAnalytics.ctr).label("avg_ctr"))
    filters = [partial(filter_site, site_url=site_url),
               partial(filter_dates, start=start_date, end=end_date)]
    if country: filters.append(partial(filter_dimension, dimension="country", value=country))
    if page_path: filters.append(lambda q: q.where(GSCAnalytics.page.contains(page_path)))
    sort_col = func.sum(GSCAnalytics.impressions) if sort_by == "impressions" else func.sum(GSCAnalytics.clicks)
    query = (compose(*filters)(base)
             .where(GSCAnalytics.query.isnot(None))
             .group_by(GSCAnalytics.query)
             .order_by(sort_col.desc())
             .limit(limit))
    return [row._asdict() for row in session.exec(query)]

# %%
# | hide
#| eval: false

test_top_queries = get_top_queries(
session,
site_url = "sc-domain:kareemai.com",
start_date = start,
end_date = end,
country = "egy",
)
test_top_queries
# Out:
# [{'query': 'huawei freebuds 7i',
#   'total_clicks': 3,
#   'total_impressions': 644,
#   'avg_position': 6.282489375114783,
#   'avg_ctr': 0.007384823848238482},
#  {'query': 'proteinai',
#   'total_clicks': 1,
#   'total_impressions': 1,
#   'avg_position': 9.0,
#   'avg_ctr': 1.0},
#  {'query': 'oneplus pad 3',
#   'total_clicks': 1,
#   'total_impressions': 122,
#   'avg_position': 10.423333333333334,
#   'avg_ctr': 0.007407407407407407},
#  {'query': 'one plus pad 3',
#   'total_clicks': 1,
#   'total_impressions': 33,
#   'avg_position': 11.031746031746032,
#   'avg_ctr': 0.023809523809523808},
#  {'query': 'huawei earbuds 7i',
#   'total_clicks': 1,
#   'total_impressions': 54,
#   'avg_position': 6.989389233954451,
#   'avg_ctr': 0.043478260869565216},
#  {'query': 'huawei buds 7i review',
#   'total_clicks': 1,
#   'total_impressions': 3,
#   'avg_position': 2.0,
#   'avg_ctr': 0.25},
#  {'query': 'huawei 7i freebuds',
#   'total_clicks': 1,
#   'total_impressions': 67,
#   'avg_position': 8.317687074829932,
#   'avg_ctr': 0.047619047619047616},
#  {'query': 'freebuds 7i vs 5i',
#   'total_clicks': 1,
#   'total_impressions': 2,
#   'avg_position': 1.5,
#   'avg_ctr': 0.5},
#  {'query': 'freebuds 7i',
#   'total_clicks': 1,
#   'total_impressions': 144,
#   'avg_position': 6.9722561751973515,
#   'avg_ctr': 0.004901960784313725},
#  {'query': 'freebuds 5i vs 7i',
#   'total_clicks': 1,
#   'total_impressions': 4,
#   'avg_position': 1.0,
#   'avg_ctr': 0.16666666666666666}]

# %%
# | export
def get_top_queries_excluding_pages(session: Session,  # Active database session
                                    site_url: str,  # GSC property URL
                                    start_date: str,  # Start date (YYYY-MM-DD)
                                    end_date: str,  # End date (YYYY-MM-DD)
                                    exclude_pages: list[str],  # Page substrings to exclude
                                    country: str | None = None,  # Filter by country code
                                    limit: int = 10  # Max rows to return
                                    ) -> list[dict]:
    "Get top queries excluding specific pages."
    base = select(GSCAnalytics.query,
                  func.sum(GSCAnalytics.clicks).label("total_clicks"),
                  func.sum(GSCAnalytics.impressions).label("total_impressions"))
    filters = [partial(filter_site, site_url=site_url),
               partial(filter_dates, start=start_date, end=end_date),
               partial(filter_exclude_pages, exclude_pages=exclude_pages)]
    if country: filters.append(partial(filter_dimension, dimension="country", value=country))
    query = (compose(*filters)(base)
             .where(GSCAnalytics.query.isnot(None))
             .group_by(GSCAnalytics.query)
             .order_by(func.sum(GSCAnalytics.clicks).desc())
             .limit(limit))
    return [row._asdict() for row in session.exec(query)]

# %%
# | hide
#| eval: false
from sqlalchemy.testing.exclusions import exclude

test_exclude_page_from_top_queries = get_top_queries_excluding_pages(
session,
site_url = "sc-domain:kareemai.com",
start_date = start,
end_date = end,
exclude_pages = [
    "https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html",
    "https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html",
],
country = "egy",
)
pprint(test_exclude_page_from_top_queries)
# Out:
# [{'query': 'proteinai', 'total_clicks': 1, 'total_impressions': 1},
#  {'query': 'oneplus pad 3', 'total_clicks': 1, 'total_impressions': 122},
#  {'query': 'one plus pad 3', 'total_clicks': 1, 'total_impressions': 33},
#  {'query': 'tarteel careers', 'total_clicks': 0, 'total_impressions': 1},
#  {'query': 'tarteel ai jobs', 'total_clicks': 0, 'total_impressions': 2},
#  {'query': 'tarteel ai careers', 'total_clicks': 0, 'total_impressions': 2},
#  {'query': 'super productivity linux',
#   'total_clicks': 0,
#   'total_impressions': 1},
#  {'query': 'super productivity app review 2026',
#   'total_clicks': 0,
#   'total_impressions': 4},
#  {'query': 'super productivity app', 'total_clicks': 0, 'total_impressions': 1},
#  {'query': 'super productivity', 'total_clicks': 0, 'total_impressions': 6}]

# %%
# | export
def get_page_analytics(session: Session,  # Active database session
                       site_url: str,  # GSC property URL
                       page_path: str,  # Partial page path to match
                       start_date: str,  # Start date (YYYY-MM-DD)
                       end_date: str  # End date (YYYY-MM-DD)
                       ) -> dict:
    "Get aggregated analytics and top queries for a specific page."
    filters = compose(
        partial(filter_site, site_url=site_url),
        partial(filter_dates, start=start_date, end=end_date),
    )
    base = filters(select(
        func.sum(GSCAnalytics.clicks).label("total_clicks"),
        func.sum(GSCAnalytics.impressions).label("total_impressions"),
        func.avg(GSCAnalytics.position).label("avg_position"),
        func.avg(GSCAnalytics.ctr).label("avg_ctr"),
    )).where(GSCAnalytics.page.contains(page_path))
    row = session.exec(base).first()

    top_queries = session.exec(
        filters(select(GSCAnalytics.query, func.sum(GSCAnalytics.clicks).label("clicks"))
                .where(GSCAnalytics.page.contains(page_path), GSCAnalytics.query.isnot(None))
                .group_by(GSCAnalytics.query)
                .order_by(func.sum(GSCAnalytics.clicks).desc())
                .limit(10))
    ).all()

    return {"page_path": page_path,
            "total_clicks": row.total_clicks or 0,
            "total_impressions": row.total_impressions or 0,
            "avg_position": row.avg_position or 0,
            "avg_ctr": row.avg_ctr or 0,
            "top_queries": [q for q, _ in top_queries]}

# %%
# | hide
#| eval: false
test_page_analytics = get_page_analytics(
    session,
    site_url="sc-domain:kareemai.com",
    page_path="https://kareemai.com",
    start_date=start,
    end_date=end,
)
pprint(test_page_analytics)
# Out:
# {'avg_ctr': 0.011015698287363538,
#  'avg_position': 6.233690264802919,
#  'page_path': 'https://kareemai.com',
#  'top_queries': ['huawei freebuds 7i review',
#                  'huawei freebuds 7i',
#                  'huawei freebuds 5i vs 7i',
#                  'freebuds 7i',
#                  'huawei freebuds 5i review',
#                  'freebuds 7i review',
#                  'freebuds 5i vs 7i',
#                  'huawei freebuds 7i vs 5i',
#                  'freebuds 7i vs 5i',
#                  'super productivity review'],
#  'total_clicks': 147,
#  'total_impressions': 16958}

# %%
# | export
def get_analytics_by_date_range(session: Session,  # Active database session
                                site_url: str,  # GSC property URL
                                start_date: str,  # Start date (YYYY-MM-DD)
                                end_date: str  # End date (YYYY-MM-DD)
                                ) -> list[GSCAnalytics]:
    "Get all raw GSC analytics rows for a date range."
    return session.exec(
        compose(partial(filter_site, site_url=site_url),
                partial(filter_dates, start=start_date, end=end_date)
                )(select(GSCAnalytics))
    ).all()

# %%
# | hide
#| eval: false

test_get_analytics_by_date_range = get_analytics_by_date_range(
    session, site_url="sc-domain:kareemai.com", start_date=start, end_date=end
)
pprint(test_get_analytics_by_date_range)
# Out:
# [GSCAnalytics(page='https://kareemai.com/blog/posts/minishlab/blog_zaraah.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=2, position=12.0, query='"paraphrase-multilingual-minilm-l12-v2" arabic', id=388404, country='bra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 639875)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/minishlab/blog_zaraah.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=9.0, query='"paraphrase-multilingual-minilm-l12-v2" arabic', id=388405, country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 641364)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/minishlab/blog_zaraah.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=10.0, query='"paraphrase-multilingual-minilm-l12-v2" arabic', id=388406, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 642971)),
#  GSCAnalytics(page='https://kareemai.com/til/tils/2025-05-20-til.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=8.0, query='"vercel" "whois privacy" or "domain privacy"', id=388407, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 644416)),
#  GSCAnalytics(page='https://kareemai.com/til/tils/2025-05-20-til.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=9.0, query='"vercel" "whois privacy" or "domain privacy"', id=388408, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 645904)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=13.0, query='affordable gpu instances hivenet', id=388409, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 647484)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=2.0, query='and laptop', id=388410, country='som', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 649169)),
#  GSCAnalytics(page='https://kareemai.com/til/tils/2025-10-21.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=9.0, query='arabert v2', id=388411, country='fin', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 650786)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=5, position=1.0, query='audífonos huawei freebuds 7i', id=388412, country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 652513)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=72.0, query='cheap hivenet', id=388413, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 654186)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=35.0, query='cheap hivenet hpc', id=388414, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 655546)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=35.0, query='cheap hivenet hpc', id=388415, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 657034)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=39.0, query='cloud gpu price comparison', id=388416, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 663313)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=69.0, query='cloud gpu price comparison', id=388417, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 664970)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=57.0, query='cloud gpu pricing comparison', id=388418, country='irq', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 666467)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=24.0, query='cloud gpu pricing comparison', id=388419, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 668087)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=55.0, query='cloud gpu pricing comparison', id=388420, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 669639)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=38.0, query='compute with hivenet scaling pricing', id=388421, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 671269)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=37.0, query='compute with hivenet scaling pricing', id=388422, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25,
country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 847490)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=6.0, query='huawei earbuds 7i', id=388525, country='bhr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 849167)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=8, position=6.625, query='huawei earbuds 7i', id=388526, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 850524)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=12.0, query='huawei earbuds 7i', id=388527, country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 851912)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=12.0, query='huawei earbuds 7i', id=388528, country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 853270)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=7.0, query='huawei earbuds 7i', id=388529, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 854589)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=4, position=7.0, query='huawei earbuds 7i', id=388530, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 856051)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=2, position=4.5, query='huawei earbuds 7i', id=388531, country='sgp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 857458)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=6.0, query='huawei free bud 5i', id=388532, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 859413)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=5.0, query='huawei free buds 5i', id=388533, country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 861269)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=2.0, query='huawei free buds 7 i', id=388534, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 862653)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=4.0, query='huawei free buds 7i', id=388535, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 863962)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=1.0, query='huawei free buds 7i', id=388536, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 865419)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=4.0, query='huawei freebud 7i', id=388537, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 866832)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=4.0, query='huawei freebud 7i', id=388538, country='sgp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 868190)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=1.0, query='huawei freebuds 4i vs 7i', id=388539, country='hrv', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 869521)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=1, position=1.0, query='huawei freebuds 5i', id=388540, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 871025)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=2, position=6.5, query='huawei freebuds 5i', id=388541, country='arg', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 872258)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=10.0, query='huawei freebuds 5i', id=388542, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 873666)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=5.0, query='huawei freebuds 5i', id=388543, country='che', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 875103)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=1, position=6.0, query='huawei freebuds 5i', id=388544, country='col', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 877026)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='MOBILE', impressions=2, position=7.0, query='huawei freebuds 5i', id=388545, country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 878985)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-02', device='DESKTOP', impressions=2, position=11.0, query='huawei freebuds 5i', id=388546, country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 55, 25, 880852)),
# ...
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=8.0, query='huawei i5 earbuds', id=397764, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 412141)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=6.0, query='huawei i5 earbuds', id=397765, country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 413283)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=11.0, query='huawei i7 earbuds', id=397766, country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 414412)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=5.0, query='huawei i7 earbuds', id=397767, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 416011)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei_mate_pad_11.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=5.0, query='huawei matepad 11 disadvantages', id=397768, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 417291)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei_watch_gt_4_experience.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=1.0, query='huawei watch gt4 review', id=397769, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 418441)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=8.0, query='huaweifreebuds 7i', id=397770, country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 419634)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=6.0, query='huwaei free buds 7i', id=397771, country='omn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 420813)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=5.0, query='huwaei freebuds 7i', id=397772, country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 421982)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/minishlab/blog_zaraah.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=7.0, query='mteb leaderboard all-minilm-l6-v2 score', id=397773, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 423081)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=11.0, query='mteb meaning', id=397774, country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 424167)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=1.0, query='one plus pad 3', id=397775, country='npl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 425264)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=26.0, query='oneplus pad 3', id=397776, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 426387)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=9.0, query='oneplus pad 3', id=397777, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 427659)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=2.0, query='oneplus pad 3 benchmark', id=397778, country='rus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 429004)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=2.0, query='oneplus pad 3 gaming test', id=397779, country='rus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 430372)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='TABLET', impressions=1, position=1.0, query='oneplus pad 3 geekbench 6', id=397780, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 431725)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=2.0, query='oneplus pad 3 price in india', id=397781, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 433380)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=2.0, query='oneplus pad 3 price in pakistan', id=397782, country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 434672)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='TABLET', impressions=1, position=2.0, query='oneplus pad 3 processor', id=397783, country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 435836)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=1.0, query='oneplus pad 3 specs', id=397784, country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 437000)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=2, position=5.5, query='oneplus pad 3 specs 2025', id=397785, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 438273)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=4.0, query='oneplus pad 3 specs official', id=397786, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 439419)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=3.0, query='rtings huawei freebuds 5i review', id=397787, country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 440521)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=4.0, query='rtings huawei freebuds 5i review', id=397788, country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 441862)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=30.0, query='super productive', id=397789, country='vnm', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 443571)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=2, position=7.5, query='super productivity', id=397790, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 445566)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=2, position=7.0, query='super productivity', id=397791, country='mda', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 447327)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=17.0, query='super productivity app', id=397792, country='che', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 449083)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=16.0, query='super productivity app', id=397793, country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 451048)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=2, position=4.0, query='super productivity app review', id=397794, country='esp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 452387)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=4, position=3.0, query='super productivity app review 2026', id=397795, country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 453723)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=4, position=10.5, query='super productivity app screenshot', id=397796, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 455028)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=2.0, query='super productivity review', id=397797, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 456153)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=2, position=2.5, query='super productivity review', id=397798, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 457254)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=2.0, query='super productivity review', id=397799, country='phl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 458394)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=9.0, query='super productivity vs ticktick', id=397800, country='cze', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 459688)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=4.0, query='super productivity vs ticktick', id=397801, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 461294)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=8.0, query='super productivity vs todoist', id=397802, country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 462608)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=5.0, query='tarteel ai careers', id=397803, country='bgd', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 463834)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='DESKTOP', impressions=1, position=7.0, query='tarteel ai jobs', id=397804, country='bel', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 464974)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=6.0, query='tarteel careers', id=397805, country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 466141)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=6.0, query='tarteel careers', id=397806, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 467490)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=7.0, query='ticktick vs super productivity', id=397426, country='dza', clicks=1, ctr=1.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 15, 940783)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/tools_reviews/super_productivity_app.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=9.0, query='todoist vs super productivity', id=397807, country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 468645)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=2.0, query='true wireless huawei freebuds 7i', id=397808, country='alb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 469900)),
#  GSCAnalytics(page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2026-03-29', device='MOBILE', impressions=1, position=3.0, query='是', id=397809, country='mys', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 4, 1, 7, 56, 16, 471106))]

# %%
# | export
def get_trends(session: Session,  # Active database session
               site_url: str,  # GSC property URL
               start_date: str,  # Start date (YYYY-MM-DD)
               end_date: str,  # End date (YYYY-MM-DD)
               dimension: str | None = None  # Optional dimension to group by
               ) -> list[dict]:
    "Get click/impression trends over time, optionally grouped by a dimension."
    columns = [GSCAnalytics.date,
               func.sum(GSCAnalytics.clicks).label("clicks"),
               func.sum(GSCAnalytics.impressions).label("impressions"),
               func.avg(GSCAnalytics.position).label("avg_position"),
               func.avg(GSCAnalytics.ctr).label("avg_ctr")]
    group_by = [GSCAnalytics.date]
    if dimension:
        dim_col = getattr(GSCAnalytics, dimension)
        columns.insert(1, dim_col)
        group_by.append(dim_col)
    query = (compose(partial(filter_site, site_url=site_url),
                     partial(filter_dates, start=start_date, end=end_date))
             (select(*columns))
             .group_by(*group_by)
             .order_by(GSCAnalytics.date))
    return [row._asdict() for row in session.exec(query)]

# %%
# | hide
#| eval: false
test_get_trends = get_trends(
    session, site_url="sc-domain:kareemai.com", start_date=start, end_date=end
)
pprint(test_get_trends)
# Out:
# [{'avg_ctr': 0.01931150293870697,
#   'avg_position': 7.948665345395539,
#   'clicks': 10,
#   'date': '2026-03-02',
#   'impressions': 765},
#  {'avg_ctr': 0.017806267806267807,
#   'avg_position': 6.0778506045227685,
#   'clicks': 9,
#   'date': '2026-03-03',
#   'impressions': 739},
#  {'avg_ctr': 0.005319148936170213,
#   'avg_position': 5.61200418531816,
#   'clicks': 3,
#   'date': '2026-03-04',
#   'impressions': 908},
#  {'avg_ctr': 0.00684931506849315,
#   'avg_position': 5.305180376945299,
#   'clicks': 7,
#   'date': '2026-03-05',
#   'impressions': 805},
#  {'avg_ctr': 0.00533605812897366,
#   'avg_position': 6.079551113368197,
#   'clicks': 4,
#   'date': '2026-03-06',
#   'impressions': 736},
#  {'avg_ctr': 0.012008101851851851,
#   'avg_position': 6.225755602904041,
#   'clicks': 6,
#   'date': '2026-03-07',
#   'impressions': 724},
#  {'avg_ctr': 0.011188271604938271,
#   'avg_position': 6.411227389201423,
#   'clicks': 8,
#   'date': '2026-03-08',
#   'impressions': 739},
#  {'avg_ctr': 0.006425702811244979,
#   'avg_position': 6.366732169318987,
#   'clicks': 5,
#   'date': '2026-03-09',
#   'impressions': 741},
#  {'avg_ctr': 0.015745098039215685,
#   'avg_position': 6.425654550190273,
#   'clicks': 9,
#   'date': '2026-03-10',
#   'impressions': 737},
#  {'avg_ctr': 0.02169312169312169,
#   'avg_position': 6.102397953233376,
#   'clicks': 9,
#   'date': '2026-03-11',
#   'impressions': 725},
#  {'avg_ctr': 0.016709511568123392,
#   'avg_position': 5.958961396151461,
#   'clicks': 9,
#   'date': '2026-03-12',
#   'impressions': 712},
#  {'avg_ctr': 0.008407243163340723,
#   'avg_position': 6.096935959522417,
#   'clicks': 5,
#   'date': '2026-03-13',
#   'impressions': 586},
#  {'avg_ctr': 0.015625,
#   'avg_position': 5.932062961548256,
#   'clicks': 6,
#   'date': '2026-03-14',
#   'impressions': 566},
#  {'avg_ctr': 0.01403061224489796,
#   'avg_position': 6.481199468304268,
#   'clicks': 8,
#   'date': '2026-03-15',
#   'impressions': 688},
#  {'avg_ctr': 0.009173030359471037,
#   'avg_position': 6.664053263424504,
#   'clicks': 7,
#   'date': '2026-03-16',
#   'impressions': 739},
#  {'avg_ctr': 0.004457364341085271,
#   'avg_position': 6.21528568330894,
#   'clicks': 3,
#   'date': '2026-03-17',
#   'impressions': 585},
#  {'avg_ctr': 0.0,
#   'avg_position': 6.718236901858549,
#   'clicks': 0,
#   'date': '2026-03-18',
#   'impressions': 355},
#  {'avg_ctr': 0.01015228426395939,
#   'avg_position': 7.145187242601284,
#   'clicks': 2,
#   'date': '2026-03-19',
#   'impressions': 319},
#  {'avg_ctr': 0.010869565217391304,
#   'avg_position': 5.800865704442861,
#   'clicks': 3,
#   'date': '2026-03-20',
#   'impressions': 321},
#  {'avg_ctr': 0.004366812227074236,
#   'avg_position': 6.0699951252603555,
#   'clicks': 1,
#   'date': '2026-03-21',
#   'impressions': 353},
#  {'avg_ctr': 0.016055045871559634,
#   'avg_position': 7.288459238410359,
#   'clicks': 4,
#   'date': '2026-03-22',
#   'impressions': 354},
#  {'avg_ctr': 0.0031380753138075313,
#   'avg_position': 6.921556321273279,
#   'clicks': 2,
#   'date': '2026-03-23',
#   'impressions': 402},
#  {'avg_ctr': 0.009433962264150943,
#   'avg_position': 6.394663249815215,
#   'clicks': 3,
#   'date': '2026-03-24',
#   'impressions': 589},
#  {'avg_ctr': 0.01130952380952381,
#   'avg_position': 5.874045002616431,
#   'clicks': 4,
#   'date': '2026-03-25',
#   'impressions': 368},
#  {'avg_ctr': 0.010780669144981412,
#   'avg_position': 6.396070100902815,
#   'clicks': 5,
#   'date': '2026-03-26',
#   'impressions': 416},
#  {'avg_ctr': 0.01818600368324125,
#   'avg_position': 6.182867365895521,
#   'clicks': 8,
#   'date': '2026-03-27',
#   'impressions': 648},
#  {'avg_ctr': 0.008130081300813009,
#   'avg_position': 5.577101846826357,
#   'clicks': 3,
#   'date': '2026-03-28',
#   'impressions': 682},
#  {'avg_ctr': 0.00904392764857881,
#   'avg_position': 5.290476163059383,
#   'clicks': 4,
#   'date': '2026-03-29',
#   'impressions': 656}]

# %%
# | export
def get_analytics_by(session: Session,  # Active database session
                     site_url: str,  # GSC property URL
                     start_date: str,  # Start date (YYYY-MM-DD)
                     end_date: str,  # End date (YYYY-MM-DD)
                     dimension: str,  # GSCAnalytics field to filter by
                     value: str  # Value to match
                     ) -> list[AnalyticsSummary]:
    "Get query-level analytics filtered by a specific dimension value."
    base = select(GSCAnalytics.query,
                  func.sum(GSCAnalytics.clicks).label("clicks"),
                  func.sum(GSCAnalytics.impressions).label("impressions"))
    query = (compose(partial(filter_site, site_url=site_url),
                     partial(filter_dates, start=start_date, end=end_date),
                     partial(filter_dimension, dimension=dimension, value=value))
             (base).group_by(GSCAnalytics.query))
    return [AnalyticsSummary(**row._asdict()) for row in session.exec(query)]

# %%
# | hide
#| eval: false
test_result = get_analytics_by(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    dimension="country",
    value="egy",
)

pprint(test_result)
# Out:
# [AnalyticsSummary(query='7i freebuds', clicks=0, impressions=1),
#  AnalyticsSummary(query='arabert v2', clicks=0, impressions=2),
#  AnalyticsSummary(query='arabic tokenizer', clicks=0, impressions=1),
#  AnalyticsSummary(query='buds 7i huawei', clicks=0, impressions=1),
#  AnalyticsSummary(query='cloud gpu pricing comparison', clicks=0, impressions=1),
#  AnalyticsSummary(query='colgrep', clicks=0, impressions=2),
#  AnalyticsSummary(query='dailyaiproductivity reviews 2026', clicks=0, impressions=1),
#  AnalyticsSummary(query='does it have a pen', clicks=0, impressions=1),
#  AnalyticsSummary(query='does the huawei matepad have google', clicks=0, impressions=1),
#  AnalyticsSummary(query='frebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='free buds 7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='freebuds 5i', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 5i noise cancelling', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 5i vs 7i', clicks=1, impressions=4),
#  AnalyticsSummary(query='freebuds 7', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 7i', clicks=1, impressions=144),
#  AnalyticsSummary(query='freebuds 7i anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i battery life', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i huawei', clicks=0, impressions=11),
#  AnalyticsSummary(query='freebuds 7i review', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebuds 7i review anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i specs', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i vs 5i', clicks=1, impressions=2),
#  AnalyticsSummary(query='freebuds 7i vs freebuds pro 4', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds huawei 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='gpu cloud pricing comparison', clicks=0, impressions=1),
#  AnalyticsSummary(query='gpu pricing comparison', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 5i vs 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei 7i buds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i earbuds', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei 7i freebuds', clicks=1, impressions=67),
#  AnalyticsSummary(query='huawei 7i review', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei buds 7i', clicks=0, impressions=21),
#  AnalyticsSummary(query='huawei buds 7i review', clicks=1, impressions=3),
#  AnalyticsSummary(query='huawei cloud gpu pricing', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei earbuds 7i', clicks=1, impressions=54),
#  AnalyticsSummary(query='huawei earbuds i5', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei free buds 7', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei free buds 7i', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebids 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 5i', clicks=0, impressions=16),
#  AnalyticsSummary(query='huawei freebuds 5i anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i call quality review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i review', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 5i reviews', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 5i specs review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i vs 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 6i vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 6i vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebuds 7 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i', clicks=3, impressions=644),
#  AnalyticsSummary(query='huawei freebuds 7i anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i anc db', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i battery life', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i call quality', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i call quality review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i colors', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i compatible with iphone', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i driver size', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i earbuds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i earbuds specs', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i features', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i ip rating', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i iphone compatibility', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i microphone quality review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i noise cancelling', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i official specs', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i product info and reviews', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i review', clicks=0, impressions=58),
#  AnalyticsSummary(query='huawei freebuds 7i review anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i review anc sound quality', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i review microphone call quality', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i review sound quality', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i review specs', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i reviews', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei freebuds 7i sound quality', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i sound quality review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i soundguys', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i specifications', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i specs', clicks=0, impressions=31),
#  AnalyticsSummary(query='huawei freebuds 7i specs anc battery', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i specs anc battery review', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i specs earbuds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i specs review', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i test', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs 5i', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebuds 7i vs 6i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i vs anker liberty 5', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i vs soundcore liberty 5', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i wireless charging', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i wireless earbuds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i عيوب', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i مراجعة', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds i7 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds7', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei gt4 watch review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei i5 earbuds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei i7 earbuds', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei watch gt 4 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei watch gt 4 reviews', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwaei free buds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwai freebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwawei freebuds 7i', clicks=0, impressions=7),
#  AnalyticsSummary(query='i am confused', clicks=0, impressions=1),
#  AnalyticsSummary(query='is oneplus pad 3 worth it', clicks=0, impressions=1),
#  AnalyticsSummary(query='liberty 5 vs freebuds 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='mteb benchmark tasks', clicks=0, impressions=1),
#  AnalyticsSummary(query='one pad plus 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='one plus pad', clicks=0, impressions=2),
#  AnalyticsSummary(query='one plus pad 3', clicks=1, impressions=33),
#  AnalyticsSummary(query='one plus pad 3 antutu', clicks=0, impressions=1),
#  AnalyticsSummary(query='one plus pad3', clicks=0, impressions=4),
#  AnalyticsSummary(query='oneplus 3 ipad', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus 3 pad', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3', clicks=1, impressions=122),
#  AnalyticsSummary(query='oneplus pad 3 ai features', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 antutu benchmark score', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 antutu score', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 charging speed', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 kuwait', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 processor', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 review performance', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 sim support', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 specs review', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 tablet price', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 tablet specs', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 vs xiaomi pad 8 pro', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad3', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad3 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pas 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus tab 3', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus tablet 3', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus tablet 3 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='proteinai', clicks=1, impressions=1),
#  AnalyticsSummary(query='review huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='soundcore liberty 5 vs huawei freebuds 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='super productivity', clicks=0, impressions=6),
#  AnalyticsSummary(query='super productivity app', clicks=0, impressions=1),
#  AnalyticsSummary(query='super productivity app review 2026', clicks=0, impressions=4),
#  AnalyticsSummary(query='super productivity linux', clicks=0, impressions=1),
#  AnalyticsSummary(query='tarteel ai careers', clicks=0, impressions=2),
#  AnalyticsSummary(query='tarteel ai jobs', clicks=0, impressions=2),
#  AnalyticsSummary(query='tarteel careers', clicks=0, impressions=1),
#  AnalyticsSummary(query='سماعة هواوي 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='عربي', clicks=0, impressions=1),
#  AnalyticsSummary(query='عيوبها اي', clicks=0, impressions=1),
#  AnalyticsSummary(query='فيها', clicks=0, impressions=1),
#  AnalyticsSummary(query='نعم', clicks=0, impressions=1),
#  AnalyticsSummary(query='هواوي فري بودز 7i', clicks=0, impressions=2)]

# %%
# | hide
#| eval: false
test_get_analytics_by_device = get_analytics_by(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    dimension="device",
    value="MOBILE",
)
pprint(test_get_analytics_by_device)
# Out:
# [AnalyticsSummary(query='"paraphrase-multilingual-minilm-l12-v2" arabic', clicks=0, impressions=4),
#  AnalyticsSummary(query='"vercel" "transfer" "whois privacy"', clicks=0, impressions=11),
#  AnalyticsSummary(query='"vercel" "whois privacy" transfer', clicks=0, impressions=2),
#  AnalyticsSummary(query='.', clicks=0, impressions=1),
#  AnalyticsSummary(query='5 foto', clicks=0, impressions=2),
#  AnalyticsSummary(query='5i huawei', clicks=0, impressions=1),
#  AnalyticsSummary(query='5i huawei freebuds', clicks=0, impressions=2),
#  AnalyticsSummary(query='5i vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='7i freebuds', clicks=0, impressions=3),
#  AnalyticsSummary(query='7i huawei', clicks=0, impressions=5),
#  AnalyticsSummary(query='affordable gpu instances hivenet', clicks=0, impressions=3),
#  AnalyticsSummary(query='affordable hivenet compute benchmark', clicks=0, impressions=2),
#  AnalyticsSummary(query='affordable rent gpu hivenet', clicks=0, impressions=1),
#  AnalyticsSummary(query='airpods huawei 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='and laptop', clicks=0, impressions=1),
#  AnalyticsSummary(query='anker liberty 5 vs huawei freebuds 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='anrufe', clicks=0, impressions=1),
#  AnalyticsSummary(query='arabert v2', clicks=0, impressions=1),
#  AnalyticsSummary(query='arabic tokenizer', clicks=0, impressions=5),
#  AnalyticsSummary(query='are all these free', clicks=0, impressions=1),
#  AnalyticsSummary(query='are huawei freebuds good', clicks=0, impressions=1),
#  AnalyticsSummary(query='are they noise canceling', clicks=0, impressions=1),
#  AnalyticsSummary(query='audifonos freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='audifonos huawei 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='audifonos huawei i7', clicks=0, impressions=1),
#  AnalyticsSummary(query='audífonos huawei freebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='audífonos huawei freebuds 7i', clicks=0, impressions=26),
#  AnalyticsSummary(query='battery life?', clicks=0, impressions=1),
#  AnalyticsSummary(query='best noise cancelling earbuds uk', clicks=0, impressions=1),
#  AnalyticsSummary(query='best way to learn ai 2025 roadmap arabic', clicks=0, impressions=7),
#  AnalyticsSummary(query='bm25 python library', clicks=0, impressions=1),
#  AnalyticsSummary(query='buds 7i', clicks=0, impressions=7),
#  AnalyticsSummary(query='buds 7i huawei', clicks=0, impressions=6),
#  AnalyticsSummary(query='buy hivenet compute benchmark', clicks=0, impressions=2),
#  AnalyticsSummary(query='candy ai kareem', clicks=0, impressions=3),
#  AnalyticsSummary(query='chamadas', clicks=0, impressions=1),
#  AnalyticsSummary(query='cheap hivenet', clicks=0, impressions=2),
#  AnalyticsSummary(query='cheap hivenet cheap gpu rental', clicks=0, impressions=1),
#  AnalyticsSummary(query='cheap hivenet compute benchmark', clicks=0, impressions=2),
#  AnalyticsSummary(query='cheap hivenet hpc', clicks=0, impressions=1),
#  AnalyticsSummary(query='cloud gpu price comparison', clicks=0, impressions=3),
#  AnalyticsSummary(query='cloud gpu pricing comparison', clicks=0, impressions=4),
#  AnalyticsSummary(query='colgrep', clicks=0, impressions=38),
#  AnalyticsSummary(query='colgrep github', clicks=0, impressions=1),
#  AnalyticsSummary(query='compatible with iphone?', clicks=0, impressions=1),
#  AnalyticsSummary(query='compute with hivenet scaling pricing', clicks=0, impressions=1),
#  AnalyticsSummary(query='cs197', clicks=0, impressions=5),
#  AnalyticsSummary(query='cual es el ganador', clicks=0, impressions=1),
#  AnalyticsSummary(query='curse seo ecommerce', clicks=0, impressions=26),
#  AnalyticsSummary(query='disadvantages of huawei matepad 11', clicks=0, impressions=1),
#  AnalyticsSummary(query='do huawei tablets have google', clicks=0, impressions=1),
#  AnalyticsSummary(query='does huawei freebuds 7i have wireless charging', clicks=0, impressions=1),
#  AnalyticsSummary(query='does huawei matepad have google', clicks=0, impressions=1),
#  AnalyticsSummary(query='does huawei matepad se 11 have google play store', clicks=0, impressions=1),
#  AnalyticsSummary(query='does huawei matepad support google', clicks=0, impressions=4),
#  AnalyticsSummary(query='does huawei tablet have google', clicks=0, impressions=2),
#  AnalyticsSummary(query='does huawei tablet support google', clicks=0, impressions=2),
#  AnalyticsSummary(query='does it have a pen', clicks=0, impressions=1),
#  AnalyticsSummary(query='does oneplus pad 3 come with charger', clicks=0, impressions=1),
#  AnalyticsSummary(query='does the huawei matepad have google', clicks=0, impressions=5),
#  AnalyticsSummary(query='does vercel offer domain privacy protection whois', clicks=0, impressions=2),
#  AnalyticsSummary(query='does vercel offer domain privacy protection whois privacy', clicks=0, impressions=1),
#  AnalyticsSummary(query='earbuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='earbuds huawei 5i', clicks=0, impressions=4),
#  AnalyticsSummary(query='earbuds huawei 7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='earfun air pro 4 vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='es recomendable?', clicks=0, impressions=1),
#  AnalyticsSummary(query='fast hivenet gpu vs aws', clicks=0, impressions=1),
#  AnalyticsSummary(query='final recommendation', clicks=0, impressions=1),
#  AnalyticsSummary(query='fone huawei freebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='frebuds 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='free buds 5i', clicks=0, impressions=6),
#  AnalyticsSummary(query='free buds 7', clicks=0, impressions=4),
#  AnalyticsSummary(query='free buds 7i', clicks=0, impressions=43),
#  AnalyticsSummary(query='freebids 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebud 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebud 7i', clicks=0, impressions=8),
#  AnalyticsSummary(query='freebuda 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 5', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 5i', clicks=0, impressions=101),
#  AnalyticsSummary(query='freebuds 5i huawei', clicks=0, impressions=8),
#  AnalyticsSummary(query='freebuds 5i noise cancelling', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 5i review', clicks=0, impressions=14),
#  AnalyticsSummary(query='freebuds 5i vs 6i vs 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 5i vs 7i', clicks=2, impressions=37),
#  AnalyticsSummary(query='freebuds 6 vs freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 6i vs 7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='freebuds 7', clicks=0, impressions=55),
#  AnalyticsSummary(query='freebuds 7 huawei', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7 i', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebuds 7i', clicks=11, impressions=756),
#  AnalyticsSummary(query='freebuds 7i anc', clicks=0, impressions=4),
#  AnalyticsSummary(query='freebuds 7i battery life', clicks=0, impressions=8),
#  AnalyticsSummary(query='freebuds 7i características', clicks=0, impressions=10),
#  AnalyticsSummary(query='freebuds 7i huawei', clicks=0, impressions=86),
#  AnalyticsSummary(query='freebuds 7i inceleme', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebuds 7i pink', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebuds 7i precio', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i price', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 7i review', clicks=3, impressions=74),
#  AnalyticsSummary(query='freebuds 7i specs', clicks=0, impressions=8),
#  AnalyticsSummary(query='freebuds 7i vs 5i', clicks=2, impressions=15),
#  AnalyticsSummary(query='freebuds 7i vs 6i', clicks=0, impressions=6),
#  AnalyticsSummary(query='freebuds 7i vs freebuds 6', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 7i vs freebuds 6i', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds 7i vs freebuds pro 4', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds 7i vs liberty 5', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds huawei 7i', clicks=0, impressions=12),
#  AnalyticsSummary(query='freebuds i5', clicks=0, impressions=2),
#  AnalyticsSummary(query='freebuds i7', clicks=0, impressions=1),
#  AnalyticsSummary(query='freebuds i7 huawei', clicks=0, impressions=3),
#  AnalyticsSummary(query='freebuds5i', clicks=0, impressions=4),
#  AnalyticsSummary(query='freebuds7', clicks=0, impressions=3),
#  AnalyticsSummary(query='get gpu instances hivenet', clicks=0, impressions=2),
#  AnalyticsSummary(query='get hivenet cheap gpu rental', clicks=0, impressions=1),
#  AnalyticsSummary(query='get hivenet gpu vs aws', clicks=0, impressions=2),
#  AnalyticsSummary(query='gimana caranya', clicks=0, impressions=1),
#  AnalyticsSummary(query='gpu cloud price comparison', clicks=0, impressions=2),
#  AnalyticsSummary(query='gpu instances hivenet comparison', clicks=0, impressions=2),
#  AnalyticsSummary(query='gt4 huawei watch', clicks=0, impressions=1),
#  AnalyticsSummary(query='harga huawei freebuds 5i', clicks=0, impressions=3),
#  AnalyticsSummary(query='harvard cs197', clicks=0, impressions=4),
#  AnalyticsSummary(query='harvard cs197 ai research experiences', clicks=0, impressions=1),
#  AnalyticsSummary(query='hawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='hiawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='hivenet cheap gpu rental vs google cloud', clicks=0, impressions=1),
#  AnalyticsSummary(query='hivenet compute benchmark features', clicks=0, impressions=1),
#  AnalyticsSummary(query='hivenet deep tech', clicks=0, impressions=1),
#  AnalyticsSummary(query='hivenet gpu cloud pricing', clicks=0, impressions=2),
#  AnalyticsSummary(query='hivenet high performance computing', clicks=0, impressions=1),
#  AnalyticsSummary(query='hivenet hpc', clicks=0, impressions=2),
#  AnalyticsSummary(query='hivenet nvidia gpu vs google cloud', clicks=0, impressions=4),
#  AnalyticsSummary(query='hivenet roadmap tutorial', clicks=0, impressions=1),
#  AnalyticsSummary(query='hivenet rtx 4090 vs azure', clicks=0, impressions=1),
#  AnalyticsSummary(query='how 5i', clicks=0, impressions=6),
#  AnalyticsSummary(query='how hot can it get', clicks=0, impressions=1),
#  AnalyticsSummary(query='how to transfer domain from porkbun to cloudflare', clicks=0, impressions=1),
#  AnalyticsSummary(query='how to use super productivity', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei 5i', clicks=0, impressions=27),
#  AnalyticsSummary(query='huawei 5i buds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei 5i earbuds', clicks=0, impressions=31),
#  AnalyticsSummary(query='huawei 5i freebuds', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei 5i vs 7i', clicks=3, impressions=9),
#  AnalyticsSummary(query='huawei 6i vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei 7i buds', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei 7i earbuds', clicks=2, impressions=213),
#  AnalyticsSummary(query='huawei 7i earbuds price in pakistan', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i earbuds review', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei 7i freebuds', clicks=0, impressions=195),
#  AnalyticsSummary(query='huawei 7i freebuds case', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei 7i review', clicks=0, impressions=19),
#  AnalyticsSummary(query='huawei 7i vs 6i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei airpods 7i', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei auriculares inalámbricos freebuds 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei bud 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei buds 5i', clicks=0, impressions=16),
#  AnalyticsSummary(query='huawei buds 6i vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei buds 7', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei buds 7i', clicks=1, impressions=158),
#  AnalyticsSummary(query='huawei buds 7i review', clicks=1, impressions=18),
#  AnalyticsSummary(query='huawei buds i7', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei cloud gpu pricing', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei earbud 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei earbuds', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei earbuds 5i', clicks=0, impressions=83),
#  AnalyticsSummary(query='huawei earbuds 7', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei earbuds 7i', clicks=0, impressions=213),
#  AnalyticsSummary(query='huawei earbuds 7i case', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei earbuds 7i price', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei earbuds 7i review', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei earbuds i5', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei earbuds i7', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei feebuds 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei frebuds 5', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei frebuds 5i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei frebuds 7i', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei free 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei free bud 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei free bud 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei free buds 5i', clicks=0, impressions=22),
#  AnalyticsSummary(query='huawei free buds 7', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei free buds 7 i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei free buds 7i', clicks=0, impressions=79),
#  AnalyticsSummary(query='huawei freebids 5i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebids 7i', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei freebud 5i', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebud 7', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebud 7i', clicks=0, impressions=14),
#  AnalyticsSummary(query='huawei freebuds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 4i vs 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 51', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i', clicks=2, impressions=462),
#  AnalyticsSummary(query='huawei freebuds 5i active noise cancellation', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei freebuds 5i anc', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 5i anc db', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i anc multipoint', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i black', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 5i blue', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 5i call quality microphone review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i call quality review', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 5i ceramic white', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i earbuds', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i features', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 5i harga', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebuds 5i microphone quality review', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 5i noise cancelling', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei freebuds 5i review', clicks=6, impressions=88),
#  AnalyticsSummary(query='huawei freebuds 5i review anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i reviews', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 5i sound quality review', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 5i specs review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i test', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i tws', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i vs 6i vs 7i', clicks=1, impressions=26),
#  AnalyticsSummary(query='huawei freebuds 5i vs 7i', clicks=10, impressions=84),
#  AnalyticsSummary(query='huawei freebuds 5i vs huawei freebuds se 4 anc', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 5i и 7i сравнение', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 6 vs 7i', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 6i vs 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 6i vs 7i comparison', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 6i vs freebuds 7i comparison', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 6i vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7', clicks=0, impressions=134),
#  AnalyticsSummary(query='huawei freebuds 7 i', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei freebuds 7 release date', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7 review', clicks=1, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 71', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i', clicks=17, impressions=2853),
#  AnalyticsSummary(query='huawei freebuds 7i - true wireless earphones with mic - in-ear - bluetooth - active noise canceling - black', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i amazon', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i anc', clicks=0, impressions=13),
#  AnalyticsSummary(query='huawei freebuds 7i anc db', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei freebuds 7i anc db level', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i anc performance review', clicks=0, impressions=20),
#  AnalyticsSummary(query='huawei freebuds 7i anc review', clicks=0, impressions=20),
#  AnalyticsSummary(query='huawei freebuds 7i bass review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i battery life', clicks=0, impressions=54),
#  AnalyticsSummary(query='huawei freebuds 7i battery life anc', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei freebuds 7i battery life official', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i battery life with anc', clicks=0, impressions=12),
#  AnalyticsSummary(query='huawei freebuds 7i black', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i bluetooth', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i bluetooth version', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei freebuds 7i buy', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i call quality', clicks=0, impressions=13),
#  AnalyticsSummary(query='huawei freebuds 7i call quality review', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei freebuds 7i características', clicks=0, impressions=30),
#  AnalyticsSummary(query='huawei freebuds 7i case', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i charging case', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i codec', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i codecs', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i colors', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i compatible with iphone', clicks=0, impressions=14),
#  AnalyticsSummary(query='huawei freebuds 7i driver size', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei freebuds 7i earbuds', clicks=0, impressions=38),
#  AnalyticsSummary(query='huawei freebuds 7i earbuds specs', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i equalizer settings', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i especificaciones', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i features', clicks=0, impressions=24),
#  AnalyticsSummary(query='huawei freebuds 7i frequency response', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i in ear', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i inceleme', clicks=0, impressions=13),
#  AnalyticsSummary(query='huawei freebuds 7i ip rating', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei freebuds 7i iphone', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i iphone compatibility', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i kutu içeriği', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei freebuds 7i ldac', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i microphone call quality review', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i microphone quality review', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i multipoint', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i noise cancelling', clicks=0, impressions=24),
#  AnalyticsSummary(query='huawei freebuds 7i opiniones', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i pink', clicks=0, impressions=8),
#  AnalyticsSummary(query='huawei freebuds 7i price', clicks=0, impressions=54),
#  AnalyticsSummary(query='huawei freebuds 7i price in india', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i price philippines', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i pro', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i release date specs', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i review', clicks=16, impressions=404),
#  AnalyticsSummary(query='huawei freebuds 7i review 2025', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i review 2025 or 2026', clicks=0, impressions=25),
#  AnalyticsSummary(query='huawei freebuds 7i review 2026', clicks=0, impressions=31),
#  AnalyticsSummary(query='huawei freebuds 7i review anc', clicks=0, impressions=14),
#  AnalyticsSummary(query='huawei freebuds 7i review anc battery sound quality', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebuds 7i review anc sound quality', clicks=0, impressions=16),
#  AnalyticsSummary(query='huawei freebuds 7i review sound quality', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i review specs', clicks=0, impressions=18),
#  AnalyticsSummary(query='huawei freebuds 7i review specs anc battery', clicks=0, impressions=13),
#  AnalyticsSummary(query='huawei freebuds 7i reviews', clicks=1, impressions=14),
#  AnalyticsSummary(query='huawei freebuds 7i sound quality', clicks=1, impressions=10),
#  AnalyticsSummary(query='huawei freebuds 7i sound quality review', clicks=0, impressions=26),
#  AnalyticsSummary(query='huawei freebuds 7i soundguys', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i spatial audio', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i specifications', clicks=0, impressions=70),
#  AnalyticsSummary(query='huawei freebuds 7i specifications features', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i specifications official', clicks=0, impressions=10),
#  AnalyticsSummary(query='huawei freebuds 7i specifications release date', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i specifications review', clicks=0, impressions=14),
#  AnalyticsSummary(query='huawei freebuds 7i specs', clicks=1, impressions=67),
#  AnalyticsSummary(query='huawei freebuds 7i specs anc battery', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i specs price', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i specs review', clicks=0, impressions=38),
#  AnalyticsSummary(query='huawei freebuds 7i specs review 2026', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i test', clicks=0, impressions=12),
#  AnalyticsSummary(query='huawei freebuds 7i teszt', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei freebuds 7i transparency mode review', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei freebuds 7i true wireless earbuds', clicks=0, impressions=11),
#  AnalyticsSummary(query='huawei freebuds 7i vs', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i vs 4i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds 7i vs 5i', clicks=4, impressions=65),
#  AnalyticsSummary(query='huawei freebuds 7i vs 6', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i vs 6i', clicks=0, impressions=13),
#  AnalyticsSummary(query='huawei freebuds 7i vs airpods 4', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs anker liberty 5', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i vs earfun air pro 4', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i vs freebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs freebuds 6', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei freebuds 7i vs freebuds pro 4', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs freebuds pro 5', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs jbl tune beam 2', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i vs nothing ear a', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs oneplus buds 4', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs soundcore liberty 4 nc', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i vs soundcore liberty 5', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i white', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i wired charging black', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i wireless charging', clicks=0, impressions=17),
#  AnalyticsSummary(query='huawei freebuds 7i wireless earbuds', clicks=0, impressions=21),
#  AnalyticsSummary(query='huawei freebuds 7i özellikleri', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i عيوب', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds 7i مراجعة', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei freebuds 7i ราคา', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei freebuds 7i รีวิว', clicks=1, impressions=13),
#  AnalyticsSummary(query='huawei freebuds 7i,', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds 7i.', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds i5', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei freebuds i7', clicks=0, impressions=19),
#  AnalyticsSummary(query='huawei freebuds i7 review', clicks=0, impressions=12),
#  AnalyticsSummary(query='huawei freebuds pro 5 vs 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds pro 5 vs freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds pro 7', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds pro 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds se 4 anc vs 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds se 4 vs 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei freebuds5i', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei freebuds7', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei freebuds7i', clicks=0, impressions=9),
#  AnalyticsSummary(query='huawei freebus 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei gt 4 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei gt4 review', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei gt4 test', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei gt4 watch review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei headphones review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei i5 earbuds', clicks=0, impressions=32),
#  AnalyticsSummary(query='huawei i7 buds', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei i7 earbuds', clicks=0, impressions=58),
#  AnalyticsSummary(query='huawei i7 freebuds', clicks=0, impressions=5),
#  AnalyticsSummary(query='huawei matepad', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei matepad 11 2023 review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei matepad 11 review', clicks=0, impressions=6),
#  AnalyticsSummary(query='huawei matepad linux', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei matepad review', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei matepad se 11 google', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei tablet pros and cons', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei watch gt 4 heart rate accuracy review', clicks=0, impressions=4),
#  AnalyticsSummary(query='huawei watch gt 4 review', clicks=0, impressions=7),
#  AnalyticsSummary(query='huawei watch gt 4 reviews', clicks=0, impressions=2),
#  AnalyticsSummary(query='huawei watch gt 4 sleep tracking', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawei watch gt 4 sleep tracking accuracy review', clicks=0, impressions=3),
#  AnalyticsSummary(query='huawei watch gt4 review', clicks=0, impressions=6),
#  AnalyticsSummary(query='huaweifreebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huaweii freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawi freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huawie 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huwaei free buds 7i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huwaei freebuds 5i', clicks=0, impressions=3),
#  AnalyticsSummary(query='huwaei freebuds 7i', clicks=0, impressions=8),
#  AnalyticsSummary(query='huwai 5i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huwai 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huwai freebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwai freebuds 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='huwawei freebuds 7i', clicks=0, impressions=13),
#  AnalyticsSummary(query='huwawei mate pad', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwei 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwei freebuds 5i', clicks=0, impressions=1),
#  AnalyticsSummary(query='huwei freebuds 7i', clicks=0, impressions=4),
#  AnalyticsSummary(query='i am confused', clicks=0, impressions=1),
#  AnalyticsSummary(query='immeditialy', clicks=0, impressions=1),
#  AnalyticsSummary(query='interesting engineering facts in arabic', clicks=0, impressions=2),
#  AnalyticsSummary(query='iphone', clicks=0, impressions=1),
#  AnalyticsSummary(query='is huawei matepad 11 worth it', clicks=0, impressions=1),
#  AnalyticsSummary(query='is it compatible with iphone', clicks=0, impressions=1),
#  AnalyticsSummary(query='is it free?', clicks=0, impressions=1),
#  AnalyticsSummary(query='is it good for school', clicks=0, impressions=1),
#  AnalyticsSummary(query='is oneplus pad 3 good for gaming', clicks=0, impressions=1),
#  AnalyticsSummary(query='is oneplus pad 3 good for note taking', clicks=0, impressions=9),
#  AnalyticsSummary(query='is oneplus pad 3 good for video editing', clicks=0, impressions=1),
#  AnalyticsSummary(query='is oneplus pad 3 oled', clicks=0, impressions=1),
#  AnalyticsSummary(query='is oneplus pad 3 worth it', clicks=0, impressions=1),
#  AnalyticsSummary(query='jbl tune beam 2 vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='kekurangannya', clicks=0, impressions=1),
#  AnalyticsSummary(query='liberty 5 vs freebuds 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='linux on huawei matepad', clicks=0, impressions=1),
#  AnalyticsSummary(query='matepad 11', clicks=0, impressions=2),
#  AnalyticsSummary(query='metb', clicks=0, impressions=2),
#  AnalyticsSummary(query='mics?', clicks=0, impressions=1),
#  AnalyticsSummary(query='mikrofon', clicks=0, impressions=1),
#  AnalyticsSummary(query='mini gte', clicks=0, impressions=1),
#  AnalyticsSummary(query='more info', clicks=0, impressions=1),
#  AnalyticsSummary(query='mteb', clicks=0, impressions=5),
#  AnalyticsSummary(query='mteb leaderboard current top models', clicks=0, impressions=1),
#  AnalyticsSummary(query='mteb meaning', clicks=0, impressions=2),
#  AnalyticsSummary(query='mteb reranking leaderboard', clicks=0, impressions=1),
#  AnalyticsSummary(query='mteb reranking tasks', clicks=0, impressions=5),
#  AnalyticsSummary(query='mteb retrieval metric ndcg', clicks=0, impressions=1),
#  AnalyticsSummary(query='noice cancelling', clicks=0, impressions=1),
#  AnalyticsSummary(query='one pad plus 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='one plus pad', clicks=0, impressions=3),
#  AnalyticsSummary(query='one plus pad 3', clicks=0, impressions=26),
#  AnalyticsSummary(query='one plus pad 3 antutu', clicks=0, impressions=3),
#  AnalyticsSummary(query='one plus pad3', clicks=0, impressions=4),
#  AnalyticsSummary(query='oneplus 3 ipad', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus 3 pad', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus buds 4 vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3', clicks=0, impressions=90),
#  AnalyticsSummary(query='oneplus pad 3 (2025)', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 2025', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 ai features', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 antutu benchmark', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 antutu score', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 battery capacity', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 battery capacity mah', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 battery life review', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 battery life video editing', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 benchmark scores', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 charging time', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 connect to monitor', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 cooling system', clicks=0, impressions=4),
#  AnalyticsSummary(query='oneplus pad 3 cpu', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 gaming performance', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 hdr support', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 india', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 is cellular or not', clicks=0, impressions=5),
#  AnalyticsSummary(query='oneplus pad 3 kuwait', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 nits', clicks=0, impressions=4),
#  AnalyticsSummary(query='oneplus pad 3 note taking experience', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 peak brightness', clicks=0, impressions=3),
#  AnalyticsSummary(query='oneplus pad 3 ppi', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 price', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 price 2025', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 price in india', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 price in pakistan', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 price in qatar', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 price in uae', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 processor', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 processor antutu score', clicks=0, impressions=5),
#  AnalyticsSummary(query='oneplus pad 3 processor generation', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 review pros cons', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 reviews', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 sim card support', clicks=0, impressions=5),
#  AnalyticsSummary(query='oneplus pad 3 sim support', clicks=0, impressions=5),
#  AnalyticsSummary(query='oneplus pad 3 sound quality', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 speakers', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 specs', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 specs 2025', clicks=0, impressions=3),
#  AnalyticsSummary(query='oneplus pad 3 specs review', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 support sim card', clicks=0, impressions=10),
#  AnalyticsSummary(query='oneplus pad 3 video editing performance', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 vs samsung tab s11', clicks=0, impressions=2),
#  AnalyticsSummary(query='oneplus pad 3 vs xiaomi pad 7 pro', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad 3 vs xiaomi pad 8 pro', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad snapdragon 8 gen 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pad3', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus pas 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus tab 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus tab 3 battery life', clicks=0, impressions=1),
#  AnalyticsSummary(query='oneplus tablet 3', clicks=0, impressions=2),
#  AnalyticsSummary(query='ono plus tablet review', clicks=0, impressions=1),
#  AnalyticsSummary(query='opencode.ai "models.dev" error or failed or blocked', clicks=0, impressions=1),
#  AnalyticsSummary(query='picture', clicks=0, impressions=1),
#  AnalyticsSummary(query='price', clicks=0, impressions=2),
#  AnalyticsSummary(query='pros and cons', clicks=0, impressions=1),
#  AnalyticsSummary(query='proteinai', clicks=1, impressions=1),
#  AnalyticsSummary(query='python bm25 library', clicks=0, impressions=1),
#  AnalyticsSummary(query='rank_bm25 bm25okapi get_scores returns numpy array', clicks=0, impressions=1),
#  AnalyticsSummary(query='rate out of 10', clicks=0, impressions=1),
#  AnalyticsSummary(query='redmi buds 6 pro vs freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='review', clicks=0, impressions=1),
#  AnalyticsSummary(query='review huawei freebuds 7i', clicks=0, impressions=10),
#  AnalyticsSummary(query='self-study roadmap ai machine learning for mathematicians', clicks=0, impressions=3),
#  AnalyticsSummary(query='self-study roadmap ai machine learning for mathematics mathematicians', clicks=0, impressions=2),
#  AnalyticsSummary(query="so i don't understand", clicks=0, impressions=1),
#  AnalyticsSummary(query='soundcore liberty 4 nc vs huawei freebuds 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='soundcore liberty 4 pro vs huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='soundcore liberty 5 vs huawei freebuds 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='spatial audio', clicks=0, impressions=1),
#  AnalyticsSummary(query='specs', clicks=0, impressions=1),
#  AnalyticsSummary(query='super productivity', clicks=0, impressions=13),
#  AnalyticsSummary(query='super productivity app', clicks=0, impressions=9),
#  AnalyticsSummary(query='super productivity app features', clicks=0, impressions=1),
#  AnalyticsSummary(query='super productivity app features 2026', clicks=0, impressions=19),
#  AnalyticsSummary(query='super productivity app price', clicks=0, impressions=1),
#  AnalyticsSummary(query='super productivity app review', clicks=0, impressions=9),
#  AnalyticsSummary(query='super productivity features', clicks=0, impressions=1),
#  AnalyticsSummary(query='super productivity home assistant', clicks=0, impressions=1),
#  AnalyticsSummary(query='super productivity review', clicks=1, impressions=21),
#  AnalyticsSummary(query='super productivity self hosted', clicks=0, impressions=2),
#  AnalyticsSummary(query='super productivity vs ticktick', clicks=0, impressions=6),
#  AnalyticsSummary(query='super productivity vs todoist', clicks=0, impressions=4),
#  AnalyticsSummary(query='super productivity vs vikunja', clicks=0, impressions=2),
#  AnalyticsSummary(query='super-productivity', clicks=0, impressions=1),
#  AnalyticsSummary(query='superproductivity', clicks=0, impressions=2),
#  AnalyticsSummary(query='tarteel ai careers', clicks=0, impressions=15),
#  AnalyticsSummary(query='tarteel ai jobs', clicks=1, impressions=10),
#  AnalyticsSummary(query='tarteel careers', clicks=0, impressions=22),
#  AnalyticsSummary(query='tarteel jobs', clicks=0, impressions=12),
#  AnalyticsSummary(query='ticktick vs super productivity', clicks=1, impressions=4),
#  AnalyticsSummary(query='todoist vs super productivity', clicks=0, impressions=4),
#  AnalyticsSummary(query='true wireless huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='tws huawei freebuds 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='vikunja vs super productivity', clicks=0, impressions=1),
#  AnalyticsSummary(query='what about the cons?', clicks=0, impressions=1),
#  AnalyticsSummary(query='what ai models does brave leo use', clicks=0, impressions=1),
#  AnalyticsSummary(query='what is mteb', clicks=0, impressions=1),
#  AnalyticsSummary(query='which is better for students', clicks=0, impressions=1),
#  AnalyticsSummary(query='yes', clicks=0, impressions=1),
#  AnalyticsSummary(query='yes plz', clicks=0, impressions=1),
#  AnalyticsSummary(query='го', clicks=0, impressions=1),
#  AnalyticsSummary(query='минусы', clicks=0, impressions=1),
#  AnalyticsSummary(query='недостатки', clicks=0, impressions=1),
#  AnalyticsSummary(query='отзывы', clicks=0, impressions=1),
#  AnalyticsSummary(query='сравнение huawei freebuds 5i и 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='сравнение цен', clicks=0, impressions=1),
#  AnalyticsSummary(query='стоит покупать?', clicks=0, impressions=1),
#  AnalyticsSummary(query='تابلت ون بلس باد 3', clicks=0, impressions=1),
#  AnalyticsSummary(query='سماعة هواوي 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='سماعة هواوي i7', clicks=0, impressions=1),
#  AnalyticsSummary(query='سماعة هواوي فري بودز 7i', clicks=0, impressions=1),
#  AnalyticsSummary(query='عربي', clicks=0, impressions=1),
#  AnalyticsSummary(query='عيوبها اي', clicks=0, impressions=1),
#  AnalyticsSummary(query='فيها', clicks=0, impressions=1),
#  AnalyticsSummary(query='نعم', clicks=0, impressions=1),
#  AnalyticsSummary(query='هواوي فري بودز 7i', clicks=0, impressions=2),
#  AnalyticsSummary(query='አሳየኝ', clicks=0, impressions=1),
#  AnalyticsSummary(query='华为 freebuds 7i 评测', clicks=0, impressions=1),
#  AnalyticsSummary(query='是', clicks=0, impressions=1),
#  AnalyticsSummary(query='원플러스 패드3', clicks=0, impressions=1)]

# %%
# | export
from seo_rat.gsc_client import fetch_gsc_data
import time


def store_single_date(session:Session, # Active database session
                      auth:GSCAuth,    # Authenticated GSCAuth instance
                      site_url:str,    # GSC property URL
                      date:str         # Date to fetch and store (YYYY-MM-DD)
                     ) -> int:
    "Fetch and store GSC data for a single date. Returns number of records stored."
    rows = fetch_gsc_data(auth, site_url, date, date)
    store_gsc_data(session, site_url, date, rows)
    return len(rows)

# %%
# | hide
# | test
#| eval: false
count = store_single_date(session, auth, "sc-domain:kareemai.com", start)
test_eq(count > 0, True)

# %%
# | test
#| eval: false
# Check what's actually stored
stored = session.exec(select(GSCAnalytics).limit(1)).first()
print(f"Query: {stored.query}")
print(f"Clicks: {stored.clicks}")
print(f"Date: {stored.date}")
test_eq(stored.site_url, "sc-domain:kareemai.com")
# Out:
# Query: أنواع السباكة
# Clicks: 0
# Date: 2024-11-11
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[31], line 8
#       6 print(f"Clicks: {stored.clicks}")
#       7 print(f"Date: {stored.date}")
# ----> 8 test_eq(stored.site_url, "sc-domain:kareemai.com")
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/fastcore/test.py:40, in test_eq(a, b)
#      38 def test_eq(a,b):
#      39     "`test` that `a==b`"
# ---> 40     test(a,b,equals, cname='==')
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/fastcore/test.py:30, in test(a, b, cmp, cname)
#      28 "`assert` that `cmp(a,b)`; display inputs and `cname or cmp.__name__` if it fails"
#      29 if cname is None: cname=cmp.__name__
# ---> 30 assert cmp(a,b),f"{cname}:\n{a}\n{b}"
#
# AssertionError: ==:
# sc-domain:awazly.com
# sc-domain:kareemai.com

# %%
#| export
def _sync_dates(session: Session,  # Active database session
                auth: GSCAuth,  # Authenticated GSCAuth instance
                site_url: str,  # GSC property URL
                dates: list[str]  # List of dates to sync (YYYY-MM-DD)
                ) -> dict:
    "Fetch and store GSC data for a list of dates, returning a results summary."
    results = {"successful": [], "failed": [], "total_records": 0}
    for date in dates:
        try:
            count = store_single_date(session, auth, site_url, date)
            results["successful"].append(date)
            results["total_records"] += count
            print(f"Synced {date}: {count} records")
        except Exception as e:
            results["failed"].append({"date": date, "error": str(e)})
            print(f"Failed {date}: {e}")
        time.sleep(1)
    return results

# %%
# | export
def store_date_range(session: Session, auth: GSCAuth, site_url: str, start_date: str, end_date: str) -> dict:
    "Fetch and store GSC data for all dates in range."
    return _sync_dates(session, auth, site_url, iter_dates(start_date, end_date))

# %%
# | hide
#| eval: false
result = store_date_range(session, auth, "sc-domain:https://emdadelgaz.com/", start, end)
test_eq(len(result["successful"]), 1)
print(f"Stored {result['total_records']} records")
# Out:
# Processing 2026-02-27 (1/31)...
# Processing 2026-02-28 (2/31)...
# Processing 2026-03-01 (3/31)...
# Processing 2026-03-02 (4/31)...
# Processing 2026-03-03 (5/31)...
# Processing 2026-03-04 (6/31)...
# Processing 2026-03-05 (7/31)...
# Processing 2026-03-06 (8/31)...
# Processing 2026-03-07 (9/31)...
# Processing 2026-03-08 (10/31)...
# Processing 2026-03-09 (11/31)...
# Processing 2026-03-10 (12/31)...
# Processing 2026-03-11 (13/31)...
# Processing 2026-03-12 (14/31)...
# Processing 2026-03-13 (15/31)...
# Processing 2026-03-14 (16/31)...
# Processing 2026-03-15 (17/31)...
# Processing 2026-03-16 (18/31)...
# Processing 2026-03-17 (19/31)...
# Processing 2026-03-18 (20/31)...
# Processing 2026-03-19 (21/31)...
# Processing 2026-03-20 (22/31)...
# Processing 2026-03-21 (23/31)...
# Processing 2026-03-22 (24/31)...
# Processing 2026-03-23 (25/31)...
# Processing 2026-03-24 (26/31)...
# Processing 2026-03-25 (27/31)...
# Processing 2026-03-26 (28/31)...
# Processing 2026-03-27 (29/31)...
# Processing 2026-03-28 (30/31)...
# Processing 2026-03-29 (31/31)...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 4
#       1 # | test
#       2 #| eval: false
#       3 result = store_date_range(session, auth, "sc-domain:https://emdadelgaz.com/", start, end)
# ----> 4 test_eq(len(result["successful"]), 1)
#       5 print(f"Stored {result['total_records']} records")
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/fastcore/test.py:40, in test_eq(a, b)
#      38 def test_eq(a,b):
#      39     "`test` that `a==b`"
# ---> 40     test(a,b,equals, cname='==')
#
# File ~/Desktop/seo_rat/.venv/lib/python3.13/site-packages/fastcore/test.py:30, in test(a, b, cmp, cname)
#      28 "`assert` that `cmp(a,b)`; display inputs and `cname or cmp.__name__` if it fails"
#      29 if cname is None: cname=cmp.__name__
# ---> 30 assert cmp(a,b),f"{cname}:\n{a}\n{b}"
#
# AssertionError: ==:
# 0
# 1

# %%
#| hide
#| eval: false
r = session.exec(select(GSCAnalytics).limit(1)).first()
print(f"Query: {r.query}")
print(f"Page: {r.page}")
print(f"Country: {r.country}")
print(f"Device: {r.device}")
print(f"Clicks: {r.clicks}")
print(f"Impressions: {r.impressions}")
print(f"CTR: {r.ctr}")
print(f"Position: {r.position}")
# Out:
# Query: أفضل شركة عازل بالكويت
# Page: https://shelid.com/azl_asth_balkwyt
# Country: kwt
# Device: MOBILE
# Clicks: 1
# Impressions: 5
# CTR: 0.2
# Position: 3.4

# %%
#| hide
#| eval: false
top = get_top_queries(session, "sc-domain:emdadelgaz.com", start, start, limit=5)
for q in top:
    print(
        f"{q['query']}: {q['total_clicks']} clicks, {q['total_impressions']} impressions"
    )

# %%
#| hide
from sqlalchemy import delete

# %%
# | hide
#| eval: false

session = get_session()

# session.exec(delete(GSCAnalytics))
# session.commit()

# %%
# | hide
#| eval: false

# delay 3 because GSC api limitation
end = datetime.now() - timedelta(days=3)
start = end - timedelta(days=365 * 3)

result = store_date_range(
    session,
    auth,
    "sc-domain:awazly.com",
    start.strftime("%Y-%m-%d"),
    end.strftime("%Y-%m-%d"),
)
# Out:
# Processing 2023-03-31 (1/1096)...
# Processing 2026-03-14 (1080/1096)...
# Processing 2026-03-15 (1081/1096)...
# Processing 2026-03-16 (1082/1096)...
# Processing 2026-03-17 (1083/1096)...
# Processing 2026-03-18 (1084/1096)...
# Processing 2026-03-19 (1085/1096)...
# Processing 2026-03-20 (1086/1096)...
# Processing 2026-03-21 (1087/1096)...
# Processing 2026-03-22 (1088/1096)...
# Processing 2026-03-23 (1089/1096)...
# Processing 2026-03-24 (1090/1096)...
# Processing 2026-03-25 (1091/1096)...
# Processing 2026-03-26 (1092/1096)...
# Processing 2026-03-27 (1093/1096)...
# Processing 2026-03-28 (1094/1096)...
# Processing 2026-03-29 (1095/1096)...
# Processing 2026-03-30 (1096/1096)...

# %%
#| export
from datetime import date, timedelta


def iter_dates(start_date: str,  # Start date (YYYY-MM-DD)
               end_date: str  # End date (YYYY-MM-DD)
               ) -> list[str]:
    "Generate all dates between start and end inclusive."

    start_d = datetime.strptime(start_date, "%Y-%m-%d").date()
    end_d = datetime.strptime(end_date, "%Y-%m-%d").date()
    return [(start_d + timedelta(days=i)).strftime("%Y-%m-%d")
            for i in range((end_d - start_d).days + 1)]


def get_missing_dates(session: Session,  # Active database session
                      site_url: str,  # GSC property URL
                      start_date: str,  # Start date (YYYY-MM-DD)
                      end_date: str  # End date (YYYY-MM-DD)
                      ) -> list[str]:
    "Return dates in range that have no stored GSC data."
    stored = set(session.exec(
        select(GSCAnalytics.date).where(GSCAnalytics.site_url == site_url).distinct()
    ).all())
    return sorted(set(iter_dates(start_date, end_date)) - stored)

# %%
#| hide
#| eval: false
missing = get_missing_dates(session, "sc-domain:shelid.com", "2026-01-01", "2026-03-28")
print(len(missing), missing[:5])
# Out:
# 0 []

# %%
#| export
def sync_missing_dates(session: Session, auth: GSCAuth, site_url: str, start_date: str, end_date: str) -> dict:
    "Fetch and store GSC data for missing dates only."
    return _sync_dates(session, auth, site_url, get_missing_dates(session, site_url, start_date, end_date))

# %%
# | export
def daily_sync(session: Session,  # Active database session
               auth: GSCAuth,  # Authenticated GSCAuth instance
               sites: list[str]  # List of GSC property URLs to sync
               ) -> dict:
    "Sync missing GSC data for all sites up to today."
    _, end = get_date_range("today")
    return {site: sync_missing_dates(session, auth, site,
                                     min(get_missing_dates(session, site, "2020-01-01", end), default=end),
                                     end)
            for site in sites}

# %%
#| hide
#| eval: false
daily_sync_result = daily_sync(session, auth, ["sc-domain:shelid.com"])
print(daily_sync_result)
# Out:
# Syncing sc-domain:shelid.com from 2024-11-17 to 2026-03-29...
# Found 12 missing dates
# Synced 2024-11-27 with 278 records
# Synced 2024-11-28 with 322 records
# Synced 2024-11-29 with 301 records
# Synced 2024-11-30 with 316 records
# Synced 2024-12-01 with 334 records
# Synced 2025-01-05 with 445 records
# Synced 2025-12-24 with 234 records
# Synced 2026-03-11 with 129 records
# Synced 2026-03-12 with 129 records
# Synced 2026-03-13 with 159 records
# Synced 2026-03-14 with 120 records
# Synced 2026-03-15 with 134 records
# {'sc-domain:shelid.com': {'synced': 12, 'failed': 0, 'total_records': 2901}}
