# %%
# | default_exp gsc_storage

# %%
# | export
from sqlmodel import Session, select
from seo_rat.models import GSCAnalytics
from typing import List, Dict
from datetime import datetime
from seo_rat.gsc_client import GSCAuth

# %%
# | export
def store_gsc_data(session: Session, site_url: str, date: str, rows: List[Dict]):
    """Store GSC data with upsert (update or insert)"""
    for row in rows:
        # Check if record exists
        stmt = select(GSCAnalytics).where(
            GSCAnalytics.site_url == site_url,
            GSCAnalytics.date == date,
            GSCAnalytics.query == row["keys"][0] if len(row["keys"]) > 0 else None,
            GSCAnalytics.page == row["keys"][1] if len(row["keys"]) > 1 else None,
            GSCAnalytics.country == row["keys"][2] if len(row["keys"]) > 2 else None,
            GSCAnalytics.device == row["keys"][3] if len(row["keys"]) > 3 else None,
        )
        existing = session.exec(stmt).first()

        if existing:
            # Update
            existing.clicks = row["clicks"]
            existing.impressions = row["impressions"]
            existing.ctr = row["ctr"]
            existing.position = row["position"]
        else:
            # Insert
            analytics = GSCAnalytics(
                site_url=site_url,
                date=date,
                query=row["keys"][0] if len(row["keys"]) > 0 else None,
                page=row["keys"][1] if len(row["keys"]) > 1 else None,
                country=row["keys"][2] if len(row["keys"]) > 2 else None,
                device=row["keys"][3] if len(row["keys"]) > 3 else None,
                clicks=row["clicks"],
                impressions=row["impressions"],
                ctr=row["ctr"],
                position=row["position"],
            )
            session.add(analytics)

    session.commit()

# %%
# | hide
from fastcore.test import test_eq
from seo_rat.gsc_client import GSCAuth, fetch_gsc_data, get_date_range
from seo_rat.sqlite_db import SQLiteDB
from sqlmodel import Session
from pprint import pprint


auth = GSCAuth()
start, end = get_date_range("last_days", days=30)
data = fetch_gsc_data(auth, "sc-domain:kareemai.com", start, end)

# %%
db = SQLiteDB()
with db.get_session() as session:
    store_gsc_data(session, "sc-domain:kareemai.com", start, data[:5])
    # verfiy stored
    test_eq(len(session.exec(select(GSCAnalytics)).all()) > 4, True)

# %%
def get_top_queries(
    session: Session, 
    site_url: str, 
    start_date: str, 
    end_date: str,
    country: str = None,  # Add this
    limit: int = 10
) -> List[Dict]:
    """Get top queries, optionally filtered by country"""
    from sqlalchemy import func
    
    stmt = select(...)
    .where(
        GSCAnalytics.site_url == site_url,
        GSCAnalytics.date >= start_date,
        GSCAnalytics.date <= end_date,
    )
    
    # Add country filter if provided
    if country:
        stmt = stmt.where(GSCAnalytics.country == country)

# %%
# | export
def get_top_queries(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    country=None,
    limit: int = 10,
) -> List[Dict]:
    """Get top performing queries"""
    from sqlalchemy import func

    stmt = (
        select(
            GSCAnalytics.query,
            func.sum(GSCAnalytics.clicks).label("total_clicks"),
            func.sum(GSCAnalytics.impressions).label("total_impressions"),
            func.avg(GSCAnalytics.position).label("avg_position"),
            func.avg(GSCAnalytics.ctr).label("avg_ctr"),
        )
        .where(
            GSCAnalytics.site_url == site_url,
            GSCAnalytics.date >= start_date,
            GSCAnalytics.date <= end_date,
            GSCAnalytics.query.isnot(None),
        )
        .group_by(GSCAnalytics.query)
        .order_by(func.sum(GSCAnalytics.clicks).desc())
        .limit(limit)
    )
    if country:
        stmt = stmt.where(GSCAnalytics.country == country)

    return [dict(row._mapping) for row in session.exec(stmt)]

# %%
# | hide

test_top_queries = get_top_queries(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    country="egy",
)

# %%
test_top_queries
# Out:
# [{'query': 'هواوي ايربودز 7i',
#   'total_clicks': 1,
#   'total_impressions': 1,
#   'avg_position': 2.0,
#   'avg_ctr': 1.0},
#  {'query': 'oneplus pad 3',
#   'total_clicks': 1,
#   'total_impressions': 32,
#   'avg_position': 12.474509803921569,
#   'avg_ctr': 0.029411764705882353},
#  {'query': 'huawei freebuds 5i vs 7i',
#   'total_clicks': 1,
#   'total_impressions': 3,
#   'avg_position': 1.0,
#   'avg_ctr': 0.3333333333333333},
#  {'query': 'huawei buds 7i review',
#   'total_clicks': 1,
#   'total_impressions': 2,
#   'avg_position': 1.0,
#   'avg_ctr': 0.5},
#  {'query': 'freebuds 7i review',
#   'total_clicks': 1,
#   'total_impressions': 47,
#   'avg_position': 2.485144927536232,
#   'avg_ctr': 0.043478260869565216},
#  {'query': 'وان بلس باد 3',
#   'total_clicks': 0,
#   'total_impressions': 1,
#   'avg_position': 2.0,
#   'avg_ctr': 0.0},
#  {'query': 'هواوي فري بودز 7i',
#   'total_clicks': 0,
#   'total_impressions': 5,
#   'avg_position': 5.375,
#   'avg_ctr': 0.0},
#  {'query': 'هواوي freebuds 7i',
#   'total_clicks': 0,
#   'total_impressions': 1,
#   'avg_position': 7.0,
#   'avg_ctr': 0.0},
#  {'query': 'هواوى فرى بودز 7i',
#   'total_clicks': 0,
#   'total_impressions': 1,
#   'avg_position': 5.0,
#   'avg_ctr': 0.0},
#  {'query': 'سماعة هواوي فري بودز 7i',
#   'total_clicks': 0,
#   'total_impressions': 1,
#   'avg_position': 7.0,
#   'avg_ctr': 0.0}]

# %%
# | export
def get_top_queries_excluding_pages(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    exclude_pages: List[str],
    country=None,
    limit: int = 10,
) -> List[Dict]:
    """Get top queries excluding certain pages"""
    from sqlalchemy import func, not_, or_

    # Build exclusion filter
    filters = [GSCAnalytics.page.contains(page) for page in exclude_pages]

    stmt = (
        select(
            GSCAnalytics.query,
            func.sum(GSCAnalytics.clicks).label("total_clicks"),
            func.sum(GSCAnalytics.impressions).label("total_impressions"),
        )
        .where(
            GSCAnalytics.site_url == site_url,
            GSCAnalytics.date >= start_date,
            GSCAnalytics.date <= end_date,
            not_(or_(*filters)),  # Exclude pages
        )
        .group_by(GSCAnalytics.query)
        .order_by(func.sum(GSCAnalytics.clicks).desc())
        .limit(limit)
    )
    if country:
        stmt = stmt.where(GSCAnalytics.country == country)

    return [dict(row._mapping) for row in session.exec(stmt)]

# %%
# | hide
from sqlalchemy.testing.exclusions import exclude

test_exclude_page_from_top_queries = get_top_queries_excluding_pages(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    exclude_pages=[
        "https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html",
        "https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html",
    ],
    country="egy",
)
pprint(test_exclude_page_from_top_queries)
# Out:
# [{'query': 'oneplus pad 3', 'total_clicks': 1, 'total_impressions': 32},
#  {'query': 'وان بلس باد 3', 'total_clicks': 0, 'total_impressions': 1},
#  {'query': 'ساعة هواوي gt4', 'total_clicks': 0, 'total_impressions': 1},
#  {'query': 'أفضل أنواع الكرياتين للتضخيم',
#   'total_clicks': 0,
#   'total_impressions': 1},
#  {'query': 'tokenization in arabic', 'total_clicks': 0, 'total_impressions': 1},
#  {'query': 'tarteel jobs', 'total_clicks': 0, 'total_impressions': 2},
#  {'query': 'tarteel careers', 'total_clicks': 0, 'total_impressions': 7},
#  {'query': 'tarteel ai careers', 'total_clicks': 0, 'total_impressions': 3},
#  {'query': 'pylate', 'total_clicks': 0, 'total_impressions': 3},
#  {'query': 'proteinai', 'total_clicks': 0, 'total_impressions': 1}]

# %%
# | export
def get_page_analytics(
    session: Session, site_url: str, page_path: str, start_date: str, end_date: str
) -> Dict:
    """Get analytics for specific page"""
    from sqlalchemy import func

    stmt = select(GSCAnalytics).where(
        GSCAnalytics.site_url == site_url,
        GSCAnalytics.page.contains(page_path),
        GSCAnalytics.date >= start_date,
        GSCAnalytics.date <= end_date,
    )

    results = session.exec(stmt).all()

    return {
        "page_path": page_path,
        "total_clicks": sum(r.clicks for r in results),
        "total_impressions": sum(r.impressions for r in results),
        "avg_position": sum(r.position for r in results) / len(results)
        if results
        else 0,
        "avg_ctr": sum(r.ctr for r in results) / len(results) if results else 0,
        "top_queries": list(set(r.query for r in results if r.query))[:10],
    }

# %%
# | hide
test_page_analytics = get_page_analytics(
    session,
    site_url="sc-domain:kareemai.com",
    page_path="https://kareemai.com",
    start_date=start,
    end_date=end,
)
pprint(test_page_analytics)
# Out:
# {'avg_ctr': 0.012163857114188239,
#  'avg_position': 8.890007641405472,
#  'page_path': 'https://kareemai.com',
#  'top_queries': ['huawei freebuds 7',
#                  'huawei earbuds 7',
#                  'huawei freebuds 7i sound quality',
#                  'huawei freebuds 7i product info and reviews',
#                  'huawei 7i buds',
#                  'son buenos?',
#                  'freebuds5i',
#                  'huawei gt watch review',
#                  'huawei freebuds 7i box',
#                  'huawei earbuds 7i price in pakistan'],
#  'total_clicks': 97,
#  'total_impressions': 10114}

# %%
# | export
def get_analytics_by_date_range(
    session: Session, site_url: str, start_date: str, end_date: str
) -> List[GSCAnalytics]:
    """Get all analytics for date range"""
    stmt = select(GSCAnalytics).where(
        GSCAnalytics.site_url == site_url,
        GSCAnalytics.date >= start_date,
        GSCAnalytics.date <= end_date,
    )
    return session.exec(stmt).all()

# %%
# | hide

test_get_analytics_by_date_range = get_analytics_by_date_range(
    session, site_url="sc-domain:kareemai.com", start_date=start, end_date=end
)
pprint(test_get_analytics_by_date_range)
# Out:
# [GSCAnalytics(id=48968, query='audífonos huawei freebuds 5i', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 820373), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=48969, query='audífonos huawei freebuds 7i', country='col', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 821063), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=48970, query='audífonos huawei freebuds 7i', country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 821955), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=4, position=1.0),
#  GSCAnalytics(id=48971, query='ctranslate2 int4 quantization support', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 822678), page='https://kareemai.com/blog/posts/minishlab/ctranslate_maswray.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=6.0),
#  GSCAnalytics(id=48972, query='ctranslate2 quantization int8 float16 whisper', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 823412), page='https://kareemai.com/blog/posts/minishlab/ctranslate_maswray.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=11.0),
#  GSCAnalytics(id=48973, query='ctranslate2 quantization int8_float16 documentation', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 824091), page='https://kareemai.com/blog/posts/minishlab/ctranslate_maswray.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=48974, query='does porkbun use cloudflare', country='jor', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 824853), page='https://kareemai.com/til/tils/2025-05-20-til.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=42.0),
#  GSCAnalytics(id=48975, query='does porkbun use cloudflare', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 825585), page='https://kareemai.com/til/tils/2025-05-20-til.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=30.0),
#  GSCAnalytics(id=48976, query='dspy', country='che', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 826304), page='https://kareemai.com/til/tils/2025-12-14.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=15.0),
#  GSCAnalytics(id=48977, query='free buds 5i', country='yem', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 826986), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=6.0),
#  GSCAnalytics(id=48978, query='freebuds 5i', country='aus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 827713), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=48979, query='freebuds 5i', country='chn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 828442), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=3.0),
#  GSCAnalytics(id=48980, query='freebuds 5i', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 829127), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=2, position=11.0),
#  GSCAnalytics(id=48981, query='freebuds 5i', country='hkg', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 829817), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=48982, query='freebuds 5i', country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 830505), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=11.0),
#  GSCAnalytics(id=48983, query='freebuds 5i', country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 831184), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=35.0),
#  GSCAnalytics(id=48984, query='freebuds 5i', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 832016), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=48985, query='freebuds 5i vs 7i', country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 832766), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=2.0),
#  GSCAnalytics(id=48986, query='freebuds 6i vs 7i', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 833497), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=5, position=1.0),
#  GSCAnalytics(id=48987, query='freebuds 7i', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 834187), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=7.0),
#  GSCAnalytics(id=48988, query='freebuds 7i', country='lva', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 834916), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=7.0),
#  GSCAnalytics(id=48989, query='freebuds 7i', country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 835712), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=8.0),
#  GSCAnalytics(id=48990, query='freebuds 7i', country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 836437), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=48991, query='freebuds 7i', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 837116), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=4, position=5.0),
#  GSCAnalytics(id=48992, query='freebuds 7i review', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 837864), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=7.0),
#  GSCAnalytics(id=48993, query='freebuds 7i review', country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 838591), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=48994, query='freebuds 7i review', country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 839275), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=48995, query='freebuds 7i review', country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 839962), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=7.0),
#  GSCAnalytics(id=48996, query='freebuds 7i review', country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 840697), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=5.0),
#  GSCAnalytics(id=48997, query='freebuds 7i review', country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 841382), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=3.5),
#  GSCAnalytics(id=48998, query='freebuds 7i vs 5i', country='rus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 842070), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=1.0),
#  GSCAnalytics(id=48999, query='freebuds 7i vs 5i', country='rus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 842805), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49000, query='gpu cloud pricing', country='isr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 843529), page='https://kareemai.com/blog/posts/life_style/gpuvec.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=96.0),
#  GSCAnalytics(id=49001, query='how 5i', country='alb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 844213), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=49002, query='huawei 5i freebuds', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 844900), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=7.0),
#  GSCAnalytics(id=49003, query='huawei 7i earbuds', country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 845591), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=2, position=8.0),
#  GSCAnalytics(id=49004, query='huawei 7i earbuds', country='chn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 846351), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49005, query='huawei 7i earbuds', country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 847033), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=8.0),
#  GSCAnalytics(id=49006, query='huawei 7i earbuds', country='prt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 847727), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=13.0),
#  GSCAnalytics(id=49007, query='huawei 7i freebuds', country='mys', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 848462), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=11.0),
#  GSCAnalytics(id=49008, query='huawei 7i freebuds', country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 849142), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=9.0),
#  GSCAnalytics(id=49009, query='huawei earbuds 5i', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 849869), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=2, position=12.5),
#  GSCAnalytics(id=49010, query='huawei earbuds 7i', country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 850560), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=3, position=7.0),
#  GSCAnalytics(id=49011, query='huawei earbuds 7i', country='blr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 851244), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=9.0),
#  GSCAnalytics(id=49012, query='huawei earbuds 7i', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 851933), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=3, position=7.0),
#  GSCAnalytics(id=49013, query='huawei earbuds 7i', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 852623), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=10.0),
#  GSCAnalytics(id=49014, query='huawei earbuds 7i', country='hkg', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 853321), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=49015, query='huawei earbuds 7i', country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 854009), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=7.0),
#  GSCAnalytics(id=49016, query='huawei earbuds 7i', country='mys', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 854745), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49017, query='huawei earbuds 7i', country='nga', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 855473), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=49018, query='huawei free buds 5i', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 856153), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=12.0),
#  GSCAnalytics(id=49019, query='huawei free buds 7i', country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 856944), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=4.0),
#  GSCAnalytics(id=49020, query='huawei freebuds 5 review', country='esp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 857668), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=68.0),
#  GSCAnalytics(id=49021, query='huawei freebuds 5i', country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 858399), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=2, position=10.0),
#  GSCAnalytics(id=49022, query='huawei freebuds 5i', country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 859081), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=49023, query='huawei freebuds 5i', country='fin', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 859815), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=11.0),
#  GSCAnalytics(id=49024, query='huawei freebuds 5i', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 860548), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=7.0),
#  GSCAnalytics(id=49025, query='huawei freebuds 5i', country='hkg', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 861233), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=12.0),
#  GSCAnalytics(id=49026, query='huawei freebuds 5i', country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 861980), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=3, position=11.0),
#  GSCAnalytics(id=49027, query='huawei freebuds 5i', country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 862718), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=3, position=5.0),
#  GSCAnalytics(id=49028, query='huawei freebuds 5i', country='lbn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 863444), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=8.0),
#  GSCAnalytics(id=49029, query='huawei freebuds 5i', country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 864128), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=24.5),
#  GSCAnalytics(id=49030, query='huawei freebuds 5i', country='qat', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 864865), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=8.0),
#  GSCAnalytics(id=49031, query='huawei freebuds 5i', country='rus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 865592), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=13.0),
#  GSCAnalytics(id=49032, query='huawei freebuds 5i', country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 866320), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=49033, query='huawei freebuds 5i', country='uga', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 867005), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=3, position=4.0),
#  GSCAnalytics(id=49034, query='huawei freebuds 5i', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 867825), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=3, position=3.3333333333333335),
#  GSCAnalytics(id=49035, query='huawei freebuds 5i', country='yem', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 868563), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=49036, query='huawei freebuds 5i microphone call quality review', country='mar', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 869277), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=6.0),
#  GSCAnalytics(id=49037, query='huawei freebuds 5i opinie', country='esp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 869999), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=36.0),
#  GSCAnalytics(id=49038, query='huawei freebuds 5i review', country='aut', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 870733), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=1.0),
#  GSCAnalytics(id=49039, query='huawei freebuds 5i review', country='bgr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 871432), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=2.0),
#  GSCAnalytics(id=49040, query='huawei freebuds 5i review', country='cze', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 872376), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=2.0),
#  GSCAnalytics(id=49041, query='huawei freebuds 5i review', country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 873067), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=1.0),
#  GSCAnalytics(id=49042, query='huawei freebuds 5i review', country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 873795), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=7.0),
#  GSCAnalytics(id=49043, query='huawei freebuds 5i review', country='kaz', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 874526), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=3.5),
#  GSCAnalytics(id=49044, query='huawei freebuds 5i review', country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 875210), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=3.0),
#  GSCAnalytics(id=49045, query='huawei freebuds 5i review', country='nor', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 875939), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=1.0),
#  GSCAnalytics(id=49046, query='huawei freebuds 5i review', country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 876669), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49047, query='huawei freebuds 5i review', country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 877396), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=3, position=1.3333333333333333),
#  GSCAnalytics(id=49048, query='huawei freebuds 5i review', country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 878147), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=2, position=1.5),
#  GSCAnalytics(id=49049, query='huawei freebuds 5i review', country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 878874), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=49050, query='huawei freebuds 5i review', country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 879626), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=2.0),
#  GSCAnalytics(id=49051, query='huawei freebuds 5i vs 7i', country='aut', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 880314), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=4.0),
#  GSCAnalytics(id=49052, query='huawei freebuds 5i vs 7i', country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 883857), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='TABLET', impressions=1, position=5.0),
#  GSCAnalytics(id=49053, query='huawei freebuds 7', country='kor', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 884612), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='TABLET', impressions=1, position=1.0),
#  GSCAnalytics(id=49054, query='huawei freebuds 71', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 885350), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=2.0),
#  GSCAnalytics(id=49055, query='huawei freebuds 7i', country='aus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 886030), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=10.0),
#  GSCAnalytics(id=49056, query='huawei freebuds 7i', country='gha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 886717), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=9.0),
#  GSCAnalytics(id=49057, query='huawei freebuds 7i', country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 887409), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49058, query='huawei freebuds 7i', country='pak', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 888089), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=49059, query='huawei freebuds 7i', country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 888837), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=9.0),
#  GSCAnalytics(id=49060, query='huawei freebuds 7i', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 889567), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=5.0),
#  GSCAnalytics(id=49061, query='huawei freebuds 7i', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 890259), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=4, position=5.0),
#  GSCAnalytics(id=49062, query='huawei freebuds 7i anc', country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 890949), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=2.0),
#  GSCAnalytics(id=49063, query='huawei freebuds 7i anc review', country='tur', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 891637), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=3.0),
#  GSCAnalytics(id=49064, query='huawei freebuds 7i battery life', country='nld', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 892331), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49065, query='huawei freebuds 7i features', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 893026), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49066, query='huawei freebuds 7i features', country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 893714), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=8.0),
#  GSCAnalytics(id=49067, query='huawei freebuds 7i mic test', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 894401), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=2.0),
#  GSCAnalytics(id=49068, query='huawei freebuds 7i mic test', country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 895084), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=2.0),
#  GSCAnalytics(id=49069, query='huawei freebuds 7i product info and reviews', country='chl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 895819), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=3.0),
#  GSCAnalytics(id=49070, query='huawei freebuds 7i product info and reviews', country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 896560), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49071, query='huawei freebuds 7i product info and reviews', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 897259), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49072, query='huawei freebuds 7i review', country='aze', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 897942), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49073, query='huawei freebuds 7i review', country='chl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 898629), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=49074, query='huawei freebuds 7i review', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 899388), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=4, position=4.5),
#  GSCAnalytics(id=49075, query='huawei freebuds 7i review', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 900080), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=4, position=2.0),
#  GSCAnalytics(id=49076, query='huawei freebuds 7i review', country='grc', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 900807), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=49077, query='huawei freebuds 7i review', country='hun', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 901537), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=3, position=2.666666666666667),
#  GSCAnalytics(id=49078, query='huawei freebuds 7i review', country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 902226), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=3.0),
#  GSCAnalytics(id=49079, query='huawei freebuds 7i review', country='idn', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 902911), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49080, query='huawei freebuds 7i review', country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 903625), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='TABLET', impressions=1, position=3.0),
#  GSCAnalytics(id=49081, query='huawei freebuds 7i review', country='jor', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 904328), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=3.0),
#  GSCAnalytics(id=49082, query='huawei freebuds 7i review', country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 905024), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49083, query='huawei freebuds 7i review', country='mys', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 905714), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=3.0),
#  GSCAnalytics(id=49084, query='huawei freebuds 7i review', country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 906432), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=4, position=2.75),
#  GSCAnalytics(id=49085, query='huawei freebuds 7i review', country='prt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 907128), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=2.0),
#  GSCAnalytics(id=49086, query='huawei freebuds 7i review', country='rou', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 907835), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=49087, query='huawei freebuds 7i review', country='sau', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 908546), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=2, position=1.0),
#  GSCAnalytics(id=49088, query='huawei freebuds 7i review', country='sgp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 909257), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49089, query='huawei freebuds 7i review', country='sgp', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 909961), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=8.0),
#  GSCAnalytics(id=49090, query='huawei freebuds 7i review', country='srb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 910725), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49091, query='huawei freebuds 7i review', country='svk', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 911481), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=3.5),
#  GSCAnalytics(id=49092, query='huawei freebuds 7i review', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 912200), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=2.0),
#  GSCAnalytics(id=49093, query='huawei freebuds 7i review', country='vnm', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 912928), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=1.0),
#  GSCAnalytics(id=49094, query='huawei freebuds 7i review', country='vnm', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 913643), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=49095, query='huawei freebuds 7i review anc', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 914363), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49096, query='huawei freebuds 7i review anc', country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 915082), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49097, query='huawei freebuds 7i reviews', country='chl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 915811), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=6.0),
#  GSCAnalytics(id=49098, query='huawei freebuds 7i reviews', country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 916517), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=3.5),
#  GSCAnalytics(id=49099, query='huawei freebuds 7i reviews', country='ita', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 917216), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49100, query='huawei freebuds 7i specifications', country='mex', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 917996), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=49101, query='huawei freebuds 7i specifications features', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 918735), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=3.0),
#  GSCAnalytics(id=49102, query='huawei freebuds 7i specs', country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 919485), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=1.0),
#  GSCAnalytics(id=49103, query='huawei freebuds 7i specs', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 920204), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=2, position=7.0),
#  GSCAnalytics(id=49104, query='huawei freebuds 7i specs', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 920926), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=2.0),
#  GSCAnalytics(id=49105, query='huawei freebuds 7i specs', country='kwt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 921665), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=1.0),
#  GSCAnalytics(id=49106, query='huawei freebuds 7i specs', country='pol', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 922387), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=7.0),
#  GSCAnalytics(id=49107, query='huawei freebuds 7i teszt', country='hun', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 923105), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='DESKTOP', impressions=1, position=3.0),
#  GSCAnalytics(id=49108, query='huawei freebuds 7i teszt', country='hun', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 2, 59, 923833), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html', site_url='sc-domain:kareemai.com', date='2025-12-14', device='MOBILE', impressions=1, position=2.0),
# ...
#  GSCAnalytics(id=55372, query='mteb number of tasks', country='bih', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 4093), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=10.0),
#  GSCAnalytics(id=55373, query='mteb number of tasks', country='chl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 5150), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=10.0),
#  GSCAnalytics(id=55374, query='mteb number of tasks', country='dza', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 5984), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=2, position=10.0),
#  GSCAnalytics(id=55375, query='mteb number of tasks', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 6775), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=22, position=10.181818181818182),
#  GSCAnalytics(id=55376, query='mteb number of tasks', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 7649), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=3, position=10.0),
#  GSCAnalytics(id=55377, query='mteb number of tasks', country='mar', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 8634), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=10.0),
#  GSCAnalytics(id=55378, query='mteb number of tasks', country='prt', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 9618), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=10.0),
#  GSCAnalytics(id=55379, query='mteb number of tasks', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 10620), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=16, position=10.4375),
#  GSCAnalytics(id=55380, query='mteb number of tasks', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 11563), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=3, position=10.333333333333334),
#  GSCAnalytics(id=55381, query='mteb number of tasks', country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 12468), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=2, position=10.0),
#  GSCAnalytics(id=55382, query='mteb number of tasks datasets', country='alb', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 13281), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=55383, query='mteb number of tasks datasets', country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 14062), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=55384, query='mteb number of tasks datasets', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 14824), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=2, position=5.0),
#  GSCAnalytics(id=55385, query='mteb number of tasks datasets', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 15590), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=2, position=5.0),
#  GSCAnalytics(id=55386, query='mteb number of tasks english', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 16355), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=55387, query='mteb number of tasks english', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 17118), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=55388, query='mteb number of tasks english', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 18011), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=3, position=6.0),
#  GSCAnalytics(id=55389, query='mteb retrieval', country='aus', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 18998), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=39.0),
#  GSCAnalytics(id=55390, query='mteb retrieval metric ndcg@10 beir', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 22703), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=10.0),
#  GSCAnalytics(id=55391, query='mteb retrieval number of datasets', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 23651), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=4, position=5.0),
#  GSCAnalytics(id=55392, query='mteb retrieval number of datasets', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 24555), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=55393, query='mteb retrieval number of datasets', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 25372), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=55394, query='mteb retrieval number of datasets', country='zaf', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 26129), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=4.0),
#  GSCAnalytics(id=55395, query='mteb retrieval task metric ndcg@10 beir', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 26890), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=3, position=9.0),
#  GSCAnalytics(id=55396, query='mteb retrieval task metric ndcg@10 beir', country='tto', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 27652), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=11.0),
#  GSCAnalytics(id=55397, query='mteb retrieval task number of datasets', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 28424), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=2, position=5.0),
#  GSCAnalytics(id=55398, query='mteb retrieval task number of datasets', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 29404), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=55399, query='mteb retrieval task number of datasets', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 30243), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=3, position=5.333333333333333),
#  GSCAnalytics(id=55400, query='number of datasets in mteb retrieval task', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 31058), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=6.0),
#  GSCAnalytics(id=55401, query='number of datasets in mteb retrieval task', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 31855), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=4, position=9.0),
#  GSCAnalytics(id=55402, query='number of datasets in mteb retrieval task', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 32632), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=2, position=8.0),
#  GSCAnalytics(id=55403, query='number of tasks in english mteb', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 33413), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=8.0),
#  GSCAnalytics(id=55404, query='number of tasks in english mteb', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 34187), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=6, position=6.0),
#  GSCAnalytics(id=55405, query='number of tasks in mteb english', country='gbr', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 34976), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=2, position=7.0),
#  GSCAnalytics(id=55406, query='number of tasks in mteb english', country='pri', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 35759), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=7.0),
#  GSCAnalytics(id=55407, query='number of tasks in mteb english', country='usa', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 36541), page='https://kareemai.com/blog/posts/mteb_encoding/MTEB_massive_text_embedding_benchmark.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=2, position=8.0),
#  GSCAnalytics(id=55408, query='oneplus pad 3', country='egy', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 37314), page='https://kareemai.com/blog/posts/products_reviews/one_plus_pad_3.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=22.0),
#  GSCAnalytics(id=55409, query='pylate', country='ind', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 38085), page='https://kareemai.com/til/tils/2025-05-28-til.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=22.0),
#  GSCAnalytics(id=55410, query='soundguys huawei freebuds 5i review', country='bra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 38867), page='https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%205i.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=6.0),
#  GSCAnalytics(id=55411, query='tarteel ai careers', country='can', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 39646), page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=5.0),
#  GSCAnalytics(id=55412, query='tarteel ai careers', country='fra', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 40453), page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=5.0),
#  GSCAnalytics(id=55413, query='tarteel ai jobs', country='are', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 41373), page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=6.0),
#  GSCAnalytics(id=55414, query='tarteel ai jobs', country='deu', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 42424), page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=55415, query='tarteel careers', country='irl', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 43482), page='https://kareemai.com/blog/posts/speech_recognition/my_dream_job_at_tarteel.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='MOBILE', impressions=1, position=6.0),
#  GSCAnalytics(id=55416, query='vercel porkbun', country='tha', clicks=0, ctr=0.0, created_at=datetime.datetime(2026, 1, 16, 21, 3, 51, 44482), page='https://kareemai.com/til/tils/2025-05-20-til.html', site_url='sc-domain:kareemai.com', date='2026-01-13', device='DESKTOP', impressions=1, position=16.0)]

# %%
# | export
def get_trends(
    session: Session,
    site_url: str,
    start_date: str,
    end_date: str,
    dimension: str = None,
) -> List[Dict]:
    """Get trends over time, optionally grouped by dimension"""
    from sqlalchemy import func

    if dimension:
        stmt = (
            select(
                GSCAnalytics.date,
                getattr(GSCAnalytics, dimension),
                func.sum(GSCAnalytics.clicks).label("clicks"),
                func.sum(GSCAnalytics.impressions).label("impressions"),
                func.avg(GSCAnalytics.position).label("avg_position"),
                func.avg(GSCAnalytics.ctr).label("avg_ctr"),
            )
            .where(
                GSCAnalytics.site_url == site_url,
                GSCAnalytics.date >= start_date,
                GSCAnalytics.date <= end_date,
            )
            .group_by(GSCAnalytics.date, getattr(GSCAnalytics, dimension))
            .order_by(GSCAnalytics.date)
        )
    else:
        stmt = (
            select(
                GSCAnalytics.date,
                func.sum(GSCAnalytics.clicks).label("clicks"),
                func.sum(GSCAnalytics.impressions).label("impressions"),
                func.avg(GSCAnalytics.position).label("avg_position"),
                func.avg(GSCAnalytics.ctr).label("avg_ctr"),
            )
            .where(
                GSCAnalytics.site_url == site_url,
                GSCAnalytics.date >= start_date,
                GSCAnalytics.date <= end_date,
            )
            .group_by(GSCAnalytics.date)
            .order_by(GSCAnalytics.date)
        )

    return [dict(row._mapping) for row in session.exec(stmt)]

# %%
# | hide
test_get_trends = get_trends(
    session, site_url="sc-domain:kareemai.com", start_date=start, end_date=end
)
pprint(test_get_trends)
# Out:
# [{'avg_ctr': 0.00546448087431694,
#   'avg_position': 8.189642324888228,
#   'clicks': 1,
#   'date': '2025-12-14',
#   'impressions': 262},
#  {'avg_ctr': 0.02843601895734597,
#   'avg_position': 10.81911532385466,
#   'clicks': 7,
#   'date': '2025-12-15',
#   'impressions': 293},
#  {'avg_ctr': 0.0136986301369863,
#   'avg_position': 6.706816699282453,
#   'clicks': 3,
#   'date': '2025-12-16',
#   'impressions': 301},
#  {'avg_ctr': 0.022026431718061675,
#   'avg_position': 8.283590308370044,
#   'clicks': 5,
#   'date': '2025-12-17',
#   'impressions': 299},
#  {'avg_ctr': 0.021164021164021163,
#   'avg_position': 9.289241622574956,
#   'clicks': 5,
#   'date': '2025-12-18',
#   'impressions': 252},
#  {'avg_ctr': 0.012280701754385965,
#   'avg_position': 8.329720893141946,
#   'clicks': 4,
#   'date': '2025-12-19',
#   'impressions': 285},
#  {'avg_ctr': 0.015957446808510637,
#   'avg_position': 7.992287234042553,
#   'clicks': 3,
#   'date': '2025-12-20',
#   'impressions': 260},
#  {'avg_ctr': 0.020512820512820513,
#   'avg_position': 8.378632478632479,
#   'clicks': 4,
#   'date': '2025-12-21',
#   'impressions': 259},
#  {'avg_ctr': 0.02072538860103627,
#   'avg_position': 8.69818652849741,
#   'clicks': 5,
#   'date': '2025-12-22',
#   'impressions': 283},
#  {'avg_ctr': 0.028846153846153848,
#   'avg_position': 8.074633699633699,
#   'clicks': 7,
#   'date': '2025-12-23',
#   'impressions': 268},
#  {'avg_ctr': 0.011608623548922057,
#   'avg_position': 6.9,
#   'clicks': 3,
#   'date': '2025-12-24',
#   'impressions': 302},
#  {'avg_ctr': 0.004524886877828055,
#   'avg_position': 7.467027580262875,
#   'clicks': 1,
#   'date': '2025-12-25',
#   'impressions': 326},
#  {'avg_ctr': 0.015486725663716814,
#   'avg_position': 6.040193631344073,
#   'clicks': 5,
#   'date': '2025-12-26',
#   'impressions': 365},
#  {'avg_ctr': 0.011848341232227487,
#   'avg_position': 7.58577241610417,
#   'clicks': 3,
#   'date': '2025-12-27',
#   'impressions': 326},
#  {'avg_ctr': 0.0,
#   'avg_position': 7.60478536242083,
#   'clicks': 0,
#   'date': '2025-12-28',
#   'impressions': 297},
#  {'avg_ctr': 0.011013215859030838,
#   'avg_position': 9.159041325781413,
#   'clicks': 3,
#   'date': '2025-12-29',
#   'impressions': 335},
#  {'avg_ctr': 0.013824884792626729,
#   'avg_position': 7.223036819811013,
#   'clicks': 3,
#   'date': '2025-12-30',
#   'impressions': 328},
#  {'avg_ctr': 0.001142857142857143,
#   'avg_position': 10.697815708101423,
#   'clicks': 1,
#   'date': '2025-12-31',
#   'impressions': 289},
#  {'avg_ctr': 0.0043859649122807015,
#   'avg_position': 11.916217320261438,
#   'clicks': 1,
#   'date': '2026-01-01',
#   'impressions': 329},
#  {'avg_ctr': 0.00904977375565611,
#   'avg_position': 9.714328808446457,
#   'clicks': 2,
#   'date': '2026-01-02',
#   'impressions': 354},
#  {'avg_ctr': 0.0,
#   'avg_position': 9.889292529569538,
#   'clicks': 0,
#   'date': '2026-01-03',
#   'impressions': 336},
#  {'avg_ctr': 0.009166666666666667,
#   'avg_position': 9.591031746031746,
#   'clicks': 3,
#   'date': '2026-01-04',
#   'impressions': 415},
#  {'avg_ctr': 0.010917030567685589,
#   'avg_position': 9.476280585014209,
#   'clicks': 4,
#   'date': '2026-01-05',
#   'impressions': 364},
#  {'avg_ctr': 0.01425438596491228,
#   'avg_position': 7.576730019493178,
#   'clicks': 4,
#   'date': '2026-01-06',
#   'impressions': 330},
#  {'avg_ctr': 0.01,
#   'avg_position': 10.06480476190476,
#   'clicks': 3,
#   'date': '2026-01-07',
#   'impressions': 409},
#  {'avg_ctr': 0.010256410256410256,
#   'avg_position': 11.477464387464387,
#   'clicks': 2,
#   'date': '2026-01-08',
#   'impressions': 292},
#  {'avg_ctr': 0.00909090909090909,
#   'avg_position': 9.798679653679654,
#   'clicks': 2,
#   'date': '2026-01-09',
#   'impressions': 356},
#  {'avg_ctr': 0.0,
#   'avg_position': 10.092634641128617,
#   'clicks': 0,
#   'date': '2026-01-10',
#   'impressions': 412},
#  {'avg_ctr': 0.005415162454873646,
#   'avg_position': 9.03166580711707,
#   'clicks': 2,
#   'date': '2026-01-11',
#   'impressions': 458},
#  {'avg_ctr': 0.019329896907216496,
#   'avg_position': 11.08235149729995,
#   'clicks': 5,
#   'date': '2026-01-12',
#   'impressions': 282},
#  {'avg_ctr': 0.020754716981132074,
#   'avg_position': 8.412525728987994,
#   'clicks': 6,
#   'date': '2026-01-13',
#   'impressions': 447}]

# %%
# | export
def get_analytics_by_country(
    session: Session, site_url: str, country: str, start_date: str, end_date: str
) -> List[Dict]:
    """Get analytics filtered by country"""
    from sqlalchemy import func

    stmt = (
        select(
            GSCAnalytics.query,
            func.sum(GSCAnalytics.clicks).label("clicks"),
            func.sum(GSCAnalytics.impressions).label("impressions"),
        )
        .where(
            GSCAnalytics.site_url == site_url,
            GSCAnalytics.country == country,
            GSCAnalytics.date >= start_date,
            GSCAnalytics.date <= end_date,
        )
        .group_by(GSCAnalytics.query)
    )

    return [dict(row._mapping) for row in session.exec(stmt)]

# %%
# hide
test_get_analytics_by_country = get_analytics_by_country(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    country="egy",
)
pprint(test_get_analytics_by_country)
# Out:
# [{'clicks': 0, 'impressions': 1, 'query': 'ai summary'},
#  {'clicks': 0,
#   'impressions': 2,
#   'query': 'anker liberty 5 vs huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 7, 'query': 'arabic tokenizer'},
#  {'clicks': 0, 'impressions': 2, 'query': 'cloud gpu pricing comparison'},
#  {'clicks': 0, 'impressions': 1, 'query': 'farasa segmenter arabic tokenizer'},
#  {'clicks': 0, 'impressions': 2, 'query': 'free buds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'freebuds 5i'},
#  {'clicks': 0, 'impressions': 4, 'query': 'freebuds 5i review'},
#  {'clicks': 0, 'impressions': 9, 'query': 'freebuds 6i vs 7i'},
#  {'clicks': 0, 'impressions': 10, 'query': 'freebuds 7i'},
#  {'clicks': 0, 'impressions': 3, 'query': 'freebuds 7i battery life'},
#  {'clicks': 0, 'impressions': 2, 'query': 'freebuds 7i huawei'},
#  {'clicks': 0, 'impressions': 1, 'query': 'freebuds 7i inceleme'},
#  {'clicks': 1, 'impressions': 47, 'query': 'freebuds 7i review'},
#  {'clicks': 0, 'impressions': 14, 'query': 'freebuds 7i review anc'},
#  {'clicks': 0, 'impressions': 2, 'query': 'freebuds 7i specs'},
#  {'clicks': 0, 'impressions': 3, 'query': 'freebuds 7i vs 5i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'freebuds 7i vs freebuds 6'},
#  {'clicks': 0, 'impressions': 5, 'query': 'freebuds 7i vs liberty 5'},
#  {'clicks': 0, 'impressions': 4, 'query': 'gpu cloud price comparison'},
#  {'clicks': 0, 'impressions': 1, 'query': 'gpu cloud pricing comparison'},
#  {'clicks': 0, 'impressions': 2, 'query': 'gpu pricing comparison'},
#  {'clicks': 0,
#   'impressions': 2,
#   'query': 'how to connect huawei freebuds 7i to laptop'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei 7i buds'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei 7i earbuds'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei 7i earbuds specs'},
#  {'clicks': 0, 'impressions': 18, 'query': 'huawei 7i freebuds'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei buds 7i'},
#  {'clicks': 1, 'impressions': 2, 'query': 'huawei buds 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei buds 7i specs'},
#  {'clicks': 0, 'impressions': 64, 'query': 'huawei earbuds 7i'},
#  {'clicks': 0, 'impressions': 10, 'query': 'huawei earbuds 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 5i'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 5i microphone call quality review'},
#  {'clicks': 0, 'impressions': 16, 'query': 'huawei freebuds 5i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 5i review anc'},
#  {'clicks': 1, 'impressions': 3, 'query': 'huawei freebuds 5i vs 7i'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 6 vs huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 20, 'query': 'huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i anc'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i anc db'},
#  {'clicks': 0, 'impressions': 4, 'query': 'huawei freebuds 7i battery life'},
#  {'clicks': 0, 'impressions': 5, 'query': 'huawei freebuds 7i box contents'},
#  {'clicks': 0, 'impressions': 6, 'query': 'huawei freebuds 7i buy'},
#  {'clicks': 0,
#   'impressions': 4,
#   'query': 'huawei freebuds 7i call quality review'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei freebuds 7i case dimensions'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i charging case'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i earbuds'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i features'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i ip rating'},
#  {'clicks': 0, 'impressions': 8, 'query': 'huawei freebuds 7i mic test'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i microphone'},
#  {'clicks': 0,
#   'impressions': 3,
#   'query': 'huawei freebuds 7i noise cancelling'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei freebuds 7i price buy'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i release date'},
#  {'clicks': 0, 'impressions': 104, 'query': 'huawei freebuds 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i review 2025'},
#  {'clicks': 0, 'impressions': 7, 'query': 'huawei freebuds 7i review anc'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i review specs'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i rtings'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 7i sound quality review'},
#  {'clicks': 0, 'impressions': 5, 'query': 'huawei freebuds 7i specifications'},
#  {'clicks': 0, 'impressions': 37, 'query': 'huawei freebuds 7i specs'},
#  {'clicks': 0, 'impressions': 6, 'query': 'huawei freebuds 7i specs review'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 7i true wireless earbuds'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i unboxing'},
#  {'clicks': 0, 'impressions': 7, 'query': 'huawei freebuds 7i vs 5i'},
#  {'clicks': 0, 'impressions': 7, 'query': 'huawei freebuds 7i vs 6i'},
#  {'clicks': 0,
#   'impressions': 11,
#   'query': 'huawei freebuds 7i vs anker liberty 5'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i vs freebuds 6'},
#  {'clicks': 0,
#   'impressions': 3,
#   'query': 'huawei freebuds 7i vs huawei freebuds 5i'},
#  {'clicks': 0, 'impressions': 6, 'query': 'huawei freebuds 7i vs liberty 5'},
#  {'clicks': 0,
#   'impressions': 4,
#   'query': 'huawei freebuds 7i vs soundcore liberty 5'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i wired charging'},
#  {'clicks': 0, 'impressions': 4, 'query': 'huawei freebuds 7i مراجعة'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds i5'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds i7'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds i7 review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei mate 11'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei matepad google services support'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei watch gt 4 heart rate accuracy review'},
#  {'clicks': 0, 'impressions': 8, 'query': 'huawei watch gt 4 review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei watch gt 4 review english'},
#  {'clicks': 0, 'impressions': 2, 'query': 'liberty 5 vs freebuds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'mteb number of tasks english'},
#  {'clicks': 0, 'impressions': 1, 'query': 'mteb retrieval metric ndcg@10'},
#  {'clicks': 0, 'impressions': 1, 'query': 'one plus bad 3'},
#  {'clicks': 0, 'impressions': 7, 'query': 'one plus pad 3'},
#  {'clicks': 1, 'impressions': 32, 'query': 'oneplus pad 3'},
#  {'clicks': 0, 'impressions': 3, 'query': 'oneplus pad 3 ai features'},
#  {'clicks': 0, 'impressions': 2, 'query': 'oneplus pad 3 price 2025'},
#  {'clicks': 0, 'impressions': 2, 'query': 'oneplus pad 3 price egypt 2025'},
#  {'clicks': 0, 'impressions': 2, 'query': 'oneplus pad 3 review 2025'},
#  {'clicks': 0, 'impressions': 1, 'query': 'oneplus pad 3 specs 2025'},
#  {'clicks': 0, 'impressions': 1, 'query': 'oneplus pad 3 vs laptop'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'oneplus pad 3 with keyboard and pen'},
#  {'clicks': 0, 'impressions': 1, 'query': 'oneplus tab 3'},
#  {'clicks': 0, 'impressions': 1, 'query': 'proteinai'},
#  {'clicks': 0, 'impressions': 3, 'query': 'pylate'},
#  {'clicks': 0,
#   'impressions': 12,
#   'query': 'soundcore liberty 5 vs huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 3, 'query': 'tarteel ai careers'},
#  {'clicks': 0, 'impressions': 7, 'query': 'tarteel careers'},
#  {'clicks': 0, 'impressions': 2, 'query': 'tarteel jobs'},
#  {'clicks': 0, 'impressions': 1, 'query': 'tokenization in arabic'},
#  {'clicks': 0, 'impressions': 1, 'query': 'أفضل أنواع الكرياتين للتضخيم'},
#  {'clicks': 0, 'impressions': 1, 'query': 'جاوب'},
#  {'clicks': 0, 'impressions': 1, 'query': 'ساعة هواوي gt4'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعات هواوي freebuds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعة هواوي 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعة هواوي freebuds 5i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعة هواوي فري بودز 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'هواوى فرى بودز 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'هواوي freebuds 7i'},
#  {'clicks': 1, 'impressions': 1, 'query': 'هواوي ايربودز 7i'},
#  {'clicks': 0, 'impressions': 5, 'query': 'هواوي فري بودز 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'وان بلس باد 3'}]

# %%
# | export
def get_analytics_by_device(
    session: Session, site_url: str, device: str, start_date: str, end_date: str
) -> List[Dict]:
    """Get analytics filtered by device"""
    from sqlalchemy import func

    stmt = (
        select(
            GSCAnalytics.query,
            func.sum(GSCAnalytics.clicks).label("clicks"),
            func.sum(GSCAnalytics.impressions).label("impressions"),
        )
        .where(
            GSCAnalytics.site_url == site_url,
            GSCAnalytics.device == device,
            GSCAnalytics.date >= start_date,
            GSCAnalytics.date <= end_date,
        )
        .group_by(GSCAnalytics.query)
    )

    return [dict(row._mapping) for row in session.exec(stmt)]

# %%
# hide
test_get_analytics_by_device = get_analytics_by_device(
    session,
    site_url="sc-domain:kareemai.com",
    start_date=start,
    end_date=end,
    device="mobile",
)
pprint(test_get_analytics_by_country)
# Out:
# [{'clicks': 0, 'impressions': 1, 'query': 'ai summary'},
#  {'clicks': 0,
#   'impressions': 2,
#   'query': 'anker liberty 5 vs huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 7, 'query': 'arabic tokenizer'},
#  {'clicks': 0, 'impressions': 2, 'query': 'cloud gpu pricing comparison'},
#  {'clicks': 0, 'impressions': 1, 'query': 'farasa segmenter arabic tokenizer'},
#  {'clicks': 0, 'impressions': 2, 'query': 'free buds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'freebuds 5i'},
#  {'clicks': 0, 'impressions': 4, 'query': 'freebuds 5i review'},
#  {'clicks': 0, 'impressions': 9, 'query': 'freebuds 6i vs 7i'},
#  {'clicks': 0, 'impressions': 10, 'query': 'freebuds 7i'},
#  {'clicks': 0, 'impressions': 3, 'query': 'freebuds 7i battery life'},
#  {'clicks': 0, 'impressions': 2, 'query': 'freebuds 7i huawei'},
#  {'clicks': 0, 'impressions': 1, 'query': 'freebuds 7i inceleme'},
#  {'clicks': 1, 'impressions': 47, 'query': 'freebuds 7i review'},
#  {'clicks': 0, 'impressions': 14, 'query': 'freebuds 7i review anc'},
#  {'clicks': 0, 'impressions': 2, 'query': 'freebuds 7i specs'},
#  {'clicks': 0, 'impressions': 3, 'query': 'freebuds 7i vs 5i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'freebuds 7i vs freebuds 6'},
#  {'clicks': 0, 'impressions': 5, 'query': 'freebuds 7i vs liberty 5'},
#  {'clicks': 0, 'impressions': 4, 'query': 'gpu cloud price comparison'},
#  {'clicks': 0, 'impressions': 1, 'query': 'gpu cloud pricing comparison'},
#  {'clicks': 0, 'impressions': 2, 'query': 'gpu pricing comparison'},
#  {'clicks': 0,
#   'impressions': 2,
#   'query': 'how to connect huawei freebuds 7i to laptop'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei 7i buds'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei 7i earbuds'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei 7i earbuds specs'},
#  {'clicks': 0, 'impressions': 18, 'query': 'huawei 7i freebuds'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei buds 7i'},
#  {'clicks': 1, 'impressions': 2, 'query': 'huawei buds 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei buds 7i specs'},
#  {'clicks': 0, 'impressions': 64, 'query': 'huawei earbuds 7i'},
#  {'clicks': 0, 'impressions': 10, 'query': 'huawei earbuds 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 5i'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 5i microphone call quality review'},
#  {'clicks': 0, 'impressions': 16, 'query': 'huawei freebuds 5i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 5i review anc'},
#  {'clicks': 1, 'impressions': 3, 'query': 'huawei freebuds 5i vs 7i'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 6 vs huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 20, 'query': 'huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i anc'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i anc db'},
#  {'clicks': 0, 'impressions': 4, 'query': 'huawei freebuds 7i battery life'},
#  {'clicks': 0, 'impressions': 5, 'query': 'huawei freebuds 7i box contents'},
#  {'clicks': 0, 'impressions': 6, 'query': 'huawei freebuds 7i buy'},
#  {'clicks': 0,
#   'impressions': 4,
#   'query': 'huawei freebuds 7i call quality review'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei freebuds 7i case dimensions'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i charging case'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i earbuds'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i features'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i ip rating'},
#  {'clicks': 0, 'impressions': 8, 'query': 'huawei freebuds 7i mic test'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i microphone'},
#  {'clicks': 0,
#   'impressions': 3,
#   'query': 'huawei freebuds 7i noise cancelling'},
#  {'clicks': 0, 'impressions': 3, 'query': 'huawei freebuds 7i price buy'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i release date'},
#  {'clicks': 0, 'impressions': 104, 'query': 'huawei freebuds 7i review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i review 2025'},
#  {'clicks': 0, 'impressions': 7, 'query': 'huawei freebuds 7i review anc'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i review specs'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i rtings'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 7i sound quality review'},
#  {'clicks': 0, 'impressions': 5, 'query': 'huawei freebuds 7i specifications'},
#  {'clicks': 0, 'impressions': 37, 'query': 'huawei freebuds 7i specs'},
#  {'clicks': 0, 'impressions': 6, 'query': 'huawei freebuds 7i specs review'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei freebuds 7i true wireless earbuds'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i unboxing'},
#  {'clicks': 0, 'impressions': 7, 'query': 'huawei freebuds 7i vs 5i'},
#  {'clicks': 0, 'impressions': 7, 'query': 'huawei freebuds 7i vs 6i'},
#  {'clicks': 0,
#   'impressions': 11,
#   'query': 'huawei freebuds 7i vs anker liberty 5'},
#  {'clicks': 0, 'impressions': 2, 'query': 'huawei freebuds 7i vs freebuds 6'},
#  {'clicks': 0,
#   'impressions': 3,
#   'query': 'huawei freebuds 7i vs huawei freebuds 5i'},
#  {'clicks': 0, 'impressions': 6, 'query': 'huawei freebuds 7i vs liberty 5'},
#  {'clicks': 0,
#   'impressions': 4,
#   'query': 'huawei freebuds 7i vs soundcore liberty 5'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds 7i wired charging'},
#  {'clicks': 0, 'impressions': 4, 'query': 'huawei freebuds 7i مراجعة'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds i5'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds i7'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei freebuds i7 review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei mate 11'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei matepad google services support'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'huawei watch gt 4 heart rate accuracy review'},
#  {'clicks': 0, 'impressions': 8, 'query': 'huawei watch gt 4 review'},
#  {'clicks': 0, 'impressions': 1, 'query': 'huawei watch gt 4 review english'},
#  {'clicks': 0, 'impressions': 2, 'query': 'liberty 5 vs freebuds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'mteb number of tasks english'},
#  {'clicks': 0, 'impressions': 1, 'query': 'mteb retrieval metric ndcg@10'},
#  {'clicks': 0, 'impressions': 1, 'query': 'one plus bad 3'},
#  {'clicks': 0, 'impressions': 7, 'query': 'one plus pad 3'},
#  {'clicks': 1, 'impressions': 32, 'query': 'oneplus pad 3'},
#  {'clicks': 0, 'impressions': 3, 'query': 'oneplus pad 3 ai features'},
#  {'clicks': 0, 'impressions': 2, 'query': 'oneplus pad 3 price 2025'},
#  {'clicks': 0, 'impressions': 2, 'query': 'oneplus pad 3 price egypt 2025'},
#  {'clicks': 0, 'impressions': 2, 'query': 'oneplus pad 3 review 2025'},
#  {'clicks': 0, 'impressions': 1, 'query': 'oneplus pad 3 specs 2025'},
#  {'clicks': 0, 'impressions': 1, 'query': 'oneplus pad 3 vs laptop'},
#  {'clicks': 0,
#   'impressions': 1,
#   'query': 'oneplus pad 3 with keyboard and pen'},
#  {'clicks': 0, 'impressions': 1, 'query': 'oneplus tab 3'},
#  {'clicks': 0, 'impressions': 1, 'query': 'proteinai'},
#  {'clicks': 0, 'impressions': 3, 'query': 'pylate'},
#  {'clicks': 0,
#   'impressions': 12,
#   'query': 'soundcore liberty 5 vs huawei freebuds 7i'},
#  {'clicks': 0, 'impressions': 3, 'query': 'tarteel ai careers'},
#  {'clicks': 0, 'impressions': 7, 'query': 'tarteel careers'},
#  {'clicks': 0, 'impressions': 2, 'query': 'tarteel jobs'},
#  {'clicks': 0, 'impressions': 1, 'query': 'tokenization in arabic'},
#  {'clicks': 0, 'impressions': 1, 'query': 'أفضل أنواع الكرياتين للتضخيم'},
#  {'clicks': 0, 'impressions': 1, 'query': 'جاوب'},
#  {'clicks': 0, 'impressions': 1, 'query': 'ساعة هواوي gt4'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعات هواوي freebuds 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعة هواوي 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعة هواوي freebuds 5i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'سماعة هواوي فري بودز 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'هواوى فرى بودز 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'هواوي freebuds 7i'},
#  {'clicks': 1, 'impressions': 1, 'query': 'هواوي ايربودز 7i'},
#  {'clicks': 0, 'impressions': 5, 'query': 'هواوي فري بودز 7i'},
#  {'clicks': 0, 'impressions': 1, 'query': 'وان بلس باد 3'}]

# %%
# | export
def store_single_date(session: Session, auth: GSCAuth, site_url: str, date: str) -> int:
    """Store GSC data for a single date"""
    from seo_rat.gsc_client import fetch_gsc_data

    rows = fetch_gsc_data(auth, site_url, date, date)
    store_gsc_data(session, site_url, date, rows)
    return len(rows)

# %%
# hide
# | test
count = store_single_date(session, auth, "sc-domain:kareemai.com", start)
test_eq(count > 0, True)

# %%
# | test
# Check what's actually stored
stored = session.exec(select(GSCAnalytics).limit(1)).first()
print(f"Query: {stored.query}")
print(f"Clicks: {stored.clicks}")
print(f"Date: {stored.date}")
test_eq(stored.site_url, "sc-domain:kareemai.com")
# Out:
# Query: huawei 7i review
# Clicks: 1
# Date: 2026-01-12

# %%
# | export
def store_date_range(
    session: Session, auth: GSCAuth, site_url: str, start_date: str, end_date: str
) -> Dict:
    """Store GSC data for a date range with progress"""
    from datetime import datetime, timedelta
    from seo_rat.gsc_client import fetch_gsc_data
    import time

    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")

    results = {"successful": [], "failed": [], "total_records": 0}
    current = start
    total_days = (end - start).days + 1

    for day_num in range(total_days):
        date_str = current.strftime("%Y-%m-%d")
        print(f"Processing {date_str} ({day_num + 1}/{total_days})...")

        try:
            rows = fetch_gsc_data(auth, site_url, date_str, date_str)
            store_gsc_data(session, site_url, date_str, rows)
            results["successful"].append(date_str)
            results["total_records"] += len(rows)
        except Exception as e:
            results["failed"].append({"date": date_str, "error": str(e)})

        current += timedelta(days=1)
        time.sleep(1)

    return results

# %%
# | test
result = store_date_range(session, auth, "sc-domain:kareemai.com", start, start)
test_eq(len(result["successful"]), 1)
print(f"Stored {result['total_records']} records")
# Out:
# Stored 191 records

# %%
r = session.exec(select(GSCAnalytics).limit(1)).first()
print(f"Query: {r.query}")
print(f"Page: {r.page}")
print(f"Country: {r.country}")
print(f"Device: {r.device}")
print(f"Clicks: {r.clicks}")
print(f"Impressions: {r.impressions}")
print(f"CTR: {r.ctr}")
print(f"Position: {r.position}")
# Out:
# Query: huawei 7i review
# Page: https://kareemai.com/blog/posts/products_reviews/Huawei%20freebuds%207i.html
# Country: deu
# Device: MOBILE
# Clicks: 1
# Impressions: 2
# CTR: 0.5
# Position: 3.5

# %%
# | test
top = get_top_queries(session, "sc-domain:kareemai.com", start, start, limit=5)
for q in top:
    print(
        f"{q['query']}: {q['total_clicks']} clicks, {q['total_impressions']} impressions"
    )
# Out:
# هواوي ايربودز 7i: 1 clicks, 1 impressions
# tarteel ai jobs: 0 clicks, 2 impressions
# tarteel ai careers: 0 clicks, 3 impressions
# tai nghe huawei freebuds 7i: 0 clicks, 1 impressions
# soundcore liberty 5 vs huawei freebuds 7i: 0 clicks, 1 impressions

# %%
# | hide

from datetime import datetime, timedelta

#delay 3 because GSC api limitation 
end = datetime.now() - timedelta(days=3)
start = end - timedelta(days=365 * 1)

result = store_date_range(
    session,
    auth,
    "sc-domain:kareemai.com",
    start.strftime("%Y-%m-%d"),
    end.strftime("%Y-%m-%d"),
)
# Out:
# Processing 2025-01-13 (1/366)...
# Processing 2025-01-14 (2/366)...
# Processing 2025-01-15 (3/366)...
# Processing 2025-01-16 (4/366)...
# Processing 2025-01-17 (5/366)...
# Processing 2025-01-18 (6/366)...
# Processing 2025-01-19 (7/366)...
# Processing 2025-01-20 (8/366)...
# Processing 2025-01-21 (9/366)...
# Processing 2025-01-22 (10/366)...
# Processing 2025-01-23 (11/366)...
# Processing 2025-01-24 (12/366)...
# Processing 2025-01-25 (13/366)...
# Processing 2025-01-26 (14/366)...
# Processing 2025-01-27 (15/366)...
# Processing 2025-01-28 (16/366)...
# Processing 2025-01-29 (17/366)...
# Processing 2025-01-30 (18/366)...
# Processing 2025-01-31 (19/366)...
# Processing 2025-02-01 (20/366)...
# Processing 2025-02-02 (21/366)...
# Processing 2025-02-03 (22/366)...
# Processing 2025-02-04 (23/366)...
# Processing 2025-02-05 (24/366)...
# Processing 2025-02-06 (25/366)...
# Processing 2025-02-07 (26/366)...
# Processing 2025-02-08 (27/366)...
# Processing 2025-02-09 (28/366)...
# Processing 2025-02-10 (29/366)...
# Processing 2025-02-11 (30/366)...
# Processing 2025-02-12 (31/366)...
# Processing 2025-02-13 (32/366)...
# Processing 2025-02-14 (33/366)...
# Processing 2025-02-15 (34/366)...
# Processing 2025-02-16 (35/366)...
# Processing 2025-02-17 (36/366)...
# Processing 2025-02-18 (37/366)...
# Processing 2025-02-19 (38/366)...
# Processing 2025-02-20 (39/366)...
# Processing 2025-02-21 (40/366)...
# Processing 2025-02-22 (41/366)...
# Processing 2025-02-23 (42/366)...
# Processing 2025-02-24 (43/366)...
# Processing 2025-02-25 (44/366)...
# Processing 2025-02-26 (45/366)...
# Processing 2025-02-27 (46/366)...
# Processing 2025-02-28 (47/366)...
# Processing 2025-03-01 (48/366)...
# Processing 2025-03-02 (49/366)...
# Processing 2025-03-03 (50/366)...
# Processing 2025-03-04 (51/366)...
# Processing 2025-03-05 (52/366)...
# Processing 2025-03-06 (53/366)...
# Processing 2025-03-07 (54/366)...
# Processing 2025-03-08 (55/366)...
# Processing 2025-03-09 (56/366)...
# Processing 2025-03-10 (57/366)...
# Processing 2025-03-11 (58/366)...
# Processing 2025-03-12 (59/366)...
# Processing 2025-03-13 (60/366)...
# Processing 2025-03-14 (61/366)...
# Processing 2025-03-15 (62/366)...
# Processing 2025-03-16 (63/366)...
# Processing 2025-03-17 (64/366)...
# Processing 2025-03-18 (65/366)...
# Processing 2025-03-19 (66/366)...
# Processing 2025-03-20 (67/366)...
# Processing 2025-03-21 (68/366)...
# Processing 2025-03-22 (69/366)...
# Processing 2025-03-23 (70/366)...
# Processing 2025-03-24 (71/366)...
# Processing 2025-03-25 (72/366)...
# Processing 2025-03-26 (73/366)...
# Processing 2025-03-27 (74/366)...
# Processing 2025-03-28 (75/366)...
# Processing 2025-03-29 (76/366)...
# Processing 2025-03-30 (77/366)...
# Processing 2025-03-31 (78/366)...
# Processing 2025-04-01 (79/366)...
# Processing 2025-04-02 (80/366)...
# Processing 2025-04-03 (81/366)...
# Processing 2025-04-04 (82/366)...
# Processing 2025-04-05 (83/366)...
# Processing 2025-04-06 (84/366)...
# Processing 2025-04-07 (85/366)...
# Processing 2025-04-08 (86/366)...
# Processing 2025-04-09 (87/366)...
# Processing 2025-04-10 (88/366)...
# Processing 2025-04-11 (89/366)...
# Processing 2025-04-12 (90/366)...
# Processing 2025-04-13 (91/366)...
# Processing 2025-04-14 (92/366)...
# Processing 2025-04-15 (93/366)...
# Processing 2025-04-16 (94/366)...
# Processing 2025-04-17 (95/366)...
# Processing 2025-04-18 (96/366)...
# Processing 2025-04-19 (97/366)...
# Processing 2025-04-20 (98/366)...
# Processing 2025-04-21 (99/366)...
# Processing 2025-04-22 (100/366)...
# Processing 2025-04-23 (101/366)...
# Processing 2025-04-24 (102/366)...
# Processing 2025-04-25 (103/366)...
# Processing 2025-04-26 (104/366)...
# Processing 2025-04-27 (105/366)...
# Processing 2025-04-28 (106/366)...
# Processing 2025-04-29 (107/366)...
# Processing 2025-04-30 (108/366)...
# Processing 2025-05-01 (109/366)...
# Processing 2025-05-02 (110/366)...
# Processing 2025-05-03 (111/366)...
# Processing 2025-05-04 (112/366)...
# Processing 2025-05-05 (113/366)...
# Processing 2025-05-06 (114/366)...
# Processing 2025-05-07 (115/366)...
# Processing 2025-05-08 (116/366)...
# Processing 2025-05-09 (117/366)...
# Processing 2025-05-10 (118/366)...
# Processing 2025-05-11 (119/366)...
# Processing 2025-05-12 (120/366)...
# Processing 2025-05-13 (121/366)...
# Processing 2025-05-14 (122/366)...
# Processing 2025-05-15 (123/366)...
# Processing 2025-05-16 (124/366)...
# Processing 2025-05-17 (125/366)...
# Processing 2025-05-18 (126/366)...
# Processing 2025-05-19 (127/366)...
# Processing 2025-05-20 (128/366)...
# Processing 2025-05-21 (129/366)...
# Processing 2025-05-22 (130/366)...
# Processing 2025-05-23 (131/366)...
# Processing 2025-05-24 (132/366)...
# Processing 2025-05-25 (133/366)...
# Processing 2025-05-26 (134/366)...
# Processing 2025-05-27 (135/366)...
# Processing 2025-05-28 (136/366)...
# Processing 2025-05-29 (137/366)...
# Processing 2025-05-30 (138/366)...
# Processing 2025-05-31 (139/366)...
# Processing 2025-06-01 (140/366)...
# Processing 2025-06-02 (141/366)...
# Processing 2025-06-03 (142/366)...
# Processing 2025-06-04 (143/366)...
# Processing 2025-06-05 (144/366)...
# Processing 2025-06-06 (145/366)...
# Processing 2025-06-07 (146/366)...
# Processing 2025-06-08 (147/366)...
# Processing 2025-06-09 (148/366)...
# Processing 2025-06-10 (149/366)...
# Processing 2025-06-11 (150/366)...
# Processing 2025-06-12 (151/366)...
# Processing 2025-06-13 (152/366)...
# Processing 2025-06-14 (153/366)...
# Processing 2025-06-15 (154/366)...
# Processing 2025-06-16 (155/366)...
# Processing 2025-06-17 (156/366)...
# Processing 2025-06-18 (157/366)...
# Processing 2025-06-19 (158/366)...
# Processing 2025-06-20 (159/366)...
# Processing 2025-06-21 (160/366)...
# Processing 2025-06-22 (161/366)...
# Processing 2025-06-23 (162/366)...
# Processing 2025-06-24 (163/366)...
# Processing 2025-06-25 (164/366)...
# Processing 2025-06-26 (165/366)...
# Processing 2025-06-27 (166/366)...
# Processing 2025-06-28 (167/366)...
# Processing 2025-06-29 (168/366)...
# Processing 2025-06-30 (169/366)...
# Processing 2025-07-01 (170/366)...
# Processing 2025-07-02 (171/366)...
# Processing 2025-07-03 (172/366)...
# Processing 2025-07-04 (173/366)...
# Processing 2025-07-05 (174/366)...
# Processing 2025-07-06 (175/366)...
# Processing 2025-07-07 (176/366)...
# Processing 2025-07-08 (177/366)...
# Processing 2025-07-09 (178/366)...
# Processing 2025-07-10 (179/366)...
# Processing 2025-07-11 (180/366)...
# Processing 2025-07-12 (181/366)...
# Processing 2025-07-13 (182/366)...
# Processing 2025-07-14 (183/366)...
# Processing 2025-07-15 (184/366)...
# Processing 2025-07-16 (185/366)...
# Processing 2025-07-17 (186/366)...
# Processing 2025-07-18 (187/366)...
# Processing 2025-07-19 (188/366)...
# Processing 2025-07-20 (189/366)...
# Processing 2025-07-21 (190/366)...
# Processing 2025-07-22 (191/366)...
# Processing 2025-07-23 (192/366)...
# Processing 2025-07-24 (193/366)...
# Processing 2025-07-25 (194/366)...
# Processing 2025-07-26 (195/366)...
# Processing 2025-07-27 (196/366)...
# Processing 2025-07-28 (197/366)...
# Processing 2025-07-29 (198/366)...
# Processing 2025-07-30 (199/366)...
# Processing 2025-07-31 (200/366)...
# Processing 2025-08-01 (201/366)...
# Processing 2025-08-02 (202/366)...
# Processing 2025-08-03 (203/366)...
# Processing 2025-08-04 (204/366)...
# Processing 2025-08-05 (205/366)...
# Processing 2025-08-06 (206/366)...
# Processing 2025-08-07 (207/366)...
# Processing 2025-08-08 (208/366)...
# Processing 2025-08-09 (209/366)...
# Processing 2025-08-10 (210/366)...
# Processing 2025-08-11 (211/366)...
# Processing 2025-08-12 (212/366)...
# Processing 2025-08-13 (213/366)...
# Processing 2025-08-14 (214/366)...
# Processing 2025-08-15 (215/366)...
# Processing 2025-08-16 (216/366)...
# Processing 2025-08-17 (217/366)...
# Processing 2025-08-18 (218/366)...
# Processing 2025-08-19 (219/366)...
# Processing 2025-08-20 (220/366)...
# Processing 2025-08-21 (221/366)...
# Processing 2025-08-22 (222/366)...
# Processing 2025-08-23 (223/366)...
# Processing 2025-08-24 (224/366)...
# Processing 2025-08-25 (225/366)...
# Processing 2025-08-26 (226/366)...
# Processing 2025-08-27 (227/366)...
# Processing 2025-08-28 (228/366)...
# Processing 2025-08-29 (229/366)...
# Processing 2025-08-30 (230/366)...
# Processing 2025-08-31 (231/366)...
# Processing 2025-09-01 (232/366)...
# Processing 2025-09-02 (233/366)...
# Processing 2025-09-03 (234/366)...
# Processing 2025-09-04 (235/366)...
# Processing 2025-09-05 (236/366)...
# Processing 2025-09-06 (237/366)...
# Processing 2025-09-07 (238/366)...
# Processing 2025-09-08 (239/366)...
# Processing 2025-09-09 (240/366)...
# Processing 2025-09-10 (241/366)...
# Processing 2025-09-11 (242/366)...
# Processing 2025-09-12 (243/366)...
# Processing 2025-09-13 (244/366)...
# Processing 2025-09-14 (245/366)...
# Processing 2025-09-15 (246/366)...
# Processing 2025-09-16 (247/366)...
# Processing 2025-09-17 (248/366)...
# Processing 2025-09-18 (249/366)...
# Processing 2025-09-19 (250/366)...
# Processing 2025-09-20 (251/366)...
# Processing 2025-09-21 (252/366)...
# Processing 2025-09-22 (253/366)...
# Processing 2025-09-23 (254/366)...
# Processing 2025-09-24 (255/366)...
# Processing 2025-09-25 (256/366)...
# Processing 2025-09-26 (257/366)...
# Processing 2025-09-27 (258/366)...
# Processing 2025-09-28 (259/366)...
# Processing 2025-09-29 (260/366)...
# Processing 2025-09-30 (261/366)...
# Processing 2025-10-01 (262/366)...
# Processing 2025-10-02 (263/366)...
# Processing 2025-10-03 (264/366)...
# Processing 2025-10-04 (265/366)...
# Processing 2025-10-05 (266/366)...
# Processing 2025-10-06 (267/366)...
# Processing 2025-10-07 (268/366)...
# Processing 2025-10-08 (269/366)...
# Processing 2025-10-09 (270/366)...
# Processing 2025-10-10 (271/366)...
# Processing 2025-10-11 (272/366)...
# Processing 2025-10-12 (273/366)...
# Processing 2025-10-13 (274/366)...
# Processing 2025-10-14 (275/366)...
# Processing 2025-10-15 (276/366)...
# Processing 2025-10-16 (277/366)...
# Processing 2025-10-17 (278/366)...
# Processing 2025-10-18 (279/366)...
# Processing 2025-10-19 (280/366)...
# Processing 2025-10-20 (281/366)...
# Processing 2025-10-21 (282/366)...
# Processing 2025-10-22 (283/366)...
# Processing 2025-10-23 (284/366)...
# Processing 2025-10-24 (285/366)...
# Processing 2025-10-25 (286/366)...
# Processing 2025-10-26 (287/366)...
# Processing 2025-10-27 (288/366)...
# Processing 2025-10-28 (289/366)...
# Processing 2025-10-29 (290/366)...
# Processing 2025-10-30 (291/366)...
# Processing 2025-10-31 (292/366)...
# Processing 2025-11-01 (293/366)...
# Processing 2025-11-02 (294/366)...
# Processing 2025-11-03 (295/366)...
# Processing 2025-11-04 (296/366)...
# Processing 2025-11-05 (297/366)...
# Processing 2025-11-06 (298/366)...
# Processing 2025-11-07 (299/366)...
# Processing 2025-11-08 (300/366)...
# Processing 2025-11-09 (301/366)...
# Processing 2025-11-10 (302/366)...
# Processing 2025-11-11 (303/366)...
# Processing 2025-11-12 (304/366)...
# Processing 2025-11-13 (305/366)...
# Processing 2025-11-14 (306/366)...
# Processing 2025-11-15 (307/366)...
# Processing 2025-11-16 (308/366)...
# Processing 2025-11-17 (309/366)...
# Processing 2025-11-18 (310/366)...
# Processing 2025-11-19 (311/366)...
# Processing 2025-11-20 (312/366)...
# Processing 2025-11-21 (313/366)...
# Processing 2025-11-22 (314/366)...
# Processing 2025-11-23 (315/366)...
# Processing 2025-11-24 (316/366)...
# Processing 2025-11-25 (317/366)...
# Processing 2025-11-26 (318/366)...
# Processing 2025-11-27 (319/366)...
# Processing 2025-11-28 (320/366)...
# Processing 2025-11-29 (321/366)...
# Processing 2025-11-30 (322/366)...
# Processing 2025-12-01 (323/366)...
# Processing 2025-12-02 (324/366)...
# Processing 2025-12-03 (325/366)...
# Processing 2025-12-04 (326/366)...
# Processing 2025-12-05 (327/366)...
# Processing 2025-12-06 (328/366)...
# Processing 2025-12-07 (329/366)...
# Processing 2025-12-08 (330/366)...
# Processing 2025-12-09 (331/366)...
# Processing 2025-12-10 (332/366)...
# Processing 2025-12-11 (333/366)...
# Processing 2025-12-12 (334/366)...
# Processing 2025-12-13 (335/366)...
# Processing 2025-12-14 (336/366)...
# Processing 2025-12-15 (337/366)...
# Processing 2025-12-16 (338/366)...
# Processing 2025-12-17 (339/366)...
# Processing 2025-12-18 (340/366)...
# Processing 2025-12-19 (341/366)...
# Processing 2025-12-20 (342/366)...
# Processing 2025-12-21 (343/366)...
# Processing 2025-12-22 (344/366)...
# Processing 2025-12-23 (345/366)...
# Processing 2025-12-24 (346/366)...
# Processing 2025-12-25 (347/366)...
# Processing 2025-12-26 (348/366)...
# Processing 2025-12-27 (349/366)...
# Processing 2025-12-28 (350/366)...
# Processing 2025-12-29 (351/366)...
# Processing 2025-12-30 (352/366)...
# Processing 2025-12-31 (353/366)...
# Processing 2026-01-01 (354/366)...
# Processing 2026-01-02 (355/366)...
# Processing 2026-01-03 (356/366)...
# Processing 2026-01-04 (357/366)...
# Processing 2026-01-05 (358/366)...
# Processing 2026-01-06 (359/366)...
# Processing 2026-01-07 (360/366)...
# Processing 2026-01-08 (361/366)...
# Processing 2026-01-09 (362/366)...
# Processing 2026-01-10 (363/366)...
# Processing 2026-01-11 (364/366)...
# Processing 2026-01-12 (365/366)...
# Processing 2026-01-13 (366/366)...
